# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib_venn import venn2,venn3
from matplotlib.patches import Patch
import sys
from matplotlib_venn import venn3_unweighted

sys.path.append('../retrosynthesis/')
# sys.path.append('../')

from common import *

# %%
#input
# yeast870_path =  '../../Data/model/yeast-GEM.mat'
sce_gene_clean_ec = '../../Results/ECnumber_prediction/Saccharomyces_cerevisiae_maxsep.csv'
DeepEC_path = '../../Results/ECnumber_prediction/Sce_DeepECv2.txt'
sce_uniprotkb_gene_file = '../../Data/uniprot/uniprotkb_organism_id_559292_2023_11_08.tsv'

#output
figs3a_path = '../../Results/Figures/figs3-a.pdf'
figs3b_path = '../../Results/Figures/figs3-b.pdf'
figs4a_path = '../../Results/Figures/figs4-a.pdf'
figs4b_path = '../../Results/Figures/figs4-b.pdf'

# %% [markdown]
# # different cut-off, different top number

# %%
# Set general parameters
plt.figure(figsize=(2, 2), dpi=400)
plt.rcParams.update({'font.size': 8})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Set axis styles
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Data
labels = [ '30', '40', '50', '60', '70']
data1 = [ 0.743, 0.760, 0.774, 0.783, 0.795] 
data2 = [ 0.743, 0.760, 0.774, 0.783, 0.795] 
data3 = [0.743, 0.760, 0.773, 0.780, 0.793]

# Create bar chart
# Create bar chart
width = 0.3
positions = [1, 2.5, 4, 5.5, 7]

plt.bar([p - width for p in positions], data1, color='#984ea3', width=width, edgecolor='black', linewidth=0.5, label='Substrate similarity score > 0.2')
plt.bar(positions, data2, color='#ff7f00', width=width, edgecolor='black', linewidth=0.5, label='Substrate similarity score > 0.3')
plt.bar([p + width for p in positions], data3, color='#a65628', width=width, edgecolor='black', linewidth=0.5, label='Substrate similarity score > 0.4')

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', direction='in', width=0.5, which='both', length=1)
plt.xlim(0, 8)
plt.ylim(0.3, 1)

# Set x-axis labels
plt.xticks(positions, labels)

# Set labels and title
plt.xlabel('Substrate match topN', fontsize=8)
plt.ylabel('Reaction recovery rate of Yeast8', fontsize=8)

# Draw red inverted triangle
plt.plot(4, 0.80, marker='v', color='#dd3497', markersize=1.8)  # marker='v' indicates an inverted triangle

# Add legend
plt.legend(frameon=False, fontsize=6, loc='upper left', bbox_to_anchor=(0, 1.02), labelspacing=0.5, handletextpad=0.3)

# Save the figure
plt.savefig(figs3a_path, dpi=400, bbox_inches='tight')

# Show the figure
plt.show()

# %% [markdown]
# # Running time of different parameters
# # S3-b

# %%
# Set general parameters
plt.figure(figsize=(1.8, 2), dpi=400)
plt.rcParams.update({'font.size': 8})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Set axis styles
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Data
labels = ['20', '30', '40', '50', '60', '70']
data2 = [30, 37, 46, 53, 57, 60] 

# Create bar chart
width = 0.5
plt.bar([1, 2.5, 4, 5.5, 7, 8.5], data2, color='#f781bf', width=width, edgecolor='black', linewidth=0.5, label='Substrate similarity score > 0.4')

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', direction='in', width=0.5, which='both', length=1)
plt.xlim(0, 9.5)
plt.ylim(10, 70)

# Set x-axis labels
plt.xticks([1, 2.5, 4, 5.5, 7, 8.5], labels)

# Set labels and title
plt.xlabel('Substrate match topN', fontsize=8)
plt.ylabel('Retrosynthesis time [h]', fontsize=8)

# Draw red inverted triangle
plt.plot(5.5, 55, marker='v', color='#dd3497', markersize=1.8)  # marker='v' indicates an inverted triangle

# Add legend (commented out)
# plt.legend(frameon=False, fontsize=6, loc='upper left', bbox_to_anchor=(0, 1.02), labelspacing=0.5, handletextpad=0.3)

# Save the figure
plt.savefig(figs3b_path, dpi=400, bbox_inches='tight')

# Show the figure
plt.show()

# %% [markdown]
# # new gene strategy：clean+deepec
# # GPR recovery ratio

# %%
# Set general parameters
plt.figure(figsize=(2, 2), dpi=400)
plt.rcParams.update({'font.size': 8})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Set axis styles
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Data
labels = ['ACC', 'FP']
data1 = [0.66, 0.78]
data2 = [0.86, 0.90]
data3 = [0.86, 0.76]

# Create bar chart
width = 0.3

plt.bar([1 - width, 2.5 - width], data1, color='#ff7f00', width=width, edgecolor='black', linewidth=0.5, label='DeepECtransformer')
plt.bar([1, 2.5], data2, color='#984ea3', width=width, edgecolor='black', linewidth=0.5, label='CLEAN')
plt.bar([1 + width, 2.5 + width], data3, color='#f781bf', width=width, edgecolor='black', linewidth=0.5, label='CLEAN + DeepECtransformer')

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', direction='in', width=0.5, which='both', length=1)
plt.xlim(0, 3.5)
plt.ylim(0.6, 1)

# Set x-axis labels
plt.xticks([1, 2.5], labels)

# Set labels and title
# plt.xlabel('Reaction annotation', fontsize=6)
plt.ylabel('Reaction annotation score', fontsize=8)

# Add legend
plt.legend(frameon=False, fontsize=6, loc='upper left', bbox_to_anchor=(0, 1.02), labelspacing=0.5, handletextpad=0.3)

# Save the figure
plt.savefig(figs4a_path, dpi=400, bbox_inches='tight')

# Show the figure
plt.show()

# %% [markdown]
# # gene set venn of different prediction methods s4-b

# %%
clean_gene2ec_dict = get_gene2ec_dict_clean(sce_gene_clean_ec)
clean_ec2gene_dict = get_ec2gene_dict_clean(clean_gene2ec_dict)
print(len(clean_ec2gene_dict))
clean_ec2gene_dict
# Out:
# 187
# {'5.3.99': ['YDL204W',
#   'YNR040W',
#   'YLR455W',
#   'YPR028W',
#   'YNL149C',
#   'YGR082W',
#   'YGR183C',
#   'YKL117W',
#   'YMR173W',
#   'YGR174C',
#   'YBR106W',
#   'YML081C-A',
#   'YBR230C',
#   'YOR020W-A',
#   'YOL165C',
#   'YDR233C',
#   'YER083C',
#   'YMR072W',
#   'YNL070W',
#   'YHR073W'],
#  '2.3.2': ['YNL167C',
#   'YDR170C',
#   'YDR177W',
#   'YHR121W',
#   'YLR145W',
#   'YOR161C',
#   'YLR224W',
#   'YIL097W',
#   'YPL007C',
#   'YPL199C',
#   'YDR397C',
#   'YDR073W',
#   'YOR064C',
#   'YFR052W',
#   'YIR011C',
#   'YJR141W',
#   'YDR398W',
#   'YBR082C',
#   'YFL009W',
#   'YCR087C-A',
#   'YBL047C',
#   'YGL049C',
#   'YJL048C',
#   'YLR283W',
#   'YMR269W',
#   'YCL039W',
#   'YLL006W',
#   'YKR082W',
#   'YJR090C',
#   'YHL044W',
#   'YOR077W',
#   'YGL058W',
#   'YLR099W-A',
#   'YMR153W',
#   'YDL161W',
#   'YLR337C',
#   'YBR258C',
#   'YDL058W',
#   'YJL036W',
#   'YHR090C',
#   'YDL233W',
#   'YLR323C',
#   'YPR125W',
#   'YDL209C',
#   'YLR045C',
#   'YMR021C',
#   'YLR268W',
#   'YLR078C',
#   'YML091C',
#   'YOR269W',
#   'YOL054W',
#   'YEL043W',
#   'YLR073C',
#   'YGR159C',
#   'YCR009C',
#   'YJR067C',
#   'YOL013C',
#   'YGR133W',
#   'YOR106W',
#   'YBR280C',
#   'YLR009W',
#   'YLR271W',
#   'YMR111C',
#   'YDR282C',
#   'YGL043W',
#   'YOL107W',
#   'YBR112C',
#   'YGL244W',
#   'YGL110C',
#   'YGL087C',
#   'YLR025W',
#   'YIL150C',
#   'YJR097W',
#   'YGL153W',
#   'YDR059C',
#   'YGL098W',
#   'YKL084W',
#   'YOR042W',
#   'YDR200C',
#   'YGL212W',
#   'YHL010C',
#   'YMR017W',
#   'YPR190C',
#   'YPL232W',
#   'YER100W',
#   'YOR132W',
#   'YHL009W-A',
#   'YDL008W',
#   'YGL079W',
#   'YDR485C',
#   'YML034W',
#   'YDR265W',
#   'YPL213W',
#   'YDL234C',
#   'YDR415C',
#   'YEL012W',
#   'YDR174W',
#   'YPR137W',
#   'YDR288W',
#   'YMR302C',
#   'YDR066C',
#   'YBL059W',
#   'YOR358W',
#   'YDR372C',
#   'YPL239W',
#   'YEL017W',
#   'YDL087C',
#   'YLR015W',
#   'YJL095W',
#   'YKL196C',
#   'YIL046W',
#   'YDR364C',
#   'YNL110C',
#   'YDR034W-B',
#   'YLL036C',
#   'YGL090W',
#   'YDL098C',
#   'YNL116W',
#   'YDR313C',
#   'YFR029W',
#   'YGR225W',
#   'YMR140W',
#   'YLR127C',
#   'YDR089W',
#   'YLR074C',
#   'YPR104C',
#   'YOR057W',
#   'YLR394W',
#   'YML114C',
#   'YHR115C',
#   'YOL116W',
#   'YDR515W',
#   'YGR119C',
#   'YGR086C',
#   'YPR143W',
#   'YMR067C',
#   'YJL049W',
#   'YMR171C',
#   'YPR135W',
#   'YBR200W',
#   'YPL202C',
#   'YER068W',
#   'YDR328C',
#   'YFR018C',
#   'YGL019W',
#   'YDR128W',
#   'YCL008C',
#   'YOL027C',
#   'YIR004W',
#   'YDR358W',
#   'YOR118W',
#   'YLL007C',
#   'YDL091C',
#   'YPR154W',
#   'YJR060W',
#   'YKL179C',
#   'YBR290W',
#   'YNL272C',
#   'YLR422W',
#   'YER021W',
#   'YNL176C',
#   'YNL023C',
#   'YOR212W',
#   'YLR309C',
#   'YHR114W',
#   'YGL017W',
#   'YHR071W',
#   'YML010W',
#   'YDL190C',
#   'YGL061C',
#   'YML101C',
#   'YHL034C',
#   'YDR409W',
#   'YDR092W',
#   'YOR164C',
#   'YAR028W',
#   'YOR070C',
#   'YMR075W',
#   'YGR082W',
#   'YHR039C-A',
#   'YCL029C',
#   'YDR495C',
#   'YGL122C',
#   'YKR017C',
#   'YDR228C',
#   'YDL064W',
#   'YDL003W',
#   'YBR260C',
#   'YNL236W',
#   'YHR187W',
#   'YBR111W-A',
#   'YER125W',
#   'YBR062C',
#   'YML097C',
#   'YLR222C',
#   'YDL077C',
#   'YCL031C',
#   'YOR206W',
#   'YIL079C',
#   'YHR108W',
#   'YOR036W',
#   'YLR093C',
#   'YCR088W',
#   'YBR255C-A',
#   'YLR427W',
#   'YPR108W',
#   'YJR054W',
#   'YJR052W',
#   'YOR007C',
#   'YOL026C',
#   'YIL071C',
#   'YGL242C',
#   'YBR065C',
#   'YDR255C',
#   'YDL012C',
#   'YHR069C',
#   'YIR017C',
#   'YOR181W',
#   'YBR273C',
#   'YJL104W',
#   'YNL243W',
#   'YNL047C',
#   'YIL138C',
#   'YOR213C',
#   'YHR059W',
#   'YPR056W',
#   'YMR148W',
#   'YMR192W',
#   'YDR054C',
#   'YMR119W',
#   'YDR211W',
#   'YDR348C',
#   'YDR425W',
#   'YPR148C',
#   'YDL240W',
#   'YDR143C',
#   'YDR489W',
#   'YDL175C',
#   'YJL210W',
#   'YLR010C',
#   'YKL124W',
#   'YMR077C',
#   'YOR069W',
#   'YOR043W',
#   'YBL104C',
#   'YOR216C',
#   'YJR112W-A',
#   'YMR264W',
#   'YJR086W',
#   'YIR001C',
#   'YDR152W',
#   'YAL002W',
#   'YGR285C',
#   'YOR080W',
#   'YKR092C',
#   'YCL012C',
#   'YOR272W',
#   'YPL138C',
#   'YIL001W',
#   'YBR089C-A',
#   'YBR188C',
#   'YIR006C',
#   'YHR197W',
#   'YBR103W',
#   'YJR134C',
#   'YGR136W',
#   'YPL004C',
#   'YNL008C',
#   'YPL120W',
#   'YCR030C',
#   'YKL214C',
#   'YGR128C',
#   'YOL133W',
#   'YLR082C',
#   'YKL034W',
#   'YCR023C',
#   'YER143W',
#   'YDL002C',
#   'YOR327C',
#   'YLR387C',
#   'YBL086C',
#   'YMR183C',
#   'YEL019C',
#   'YGL227W',
#   'YBR217W',
#   'YDR330W',
#   'YDL051W',
#   'YDR388W',
#   'YKL092C',
#   'YKR016W',
#   'YFR003C',
#   'YIL161W',
#   'YJR036C',
#   'YDR460W',
#   'YML029W',
#   'YEL037C',
#   'YLR016C',
#   'YPL181W',
#   'YMR026C',
#   'YOL073C',
#   'YDR363W',
#   'YML013W',
#   'YDL099W',
#   'YOL044W',
#   'YIL038C',
#   'YNL107W',
#   'YDR323C',
#   'YLR007W',
#   'YDL013W',
#   'YLR196W',
#   'YPR030W',
#   'YKR049C',
#   'YJR031C',
#   'YLR298C',
#   'YEL055C',
#   'YPL129W',
#   'YBR267W',
#   'YFR022W',
#   'YBR238C',
#   'YDR311W',
#   'YDR016C',
#   'YMR231W',
#   'YML002W',
#   'YLR332W',
#   'YMR022W',
#   'YGL141W',
#   'YDR266C',
#   'YPL169C',
#   'YOL108C',
#   'YDL105W',
#   'YNL227C',
#   'YNL097C',
#   'YGL128C',
#   'YER085C',
#   'YAR027W',
#   'YOR223W',
#   'YLR306W',
#   'YER016W',
#   'YLR390W',
#   'YHL002W',
#   'YDR333C',
#   'YGR009C',
#   'YHR192W',
#   'YKL057C',
#   'YPL149W',
#   'YPR067W',
#   'YPL047W',
#   'YDR145W',
#   'YKL028W',
#   'YOL072W',
#   'YMR276W',
#   'YJR055W',
#   'YKR083C',
#   'YMR147W',
#   'YLR181C',
#   'YKR007W',
#   'YGL164C',
#   'YGL181W',
#   'YAL041W',
#   'YEL022W',
#   'YCR033W',
#   'YDR229W',
#   'YHL031C',
#   'YOR123C',
#   'YIL030C',
#   'YDR468C',
#   'YPR041W',
#   'YNR006W',
#   'YDR325W',
#   'YER112W',
#   'YLR024C',
#   'YNR069C',
#   'YHL020C',
#   'YKR078W',
#   'YDL074C',
#   'YOL051W',
#   'YGR091W',
#   'YJL025W',
#   'YGR184C',
#   'YBR152W',
#   'YBL058W',
#   'YPR031W',
#   'YLR206W',
#   'YGL250W',
#   'YML088W',
#   'YPL190C',
#   'YIR018W',
#   'YNL260C',
#   'YIL062C',
#   'YBL021C',
#   'YML083C',
#   'YNR003C',
#   'YLR254C',
#   'YER116C',
#   'YGR280C',
#   'YBR128C',
#   'YMR187C',
#   'YIL004C',
#   'YKL059C',
#   'YDR469W',
#   'YIL041W',
#   'YML068W',
#   'YHR040W',
#   'YOR353C',
#   'YNL124W',
#   'YDL113C',
#   'YLR002C',
#   'YGL172W',
#   'YMR004W',
#   'YNR054C',
#   'YHR105W',
#   'YDR080W',
#   'YBR130C',
#   'YBR275C',
#   'YKR023W',
#   'YNL155W',
#   'YOR156C',
#   'YLR319C',
#   'YAL030W',
#   'YHR200W',
#   'YLR128W',
#   'YDR496C',
#   'YMR032W',
#   'YOR107W',
#   'YCR066W',
#   'YOR339C',
#   'YOR052C',
#   'YDL195W',
#   'YDR320C',
#   'YOR194C',
#   'YGR162W',
#   'YLR005W',
#   'YGR186W',
#   'YLR421C',
#   'YLR299W',
#   'YDR320C-A',
#   'YNL159C',
#   'YLR148W',
#   'YIL144W',
#   'YPR093C',
#   'YDR081C',
#   'YJL118W',
#   'YML104C',
#   'YLR238W',
#   'YCR084C',
#   'YMR197C'],
#  '3.1.2': ['YJL068C',
#   'YFL037W',
#   'YER027C',
#   'YJR019C',
#   'YDR036C',
#   'YOR084W',
#   'YJR042W',
#   'YBL015W',
#   'YGR031W',
#   'YDR096W',
#   'YDR272W',
#   'YJR074W',
#   'YKL186C',
#   'YOR280C',
#   'YBL095W',
#   'YHR067W',
#   'YBR096W',
#   'YMR222C',
#   'YKL112W',
#   'YLR212C',
#   'YNL320W',
#   'YOR040W',
#   'YER154W',
#   'YDL057W',
#   'YHR049W',
#   'YEL023C',
#   'YLR118C',
#   'YIL077C',
#   'YER182W'],
#  '2.3.1': ['YBL005W',
#   'YFR013W',
#   'YGL249W',
#   'YLR226W',
#   'YOR083W',
#   'YDR125C',
#   'YLR352W',
#   'YHR178W',
#   'YLL063C',
#   'YDR138W',
#   'YDR169C-A',
#   'YGL084C',
#   'YKR064W',
#   'YPR045C',
#   'YLR177W',
#   'YFL047W',
#   'YNL071W',
#   'YLR278C',
#   'YPL119C-A',
#   'YDR264C',
#   'YBR042C',
#   'YOL089C',
#   'YBL029W',
#   'YOR175C',
#   'YIL160C',
#   'YEL048C',
#   'YOL015W',
#   'YOR162C',
#   'YPR119W',
#   'YDL069C',
#   'YDL044C',
#   'YOR229W',
#   'YLR312W-A',
#   'YDL233W',
#   'YLR246W',
#   'YPL248C',
#   'YPL021W',
#   'YBL066C',
#   'YMR021C',
#   'YNR019W',
#   'YOR114W',
#   'YDR123C',
#   'YPL094C',
#   'YDR159W',
#   'YOR269W',
#   'YNR049C',
#   'YLR014C',
#   'YCR096C',
#   'YDL202W',
#   'YLR372W',
#   'YGL162W',
#   'YJL027C',
#   'YEL062W',
#   'YDR078C',
#   'YDR427W',
#   'YFL031W',
#   'YOR221C',
#   'YAL034C',
#   'YPL256C',
#   'YDR018C',
#   'YMR098C',
#   'YMR266W',
#   'YEL003W',
#   'YGR213C',
#   'YML099C',
#   'YPR025C',
#   'YIR023W',
#   'YJL117W',
#   'YBR182C',
#   'YMR237W',
#   'YPL196W',
#   'YMR042W',
#   'YMR306W',
#   'YDR451C',
#   'YGR196C',
#   'YPL010W',
#   'YMR191W',
#   'YBL074C',
#   'YDR296W',
#   'YCR018C',
#   'YAR035W',
#   'YGR032W',
#   'YLR210W',
#   'YML102W',
#   'YNL214W',
#   'YHR159W',
#   'YBR289W',
#   'YLL002W',
#   'YPR023C',
#   'YPL028W',
#   'YCL010C',
#   'YBR239C',
#   'YGL159W',
#   'YOL104C',
#   'YOL135C',
#   'YCR097W',
#   'YDL076C',
#   'YGR111W',
#   'YDR066C',
#   'YEL066W',
#   'YGR109C',
#   'YCR052W',
#   'YOR058C',
#   'YOR337W',
#   'YLR098C',
#   'YHL006C',
#   'YKL185W',
#   'YDR191W',
#   'YCR039C',
#   'YDR062W',
#   'YLR033W',
#   'YGR015C',
#   'YDR065W',
#   'YOR144C',
#   'YLR460C',
#   'YFL017C',
#   'YML052W',
#   'YJL218W',
#   'YGR177C',
#   'YJL006C',
#   'YPR139C',
#   'YKL023C-A',
#   'YGL175C',
#   'YNR023W',
#   'YMR127C',
#   'YML027W',
#   'YLR418C',
#   'YLR239C',
#   'YDR071C',
#   'Q0140',
#   'Q0255',
#   'YDR179C',
#   'YKR038C',
#   'YMR064W',
#   'YDR501W',
#   'YOR298W',
#   'YGR031W',
#   'YHR172W',
#   'YLR266C',
#   'YDR124W',
#   'YKR067W',
#   'YNR008W',
#   'YPR009W',
#   'YOR338W',
#   'YPR116W',
#   'YFR002W',
#   'YMR296C',
#   'YJL062W',
#   'YPR091C',
#   'YLR390W-A',
#   'YML011C',
#   'YNR063W',
#   'YGR200C',
#   'YLR170C',
#   'YPR129W',
#   'YDR382W',
#   'YDR235W',
#   'YKR099W',
#   'YGR110W',
#   'YPL166W',
#   'YDR207C',
#   'YPL231W',
#   'YLR183C',
#   'YDR324C',
#   'YGR193C',
#   'YOR253W',
#   'YLR108C',
#   'YPL126W',
#   'YCR016W',
#   'YPL183C',
#   'YOR025W',
#   'YLR451W',
#   'YLR195C',
#   'YPL133C',
#   'YMR079W',
#   'YMR069W',
#   'YPR086W',
#   'YOL067C',
#   'YNL196C',
#   'YHR185C',
#   'YER019C-A',
#   'YML077W',
#   'YPR140W',
#   'YIL011W',
#   'YBR081C',
#   'YOL017W',
#   'YLR360W',
#   'YPR120C',
#   'YLR439W',
#   'YMR019W',
#   'YJR056C',
#   'YNL326C',
#   'YGR054W',
#   'YLR099C',
#   'YOL141W',
#   'YMR073C',
#   'YLR013W',
#   'YEL067C',
#   'YHR051W',
#   'YJL112W',
#   'YPR072W',
#   'YMR168C',
#   'YML031W',
#   'YJL071W',
#   'YOR080W',
#   'YML003W',
#   'YDR148C',
#   'YER024W',
#   'YBL052C',
#   'YGL113W',
#   'YIL130W',
#   'YLL031C',
#   'YGL166W',
#   'YAL040C',
#   'YMR252C',
#   'YNL132W',
#   'YNL134C',
#   'YJL206C',
#   'YJL127C',
#   'YGR070W',
#   'YCR023C',
#   'YDL073W',
#   'YKL222C',
#   'YGR161W-C',
#   'YLR176C',
#   'YNR045W',
#   'YDL051W',
#   'YPR131C',
#   'YOR350C',
#   'YKR016W',
#   'YPL177C',
#   'YMR062C',
#   'YCR034W',
#   'YPR196W',
#   'YOL068C',
#   'YNL039W',
#   'YDL208W',
#   'YML042W',
#   'YMR137C',
#   'YIR013C',
#   'YPR051W',
#   'YLR342W',
#   'YIL038C',
#   'YDR131C',
#   'YNL025C',
#   'YNL311C',
#   'YJR098C',
#   'YPR199C',
#   'YBR177C',
#   'YPL039W',
#   'YNL136W',
#   'YCL067C',
#   'YGR066C',
#   'YOR245C',
#   'YLR204W',
#   'YBR297W',
#   'YDL155W',
#   'YCR106W',
#   'YPL189W',
#   'YIL101C',
#   'YDL104C',
#   'YPR114W',
#   'YEL009C',
#   'YLR429W',
#   'YBR234C',
#   'YLR357W',
#   'YBR135W',
#   'YJL024C',
#   'YML002W',
#   'YCR048W',
#   'YBL014C',
#   'YEL072W',
#   'YDL165W',
#   'YHL003C',
#   'YJL196C',
#   'YMR122W-A',
#   'YDR013W',
#   'YDR303C',
#   'YDR416W',
#   'YGR166W',
#   'R0030W',
#   'YER061C',
#   'YEL052W',
#   'YER085C',
#   'YDR232W',
#   'YKR011C',
#   'YLR103C',
#   'YOL003C',
#   'YPL272C',
#   'YER184C',
#   'YML107C',
#   'YMR061W',
#   'YPL001W',
#   'YBR105C',
#   'YLR071C',
#   'YDL129W',
#   'YPR018W',
#   'YML046W',
#   'YCL016C',
#   'YLL033W',
#   'YMR092C',
#   'YDR391C',
#   'YER064C',
#   'YDR362C',
#   'YGL213C',
#   'YLR262C-A',
#   'YOR244W',
#   'YMR199W',
#   'YDR421W',
#   'YMR258C',
#   'YER112W',
#   'YDR132C',
#   'YOL039W',
#   'YGR252W',
#   'YPL095C',
#   'YDR126W',
#   'YBR240C',
#   'YOL084W',
#   'YMR043W',
#   'YMR125W',
#   'YHR060W',
#   'YHR118C',
#   'YNR003C',
#   'YLR407W',
#   'YDL042C',
#   'YKL182W',
#   'YJL176C',
#   'YHR157W',
#   'YPL134C',
#   'YBR090C',
#   'YGL075C',
#   'YDR176W',
#   'YGR212W',
#   'YAL013W',
#   'YOR047C',
#   'YDR449C',
#   'YKL008C',
#   'YHR013C',
#   'YJR058C',
#   'YGR056W',
#   'YNL084C',
#   'YGL013C',
#   'YJR116W',
#   'YDR359C',
#   'YAL044C',
#   'YOR034C',
#   'YDR520C',
#   'YJL013C',
#   'YDL052C',
#   'YNL277W',
#   'YGR084C',
#   'YFR027W',
#   'YOR107W',
#   'YPL015C',
#   'YLL054C',
#   'YPR193C',
#   'YDR488C',
#   'YCR072C',
#   'YBR076W',
#   'YGR186W',
#   'YLR399C',
#   'YGR108W',
#   'YBR254C',
#   'YOR172W',
#   'YDR459C',
#   'YGR105W',
#   'YJL099W',
#   'YGR246C',
#   'YBL011W',
#   'YLR253W',
#   'YOR377W',
#   'YHR182W',
#   'YOL028C'],
#  '1.12.99': ['YLR037C', 'YMR325W', 'YIR041W', 'YCR104W', 'YLL025W', 'YKL224C'],
#  '5.6.2': ['YHR077C',
#   'YGR003W',
#   'YPL009C',
#   'YMR076C',
#   'YBR175W',
#   'YGR278W',
#   'YAL032C',
#   'YML069W',
#   'YOR367W',
#   'YPL083C',
#   'YKL045W',
#   'YKL095W',
#   'YHL022C',
#   'YDR088C',
#   'YLR234W',
#   'YGR169C-A',
#   'YLR272C',
#   'YGR054W',
#   'YNL088W',
#   'YJR138W',
#   'YAR003W',
#   'YKL009W',
#   'YOL006C',
#   'YAR007C',
#   'YNL253W',
#   'YBL112C',
#   'YNL059C'],
#  '3.2.2': ['YGR294W',
#   'YFL048C',
#   'YIL156W-B',
#   'YKR044W',
#   'YML012W',
#   'YFL020C',
#   'YOL161C',
#   'YPR107C',
#   'YLR080W',
#   'YKL219W',
#   'YHL017W',
#   'YGL263W',
#   'YGL200C',
#   'YOR382W',
#   'YCL039W',
#   'YGR109W-A',
#   'YDR153C',
#   'YNR076W',
#   'YJL039C',
#   'YOR060C',
#   'YDR210W',
#   'YHR041C',
#   'YPL084W',
#   'YEL049W',
#   'YGL146C',
#   'YLR291C',
#   'YBL093C',
#   'YLR301W',
#   'YAL058W',
#   'YPL201C',
#   'YMR065W',
#   'YIL176C',
#   'YHL009W-A',
#   'YJL037W',
#   'YOR008C',
#   'YFR039C',
#   'YPL241C',
#   'YPR071W',
#   'YNL327W',
#   'YOR179C',
#   'YDR238C',
#   'YBR282W',
#   'YML048W',
#   'YJL223C',
#   'YJR004C',
#   'YGL176C',
#   'YJL158C',
#   'YDR358W',
#   'YHL030W',
#   'YEL002C',
#   'YBR302C',
#   'YOL086W-A',
#   'YPL271W',
#   'YGR050C',
#   'YKL096W',
#   'YML112W',
#   'YLR305C',
#   'YML095C',
#   'YEL068C',
#   'YGR295C',
#   'YAR002C-A',
#   'YPR079W',
#   'YJL159W',
#   'YJR118C',
#   'YKL077W',
#   'YNL211C',
#   'YOR148C',
#   'YKR057W',
#   'YAL068C',
#   'YOL031C',
#   'YMR129W',
#   'YML060W',
#   'YGL247W',
#   'YHR101C',
#   'YGL228W',
#   'YCL045C',
#   'YDR156W',
#   'YJL073W',
#   'YNL306W',
#   'YHL048W',
#   'YCL032W',
#   'YAR020C',
#   'YCR007C',
#   'YMR247C',
#   'YML031W',
#   'YIL017C',
#   'YHR110W',
#   'YAL016W',
#   'YGR078C',
#   'YOL043C',
#   'YBR013C',
#   'YNL271C',
#   'YMR029C',
#   'YJL019W',
#   'YLR461W',
#   'YJR125C',
#   'YDR246W',
#   'YHR212W-A',
#   'YGL151W',
#   'YKL163W',
#   'YOR152C',
#   'YKL058W',
#   'YPR036W',
#   'YKL164C',
#   'YFR024C-A',
#   'YOL014W',
#   'YER007W',
#   'YJL207C',
#   'YGL204C',
#   'YER038W-A',
#   'YBL004W',
#   'YJL174W',
#   'YML049C',
#   'YDR400W',
#   'YBR140C',
#   'YLR335W',
#   'YBR301W',
#   'YCR032W',
#   'YJL109C',
#   'YJL184W',
#   'YML132W',
#   'YIL027C',
#   'YKL142W',
#   'YGR057C',
#   'YGR122W',
#   'YJL055W',
#   'YMR263W',
#   'YLR154C',
#   'YAR027W',
#   'YGL002W',
#   'YOR249C',
#   'YDL049C',
#   'YPL065W',
#   'YNL212W',
#   'YHR087W',
#   'YDL215C',
#   'YLR327C',
#   'YHL043W',
#   'YEL018W',
#   'YOL081W',
#   'YDL248W',
#   'YDR424C',
#   'YLR340W',
#   'YML103C',
#   'YOR016C',
#   'YOR349W',
#   'YDL121C',
#   'YGL051W',
#   'YDL018C',
#   'YNL155W',
#   'YGL261C',
#   'YKL014C',
#   'YIL040W',
#   'YLL064C',
#   'YDL241W',
#   'YCL048W',
#   'YER187W',
#   'YJL038C',
#   'YML021C',
#   'YAL007C',
#   'YBR254C',
#   'YHR124W',
#   'YGL138C',
#   'YBR216C',
#   'YER142C'],
#  '4.2.3': ['YGR233C',
#   'YOR093C',
#   'YOR083W',
#   'YPL005W',
#   'YOR255W',
#   'YDR322W',
#   'YFR016C',
#   'YGL148W',
#   'YML023C',
#   'YER077C',
#   'YNL336W',
#   'YJR160C',
#   'YMR098C',
#   'YOR385W',
#   'YCL042W',
#   'YDL184C',
#   'YLR227C',
#   'YOL008W',
#   'YOL131W',
#   'YIL127C',
#   'YGL107C',
#   'YBL044W',
#   'YDR179C',
#   'YBR302C',
#   'YML112W',
#   'YNL211C',
#   'YDR381C-A',
#   'YDR127W',
#   'YJR161C',
#   'YDL053C',
#   'YLR102C',
#   'YNL196C',
#   'YFL062W',
#   'YGL015C',
#   'YDR350C',
#   'YJR003C',
#   'YNL140C',
#   'YIL136W',
#   'YCR053W',
#   'YDL247W',
#   'YGL113W',
#   'YPL247C',
#   'YOR105W',
#   'YBL025W',
#   'YNR051C',
#   'YLR437C',
#   'YPL225W',
#   'YOR350C',
#   'Q0115',
#   'YJL127C-B',
#   'YLR307C-A',
#   'YML132W',
#   'YDR306C',
#   'YOL053W',
#   'YGL116W',
#   'YOR252W',
#   'YJL043W',
#   'YHR155W',
#   'YKL108W',
#   'YFL012W',
#   'YFL041W-A',
#   'YLR068W',
#   'YDR374W-A',
#   'YER044C-A',
#   'YKL068W-A',
#   'YKL075C',
#   'YDL133C-A',
#   'YLR256W',
#   'YLL042C',
#   'YMR282C',
#   'YGR150C'],
#  '1.14.15': ['YOL162W', 'YLR250W', 'YIL105W-A'],
#  '2.7.6': ['YLR001C',
#   'YHL011C',
#   'YOR143C',
#   'YKL084W',
#   'YOL061W',
#   'YER099C',
#   'YNL256W',
#   'YBL068W',
#   'YPL260W',
#   'YKL181W'],
#  '3.5.1': ['YJL052C-A',
#   'YOL137W',
#   'YIR020C',
#   'YPL119C-A',
#   'YNL021W',
#   'YJR146W',
#   'YHR022C-A',
#   'YER162C',
#   'YLR034C',
#   'YJL098W',
#   'YPL170W',
#   'YFL060C',
#   'YHR021W-A',
#   'YIL060W',
#   'YLR156W',
#   'YJL217W',
#   'YNL334C',
#   'YPR108W-A',
#   'YLR351C',
#   'YKR095W-A',
#   'YGR204C-A',
#   'YPR068C',
#   'YKL037W',
#   'YLR154C-H',
#   'YMR315W-A',
#   'YGR127W',
#   'YGL037C',
#   'YGL041C-B',
#   'YKR028W',
#   'YLR308W',
#   'YMR281W',
#   'YBR248C',
#   'YLR155C',
#   'YBR183W',
#   'YGL124C',
#   'YLR023C',
#   'YML007C-A',
#   'YCR044C',
#   'YGL014W',
#   'YJL213W',
#   'YPL096W',
#   'YDL009C',
#   'YOR389W',
#   'YPL087W',
#   'YMR154C',
#   'YPL116W',
#   'YIL163C',
#   'YLR157W-E',
#   'YDR428C',
#   'YPR138C',
#   'YPR147C',
#   'YOR394C-A',
#   'YGL194C',
#   'YNL330C',
#   'YJR112W-A',
#   'YGR146C-A',
#   'YLR158C',
#   'YDR314C',
#   'YKL051W',
#   'YLR161W',
#   'YMR316C-A',
#   'YLR307W',
#   'YOR008C-A',
#   'YJL126W',
#   'YHR139C',
#   'YER155C',
#   'YJR062C',
#   'YDR321W',
#   'YLR415C',
#   'YOL002C',
#   'YLR157C-C',
#   'YNL305C',
#   'YLR156C-A',
#   'YOL019W-A',
#   'YLR159W',
#   'YMR247W-A',
#   'YOL164W-A',
#   'YNL160W',
#   'YML054C-A',
#   'YNL184C',
#   'YMR105W-A',
#   'YMR272W-B',
#   'YOR032W-A',
#   'YLR157C',
#   'YDR479C',
#   'YDR242W',
#   'YBR200W-A',
#   'YJL028W',
#   'YHR150W',
#   'YLR159C-A',
#   'YLR160C',
#   'YDR492W',
#   'YMR095C',
#   'YBR221W-A',
#   'YOR161C-C',
#   'YGL258W-A'],
#  '3.6.4': ['YPL240C',
#   'YJR045C',
#   'YLL008W',
#   'YDL031W',
#   'YOR217W',
#   'YFR031C',
#   'YPR011C',
#   'YLR409C',
#   'YMR190C',
#   'YPL060C-A',
#   'YLL024C',
#   'YKR035W-A',
#   'YBR060C',
#   'YEL077C',
#   'YJR145C',
#   'YNL218W',
#   'YOR382W',
#   'YJL029C',
#   'YMR078C',
#   'YGR074W',
#   'YDR135C',
#   'YDR429C',
#   'YKL002W',
#   'YDR190C',
#   'YEL030W',
#   'YDL229W',
#   'YPR128C',
#   'YDR217C',
#   'YNL250W',
#   'YNL257C',
#   'YNL261W',
#   'YML041C',
#   'YER013W',
#   'YOL094C',
#   'YIL134W',
#   'YLR268W',
#   'YLR078C',
#   'YPR007C',
#   'YCR060W',
#   'YPL119C',
#   'YJL039C',
#   'YPL130W',
#   'YHR023W',
#   'YER164W',
#   'YKL041W',
#   'YGR159C',
#   'YBR114W',
#   'YGR145W',
#   'YOR222W',
#   'YPL235W',
#   'YLR009W',
#   'YER107C',
#   'YNL209W',
#   'YGR278W',
#   'YLR276C',
#   'YLR419W',
#   'YLL066C',
#   'YPL106C',
#   'YIL150C',
#   'YDR027C',
#   'YJL108C',
#   'YMR056C',
#   'YPL008W',
#   'YCL058W-A',
#   'YNL312W',
#   'YJL069C',
#   'YER095W',
#   'YGL098W',
#   'YKR052C',
#   'YIR002C',
#   'YFR045W',
#   'YFL002C',
#   'YJR077C',
#   'YGL031C',
#   'YAL005C',
#   'YLL034C',
#   'YMR128W',
#   'YGR271W',
#   'YNL328C',
#   'YGL206C',
#   'YPR088C',
#   'YCL011C',
#   'YDL191W',
#   'YBR080C',
#   'YLR197W',
#   'YJR035W',
#   'YDL156W',
#   'YPL029W',
#   'YOR144C',
#   'YIL061C',
#   'YHL009W-B',
#   'YGR023W',
#   'YBR245C',
#   'YNL007C',
#   'YPL242C',
#   'YBR009C',
#   'YNL153C',
#   'YER190W',
#   'YOL012C',
#   'YOR204W',
#   'YML098W',
#   'YFR038W',
#   'YKL073W',
#   'YPL100W',
#   'YPR173C',
#   'YLR040C',
#   'YML094W',
#   'YNR038W',
#   'YOR026W',
#   'YDR301W',
#   'YNL206C',
#   'YDR055W',
#   'YCR067C',
#   'YMR290C',
#   'YKL145W',
#   'YBL075C',
#   'YBR142W',
#   'YOR167C',
#   'YGR081C',
#   'YML010W',
#   'YNL126W',
#   'YOL034W',
#   'YLR055C',
#   'YIL006W',
#   'YDR382W',
#   'YLL011W',
#   'YER053C',
#   'YMR309C',
#   'YER176W',
#   'YLR003C',
#   'YDR088C',
#   'YDR243C',
#   'YDR172W',
#   'YDL160C',
#   'YGR284C',
#   'YBR087W',
#   'YJL113W',
#   'YHR203C',
#   'YDR121W',
#   'YDR291W',
#   'YPL045W',
#   'YMR219W',
#   'YOR206W',
#   'YDL136W',
#   'YOR036W',
#   'YDL145C',
#   'YGL171W',
#   'YMR080C',
#   'YOR117W',
#   'YER172C',
#   'YGL004C',
#   'YFL008W',
#   'YLR369W',
#   'YJL050W',
#   'YNL243W',
#   'YLR336C',
#   'YKL120W',
#   'YMR074C',
#   'YDL126C',
#   'YDR334W',
#   'YOL018C',
#   'YMR106C',
#   'YNL003C',
#   'YMR077C',
#   'YPR162C',
#   'YEL051W',
#   'YNL329C',
#   'YOR257W',
#   'YBR186W',
#   'YLR348C',
#   'YCR057C',
#   'YLR026C',
#   'YEL032W',
#   'YDR064W',
#   'YKL098W',
#   'YAL016W',
#   'YMR284W',
#   'YJL074C',
#   'YDR292C',
#   'YNL182C',
#   'YLR117C',
#   'YGR096W',
#   'YNL317W',
#   'YOR259C',
#   'YMR093W',
#   'YLR397C',
#   'YER103W',
#   'YMR166C',
#   'YDR076W',
#   'YBR109C',
#   'YNL273W',
#   'YGL190C',
#   'YBR202W',
#   'YER029C',
#   'YBR085W',
#   'YDL007W',
#   'YCL034W',
#   'YKL063C',
#   'YBL023C',
#   'YOR046C',
#   'YKL214C',
#   'YGL251C',
#   'YEL044W',
#   'YOR296W',
#   'YPL164C',
#   'YGL029W',
#   'YNL215W',
#   'YML065W',
#   'YLL045C',
#   'YBR192W',
#   'YNR011C',
#   'YLR417W',
#   'YDR478W',
#   'YGR241C',
#   'YDR386W',
#   'YLL067C',
#   'YBL030C',
#   'YOL095C',
#   'YPR019W',
#   'YGL201C',
#   'YJL033W',
#   'YGL106W',
#   'YLR032W',
#   'YDR450W',
#   'YNL287W',
#   'YGR257C',
#   'YPR178W',
#   'YKL049C',
#   'YJR113C',
#   'YGR270W',
#   'YDR194C',
#   'YLR196W',
#   'YPR179C',
#   'YLR147C',
#   'YER179W',
#   'YMR186W',
#   'YGL137W',
#   'YDR252W',
#   'YDR498C',
#   'YLR189C',
#   'YFR009W',
#   'YNL082W',
#   'YGR148C',
#   'YHR081W',
#   'YPL243W',
#   'YGL116W',
#   'YDL154W',
#   'YDR021W',
#   'YGL120C',
#   'YER034W',
#   'YDR117C',
#   'YOR304W',
#   'YIL091C',
#   'YDR381W',
#   'YHR169W',
#   'YML133C',
#   'YKR062W',
#   'YLR086W',
#   'YOL052C-A',
#   'YGL003C',
#   'YBR198C',
#   'YPL101W',
#   'YOR270C',
#   'YLR264W',
#   'YJL179W',
#   'YJL061W',
#   'YKL057C',
#   'YPL178W',
#   'YLR398C',
#   'YNL290W',
#   'YIR005W',
#   'YBR237W',
#   'YOR038C',
#   'YER082C',
#   'YML026C',
#   'YBR102C',
#   'YOR075W',
#   'YKR024C',
#   'YPR112C',
#   'YDR394W',
#   'YOR310C',
#   'YMR033W',
#   'YKL197C',
#   'YKR059W',
#   'YDR097C',
#   'YBR073W',
#   'YPL022W',
#   'YGL078C',
#   'YNR021W',
#   'YLR194C',
#   'YBR079C',
#   'YFR021W',
#   'YLR262C-A',
#   'YLR192C',
#   'YDR375C',
#   'YOR265W',
#   'YPR204W',
#   'YHR218W',
#   'YDL097C',
#   'YER171W',
#   'YOL039W',
#   'YKL078W',
#   'YAL019W',
#   'YPR188C',
#   'YBR169C',
#   'YMR167W',
#   'YER017C',
#   'YLR333C',
#   'YIL092W',
#   'YNL185C',
#   'YJL194W',
#   'YJL034W',
#   'YJL138C',
#   'YBR098W',
#   'YGR231C',
#   'YHR031C',
#   'YJL092W',
#   'YDR295C',
#   'YGL163C',
#   'YDR472W',
#   'YOL090W',
#   'YHL033C',
#   'YKL018W',
#   'YOR361C',
#   'YBR227C',
#   'YGL048C',
#   'YOR141C',
#   'YIL126W',
#   'YDR258C',
#   'YHR065C',
#   'YCR092C',
#   'YLR002C',
#   'YPL024W',
#   'YDL063C',
#   'YMR089C',
#   'YGL044C',
#   'YLR453C',
#   'YFL003C',
#   'YLR466W',
#   'YLR274W',
#   'YNL244C',
#   'YLR383W',
#   'YDL147W',
#   'YLR035C',
#   'YER173W',
#   'YDR486C',
#   'YHR064C',
#   'YAL014C',
#   'YEL006W',
#   'YJL080C',
#   'YNL166C',
#   'YNL030W',
#   'YKR086W',
#   'YML015C',
#   'YDL084W',
#   'YDL119C',
#   'YBL106C',
#   'YNL122C',
#   'YNL112W',
#   'YMR251W-A',
#   'YGL064C',
#   'YJL154C',
#   'YDL065C',
#   'YHR193C',
#   'YER006W',
#   'YMR197C',
#   'YJR068W',
#   'YHR089C',
#   'YPR024W'],
#  '3.4.21': ['YER159C-A',
#   'YDR289C',
#   'YLR097C',
#   'YDR365W-A',
#   'YEL060C',
#   'YCR076C',
#   'YHL025W',
#   'YLR191W',
#   'YPL246C',
#   'YJL214W',
#   'YOR329C',
#   'YFL067W',
#   'YLR337C',
#   'YPL105C',
#   'YLR227W-A',
#   'YNL284C-A',
#   'YOL048C',
#   'YOL047C',
#   'YDL189W',
#   'YKL074C',
#   'YPR158C-C',
#   'YGR161W-A',
#   'YAL018C',
#   'YBR201W',
#   'YBL093C',
#   'YOR343W-A',
#   'YDR210W-A',
#   'YBL022C',
#   'YLR410W-A',
#   'YNL230C',
#   'YDR227W',
#   'YKL054C',
#   'YBR205W',
#   'YLR008C',
#   'YNL123W',
#   'YFL002W-B',
#   'YER045C',
#   'YMR051C',
#   'YGR027C',
#   'YHR177W',
#   'YPL049C',
#   'YBR083W',
#   'YBR040W',
#   'YDR210C-C',
#   'YLR079W',
#   'YBR015C',
#   'YOL116W',
#   'YDR279W',
#   'YGR013W',
#   'YCR045C',
#   'YOR003W',
#   'YIR003W',
#   'YDR501W',
#   'YDR411C',
#   'YDL220C',
#   'YMR150C',
#   'YHR214C-C',
#   'YFL049W',
#   'YHR036W',
#   'YDR261C-C',
#   'YGR273C',
#   'YLR157C-A',
#   'YML045W-A',
#   'YLR326W',
#   'YNL050C',
#   'YPL055C',
#   'YDR432W',
#   'YJR026W',
#   'YNL054W-A',
#   'YDR480W',
#   'YDR273W',
#   'YPR137C-A',
#   'YIL009C-A',
#   'YGR038C-A',
#   'YGR058W',
#   'YOR192C-A',
#   'YLL026W',
#   'YDR034C-C',
#   'YOR142W-A',
#   'YJL104W',
#   'YNL238W',
#   'YLR265C',
#   'YDR098C-A',
#   'YBR012W-A',
#   'YNL314W',
#   'YJR028W',
#   'YER046W',
#   'YGL096W',
#   'YIR006C',
#   'YHR160C',
#   'YPL193W',
#   'YGR027W-A',
#   'YGR156W',
#   'YLR263W',
#   'YML017W',
#   'YML113W',
#   'YIL122W',
#   'YMR133W',
#   'YDR316W-A',
#   'YMR035W',
#   'YHR168W',
#   'YOR152C',
#   'YER137C-A',
#   'YCL020W',
#   'YHR092C',
#   'YPL257W-A',
#   'YOL083W',
#   'YHR014W',
#   'YBL005W-A',
#   'YPL127C',
#   'YPL053C',
#   'YIL022W',
#   'YHR154W',
#   'YDR170W-A',
#   'YPR003C',
#   'YHR148W',
#   'YNL216W',
#   'YLR256W-A',
#   'YPL085W',
#   'YKR011C',
#   'YAL037W',
#   'YDR443C',
#   'YMR276W',
#   'YDR369C',
#   'YBR172C',
#   'YBL100W-A',
#   'YIL152W',
#   'YGR161C-C',
#   'YNL018C',
#   'YHR127W',
#   'YNL251C',
#   'YLR333C',
#   'YIL092W',
#   'YPL190C',
#   'YMR046C',
#   'YER084W',
#   'YPR158W-A',
#   'YOR191W',
#   'YJR043C',
#   'YIR022W',
#   'YDR258C',
#   'YAL027W',
#   'YOL082W',
#   'YOR276W',
#   'YPR061C',
#   'YBL006C',
#   'YGL237C',
#   'YDR446W',
#   'YBR108W',
#   'YDR261W-A',
#   'YJL076W',
#   'YBR199W',
#   'YHR124W',
#   'YNL034W',
#   'YAR010C',
#   'YGR101W',
#   'YML040W',
#   'YOL103W-A'],
#  '2.1.1': ['YGR245C',
#   'YKL005C',
#   'YDR497C',
#   'YMR228W',
#   'YLR063W',
#   'YDL207W',
#   'YML014W',
#   'YMR049C',
#   'YMR014W',
#   'YJR129C',
#   'YBR236C',
#   'YBR133C',
#   'YBR141C',
#   'YCL055W',
#   'YCR002C',
#   'YNL061W',
#   'YLR199C',
#   'YHR207C',
#   'YBR261C',
#   'YCR024C-A',
#   'YGL183C',
#   'YOR077W',
#   'YNL148C',
#   'YMR268C',
#   'YKL162C',
#   'YBR034C',
#   'YDL212W',
#   'YBR213W',
#   'YBR119W',
#   'YKL208W',
#   'YMR227C',
#   'YPL216W',
#   'YPL256C',
#   'YPL157W',
#   'YKL122C',
#   'YCL056C',
#   'YNL248C',
#   'YGL033W',
#   'YOR307C',
#   'YEL017C-A',
#   'YDR254W',
#   'YNL149C',
#   'YKR074W',
#   'YHL036W',
#   'YGR002C',
#   'YPL112C',
#   'YAL001C',
#   'YDR034C-A',
#   'YOR091W',
#   'YCR097W',
#   'YLR285W',
#   'YLR172C',
#   'YDR435C',
#   'YLR084C',
#   'YBR126W-A',
#   'YLL062C',
#   'YGR027C',
#   'YKR069W',
#   'YNL024C',
#   'YMR160W',
#   'YJL125C',
#   'YGL097W',
#   'YGR005C',
#   'YOR201C',
#   'YKR025W',
#   'YOL103W',
#   'YNL092W',
#   'YER060W-A',
#   'YGL192W',
#   'YGL232W',
#   'YIL108W',
#   'YJL193W',
#   'YJL168C',
#   'YJL122W',
#   'YPL146C',
#   'YML110C',
#   'YIL102C',
#   'YMR174C',
#   'YHR034C',
#   'YNL062C',
#   'YDL201W',
#   'YIL072W',
#   'YHR071W',
#   'YOR338W',
#   'YBR171W',
#   'YPR116W',
#   'YHR209W',
#   'YNL063W',
#   'YMR260C',
#   'YPL092W',
#   'YDR083W',
#   'YPL002C',
#   'YBR259W',
#   'YLR141W',
#   'YIL064W',
#   'YDR448W',
#   'YLR412W',
#   'YPR186C',
#   'YHL039W',
#   'YDL060W',
#   'YCR016W',
#   'YIL009C-A',
#   'YDR105C',
#   'YCL031C',
#   'YKL088W',
#   'YBR107C',
#   'YMR209C',
#   'YER124C',
#   'YJR073C',
#   'YFR001W',
#   'YIL139C',
#   'YOR239W',
#   'YOL147C',
#   'YGL220W',
#   'YHR109W',
#   'YOL141W',
#   'YDR410C',
#   'YGL050W',
#   'YPR133W-A',
#   'YGR006W',
#   'YFR037C',
#   'YER091C',
#   'YOR078W',
#   'YJL030W',
#   'YGL025C',
#   'YHR085W',
#   'YPR057W',
#   'YLL023C',
#   'YDR312W',
#   'YKR029C',
#   'YBL001C',
#   'YPL030W',
#   'YPR133C',
#   'YER175C',
#   'YKL007W',
#   'YPR187W',
#   'YCR047C',
#   'YOL093W',
#   'YBR061C',
#   'YOR021C',
#   'YDR049W',
#   'YKR056W',
#   'YKL082C',
#   'YOR154W',
#   'YBR030W',
#   'YLR330W',
#   'YDR140W',
#   'YGL226C-A',
#   'YJR044C',
#   'YOR294W',
#   'YGR157W',
#   'YMR257C',
#   'YAL059W',
#   'YBR267W',
#   'YGL111W',
#   'YLR051C',
#   'YCL054W',
#   'YJR137C',
#   'YHR196W',
#   'YDR120C',
#   'YBR271W',
#   'YGR271C-A',
#   'YPL165C',
#   'YBL024W',
#   'YOL020W',
#   'R0030W',
#   'YKL155C',
#   'YER002W',
#   'YHR066W',
#   'YJL105W',
#   'YJR108W',
#   'YDL092W',
#   'YKR011C',
#   'YGR018C',
#   'YAL025C',
#   'YLR186W',
#   'YDR026C',
#   'YGR049W',
#   'YDR198C',
#   'YFL051C',
#   'YDL232W',
#   'YBR115C',
#   'YDR465C',
#   'YPL273W',
#   'YHR119W',
#   'YOR074C',
#   'YLR137W',
#   'YIL096C',
#   'YOL096C',
#   'YER056C',
#   'YLR333C',
#   'YER060W',
#   'YMR321C',
#   'YNR003C',
#   'YDR257C',
#   'YDR440W',
#   'YGL133W',
#   'YIL110W',
#   'YGL136C',
#   'YPL208W',
#   'YFL064C',
#   'YGR280C',
#   'YOL124C',
#   'YBR241C',
#   'YPL266W',
#   'YHR117W',
#   'YML105C',
#   'YGL131C',
#   'YGR104C',
#   'YNL022C',
#   'YBR077C',
#   'YOL125W',
#   'YGL186C',
#   'YHR070W',
#   'YBR076W',
#   'YGR186W',
#   'YMR158C-A',
#   'YKR071C',
#   'YNL282W',
#   'YDL200C',
#   'YJL056C',
#   'YML008C',
#   'YDR240C',
#   'YJR124C'],
#  '7.1.2': ['YPL036W',
#   'YMR221C',
#   'YKL207W',
#   'YHR129C',
#   'YBL099W',
#   'YJR121W',
#   'YBR127C',
#   'YDR038C',
#   'YGL008C',
#   'YDL185W',
#   'YDR040C',
#   'YDR039C'],
#  '2.7.4': ['YDL166C',
#   'YNL231C',
#   'YKL024C',
#   'YKL067W',
#   'YPL258C',
#   'YDR226W',
#   'YMR220W',
#   'YOL055C',
#   'YJR057W',
#   'YKL192C',
#   'YDR454C',
#   'YER170W',
#   'YMR157C',
#   'YPR121W',
#   'YDR181C',
#   'YPL214C',
#   'YPR094W',
#   'YLR410W'],
#  '3.4.13': ['YBR281C', 'YFR044C'],
#  '3.4.22': ['YDR246W-A',
#   'YHR165C',
#   'YOR381W-A',
#   'YJR041C',
#   'YBL113C',
#   'YNL165W',
#   'YCL037C',
#   'YJR120W',
#   'YHR219W',
#   'YJL079C',
#   'YHL038C',
#   'YLR312W-A',
#   'YMR316W',
#   'YOR060C',
#   'YGR080W',
#   'YGL193C',
#   'YOR385W',
#   'YLR156W',
#   'YKL106C-A',
#   'YHR056C',
#   'YLR095C',
#   'YNL230C',
#   'YFR032C-B',
#   'YIR021W-A',
#   'YDR052C',
#   'YBR215W',
#   'YKR101W',
#   'YMR172W',
#   'YDR501W',
#   'YHL049C',
#   'YLR162W-A',
#   'YLR091W',
#   'YOR189W',
#   'YNL042W-B',
#   'YER080W',
#   'YDR457W',
#   'YPL020C',
#   'YNL309W',
#   'YNR035C',
#   'YOR073W',
#   'YLR273C',
#   'YLR162W',
#   'YBR184W',
#   'YER054C',
#   'YAL044W-A',
#   'YGR134W',
#   'YGR098C',
#   'YBL031W',
#   'YDR310C',
#   'YIL031W',
#   'YPL278C',
#   'YCL068C',
#   'YHR086W-A',
#   'YER111C',
#   'YLR161W',
#   'YJL019W',
#   'YMR094W',
#   'YOR178C',
#   'YOR066W',
#   'YNL225C',
#   'YBR072C-A',
#   'YNL295W',
#   'YLR159W',
#   'YPR040W',
#   'YBL088C',
#   'YLR154W-C',
#   'YML054C-A',
#   'YHR154W',
#   'YOL013W-A',
#   'YBL078C',
#   'YLR368W',
#   'YDL129W',
#   'YBR150C',
#   'YJR115W',
#   'YNL254C',
#   'YJL023C',
#   'YGL071W',
#   'YLR430W',
#   'YDR374C',
#   'YJR140C',
#   'YGR232W',
#   'YGL013C',
#   'YDR520C',
#   'YDL159W-A',
#   'YMR179W',
#   'YOR161C-C',
#   'YDR331W',
#   'YOR344C',
#   'YML076C',
#   'YNL239W'],
#  '3.1.3': ['YCR095C',
#   'YDR063W',
#   'YDR051C',
#   'YKR053C',
#   'YJL016W',
#   'YIL002C',
#   'YPL267W',
#   'YGR147C',
#   'YBR022W',
#   'YFR028C',
#   'YPL237W',
#   'YLR019W',
#   'YLR177W',
#   'YPR042C',
#   'YIL113W',
#   'YER020W',
#   'YJL134W',
#   'YOR322C',
#   'YDL236W',
#   'YDL115C',
#   'YDR085C',
#   'YKL129C',
#   'YPL071C',
#   'YMR044W',
#   'YLR048W',
#   'YMR016C',
#   'YDR528W',
#   'YNR032W',
#   'YNL222W',
#   'YLL010C',
#   'YKL128C',
#   'YER075C',
#   'YJR094C',
#   'YLR433C',
#   'YAR071W',
#   'YBR173C',
#   'YJL081C',
#   'YGR208W',
#   'YML053C',
#   'YGL129C',
#   'YJL155C',
#   'YBR242W',
#   'YOR131C',
#   'YML118W',
#   'YKR091W',
#   'YJR110W',
#   'YPL263C',
#   'YKR075C',
#   'YMR156C',
#   'YCL061C',
#   'YOL064C',
#   'YOR283W',
#   'YBL081W',
#   'YNL255C',
#   'YMR130W',
#   'YNL010W',
#   'YDL234C',
#   'YJL010C',
#   'YBL054W',
#   'YFR017C',
#   'YDR066C',
#   'YDR503C',
#   'YGL126W',
#   'YKL185W',
#   'YJL115W',
#   'YOR098C',
#   'YIR026C',
#   'YEL038W',
#   'YNL233W',
#   'YLR377C',
#   'YDR287W',
#   'YER134C',
#   'YBR125C',
#   'YAL029C',
#   'YLL013C',
#   'YBR053C',
#   'YDL006W',
#   'YDR162C',
#   'YNL144C',
#   'YIL053W',
#   'YGL014W',
#   'YKL159C',
#   'YNL035C',
#   'YMR195W',
#   'YDR481C',
#   'YNL224C',
#   'YMR277W',
#   'YDL188C',
#   'YDR319C',
#   'YKL033W-A',
#   'YNL076W',
#   'YNL042W',
#   'YBL056W',
#   'YBR093C',
#   'YBR050C',
#   'YGR222W',
#   'YDR088C',
#   'YMR135C',
#   'YOL065C',
#   'YNL325C',
#   'YNL032W',
#   'YMR165C',
#   'YNR014W',
#   'YOR208W',
#   'YHR044C',
#   'YMR283C',
#   'YDL047W',
#   'YDL186W',
#   'YKL212W',
#   'YHR215W',
#   'YER030W',
#   'YOR110W',
#   'YBL031W',
#   'YMR109W',
#   'YER033C',
#   'YGL004C',
#   'YOR242C',
#   'YER019C-A',
#   'YER089C',
#   'YNL056W',
#   'YHR012W',
#   'YER133W',
#   'YLR046C',
#   'YKL213C',
#   'YNL074C',
#   'YGL092W',
#   'YJR091C',
#   'YNL099C',
#   'YBL043W',
#   'YJR065C',
#   'YGL221C',
#   'YOR155C',
#   'YDR003W',
#   'YER088C',
#   'YGR079W',
#   'YPR073C',
#   'YDR239C',
#   'YGL178W',
#   'YOR049C',
#   'YHR158C',
#   'YKR077W',
#   'YHR004C',
#   'YHR160C',
#   'YFL013C',
#   'YER037W',
#   'YFR025C',
#   'YGL224C',
#   'YDR075W',
#   'YHR202W',
#   'YHR043C',
#   'YCL051W',
#   'YPL179W',
#   'YML121W',
#   'YLR417W',
#   'YLR345W',
#   'YDR284C',
#   'YPL250C',
#   'YPL063W',
#   'YNL128W',
#   'YOR315W',
#   'YHR076W',
#   'YNL053W',
#   'YCR079W',
#   'YER139C',
#   'YMR204C',
#   'YLR330W',
#   'YKL093W',
#   'YMR137C',
#   'YOR316C',
#   'YDR067C',
#   'YIL023C',
#   'YMR257C',
#   'YGR100W',
#   'YNL054W',
#   'YCR015C',
#   'YHR100C',
#   'YPL249C',
#   'YNL094W',
#   'YKR068C',
#   'YER062C',
#   'YDL230W',
#   'YMR087W',
#   'YDL169C',
#   'YIL045W',
#   'YDR309C',
#   'YBL046W',
#   'YKL052C',
#   'YKL175W',
#   'YKL149C',
#   'YNL281W',
#   'YHR061C',
#   'YMR086W',
#   'YBR276C',
#   'YLR103C',
#   'YOR090C',
#   'YER156C',
#   'YMR070W',
#   'YNL108C',
#   'YML057W',
#   'YGL215W',
#   'YLR052W',
#   'YOR062C',
#   'YOR109W',
#   'YHR136C',
#   'YGL071W',
#   'YMR036C',
#   'YDL139C',
#   'YGR123C',
#   'YGL101W',
#   'YNL253W',
#   'YMR243C',
#   'YKR070W',
#   'YKL109W',
#   'YNR039C',
#   'YML119W',
#   'YGL108C',
#   'YML016C',
#   'YOR326W',
#   'YHR046C',
#   'YDR505C',
#   'YNR009W',
#   'YDR436W',
#   'YML081W',
#   'YNL106C',
#   'YMR206W',
#   'YHR146W',
#   'YDR365C',
#   'YMR273C',
#   'YDL134C',
#   'YML117W',
#   'YGL134W',
#   'YOR342C',
#   'YNL166C',
#   'YKL204W',
#   'YBR005W',
#   'YAR002W',
#   'YBR092C',
#   'YPL180W',
#   'YMR081C',
#   'YHR131C',
#   'YLR085C',
#   'YKR043C',
#   'YDL024C',
#   'YGR214W'],
#  '2.4.1': ['YBR180W',
#   'YCR089W',
#   'YGL198W',
#   'YDR281C',
#   'YKR058W',
#   'YOR192C',
#   'YGR149W',
#   'YLR258W',
#   'YAL010C',
#   'YPL076W',
#   'YGR223C',
#   'YPR107C',
#   'YGL142C',
#   'YIL067C',
#   'YLL006W',
#   'YMR149W',
#   'YJL059W',
#   'YNL038W',
#   'YBR043C',
#   'YER186C',
#   'YDR407C',
#   'YPL175W',
#   'YEL036C',
#   'YBR036C',
#   'YBR110W',
#   'YPR032W',
#   'YAL008W',
#   'YOR273C',
#   'YBR161W',
#   'YOR100C',
#   'YNL087W',
#   'YHR133C',
#   'YBR185C',
#   'YLR034C',
#   'YDR160W',
#   'YMR203W',
#   'YGR138C',
#   'YGR213C',
#   'YHR211W',
#   'YPL050C',
#   'YPL257W',
#   'YOR307C',
#   'YGR289C',
#   'YDR118W',
#   'YNL048W',
#   'YKR061W',
#   'YBR168W',
#   'YFR015C',
#   'YPL244C',
#   'YBL079W',
#   'YHL036W',
#   'YKR093W',
#   'YBR205W',
#   'YLR203C',
#   'YPR134W',
#   'YBR023C',
#   'YJL146W',
#   'YGR216C',
#   'YOR002W',
#   'YLR237W',
#   'YDR412W',
#   'YCL001W',
#   'YEL017W',
#   'YGR038W',
#   'YJL183W',
#   'YJL186W',
#   'YNR030W',
#   'YHR181W',
#   'YAL023C',
#   'YNL264C',
#   'YMR071C',
#   'YML114C',
#   'YBR015C',
#   'YBR038W',
#   'YER060W-A',
#   'YPR160W',
#   'YOL063C',
#   'YJL193W',
#   'YGR168C',
#   'YGL014W',
#   'YNL263C',
#   'YKR051W',
#   'YDL095W',
#   'YBR131W',
#   'YPR109W',
#   'YDL037C',
#   'YHR034C',
#   'YGR026W',
#   'YPL274W',
#   'YOR044W',
#   'YGR089W',
#   'YAR028W',
#   'YPL221W',
#   'YML047C',
#   'YER105C',
#   'YNL219C',
#   'YML100W',
#   'YOL129W',
#   'YDR231C',
#   'YPL122C',
#   'YJL004C',
#   'YOR099W',
#   'YPL145C',
#   'YNL029C',
#   'YMR059W',
#   'YOR166C',
#   'YHR120W',
#   'YDR307W',
#   'YNL127W',
#   'YPL107W',
#   'YNL080C',
#   'YOR149C',
#   'YDR275W',
#   'YGR189C',
#   'YNL131W',
#   'YPL254W',
#   'YGR132C',
#   'YML031W',
#   'YGL257C',
#   'YKL039W',
#   'YDR074W',
#   'YGR285C',
#   'YLR213C',
#   'YDL093W',
#   'YDR508C',
#   'YDR091C',
#   'YOR183W',
#   'YCL021W-A',
#   'YGR227W',
#   'YJR013W',
#   'YLL057C',
#   'YDL176W',
#   'YBL082C',
#   'YNL156C',
#   'YER140W',
#   'YGR174C',
#   'YGR065C',
#   'YNL273W',
#   'YOR147W',
#   'YIR014W',
#   'YKR039W',
#   'YDR483W',
#   'YLR350W',
#   'YLR436C',
#   'YLR417W',
#   'YAL053W',
#   'YER118C',
#   'YOR262W',
#   'YOR067C',
#   'YLR077W',
#   'YLR242C',
#   'YEL073C',
#   'YHR078W',
#   'YCR017C',
#   'YOR152C',
#   'YMR261C',
#   'YKL021C',
#   'YGL053W',
#   'YNL158W',
#   'YOR130C',
#   'YML072C',
#   'YGR037C',
#   'YIL085C',
#   'YNL137C',
#   'YDR476C',
#   'YJL139C',
#   'YGL047W',
#   'YOR365C',
#   'YER001W',
#   'YJR075W',
#   'YPL053C',
#   'YPR082C',
#   'YOR086C',
#   'YDR182W',
#   'YNL313C',
#   'YKL174C',
#   'YFL039C',
#   'YOR320C',
#   'YNL001W',
#   'YKR018C',
#   'YBR070C',
#   'YOR249C',
#   'YGR172C',
#   'YLR376C',
#   'YGR004W',
#   'YGR165W',
#   'YNL192W',
#   'YLL040C',
#   'YJR015W',
#   'YMR218C',
#   'YGL161C',
#   'YCL057C-A',
#   'YMR241W',
#   'YGL065C',
#   'YBR235W',
#   'YLR064W',
#   'YNR055C',
#   'YOR299W',
#   'YDR437W',
#   'YJL082W',
#   'YGR217W',
#   'YJR143C',
#   'YPL057C',
#   'YFR021W',
#   'YPL227C',
#   'YOR071C',
#   'YJR033C',
#   'YBR126C',
#   'YGR199W',
#   'YGL038C',
#   'YER060W',
#   'YPR183W',
#   'YIL090W',
#   'YAL009W',
#   'YHR214C-D',
#   'YIL114C',
#   'YOL109W',
#   'YLR088W',
#   'YIL014W',
#   'YML055W',
#   'YCL038C',
#   'YDR373W',
#   'YEL040W',
#   'YPR189W',
#   'YLL014W',
#   'YLR459W',
#   'YOR321W',
#   'YGL186C',
#   'YLR087C',
#   'YBL106C',
#   'YBR199W',
#   'YBR004C',
#   'YLR149C',
#   'YML115C',
#   'YEL011W',
#   'YGL139W',
#   'YKR030W',
#   'YJL118W',
#   'YMR292W',
#   'YGL112C',
#   'YDL180W',
#   'YMR005W',
#   'YKL190W',
#   'YPR156C',
#   'YLR324W',
#   'YJL137C'],
#  '3.4.16': ['YBR180W',
#   'YGL203C',
#   'YJL059W',
#   'YBR139W',
#   'YMR297W',
#   'YJR152W',
#   'YGR260W'],
#  '3.1.1': ['YBR180W',
#   'YPR117W',
#   'YDR125C',
#   'YPR157W',
#   'YBR068C',
#   'YCR041W',
#   'YPL119C-A',
#   'YNL270C',
#   'YDL086W',
#   'YBL029W',
#   'YMR132C',
#   'YKR089C',
#   'YBR069C',
#   'YFR026C',
#   'YJR107W',
#   'YML059C',
#   'YOL159C',
#   'YDL210W',
#   'YMR298W',
#   'YGR263C',
#   'YMR230W-A',
#   'YCL049C',
#   'YGL230C',
#   'YOL132W',
#   'YER014C-A',
#   'YAL049C',
#   'YPL038W-A',
#   'YLR036C',
#   'YOR369C',
#   'YKL183C-A',
#   'YML020W',
#   'YBR182C-A',
#   'YPR124W',
#   'YJR151W-A',
#   'YHR189W',
#   'YHR163W',
#   'YLR404W',
#   'YLR020C',
#   'YJL041W',
#   'YLR285C-A',
#   'YOR348C',
#   'YLR297W',
#   'YBR219C',
#   'YOL166W-A',
#   'YMR030W-A',
#   'YHR175W-A',
#   'YCR073W-A',
#   'YGR131W',
#   'YML052W',
#   'YNL268W',
#   'YCR043C',
#   'YEL063C',
#   'YJL145W',
#   'YAL037C-A',
#   'YGL262W',
#   'YOR059C',
#   'YNL115C',
#   'YGL168W',
#   'YDR171W',
#   'YBL042C',
#   'YNL019C',
#   'YNL291C',
#   'YOR081C',
#   'YNR061C',
#   'YCR068W',
#   'YKL091C',
#   'YDR142C',
#   'YAL063C-A',
#   'YIL089W',
#   'YGR206W',
#   'YGL144C',
#   'YMR008C',
#   'YHR213W-A',
#   'YER190C-B',
#   'YPL274W',
#   'YMR210W',
#   'YJR012C',
#   'YDR194W-A',
#   'YKL077W',
#   'YBL057C',
#   'YNL187W',
#   'YIL054W',
#   'YOR126C',
#   'YMR006C',
#   'YFL055W',
#   'YHR213W',
#   'YNL146W',
#   'YML018C',
#   'YPR149W',
#   'YMR131C',
#   'YEL056W',
#   'YGR236C',
#   'YML058W',
#   'YDL035C',
#   'YFR035C',
#   'YCL005W-A',
#   'YOR230W',
#   'YOR302W',
#   'YOR192C-C',
#   'YFL025C',
#   'YMR200W',
#   'YDR504C',
#   'YGL100W',
#   'YNL033W',
#   'YEL067C',
#   'YPL278C',
#   'YOL110W',
#   'YMR138W',
#   'YDR058C',
#   'YDR508C',
#   'YDL222C',
#   'YNR034W',
#   'YIL046W-A',
#   'YPL247C',
#   'YGL260W',
#   'YAR029W',
#   'YDL109C',
#   'YPL277C',
#   'YLL006W-A',
#   'YOR097C',
#   'YOR034C-A',
#   'YNL323W',
#   'YLR208W',
#   'YNL242W',
#   'YBR132C',
#   'YBR294W',
#   'YAL053W',
#   'YDR116C',
#   'YBR204C',
#   'YPL027W',
#   'YBR164C',
#   'YLR454W',
#   'YER188C-A',
#   'YDL218W',
#   'YLL052C',
#   'YHR173C',
#   'YBR296C',
#   'YKL094W',
#   'YGL194C-A',
#   'YKL018C-A',
#   'YOR011W-A',
#   'YOR376W-A',
#   'YER039C-A',
#   'YML025C',
#   'YLL061W',
#   'YGR248W',
#   'YDR438W',
#   'YOL164W-A',
#   'YNL012W',
#   'YKL221W',
#   'YGL115W',
#   'YDR114C',
#   'YDR367W',
#   'YDL022C-A',
#   'YHR214C-E',
#   'YBL071C-B',
#   'YNL142W',
#   'YLR104W',
#   'YLR092W',
#   'YMR122W-A',
#   'YDL219W',
#   'YML066C',
#   'YLR380W',
#   'YOL020W',
#   'YPR027C',
#   'YGL258W',
#   'YBL040C',
#   'YNL024C-A',
#   'YJL205C',
#   'YOL052C-A',
#   'YDR276C',
#   'YCR024C-B',
#   'YKL044W',
#   'YBR058C-A',
#   'YNR055C',
#   'YOL011W',
#   'YJR079W',
#   'YDR444W',
#   'YBR196C-A',
#   'YBL008W-A',
#   'YGR141W',
#   'YHL043W',
#   'YCL025C',
#   'YEL057C',
#   'YHR075C',
#   'YPL265W',
#   'YER175W-A',
#   'YOR022C',
#   'YPR063C',
#   'YLL012W',
#   'YMR313C',
#   'YGR240C-A',
#   'YOR293C-A',
#   'YOR387C',
#   'YER053C-A',
#   'YJL212C',
#   'YHR050W-A',
#   'YBR195C',
#   'YEL023C',
#   'YBR021W',
#   'YDR046C',
#   'YBR246W',
#   'YKL187C',
#   'YFL065C',
#   'YMR175W-A',
#   'YGR191W',
#   'YLR118C',
#   'YDR366C',
#   'YPL046C',
#   'YFL068W',
#   'YCR099C',
#   'YKL140W',
#   'YGL208W',
#   'YIL029C',
#   'YFR020W',
#   'YGL054C'],
#  '3.2.1': ['YPL056C',
#   'YPR026W',
#   'YEL025C',
#   'YJL216C',
#   'YCR094W',
#   'YBR223C',
#   'YOR190W',
#   'YFR026C',
#   'YIL162W',
#   'YLR261C',
#   'YKR005C',
#   'YOL157C',
#   'YMR244W',
#   'YMR196W',
#   'YOL132W',
#   'YLR144C',
#   'YKL046C',
#   'YGR213C',
#   'YMR305C',
#   'YGR287C',
#   'YCR075C',
#   'YGR282C',
#   'YMR215W',
#   'YNL097C-B',
#   'YAR066W',
#   'YDR001C',
#   'YGL027C',
#   'YJR039W',
#   'YOR072W-B',
#   'YLR084C',
#   'YGL156W',
#   'YBR162C',
#   'YLL066W-B',
#   'YBR229C',
#   'YHR142W',
#   'YLR300W',
#   'YHR204W',
#   'YIL014C-A',
#   'YGR275W',
#   'YBR299W',
#   'YOR186W',
#   'YBR054W',
#   'YCR100C',
#   'YNL199C',
#   'YDR261C',
#   'YJL171C',
#   'YPR153W',
#   'YCL002C',
#   'YMR175W',
#   'YMR242W-A',
#   'YCR021C',
#   'YGL028C',
#   'YKR042W',
#   'YNL067W-B',
#   'YER076C',
#   'YIL123W',
#   'YNL066W',
#   'YJR112W-A',
#   'YDR033W',
#   'YNR048W',
#   'YPR192W',
#   'YLR286C',
#   'YKR013W',
#   'YJR131W',
#   'YMR238W',
#   'YMR307W',
#   'YNR066C',
#   'YGR279C',
#   'YJR062C',
#   'YDR129C',
#   'YPR159W',
#   'YCR101C',
#   'YKL164C',
#   'YBR001C',
#   'YAL064C-A',
#   'YNR067C',
#   'YIL172C',
#   'YGR292W',
#   'YOL030W',
#   'YIL099W',
#   'YHR007C-A',
#   'YML054C-A',
#   'YLR173W',
#   'YLR154C-G',
#   'YML066C',
#   'YPR027C',
#   'YBL040C',
#   'YOL013W-A',
#   'YLR057W',
#   'YNR056C',
#   'YJL116C',
#   'YJR153W',
#   'YGR143W',
#   'YDR371W',
#   'YCL028W',
#   'YLR343W',
#   'YBR230W-A',
#   'YER185W',
#   'YJL160C',
#   'YBR056W',
#   'YGL006W-A',
#   'YOR197W',
#   'YMR182W-A',
#   'YJL221C',
#   'YHR214W',
#   'YML007W',
#   'YIR007W',
#   'YER066W'],
#  '1.11.1': ['YDR260C',
#   'YMR149W',
#   'YCR083W',
#   'YDR453C',
#   'YPL170W',
#   'YER071C',
#   'YLR036C',
#   'YHR211W',
#   'YKR066C',
#   'YML028W',
#   'YER150W',
#   'YKL154W',
#   'YDL004W',
#   'YPL282C',
#   'YBL064C',
#   'YDR256C',
#   'YIL010W',
#   'YJL144W',
#   'YBR244W',
#   'YAL063C',
#   'YDR322C-A',
#   'YIR037W',
#   'YCL035C',
#   'YGR088W',
#   'YLR104W',
#   'YDR524C-B',
#   'YBR024W',
#   'YFL010W-A',
#   'YLR109W',
#   'YLR179C',
#   'YKL026C',
#   'YOR394W',
#   'YHR214C-D',
#   'YMR182W-A',
#   'YBR014C',
#   'YAR050W'],
#  '3.4.24': ['YIL134C-A',
#   'YBR296C-A',
#   'YOR254C',
#   'YJL077W-B',
#   'YBR196C-B',
#   'YKL096C-B',
#   'YOR072W-B',
#   'YLR342W-A',
#   'YLR106C',
#   'YMR047C',
#   'YHR126C',
#   'YGR014W',
#   'YLR389C',
#   'YBR086C',
#   'YHL048C-A',
#   'YBL045C',
#   'YDR430C',
#   'YPR129W',
#   'YNR020C',
#   'YPR122W',
#   'YGR058W',
#   'YCR095W-A',
#   'YOL097W-A',
#   'YKL134C',
#   'YCL057W',
#   'YGR121W-A',
#   'YOL098C',
#   'YNL125C',
#   'YNL146C-A',
#   'YLR163C',
#   'YJR117W',
#   'YKR087C',
#   'YOL155W-A',
#   'YDR003W-A',
#   'YJL047C-A',
#   'YOL013W-A',
#   'YMR066W',
#   'YHR024C',
#   'YKL068W',
#   'YHR143W',
#   'YDR182W-A',
#   'YPR191W',
#   'YGL258W-A'],
#  '2.7.1': ['YDR051C',
#   'YLL035W',
#   'YFR053C',
#   'YOL136C',
#   'YOL137W',
#   'YCR054C',
#   'YMR053C',
#   'YOR035C',
#   'YGR205W',
#   'YJL173C',
#   'YJR049C',
#   'YGR194C',
#   'YLR220W',
#   'YFL053W',
#   'YGL253W',
#   'YJL155C',
#   'YLR240W',
#   'YDR248C',
#   'YNL267W',
#   'YDR236C',
#   'YOR119C',
#   'YMR208W',
#   'YHL032C',
#   'YGL126W',
#   'YDR017C',
#   'YOR311C',
#   'YKL065C',
#   'YIL107C',
#   'YPL258C',
#   'YOR347C',
#   'YKL001C',
#   'YER080W',
#   'YKL110C',
#   'YLR260W',
#   'YDR529C',
#   'YNL275W',
#   'YOL055C',
#   'YOR070C',
#   'YCL040W',
#   'YDR147W',
#   'YCR036W',
#   'YHR025W',
#   'YDR020C',
#   'YNR012W',
#   'YNL249C',
#   'YGR240C',
#   'YMR013C',
#   'YBR020W',
#   'YJL100W',
#   'YDR009W',
#   'YOR250C',
#   'YJR105W',
#   'YCR019W',
#   'YMR278W',
#   'YJL091C',
#   'YPL188W',
#   'YLR345W',
#   'YLL043W',
#   'YML070W',
#   'YDR072C',
#   'YEL029C',
#   'YGR068C',
#   'YLR133W',
#   'YDL208W',
#   'YKL047W',
#   'YDR531W',
#   'YNL158W',
#   'YDR315C',
#   'YPR121W',
#   'YDR109C',
#   'YGR262C',
#   'YMR205C',
#   'YLR446W',
#   'YLR154C-G',
#   'YLR104W',
#   'YAL038W',
#   'YPR184W',
#   'YFR007W',
#   'YPL214C',
#   'YOR171C',
#   'YHR155W',
#   'YNL129W',
#   'YEL041W',
#   'YKL004W',
#   'YDR516C',
#   'YDL146W',
#   'YIL090W',
#   'YFR032C',
#   'YDR196C',
#   'YNR027W',
#   'YGR121C',
#   'YOL102C',
#   'YNR059W',
#   'YDR173C',
#   'YDR208W'],
#  '1.6.5': ['YDR522C',
#   'YNL006W',
#   'YBR052C',
#   'YER004W',
#   'YBR078W',
#   'YPR021C',
#   'YNR074C',
#   'YML120C',
#   'YDR032C',
#   'YDR055W',
#   'YKL055C',
#   'YMR145C',
#   'YOL123W',
#   'YDL085W',
#   'YCR004C',
#   'YBR046C',
#   'YCL048W'],
#  '3.1.13': ['YJR007W',
#   'YDR392W',
#   'YMR229C',
#   'YDL233W',
#   'YML118W',
#   'YOR340C',
#   'YOL042W',
#   'YDR005C',
#   'YDR412W',
#   'YNL232W',
#   'YNR052C',
#   'YDR404C',
#   'YOL142W',
#   'YOL021C',
#   'YHR069C',
#   'YMR285C',
#   'YKL144C',
#   'YNL213C',
#   'YMR287C',
#   'YOL080C',
#   'YDR514C',
#   'YOR001W',
#   'YPL167C',
#   'YAL021C',
#   'YCL036W',
#   'YGR276C',
#   'YDR293C',
#   'YIL109C'],
#  '3.1.12': ['YBR163W', 'YHR164C'],
#  '2.7.7': ['YLL032C',
#   'YEL054C',
#   'YPR158W-B',
#   'YPL283C',
#   'YKL156W',
#   'YBL037W',
#   'YCR038C',
#   'YHR122W',
#   'YJL225C',
#   'YCR020C-A',
#   'YBL026W',
#   'Q0075',
#   'YHL017W',
#   'YGR021W',
#   'YDR210C-D',
#   'YCL050C',
#   'YJR145C',
#   'YCR035C',
#   'YMR055C',
#   'YGR109W-B',
#   'YGL068W',
#   'YDR407C',
#   'YER159C',
#   'YBR154C',
#   'YPL135W',
#   'YDR378C',
#   'YPL071C',
#   'YDR041W',
#   'YGR205W',
#   'YDR042C',
#   'YIL151C',
#   'YGL130W',
#   'YNL262W',
#   'YDL083C',
#   'YGL207W',
#   'YOR226C',
#   'YJL181W',
#   'YDL111C',
#   'YHR147C',
#   'YLR022C',
#   'YNL246W',
#   'YBR173C',
#   'YCR086W',
#   'YKL208W',
#   'YDL149W',
#   'YDR427W',
#   'YNL096C',
#   'YLR410W-B',
#   'YGR278W',
#   'YLL066C',
#   'YPL060W',
#   'YER113C',
#   'YIL082W-A',
#   'YBL093C',
#   'YNL139C',
#   'YBR012W-B',
#   'YAR009C',
#   'YOR355W',
#   'YKL135C',
#   'YNL102W',
#   'YOR142W-B',
#   'YDR418W',
#   'YDR254W',
#   'YBR247C',
#   'YBL090W',
#   'YNL177C',
#   'YGR024C',
#   'YGR010W',
#   'YLR381W',
#   'YOR068C',
#   'YLR325C',
#   'YJR030C',
#   'YDR225W',
#   'YJL124C',
#   'YOR207C',
#   'YDR249C',
#   'YBL100W-B',
#   'YLR053C',
#   'YOR159C',
#   'YDR034C-A',
#   'YDR034C-D',
#   'YER138W-A',
#   'YPL200W',
#   'YOL040C',
#   'YFR046C',
#   'YNL328C',
#   'YPR010C',
#   'YDR206W',
#   'YJR080C',
#   'YBL039W-B',
#   'YCL059C',
#   'YDR237W',
#   'YGL206C',
#   'YCL011C',
#   'YKL185W',
#   'YOR096W',
#   'YLR370C',
#   'YMR193W',
#   'YGR161C-D',
#   'YNL005C',
#   'YBR031W',
#   'YKR022C',
#   'YML039W',
#   'YBR009C',
#   'YMR143W',
#   'YLR127C',
#   'YML129C',
#   'YDR089W',
#   'YFL017W-A',
#   'YNL147W',
#   'YER190W',
#   'YDR238C',
#   'YNL299W',
#   'YML098W',
#   'YNL284C-B',
#   'YBR111C',
#   'YJR005W',
#   'YJL049W',
#   'YDR439W',
#   'YOL145C',
#   'YML045W',
#   'YBR120C',
#   'YIR021W',
#   'YDL102W',
#   'YGR235C',
#   'YGR046W',
#   'YGR020C',
#   'YOR026W',
#   'YNR022C',
#   'YLL007C',
#   'YER146W',
#   'YDR501W',
#   'YLR157C-B',
#   'YDR104C',
#   'YGR090W',
#   'YBL080C',
#   'YGR140W',
#   'YOR151C',
#   'YLR018C',
#   'YDR280W',
#   'YNL054W-B',
#   'YLR035C-A',
#   'YGR076C',
#   'YER041W',
#   'YOR167C',
#   'YNL085W',
#   'YNL004W',
#   'YJR029W',
#   'YLR114C',
#   'YLR275W',
#   'YJL131C',
#   'YOR334W',
#   'YOR164C',
#   'YNL031C',
#   'YMR234W',
#   'YIL133C',
#   'YDR014W-A',
#   'YGL105W',
#   'YBR122C',
#   'YNR046W',
#   'YDR365W-B',
#   'YGR038C-B',
#   'YGL123W',
#   'YDL045C',
#   'YHR187W',
#   'YJL113W',
#   'YHR203C',
#   'YDL130W-A',
#   'YPL218W',
#   'YPL045W',
#   'YDR419W',
#   'YOR166C',
#   'YHR021C',
#   'YAR033W',
#   'YAL011W',
#   'YMR045C',
#   'YIL075C',
#   'YGR027W-B',
#   'YPL195W',
#   'YGR195W',
#   'YOL115W',
#   'YDR261C-D',
#   'YAL044W-A',
#   'YOR006C',
#   'YDR012W',
#   'YKL056C',
#   'YFL062W',
#   'YER093C',
#   'YDR261W-B',
#   'YPR056W',
#   'YDR224C',
#   'YNL265C',
#   'YER160C',
#   'YNL289W',
#   'YOR033C',
#   'YMR077C',
#   'YGL173C',
#   'YIR008C',
#   'YHL012W',
#   'YEL051W',
#   'YOR343W-B',
#   'YLR150W',
#   'YKR063C',
#   'YKL138C',
#   'YDR086C',
#   'YKR027W',
#   'YPR085C',
#   'YAL016W',
#   'YML003W',
#   'YJR010W',
#   'YPR010C-A',
#   'YBR029C',
#   'YDR263C',
#   'R0040C',
#   'YHR111W',
#   'YER165W',
#   'YLR346C',
#   'YCL047C',
#   'YBR283C',
#   'YIL008W',
#   'YDR110W',
#   'YER029C',
#   'YPL173W',
#   'YIL098C',
#   'YDR530C',
#   'YFL036W',
#   'YJL044C',
#   'YGR116W',
#   'YLR417W',
#   'YNL284C',
#   'YMR312W',
#   'YLR049C',
#   'YJR027W',
#   'YJL083W',
#   'YJR022W',
#   'YJR123W',
#   'YAL042W',
#   'YKL160W',
#   'YKL113C',
#   'YOR116C',
#   'YKR085C',
#   'YGR007W',
#   'YIL093C',
#   'YJL136W-A',
#   'YNL078W',
#   'YOR001W',
#   'YDR545W',
#   'YDL208W',
#   'YGR202C',
#   'YOR396W',
#   'YBL003C',
#   'YAL031C',
#   'YGL147C',
#   'YPL067C',
#   'YJL011C',
#   'YGR258C',
#   'YML025C',
#   'YDL132W',
#   'YOR341W',
#   'YPR030W',
#   'YER138C',
#   'YMR257C',
#   'YDR210W-B',
#   'YKL089W',
#   'YOR210W',
#   'YDL055C',
#   'YNL113W',
#   'YFL050C',
#   'YHR027C',
#   'YNL339C',
#   'YML002W',
#   'YDL127W',
#   'YCR014C',
#   'YMR181C',
#   'YBL014C',
#   'YOR193W',
#   'YDR316W-B',
#   'YBR251W',
#   'YDR405W',
#   'YGR261C',
#   'YDL105W',
#   'YCL019W',
#   'YGR277C',
#   'YGL169W',
#   'YMR158W',
#   'YPR094W',
#   'YML009C',
#   'YPL118W',
#   'YPR182W',
#   'YPR175W',
#   'YMR178W',
#   'YOL103W-B',
#   'YGR047C',
#   'YER168C',
#   'YBR278W',
#   'YJL156C',
#   'YLR376C',
#   'YLR264W',
#   'YAL037W',
#   'YJL065C',
#   'YKL057C',
#   'YLR368W',
#   'YMR218C',
#   'YPR174C',
#   'YKR002W',
#   'Q0050',
#   'YPR137C-B',
#   'YOR158W',
#   'YNL040W',
#   'YDR351W',
#   'YFL002W-A',
#   'YNL178W',
#   'YFL027C',
#   'YEL034W',
#   'YBL005W-B',
#   'YBR079C',
#   'YBL055C',
#   'YBL035C',
#   'YMR256C',
#   'YDR004W',
#   'YBL002W',
#   'YLR116W',
#   'YMR050C',
#   'YHR214C-B',
#   'YKL040C',
#   'YJL062W-A',
#   'YDL089W',
#   'YGR161W-B',
#   'YIL177C',
#   'YJR006W',
#   'YGR158C',
#   'YDL140C',
#   'YPL222W',
#   'YOR224C',
#   'YOR192C-B',
#   'YCL058C',
#   'YDR082W',
#   'YDR045C',
#   'YLR467W',
#   'YDR298C',
#   'R0010W',
#   'YDR165W',
#   'YPR110C',
#   'Q0060',
#   'YDL179W',
#   'YBR262C',
#   'Q0055',
#   'YDL147W',
#   'YHR143W-A',
#   'YLR219W',
#   'YMR175W-A',
#   'YLR227W-B',
#   'YDR277C',
#   'YLR328W',
#   'YMR123W',
#   'YGR016W',
#   'YOR048C',
#   'YCL036W',
#   'YPR158C-D',
#   'YPL075W',
#   'YLR318W',
#   'YBR010W',
#   'YKL035W',
#   'YNL310C',
#   'YOR346W',
#   'YJL080C',
#   'YKL080W',
#   'YDR108W',
#   'YOR115C',
#   'YLR438C-A',
#   'YLR005W',
#   'YNL030W',
#   'YNL221C',
#   'YPR029C',
#   'YDR098C-B',
#   'YGR296W',
#   'YJL099W',
#   'YJL154C',
#   'YIL132C',
#   'YDL040C',
#   'YBR018C',
#   'YIL021W',
#   'YPL257W-B',
#   'YDL103C'],
#  '7.1.1': ['YOR065W',
#   'Q0085',
#   'YLR164W',
#   'Q0065',
#   'YOR266W',
#   'YIL157C',
#   'YDL030W',
#   'YGL226W',
#   'YKL207W',
#   'YIR024C',
#   'YBL039W-B',
#   'YML129C',
#   'YPL163C',
#   'YJL166W',
#   'YBR120C',
#   'YDL067C',
#   'YJR048W',
#   'YKR065C',
#   'Q0105',
#   'YGL020C',
#   'YPR153W',
#   'YDL130W',
#   'YJL161W',
#   'Q0120',
#   'YHR175W',
#   'YEL024W',
#   'Q0110',
#   'Q0250',
#   'YDR105C',
#   'YCL005W-A',
#   'YBR269C',
#   'YOR297C',
#   'YOR049C',
#   'YIL111W',
#   'Q0070',
#   'YDR119W-A',
#   'YBR283C',
#   'YIL070C',
#   'YGL187C',
#   'Q0275',
#   'YDR527W',
#   'YIL093C',
#   'YMR240C',
#   'Q0045',
#   'YOL077W-A',
#   'YLR378C',
#   'YDR079W',
#   'YBR268W',
#   'YLL027W',
#   'YLR201C',
#   'YCL044C',
#   'YMR118C',
#   'YPL215W',
#   'YEL039C',
#   'YPL047W',
#   'YDR107C',
#   'YOR123C',
#   'YER072W',
#   'YLR262C-A',
#   'YDR377W',
#   'YLR083C',
#   'YJL062W-A',
#   'YDL081C',
#   'YDR178W',
#   'Q0080',
#   'YGR016W',
#   'YNL310C'],
#  '3.1.4': ['YLR097C',
#   'YGR266W',
#   'YJL198W',
#   'YBR194W',
#   'YMR102C',
#   'YHR132W-A',
#   'YHR058C',
#   'YIL135C',
#   'YER119C',
#   'YPL071C',
#   'YGR237C',
#   'YBR119W',
#   'YHL023C',
#   'YGR072W',
#   'YGR247W',
# ...
#   'YBR149W',
#   'YJR156C',
#   'YJR139C',
#   'YNL274C',
#   'YGL001C',
#   'YDL138W',
#   'YMR011W',
#   'YER081W',
#   'YOR378W',
#   'YMR318C',
#   'YLR081W',
#   'YGL256W',
#   'YDR077W',
#   'YLL056C',
#   'YAL061W',
#   'YPL033C',
#   'YOR120W',
#   'YMR200W',
#   'YDL168W',
#   'YDR197W',
#   'YOL151W',
#   'YDR345C',
#   'YML056C',
#   'YHR063C',
#   'YPL088W',
#   'YNL044W',
#   'YNL055C',
#   'YPL151C',
#   'YCR107W',
#   'YCR105W',
#   'YDL144C',
#   'YDR342C',
#   'YNR073C',
#   'YDL124W',
#   'YLR426W',
#   'YNL331C',
#   'YEL020W-A',
#   'YBR008C',
#   'YBR145W',
#   'YHR092C',
#   'YLR432W',
#   'YOL163W',
#   'YGL157W',
#   'YMR303C',
#   'YGR256W',
#   'YNR072W',
#   'YPL032C',
#   'YDR343C',
#   'YIL094C',
#   'YNL332W',
#   'YGL185C',
#   'YDL078C',
#   'YLR070C',
#   'YBR265W',
#   'YEL070W',
#   'YJL219W',
#   'YDR541C',
#   'YJR155W',
#   'YJR158W',
#   'YHL004W',
#   'YIR036C',
#   'YMR083W',
#   'YFL058W',
#   'YOR136W',
#   'YBR153W',
#   'YIR042C',
#   'YLR450W',
#   'YDL246C',
#   'YLR355C',
#   'YOL165C',
#   'YML075C',
#   'YDL243C',
#   'YMR226C',
#   'YIL124W',
#   'YGL077C',
#   'YGL039W',
#   'YLR412C-A',
#   'YOL059W',
#   'YHR216W',
#   'YPR127W',
#   'YCL048W-A',
#   'YDL244W',
#   'YHR094C',
#   'YKL071W',
#   'YGR215W',
#   'YOL086C',
#   'YDL245C',
#   'YNL181W',
#   'YLL055W',
#   'YKL085W',
#   'YHR104W'],
#  '1.14.13': ['YBL098W',
#   'YNR032C-A',
#   'YNR053C',
#   'YPL034W',
#   'YAL048C',
#   'YFR043C',
#   'YMR097C',
#   'YDR296W',
#   'YIL057C',
#   'YCL059C',
#   'YHR176W',
#   'YGL099W',
#   'YOR205C',
#   'YNR024W',
#   'YJR050W',
#   'YJR014W',
#   'YOL114C',
#   'YML050W',
#   'YJR150C',
#   'YMR311C',
#   'YMR023C',
#   'YLL057C',
#   'YBR298C',
#   'YPL108W',
#   'YDR163W',
#   'YDR473C',
#   'YDR534C',
#   'YGR129W',
#   'YDR336W',
#   'YJR005C-A',
#   'YCR071C',
#   'YLR281C',
#   'YCR063W',
#   'YDL039C',
#   'YLR157W-D',
#   'YDR402C',
#   'YPR181C',
#   'YLR110C'],
#  '1.2.1': ['YBR006W',
#   'YPL061W',
#   'YJR009C',
#   'YDL085C-A',
#   'YHR037W',
#   'YER073W',
#   'YDR158W',
#   'YMR169C',
#   'YDL208W',
#   'YGR192C',
#   'YPL098C',
#   'YMR110C',
#   'YMR170C',
#   'YPR163C',
#   'YHR039C',
#   'YOR374W',
#   'YLR363W-A',
#   'YOR323C',
#   'YJL052W'],
#  '1.14.14': ['YGR223C',
#   'YPR159C-A',
#   'YPR036W-A',
#   'YDR192C',
#   'YBR037C',
#   'YKL183C-A',
#   'YCL001W',
#   'YBR137W',
#   'YCR050C',
#   'YAL065C',
#   'YCR095W-A',
#   'YGR035C',
#   'YNL273W',
#   'YHR007C',
#   'YLR436C',
#   'YAL064W',
#   'YGR175C',
#   'YGR172C',
#   'YDL039C',
#   'YIL004C',
#   'YLR205C',
#   'YJL151C'],
#  '1.2.4': ['YML124C',
#   'YML085C',
#   'YDL160C-A',
#   'YFR049W',
#   'YIL125W',
#   'YDR115W',
#   'YDR462W',
#   'YMR225C',
#   'YMR003W',
#   'YBR221C',
#   'YPL183W-A',
#   'YER050C',
#   'YER178W',
#   'YOR265W'],
#  '1.4.4': ['YMR189W'],
#  '7.2.1': ['Q0130',
#   'YOR103C',
#   'YPL234C',
#   'YDR347W',
#   'YPR194C',
#   'YDR302W',
#   'YGR284C',
#   'YDR384C',
#   'YDR100W',
#   'YHR026W',
#   'YKR085C',
#   'YIL093C',
#   'YNL237W',
#   'YNR002C',
#   'YLR295C',
#   'YEL027W',
#   'YCR010C'],
#  '1.4.1': ['YAL062W', 'YMR097C', 'YOR375C'],
#  '3.1.11': ['YOR304C-A',
#   'YNL262W',
#   'YDL209C',
#   'YIL007C',
#   'YBL097W',
#   'YNL210W',
#   'YBR088C',
#   'YKL017C',
#   'YKL119C',
#   'YIL002W-A',
#   'YNR046W',
#   'YDR357C',
#   'YML061C',
#   'YDL135C',
#   'YFR011C',
#   'YMR048W',
#   'YGR048W',
#   'YDR263C',
#   'YOL080C',
#   'YOR368W',
#   'YOL095C',
#   'YKR016W',
#   'YKL113C',
#   'YLR059C',
#   'YDR514C',
#   'YPR004C',
#   'YOR001W',
#   'YLR384C',
#   'YGR258C',
#   'YPL194W',
#   'YOR293W',
#   'YKL142W',
#   'YHR079C-A',
#   'YNL001W',
#   'YMR230W',
#   'YLR288C',
#   'YER082C',
#   'YLR200W',
#   'YMR112C',
#   'YJR006W',
#   'YOR330C',
#   'YGR093W',
#   'YGR276C',
#   'YBL019W',
#   'YLR107W',
#   'YER063W'],
#  '2.1.3': ['YKR035W-A',
#   'YML052W',
#   'YBR086C',
#   'YGR181W',
#   'YHR196W',
#   'YJL088W',
#   'YKL142W',
#   'YDR164C',
#   'YPR031W'],
#  '1.11.2': ['YDR084C',
#   'YLR191W',
#   'YKL006C-A',
#   'YBL102W',
#   'YDL123W',
#   'YBR056W-A',
#   'YNL131W',
#   'YOR045W',
#   'YPL098C',
#   'YER147C',
#   'YGL231C',
#   'YJR010C-A',
#   'YPR020W',
#   'YNL208W',
#   'YLL014W'],
#  '3.4.23': ['YPL154C',
#   'YDL054C',
#   'YPR125W',
#   'YLR034C',
#   'YCR028C',
#   'YMR155W',
#   'YMR221C',
#   'YDR144C',
#   'YFL026W',
#   'YBR298C-A',
#   'YHL016C',
#   'YIL015W',
#   'YBR054W',
#   'YCR021C',
#   'YAL022C',
#   'YIR039C',
#   'YDR033W',
#   'YHR050W',
#   'YMR063W',
#   'YCL066W',
#   'YDR349C',
#   'YOL122C',
#   'YGL259W',
#   'YGR055W',
#   'YDR461W',
#   'YLR120C',
#   'YCR040W',
#   'YLR121C',
#   'YOR247W',
#   'YGL032C',
#   'YLL055W'],
#  '3.4.14': ['YHR028C',
#   'YOR219C',
#   'YNL065W',
#   'YKR104W',
#   'YCR023C',
#   'YDR534C',
#   'YLL048C',
#   'YOL057W',
#   'YOR361C',
#   'YBL008W'],
#  '1.7.5': ['YKL141W'],
#  '4.5.1': ['YMR202W', 'YPL048W', 'YLL009C'],
#  '4.1.1': ['YNL169C',
#   'YNR007C',
#   'YGR087C',
#   'YML100W-A',
#   'YJR047C',
#   'YBR170C',
#   'YNR043W',
#   'YMR034C',
#   'YLL028W',
#   'YNL052W',
#   'YDR380W',
#   'YDL080C',
#   'YDL014W',
#   'YLR044C',
#   'YKL088W',
#   'YBL036C',
#   'YKR072C',
#   'YBL001C',
#   'YEL021W',
#   'YOR128C',
#   'YKR097W',
#   'YKL100C',
#   'YOL052C',
#   'YKL184W',
#   'YDR539W',
#   'YGR112W',
#   'YER010C',
#   'YDR047W',
#   'YMR250W',
#   'YLR134W',
#   'YAL020C',
#   'YOL139C'],
#  '1.17.5': ['YGR095C', 'YER007C-A'],
#  '1.3.1': ['YGL080W',
#   'YLR218C',
#   'YBR213W',
#   'YOR292C',
#   'YDL015C',
#   'YJR051W',
#   'YML051W',
#   'YIL024C',
#   'YKR069W',
#   'YLR460C',
#   'YBR166C',
#   'YKL107W',
#   'YIL049W',
#   'YLR405W',
#   'YMR152W',
#   'YAL055W',
#   'YNR015W',
#   'YGL012W',
#   'YJL104W',
#   'YER101C',
#   'YCR102C',
#   'YHR179W',
#   'YML080W',
#   'YML131W',
#   'YEL026W',
#   'YBL069W',
#   'YNL280C',
#   'YBR026C',
#   'YGR112W',
#   'YLR401C',
#   'YGR207C',
#   'YHR094C',
#   'YEL047C',
#   'YNL202W',
#   'YPL171C'],
#  '1.5.5': ['YOR356W', 'YLR142W'],
#  '5.1.3': ['YMR099C',
#   'YBL091C-A',
#   'YHR210C',
#   'YNR071C',
#   'YKL070W',
#   'YBR019C',
#   'YJL121C'],
#  '6.3.4': ['YNL119W',
#   'YBR218C',
#   'YBL039C',
#   'YOL058W',
#   'YGL062W',
#   'YDL141W',
#   'YNL220W',
#   'YJR103W',
#   'YOR209C',
#   'YGR204W',
#   'YGL234W',
#   'YBR084W'],
#  '1.16.1': ['YLR448W',
#   'YMR149W',
#   'YLR047C',
#   'YER004W',
#   'YML073C',
#   'YOR228C',
#   'YLL051C',
#   'YOR383C',
#   'YOR381W',
#   'YOL152W',
#   'YML052W',
#   'YNR060W',
#   'YBR040W',
#   'YNL194C',
#   'YNR061C',
#   'YIL063C',
#   'YIL133C',
#   'YNL190W',
#   'YLR414C',
#   'YNL322C',
#   'YNL300W',
#   'YFR012W',
#   'YFL050C',
#   'YOR122C',
#   'YPL279C',
#   'YOR384W',
#   'YDR542W',
#   'YOR390W',
#   'YOL101C',
#   'YLR214W',
#   'YHR214C-D',
#   'YKL220C',
#   'YGL160W'],
#  '6.3.2': ['YOR241W',
#   'YAR015W',
#   'YLR215C',
#   'YJL101C',
#   'YML101C',
#   'YOL049W',
#   'YIL145C',
#   'YIL083C',
#   'YKL132C',
#   'YBR094W',
#   'YMR113W'],
#  '3.4.25': ['YEL048C',
#   'YFR050C',
#   'YER012W',
#   'YJL001W',
#   'YOR157C',
#   'YOR362C',
#   'YOL038W',
#   'YGR135W',
#   'YMR314W',
#   'YBL041W',
#   'YER094C',
#   'YML092C',
#   'YGL011C',
#   'YGR253C',
#   'YPR103W'],
#  '3.3.2': ['YLL006W',
#   'YOL009C',
#   'YHR194W',
#   'YDR214W',
#   'YNL045W',
#   'YLR193C',
#   'YCR042C',
#   'YDR352W',
#   'YBL040C',
#   'YLR168C',
#   'YDR185C',
#   'YBR074W'],
#  '1.8.1': ['YPL091W',
#   'YER180C-A',
#   'YPL132W',
#   'YKR052C',
#   'YOR281C',
#   'YLR043C',
#   'YER174C',
#   'YFR030W',
#   'YNR062C',
#   'YFL018C',
#   'YPL107W',
#   'YOR298C-A',
#   'YKL167C',
#   'YPL017C',
#   'YDR353W',
#   'YHR106W',
#   'YGR209C',
#   'YDR205W',
#   'YMR244C-A',
#   'YKR036C',
#   'YPL134C',
#   'YDR098C'],
#  '1.97.1': ['YMR149W', 'YHR213W'],
#  '4.1.2': ['YEL046C',
#   'YHR195W',
#   'YMR262W',
#   'YJL170C',
#   'YDR294C',
#   'YKL060C',
#   'YEL020C'],
#  '5.5.1': ['YDR322W',
#   'YHR199C',
#   'YHR055C',
#   'YHR198C',
#   'YOR316C-A',
#   'YDR540C',
#   'YBR172C',
#   'YOL092W',
#   'YJL153C',
#   'YLR157W-D',
#   'YHR053C'],
#  '2.7.12': ['YIL112W',
#   'YJL110C',
#   'YOL128C',
#   'YOR371C',
#   'YOR385W',
#   'YGL170C',
#   'YPL140C',
#   'YOR231W',
#   'YKR010C',
#   'YER032W',
#   'YJL141C',
#   'YGR239C',
#   'YGR225W',
#   'YBR083W',
#   'YJL090C',
#   'YPL124W',
#   'YDR014W',
#   'YDR043C',
#   'YDR523C',
#   'YDL225W',
#   'YPR141C',
#   'YLR320W',
#   'YBR156C',
#   'YKR099W',
#   'YDL079C',
#   'YJL133W',
#   'YDL159W',
#   'YBL007C',
#   'YAL056W',
#   'YLR054C',
#   'YNL196C',
#   'YPR005C',
#   'YJR089W',
#   'YDL028C',
#   'YKR090W',
#   'YJL128C',
#   'YFR023W',
#   'YDR218C',
#   'YPL177C',
#   'YHL027W',
#   'YGL216W',
#   'YHR154W',
#   'YGR166W',
#   'YPR171W',
#   'YDR369C',
#   'YHR015W',
#   'YDR351W',
#   'YLL019C',
#   'YBR152W',
#   'YMR216C',
#   'YNR009W',
#   'YPR106W',
#   'YDR524C',
#   'YPL068C',
#   'YGR188C',
#   'YBR148W',
#   'YDR446W',
#   'YPL155C',
#   'YJL076W',
#   'YDR130C'],
#  '1.4.3': ['YJL077W-B',
#   'YPL071C',
#   'YOL038C-A',
#   'YLR125W',
#   'YDR317W',
#   'YNL138W-A',
#   'YIL089W',
#   'YHR009C',
#   'YPR096C',
#   'YPR145C-A',
#   'YBR035C',
#   'YCL054W-A',
#   'YPL108W',
#   'YPL225W',
#   'YFR033C',
#   'YGL188C-A',
#   'YFL041W-A',
#   'YCL001W-A',
#   'YGL236C',
#   'YCL001W-B'],
#  '1.14.16': ['YOL005C', 'YGR063C', 'YKL047W'],
#  '4.99.1': ['YER186C',
#   'YPL099C',
#   'YBR213W',
#   'YHR021W-A',
#   'YOR012W',
#   'YKR069W',
#   'YOR301W',
#   'YOR357C',
#   'YER115C',
#   'YNR046W',
#   'YEL076C',
#   'YML050W',
#   'YDR262W',
#   'YLR456W',
#   'YLR464W',
#   'YHL042W',
#   'YEL076C-A',
#   'YNL277W-A',
#   'YPR203W',
#   'YBR151W',
#   'YOL139C',
#   'YGL127C',
#   'YOR176W'],
#  '1.8.4': ['YBL049W',
#   'YKL069W',
#   'YER042W',
#   'YML129C',
#   'YPR017C',
#   'YML079W',
#   'YDR183W',
#   'YPR167C',
#   'YCL033C',
#   'YLL009C',
#   'YPR100W'],
#  '1.3.5': ['YJL045W', 'YLL018C-A', 'YKL148C', 'YLL041C', 'YER136W', 'YPL252C'],
#  '1.15.1': ['YMR038C',
#   'YDR461C-A',
#   'YJR104C',
#   'YER011W',
#   'YPL187W',
#   'YGL089C',
#   'YJR101W',
#   'YHR008C'],
#  '2.6.1': ['YHR208W',
#   'YLR438W',
#   'YNR077C',
#   'YIL087C',
#   'YER152C',
#   'YDR111C',
#   'YOR072W-B',
#   'YJR148W',
#   'YNL145W',
#   'YNR033W',
#   'YOR295W',
#   'YIL116W',
#   'YPR052C',
#   'YGR243W',
#   'YHR137W',
#   'YMR084W',
#   'YNR058W',
#   'YMR085W',
#   'YKL104C',
#   'YER137C',
#   'YBR201C-A',
#   'YHR162W',
#   'YOL140W',
#   'YDL208W',
#   'YDL029W',
#   'YMR233W',
#   'YGL202W',
#   'YKL106W',
#   'YJR085C',
#   'YFL030W',
#   'YLR089C',
#   'YLR201C',
#   'YIR018C-A',
#   'YCL044C',
#   'YJR122W',
#   'YLR027C',
#   'YJL060W',
#   'YOR184W',
#   'YGR019W',
#   'YLR333C',
#   'YDL157C',
#   'YDR204W',
#   'YCR108C'],
#  '1.1.99': ['YGR255C',
#   'YDL178W',
#   'YBR298C-A',
#   'YML052W',
#   'YJL077W-A',
#   'YCL005W-A',
#   'YIR028W',
#   'YEL071W',
#   'YLR154C-G'],
#  '6.3.1': ['YPR035W', 'YJL046W', 'YIR019C', 'YLR143W'],
#  '1.23.5': ['YLR099W-A', 'YJL066C', 'YDR179W-A', 'YDL046W', 'YKR046C'],
#  '6.4.1': ['YBR218C',
#   'YLR337C',
#   'YMR207C',
#   'YNR016C',
#   'YOL130W',
#   'YJL133C-A',
#   'YGL062W'],
#  '2.3.3': ['YOR108W',
#   'YNL104C',
#   'YDL131W',
#   'YIR031C',
#   'YNR001C',
#   'YCR005C',
#   'YML126C',
#   'YPR001W',
#   'YNL117W',
#   'YDL182W'],
#  '1.3.8': ['YLL018C-A', 'YGL091C', 'YPL252C', 'YIL003W'],
#  '2.4.99': ['YFR026C', 'YGL022W', 'YOR306C'],
#  '3.3.1': ['YER043C'],
#  '5.3.2': ['YOR273C', 'YER087C-B'],
#  '1.5.1': ['YER004W',
#   'YKR080W',
#   'YCL026C-A',
#   'YIR034C',
#   'YER023W',
#   'YGL125W',
#   'YCL026C-B',
#   'YMR090W',
#   'YNL055C',
#   'YOR236W',
#   'YNR050C',
#   'YPL023C',
#   'YLR011W',
#   'YCR028C-A'],
#  '4.2.99': ['YPL131W', 'YOL043C', 'YER001W', 'YAL015C'],
#  '1.1.2': ['YDL174C', 'YML054C', 'YGR008C'],
#  '2.2.1': ['YMR108W', 'YGR043C', 'YLR354C', 'YBR117C', 'YCL009C', 'YPR074C'],
#  '7.4.2': ['YLR034C', 'YDL005C', 'YKL189W'],
#  '1.6.2': ['YOR037W',
#   'YIL043C',
#   'YPR048W',
#   'YML125C',
#   'YKL150W',
#   'YHR042W',
#   'YML087C'],
#  '2.8.3': ['YJL081C'],
#  '1.2.99': ['YPL130W'],
#  '2.7.2': ['YDR300C', 'YER052C', 'YHR033W', 'YER069W', 'YCR012W'],
#  '6.5.1': ['YOL010W',
#   'YGL043W',
#   'YDL227C',
#   'YJL087C',
#   'YMR201C',
#   'YDL164C',
#   'YPR041W',
#   'YFR041C',
#   'YOR005C'],
#  '5.4.2': ['YKL127W',
#   'YFL045C',
#   'YDL021W',
#   'YMR105C',
#   'YEL058W',
#   'YOL056W',
#   'YKL152C'],
#  '3.5.4': ['YCL030C',
#   'YBR146W',
#   'YMR024W',
#   'YLR316C',
#   'YPR062W',
#   'YGR267C',
#   'YNR034W-A',
#   'YJL035C',
#   'YML032C',
#   'YHR144C',
#   'YML035C',
#   'YJL070C',
#   'YGR163W',
#   'YLR028C',
#   'YMR120C',
#   'YJR144W',
#   'YOR009W',
#   'YAL064W-B',
#   'YNL141W',
#   'YDL169C',
#   'YDL059C',
#   'YDL238C',
#   'YBR230W-A',
#   'YBR284W',
#   'YHR170W',
#   'YGL243W',
#   'YBL033C',
#   'YLR245C'],
#  '7.5.2': ['YIL166C',
#   'YNL279W',
#   'YPL058C',
#   'YNR070W',
#   'YBR297W',
#   'YLR413W',
#   'YOR153W',
#   'YGR288W',
#   'YDR011W',
#   'YLR004C',
#   'YFL052W'],
#  '1.12.1': ['YCR075W-A',
#   'YPR172W',
#   'YML108W',
#   'YAR064W',
#   'YNL240C',
#   'YML058W-A',
#   'YHR213W-B',
#   'YBR221W-A'],
#  '1.8.5': ['YKR076W', 'YHR001W-A', 'YPL059W', 'YEL001C'],
#  '1.14.19': ['YDL183C',
#   'YNL100W',
#   'YGR033C',
#   'YMR015C',
#   'YGL055W',
#   'YDR297W',
#   'YLR056W'],
#  '4.7.1': ['YHR072W-A'],
#  '4.3.3': ['YFL060C', 'YNL334C', 'YMR096W', 'YFL059W', 'YNL333W', 'YMR095C'],
#  '1.14.11': ['YER049W',
#   'YIR003W',
#   'YMR176W',
#   'YHL021C',
#   'YLL057C',
#   'YGR142W',
#   'YER051W',
#   'YKL195W',
#   'YGR053C',
#   'YJR119C',
#   'YER169W',
#   'YJR154W'],
#  '5.4.4': ['YOR228C'],
#  '1.12.98': ['YDR493W',
#   'YBR189W',
#   'YIL133C',
#   'YDR511W',
#   'YPL081W',
#   'YDR379C-A',
#   'YBR283C',
#   'YER048W-A',
#   'YDR107C',
#   'YAL046C'],
#  '5.3.1': ['YLR291C',
#   'YPR118W',
#   'YIL020C',
#   'YER003C',
#   'YKR026C',
#   'YDR050C',
#   'YDR007W',
#   'YBR196C',
#   'YOR095C'],
#  '2.8.4': ['YER067W',
#   'YHL046C',
#   'YER121W',
#   'YPL211W',
#   'YMR295C',
#   'YGR020C',
#   'YKR057W',
#   'YOL165C',
#   'YDL223C'],
#  '1.17.4': ['YGR180C',
#   'YFL004W',
#   'YBR015C',
#   'YML123C',
#   'YER070W',
#   'YPL019C',
#   'YPL223C',
#   'YIL066C',
#   'YJL026W'],
#  '3.5.2': ['YGR196C',
#   'YIR027C',
#   'YPL219W',
#   'YMR274C',
#   'YMR219W',
#   'YLR223C',
#   'YOR372C',
#   'YDR113C',
#   'YEL052W',
#   'YLR420W',
#   'YDR022C',
#   'YFR036W',
#   'YJR092W',
#   'YKR096W',
#   'YDR223W'],
#  '3.5.3': ['YEL007W',
#   'YIR029W',
#   'YGL240W',
#   'YLR187W',
#   'YPL111W',
#   'YOL149W',
#   'YDR374C',
#   'YHR124W',
#   'YNL278W'],
#  '3.4.17': ['YPL176C',
#   'YJL172W',
#   'YJR126C',
#   'YHR132C',
#   'YPL096C-A',
#   'YPL006W',
#   'YOR256C'],
#  '1.17.1': ['YOR388C'],
#  '6.6.1': ['YOR068C', 'YGR031C-A'],
#  '3.8.1': ['YNR064C'],
#  '7.2.2': ['YDR270W',
#   'YMR279C',
#   'YGL167C',
#   'YGL006W',
#   'YML116W',
#   'YKL217W',
#   'YBR127C',
#   'YGR062C',
#   'YBR295W',
#   'YLR130C',
#   'YOR316C',
#   'YOR079C',
#   'YGL255W'],
#  '6.3.5': ['YJR109C',
#   'YGR124W',
#   'YGR061C',
#   'YBR208C',
#   'YML096W',
#   'YHR074W',
#   'YMR293C',
#   'YPR145W',
#   'YJL130C',
#   'YKL215C',
#   'YOR303W',
#   'YMR217W'],
#  '1.20.4': ['YGR203W',
#   'YHR001W-A',
#   'YPR200C',
#   'YNL259C',
#   'YDR286C',
#   'YKR049C',
#   'YLL050C',
#   'YOR285W'],
#  '1.2.5': ['YBR085C-A', 'YPL152W-A', 'YOL039W', 'YBL071W-A'],
#  '1.2.7': ['YFR032C-A', 'YMR236W'],
#  '7.3.2': ['YPR169W',
#   'YOR313C',
#   'YDL100C',
#   'YDR406W',
#   'YPR085C',
#   'YOR153W',
#   'YKL133C',
#   'YOR328W'],
#  '4.3.1': ['YGL196W', 'YPL086C', 'YER086W', 'YCL064C', 'YKL218C'],
#  '5.3.3': ['YJR135W-A',
#   'YPL117C',
#   'YJL077C',
#   'YNL044W',
#   'YHR029C',
#   'YLR284C',
#   'YOR180C'],
#  '2.8.1': ['YGL211W',
#   'YOR286W',
#   'YOR026W',
#   'YOR196C',
#   'YDL033C',
#   'YOR251C',
#   'YHR111W',
#   'YCL017C',
#   'YGR286C'],
#  '1.8.98': ['YBR193C',
#   'YIL070C',
#   'YKL086W',
#   'YMR029C',
#   'YDR361C',
#   'YDR527W',
#   'YDR168W',
#   'YHR196W',
#   'YDR013W',
#   'YHR060W'],
#  '1.1.5': ['YIL155C'],
#  '1.21.99': ['YOR085W', 'YAR031W', 'YML019W', 'YDR476C', 'YLR393W'],
#  '1.1.3': ['YML086C', 'YOR370C'],
#  '3.1.7': ['YPL161C', 'YIL127C', 'YER153C', 'YDR088C', 'YKL099C', 'YIL017C'],
#  '1.14.17': ['YCL052C', 'YJL002C', 'YHR188C'],
#  '1.3.3': ['YER014W', 'YGL205W', 'YDR044W', 'YMR072W'],
#  '7.2.4': ['YLR040C',
#   'YBR162W-A',
#   'YPL037C',
#   'YDR252W',
#   'YLR065C',
#   'YER074W-A'],
#  '4.3.2': ['YBR248C', 'YER163C', 'YHR018C', 'YLR359W', 'YIR032C'],
#  '4.1.99': ['YDR087C', 'YDR487C', 'YOR386W', 'YEL004W', 'YOL154W', 'YDR403W'],
#  '5.1.99': ['YIR030C', 'YEL015W', 'YNL200C'],
#  '1.17.99': ['YER141W'],
#  '3.1.30': ['YJL208C'],
#  '2.8.2': ['YER044C', 'YGL257C'],
#  '1.18.6': ['YDL045W-A', 'YKL137W', 'YLL009C', 'YJR034W'],
#  '1.13.11': ['YLR066W', 'YMR009W', 'YHR191C', 'YJR008W', 'YJR078W', 'YJR025C'],
#  '1.8.99': ['YLR435W', 'YLR333C'],
#  '6.3.3': ['YNR057C', 'YKL206C', 'YER183C', 'YBL001C', 'YGL234W', 'YAL020C'],
#  '1.8.7': ['YER078W-A', 'YMR116C'],
#  '1.7.7': ['YDL053C'],
#  '2.7.3': ['YOL156W', 'YIL102C-A', 'YGL235W'],
#  '3.5.5': ['YDR175C', 'YIL165C', 'YIL164C'],
#  '3.5.99': ['YER057C', 'YML050W', 'YCR020C', 'YIL051C'],
#  '5.1.1': ['YOR054C'],
#  '2.1.2': ['YBR176W',
#   'YLR028C',
#   'YMR120C',
#   'YDR019C',
#   'YBR263W',
#   'YDR408C',
#   'YBL013W',
#   'YLR058C'],
#  '1.7.6': ['YML128C'],
#  '1.18.1': ['YDR376W', 'YMR211W'],
#  '3.7.1': ['YLR231C', 'YNL168C'],
#  '1.12.2': ['YBL108C-A', 'YPR016C'],
#  '1.5.3': ['YMR020W', 'YLR251W'],
#  '1.14.12': ['YGR234W'],
#  '1.14.18': ['YGR060W', 'YMR272C', 'YAL067C', 'YGL010W'],
#  '3.1.6': ['YGL246C'],
#  '1.2.3': ['YOR260W'],
#  '7.1.3': ['YOR079C'],
#  '1.3.98': ['YKL216W'],
#  '3.1.31': ['YGL085W'],
#  '3.6.2': ['YDL125C'],
#  '1.6.99': ['YPL171C']}

# %%
DeepEC_gene2ec_dict = get_gene2ec_dict_DeepEC(DeepEC_path)
DeepEC_ec2gene_dict = get_ec2gene_dict_DeepEC(DeepEC_gene2ec_dict)
print(len(DeepEC_ec2gene_dict))
DeepEC_ec2gene_dict
# Out:
# 142
# {'2.7.11': ['YNL167C',
#   'YPR161C',
#   'YPL042C',
#   'YDR490C',
#   'YPL203W',
#   'YFL009W',
#   'YLR358C',
#   'YFR014C',
#   'YNR047W',
#   'YCR008W',
#   'YBL105C',
#   'YHR030C',
#   'YPL009C',
#   'YOR351C',
#   'YPL248C',
#   'YPR054W',
#   'YNL195C',
#   'YHR102W',
#   'YHR135C',
#   'YBR059C',
#   'YDL189W',
#   'YGL179C',
#   'YLR410W-B',
#   'YOL100W',
#   'YKL171W',
#   'YDL017W',
#   'YLL021W',
#   'YOR119C',
#   'YCR091W',
#   'YBL100W-B',
#   'YHR159W',
#   'YDL025C',
#   'YDR485C',
#   'YPL140C',
#   'YDR477W',
#   'YOR231W',
#   'YDR034C-D',
#   'YBR097W',
#   'YJL010C',
#   'YER032W',
#   'YDL108W',
#   'YOR358W',
#   'YOR098C',
#   'YLR310C',
#   'YDL211C',
#   'YML114C',
#   'YIL095W',
#   'YOL016C',
#   'YLR371W',
#   'YPL031C',
#   'YOL027C',
#   'YKL166C',
#   'YOR233W',
#   'YDR507C',
#   'YCR067C',
#   'YPR109W',
#   'YDR523C',
#   'YNL161W',
#   'YGL117W',
#   'YER008C',
#   'YMR144W',
#   'YLR320W',
#   'YDR122W',
#   'YMR001C',
#   'YBL016W',
#   'YDR147W',
#   'YJR059W',
#   'YNL172W',
#   'YNL091W',
#   'YOR032C',
#   'YDR247W',
#   'YNL298W',
#   'YNL197C',
#   'YJL164C',
#   'YDR466W',
#   'YPR111W',
#   'YNL207W',
#   'YAL011W',
#   'YMR124W',
#   'YPL236C',
#   'YDR310C',
#   'YDL028C',
#   'YDL101C',
#   'YNL243W',
#   'YBR081C',
#   'YIL031W',
#   'YDR261W-B',
#   'YNL183C',
#   'YNL074C',
#   'YDR054C',
#   'YNL265C',
#   'YPL254W',
#   'YKL116C',
#   'YMR247C',
#   'YPL204W',
#   'YOR216C',
#   'YOR343W-B',
#   'YNL020C',
#   'YPL014W',
#   'YLR248W',
#   'YDL214C',
#   'YMR291W',
#   'YGR052W',
#   'YGL178W',
#   'YGR040W',
#   'YPL141C',
#   'YPL115C',
#   'YMR093W',
#   'YER123W',
#   'YER111C',
#   'YJL128C',
#   'YNL027W',
#   'YFR019W',
#   'YGL016W',
#   'YOR267C',
#   'YJL057C',
#   'YLR208W',
#   'YFL029C',
#   'YJL206C',
#   'YIL159W',
#   'YIR033W',
#   'YKL020C',
#   'YLR345W',
#   'YKL105C',
#   'YKL161C',
#   'YPL150W',
#   'YOR287C',
#   'YJL042W',
#   'YHL007C',
#   'YLR096W',
#   'YJL207C',
#   'YHL027W',
#   'YPR178W',
#   'YAL031C',
#   'YDR210W-B',
#   'YBR140C',
#   'YHR082C',
#   'YGR262C',
#   'YPL026C',
#   'YOL053W',
#   'YPL109C',
#   'YDR283C',
#   'YGL116W',
#   'YJR083C',
#   'YCL019W',
#   'YMR086W',
#   'YGL003C',
#   'YDR422C',
#   'YGR009C',
#   'YKR095W',
#   'YLR113W',
#   'YJL061W',
#   'YKL057C',
#   'YOR227W',
#   'YIL055C',
#   'YGR179C',
#   'YMR276W',
#   'YPR018W',
#   'YFL002W-A',
#   'YGL259W',
#   'YKL101W',
#   'YMR139W',
#   'YNL253W',
#   'YOL081W',
#   'YPL209C',
#   'YOL051W',
#   'YMR216C',
#   'YGR161W-B',
#   'YDR285W',
#   'YMR104C',
#   'YOL045W',
#   'YOR192C-B',
#   'YLR362W',
#   'YHR205W',
#   'YML103C',
#   'YAR019C',
#   'YNL154C',
#   'YPR106W',
#   'YGR092W',
#   'YGL180W',
#   'YGR188C',
#   'YBR274W',
#   'YJL187C',
#   'YER129W',
#   'YBR108W',
#   'YIL035C',
#   'YPL075W',
#   'YCL024W',
#   'YCR072C',
#   'YKR034W',
#   'YPR029C',
#   'YHR079C',
#   'YOL113W',
#   'YCR084C',
#   'YHR073W'],
#  '3.1.2': ['YJL068C',
#   'YML059C',
#   'YJL039C',
#   'YOR221C',
#   'YDR036C',
#   'YOR098C',
#   'YLR069C',
#   'YJL095W',
#   'YGR014W',
#   'YBL015W',
#   'YDR501W',
#   'YHR034C',
#   'YGL144C',
#   'YDR272W',
#   'YPR005C',
#   'YER111C',
#   'YDR388W',
#   'YDL013W',
#   'YGR103W',
#   'YBR033W',
#   'YOL051W',
#   'YMR317W',
#   'YOR040W',
#   'YDL216C',
#   'YFR005C',
#   'YBR275C'],
#  '2.4.1': ['YHR077C',
#   'YOR161C',
#   'YLR258W',
#   'YPL076W',
#   'YFL007W',
#   'YKL219W',
#   'YGL142C',
#   'YHL017W',
#   'YLR164W',
#   'YNL038W',
#   'YPL175W',
#   'YBR110W',
#   'YMR076C',
#   'YJL039C',
#   'YER113C',
#   'YJL117W',
#   'YPR028W',
#   'YDL072C',
#   'YMR306W',
#   'YIL087C',
#   'YNL048W',
#   'YFR015C',
#   'YBR023C',
#   'YFL026W',
#   'YCL001W',
#   'YGR038W',
#   'YAL023C',
#   'YER190W',
#   'YBR038W',
#   'YPR160W',
#   'YGR014W',
#   'YDL095W',
#   'YBR302C',
#   'YLR305C',
#   'YJL159W',
#   'YJR118C',
#   'YML047C',
#   'YDL112W',
#   'YDR307W',
#   'YDR406W',
#   'YOR149C',
#   'YMR247C',
#   'YDL093W',
#   'YIR028W',
#   'YGR227W',
#   'YBL082C',
#   'YER140W',
#   'YIR033W',
#   'YOR067C',
#   'YDL199C',
#   'YDR072C',
#   'YMR319C',
#   'YLR342W',
#   'YDR338C',
#   'YGL047W',
#   'YFR012W',
#   'YJR137C',
#   'YPL189W',
#   'YML132W',
#   'YOR320C',
#   'YNL192W',
#   'YGL065C',
#   'YDR437W',
#   'YJR143C',
#   'YPL227C',
#   'YOR071C',
#   'YBR126C',
#   'YGR199W',
#   'YDL089W',
#   'YPR183W',
#   'YMR317W',
#   'YAL009W',
#   'YLR241W',
#   'YDR420W',
#   'YKL014C',
#   'YOR321W',
#   'YBR004C',
#   'YEL011W',
#   'YGL139W'],
#  '3.4.19': ['YHR077C',
#   'YCR089W',
#   'YHL013C',
#   'YER151C',
#   'YBR058C',
#   'YDR069C',
#   'YPR144C',
#   'YOR124C',
#   'YDR517W',
#   'YIL060W',
#   'YNL312W',
#   'YMR223W',
#   'YJR099W',
#   'YLR095C',
#   'YDR227W',
#   'YKR098C',
#   'YOR051C',
#   'YGR014W',
#   'YLR389C',
#   'YER098W',
#   'YGL093W',
#   'YNL023C',
#   'YIL115C',
#   'YNL172W',
#   'YML097C',
#   'YJL197W',
#   'YPR122W',
#   'YNL127W',
#   'YBR273C',
#   'YIL031W',
#   'YLR439W',
#   'YMR019W',
#   'YMR247C',
#   'YDR511W',
#   'YFR010W',
#   'YKL105C',
#   'YLR032W',
#   'YIL156W',
#   'YBL004W',
#   'YPR030W',
#   'YER144C',
#   'YMR304W',
#   'YIL101C',
#   'YAL064W',
#   'YBL046W',
#   'YNL186W',
#   'YOR140W',
#   'YML037C',
#   'YFR040W',
#   'YFL044C',
#   'YPL191C',
#   'YBL067C',
#   'YMR317W',
#   'YJL176C',
#   'YDL216C',
#   'YJR043C',
#   'YKL189W',
#   'YFR005C',
#   'YNL084C',
#   'YDR420W',
#   'YDL122W',
#   'YJL154C',
#   'YPL072W'],
#  '3.6.5': ['YHR077C',
#   'YNL090W',
#   'YNL064C',
#   'YKR055W',
#   'YMR076C',
#   'YOR101W',
#   'YLR229C',
#   'YLL001W',
#   'YBR118W',
#   'YOR187W',
#   'YLR069C',
#   'YNL180C',
#   'YKR014C',
#   'YGR014W',
#   'YLR262C',
#   'YFL038C',
#   'YDR172W',
#   'YNL236W',
#   'YOL023W',
#   'YIL118W',
#   'YLR289W',
#   'YCR027C',
#   'YFL005W',
#   'YOR211C',
#   'YPR165W',
#   'YGR152C',
#   'YNL098C',
#   'YNL093W',
#   'YCL014W',
#   'YER025W',
#   'YPR080W',
#   'YKR046C',
#   'YJL102W'],
#  '2.7.1': ['YHR077C',
#   'YJR041C',
#   'YPR042C',
#   'YNL218W',
#   'YJR090C',
#   'YJR049C',
#   'YMR076C',
#   'YLR447C',
#   'YGR194C',
#   'YCR098C',
#   'YJL155C',
#   'YLR240W',
#   'YDR248C',
#   'YDR236C',
#   'YPL226W',
#   'YMR208W',
#   'YHL032C',
#   'YNL123W',
#   'YDR326C',
#   'YLR152C',
#   'YHL019C',
#   'YNR013C',
#   'YPL174C',
#   'YCR093W',
#   'YDL220C',
#   'YMR161W',
#   'YOR347C',
#   'YKL001C',
#   'YNL085W',
#   'YLR320W',
#   'YDR335W',
#   'YDR147W',
#   'YNL236W',
#   'YCR036W',
#   'YOR011W',
#   'YHR025W',
#   'YNR012W',
#   'YNL249C',
#   'YMR247C',
#   'YGR240C',
#   'YMR013C',
#   'YBR020W',
#   'YIR012W',
#   'YJL100W',
#   'YNL014W',
#   'YDR009W',
#   'YOR173W',
#   'YJR105W',
#   'YER059W',
#   'YPL188W',
#   'YML070W',
#   'YEL029C',
#   'YLR133W',
#   'YDR180W',
#   'YOR316C',
#   'YDR531W',
#   'YDR315C',
#   'YGR218W',
#   'YMR205C',
#   'YAL038W',
#   'YPL214C',
#   'YNL321W',
#   'YBL089W',
#   'YEL041W',
#   'YOR056C',
#   'YOL081W',
#   'YDR196C',
#   'YGR188C',
#   'YNR027W',
#   'YFL033C',
#   'YOL102C',
#   'YGR093W',
#   'YDL195W',
#   'YDR208W',
#   'YER006W',
#   'YJL137C'],
#  '3.1.21': ['YHR077C',
#   'YMR188C',
#   'YHL014C',
#   'YNL005C',
#   'YNL153C',
#   'YJL145W',
#   'YMR218C',
#   'YNL212W',
#   'YKL114C',
#   'YBR275C',
#   'YDL040C'],
#  '2.7.9': ['YPL240C'],
#  '7.1.2': ['YPL036W', 'YBL099W', 'YJR121W', 'YGL008C', 'YDL185W'],
#  '2.7.4': ['YDL166C',
#   'YGR173W',
#   'YKL024C',
#   'YDL192W',
#   'YDL137W',
#   'YKL067W',
#   'YHL019C',
#   'YPL258C',
#   'YDR226W',
#   'YMR220W',
#   'YGR222W',
#   'YKR037C',
#   'YJR057W',
#   'YOR181W',
#   'YDR454C',
#   'YMR280C',
#   'YER170W',
#   'YBR164C',
#   'YLR410W'],
#  '1.8.1': ['YBR180W',
#   'YPL091W',
#   'YOL088C',
#   'YLR043C',
#   'YFL018C',
#   'YPL017C',
#   'YDR353W',
#   'YHR106W',
#   'YGR209C'],
#  '2.7.7': ['YDR063W',
#   'YEL054C',
#   'YLR097C',
#   'YBL037W',
#   'YCR038C',
#   'YDR392W',
#   'YHR058C',
#   'YPR042C',
#   'YDR210C-D',
#   'YOR162C',
#   'YGR109W-B',
#   'YJL190C',
#   'YGR205W',
#   'YGL130W',
#   'YNL262W',
#   'YPR125W',
#   'YJL181W',
#   'YLR022C',
#   'YOR269W',
#   'YDR493W',
#   'YIL082W-A',
#   'YBR012W-B',
#   'YNL102W',
#   'YOR142W-B',
#   'YDR418W',
#   'YMR191W',
#   'YGR024C',
#   'YGR010W',
#   'YLR381W',
#   'YOR207C',
#   'YBR136W',
#   'YNL318C',
#   'YPR010C',
#   'YOR098C',
#   'YOL131W',
#   'YOR311C',
#   'YGR161C-D',
#   'YML039W',
#   'YHL019C',
#   'YNL299W',
#   'YNL284C-B',
#   'YML045W',
#   'YDR087C',
#   'YDL102W',
#   'YGR046W',
#   'YLR233C',
#   'YHL030W',
#   'YLR157C-B',
#   'YOR151C',
#   'YLR035C-A',
#   'YGR026W',
#   'YJR029W',
#   'YHL022C',
#   'YDR235W',
#   'YLR425W',
#   'YGR038C-B',
#   'YOL156W',
#   'YNL236W',
#   'YBR087W',
#   'YDR419W',
#   'YMR045C',
#   'YNL127W',
#   'YOL115W',
#   'YDR261C-D',
#   'YLR081W',
#   'YLR067C',
#   'YER160C',
#   'YDR211W',
#   'YNL131W',
#   'YDR334W',
#   'YOR243C',
#   'YOR343W-B',
#   'YKL192C',
#   'YDR345C',
#   'YER137C',
#   'YNL140C',
#   'YJR010W',
#   'YBR029C',
#   'YHR111W',
#   'YCL047C',
#   'YFL036W',
#   'YPR187W',
#   'YDR342C',
#   'YHR096C',
#   'YOR116C',
#   'YLR059C',
#   'YMR240C',
#   'YLR130C',
#   'YGR202C',
#   'YPL078C',
#   'YOR341W',
#   'YGR170W',
#   'YHR092C',
#   'YER138C',
#   'YMR257C',
#   'YDR210W-B',
#   'YOR210W',
#   'YJR137C',
#   'YDL055C',
#   'YNL113W',
#   'YAL051W',
#   'YJL024C',
#   'YNL142W',
#   'YDR316W-B',
#   'YLR380W',
#   'YDR343C',
#   'YGL169W',
#   'YOL103W-B',
#   'YJL219W',
#   'YGR165W',
#   'YKR002W',
#   'Q0050',
#   'YPR137C-B',
#   'YGL164C',
#   'YJR158W',
#   'YER092W',
#   'YCR061W',
#   'YCR033W',
#   'YBL005W-B',
#   'YDR179W-A',
#   'YPL265W',
#   'YKR078W',
#   'YMR050C',
#   'YNL260C',
#   'YDL140C',
#   'YOR330C',
#   'YOR192C-B',
#   'YKR020W',
#   'YBR275C',
#   'YKL125W',
#   'YDL179W',
#   'Q0055',
#   'YKL010C',
#   'YGR084C',
#   'YLR328W',
#   'YHR094C',
#   'YLR318W',
#   'YKL035W',
#   'YLR367W',
#   'YDL245C',
#   'YNL221C',
#   'YCR046C',
#   'YDR098C-B',
#   'YNL159C',
#   'YBR018C',
#   'YDL180W',
#   'YIL021W',
#   'YML076C',
#   'YJR068W',
#   'YPL257W-B',
#   'YDL103C'],
#  '3.2.1': ['YCR089W',
#   'YJL216C',
#   'YKR102W',
#   'YOR190W',
#   'YIL162W',
#   'YJL078C',
#   'YOL157C',
#   'YMR244W',
#   'YLR144C',
#   'YKL046C',
#   'YHR211W',
#   'YGR287C',
#   'YDR001C',
#   'YJR151C',
#   'YDR017C',
#   'YPL163C',
#   'YLR300W',
#   'YGR014W',
#   'YBR299W',
#   'YLR035C-A',
#   'YDL037C',
#   'YDR261C',
#   'YJL159W',
#   'YHR213W',
#   'YIR019C',
#   'YHR151C',
#   'YDR406W',
#   'YNL322C',
#   'YIL123W',
#   'YNL066W',
#   'YLR286C',
#   'YMR238W',
#   'YNR066C',
#   'YBR001C',
#   'YAL063C',
#   'YDR534C',
#   'YIL172C',
#   'YGR292W',
#   'YGL137W',
#   'YIL099W',
#   'YPL053C',
#   'YPR184W',
#   'YGL258W',
#   'YJR153W',
#   'YNL016W',
#   'YDR371W',
#   'YNL253W',
#   'YMR317W',
#   'YBR056W',
#   'YDR420W',
#   'YJL221C',
#   'YNR018W',
#   'YCR072C',
#   'YER187W',
#   'YBL008W',
#   'YAR050W'],
#  '1.11.1': ['YDR260C',
#   'YDR453C',
#   'YBL064C',
#   'YDR256C',
#   'YIL010W',
#   'YBR244W',
#   'YDR513W',
#   'YIR037W',
#   'YCL035C',
#   'YGR088W',
#   'YLR109W',
#   'YFR020W'],
#  '2.3.2': ['YDR177W',
#   'YOL089C',
#   'YLR375W',
#   'YNL119W',
#   'YMR269W',
#   'YIL106W',
#   'YPL099C',
#   'YML041C',
#   'YOR124C',
#   'YHR006W',
#   'YML023C',
#   'YOL054W',
#   'YKR005C',
#   'YER038C',
#   'YOL013C',
#   'YDL149W',
#   'YGR278W',
#   'YKL084W',
#   'YPR013C',
#   'YPR083W',
#   'YMR065W',
#   'YHL010C',
#   'YEL012W',
#   'YOR098C',
#   'YLL036C',
#   'YDR313C',
#   'YPL161C',
#   'YMR160W',
#   'YLR394W',
#   'YGL254W',
#   'YER068W',
#   'YLR418C',
#   'YFR018C',
#   'YBL034C',
#   'YER021W',
#   'YNL023C',
#   'YGL017W',
#   'YIL149C',
#   'YDR092W',
#   'YNR063W',
#   'YBL063W',
#   'YEL013W',
#   'YKR017C',
#   'YDR228C',
#   'YPR186C',
#   'YBR260C',
#   'YNL236W',
#   'YER125W',
#   'YBR062C',
#   'YIL079C',
#   'YLR427W',
#   'YOL069W',
#   'YIL031W',
#   'YPR056W',
#   'YLR272C',
#   'YDR425W',
#   'YDL240W',
#   'YDR143C',
#   'YJR136C',
#   'YDL048C',
#   'YKR090W',
#   'YOR380W',
#   'YJR134C',
#   'YOL133W',
#   'YDL073W',
#   'YLR431C',
#   'YGL060W',
#   'YDR460W',
#   'YMR026C',
#   'YOL044W',
#   'YDR323C',
#   'YLR007W',
#   'YDL170W',
#   'YBR297W',
#   'YCR106W',
#   'YOR177C',
#   'YML002W',
#   'YGL035C',
#   'YKL015W',
#   'YDR266C',
#   'YBL046W',
#   'YDR303C',
#   'YDR006C',
#   'YNL097C',
#   'YOR249C',
#   'YPR049C',
#   'YER184C',
#   'YKR095W',
#   'YBR150C',
#   'YKR007W',
#   'YPR015C',
#   'YDL074C',
#   'YLR116W',
#   'YGR184C',
#   'YOR363C',
#   'YGR071C',
#   'YER116C',
#   'YKR096W',
#   'YKL059C',
#   'YML068W',
#   'YPR008W',
#   'YDR141C',
#   'YOR156C',
#   'YCR066W',
#   'YIL129C',
#   'YAL014C',
#   'YOR339C',
#   'YAL047C',
#   'YLR299W',
#   'YOR172W',
#   'YPR093C',
#   'YJL056C',
#   'YGR246C',
#   'YNL077W'],
#  '1.3.1': ['YDR497C',
#   'YJR045C',
#   'YLL024C',
#   'YDL229W',
#   'YBR069C',
#   'YBR213W',
#   'YNL209W',
#   'YAL005C',
#   'YJR051W',
#   'YBR166C',
#   'YDR387C',
#   'YIL049W',
#   'YLR405W',
#   'YBL075C',
#   'YNR015W',
#   'YLR369W',
#   'YER103W',
#   'YML080W',
#   'YLR130C',
#   'YNL280C',
#   'YFR042W',
#   'YLR137W',
#   'YLR401C',
#   'YGR191W',
#   'YEL047C'],
#  '1.10.2': ['YOR065W'],
#  '3.6.1': ['YKR053C',
#   'YJL134W',
#   'YHL035C',
#   'YER036C',
#   'YCL030C',
#   'YBR011C',
#   'YMR267W',
#   'YGR036C',
#   'YCR011C',
#   'YKL188C',
#   'YBR252W',
#   'YGL067W',
#   'YOL075C',
#   'YOR111W',
#   'YOR173W',
#   'YOR262W',
#   'YKL209C',
#   'YFR009W',
#   'YJR069C',
#   'YLR109W',
#   'YCL016C',
#   'YDR394W',
#   'YGL136C',
#   'YLR270W',
#   'YEL042W',
#   'YDL125C',
#   'YDR305C',
#   'YDR452W',
#   'YHR073W'],
#  '3.1.3': ['YIL002C',
#   'YPR157W',
#   'YFR028C',
#   'YDR073W',
#   'YLR019W',
#   'YIL113W',
#   'YDL236W',
#   'YDL044C',
#   'YNR032W',
#   'YNL222W',
#   'YLL010C',
#   'YER075C',
#   'YLR433C',
#   'YAR071W',
#   'YOR138C',
#   'YGR208W',
#   'YJL155C',
#   'YBR242W',
#   'YOR131C',
#   'YJR110W',
#   'YOL064C',
#   'YBR289W',
#   'YNL010W',
#   'YGR203W',
#   'YIR026C',
#   'YEL038W',
#   'YHL019C',
#   'YLR377C',
#   'YGR229C',
#   'YDR287W',
#   'YBR125C',
#   'YDL006W',
#   'YDL220C',
#   'YBR131W',
#   'YLR305C',
#   'YDR481C',
#   'YAL017W',
#   'YMR277W',
#   'YDL188C',
#   'YBL056W',
#   'YBR093C',
#   'YJL002C',
#   'YNL032W',
#   'YMR165C',
#   'YOR208W',
#   'YPR122W',
#   'YDL047W',
#   'YKR037C',
#   'YHR215W',
#   'YJR052W',
#   'YER089C',
#   'YER133W',
#   'YLR439W',
#   'YMR048W',
#   'YOR155C',
#   'YPR073C',
#   'YIL017C',
#   'YCR057C',
#   'YAL002W',
#   'YDR074W',
#   'YLR341W',
#   'YHR004C',
#   'YFR025C',
#   'YGL016W',
#   'YMR029C',
#   'YDR075W',
#   'YNL242W',
#   'YPL179W',
#   'YJL042W',
#   'YLR059C',
#   'YHR076W',
#   'YNL053W',
#   'YCR079W',
#   'YER139C',
#   'YPL098C',
#   'YMR180C',
#   'YNL217W',
#   'YDL230W',
#   'YBR276C',
#   'YOR090C',
#   'YDR422C',
#   'YPL228W',
#   'YML057W',
#   'YMR147W',
#   'YGL071W',
#   'YMR036C',
#   'YGR123C',
#   'YGL101W',
#   'YML016C',
#   'YDL110C',
#   'YPL260W',
#   'YHR046C',
#   'YML111W',
#   'YLR129W',
#   'YDR436W',
#   'YNL106C',
#   'YMR030W',
#   'YDL134C',
#   'YNL034W',
#   'YBR092C',
#   'YFL024C',
#   'YDL024C'],
#  '3.4.11': ['YHR113W',
#   'YBR286W',
#   'YLL029W',
#   'YBL091C',
#   'YHR179W',
#   'YLR244C',
#   'YKL157W',
#   'YER078C',
#   'YHR047C'],
#  '3.6.4': ['YLL008W',
#   'YDL031W',
#   'YDR138W',
#   'YMR190C',
#   'YEL077C',
#   'YDR190C',
#   'YNL261W',
#   'YER013W',
#   'YPR007C',
#   'YPL119C',
#   'YER164W',
#   'YBR114W',
#   'YPL235W',
#   'YPL216W',
#   'YLR276C',
#   'YLR419W',
#   'YLL066C',
#   'YEL053C',
#   'YPL008W',
#   'YIR002C',
#   'YFL002C',
#   'YLL034C',
#   'YMR128W',
#   'YGR271W',
#   'YBR080C',
#   'YJR035W',
#   'YPL029W',
#   'YBR245C',
#   'YLR106C',
#   'YOR204W',
#   'YFR038W',
#   'YPR173C',
#   'YBL111C',
#   'YNR038W',
#   'YMR290C',
#   'YBR142W',
#   'YGR222W',
#   'YDR243C',
#   'YDL160C',
#   'YML061C',
#   'YPL245W',
#   'YOR011W',
#   'YGL171W',
#   'YOR117W',
#   'YLL026W',
#   'YER172C',
#   'YHL050C',
#   'YDR211W',
#   'YDL126C',
#   'YDR334W',
#   'YMR106C',
#   'YPR162C',
#   'YNL329C',
#   'YEL032W',
#   'YMR284W',
#   'YOR259C',
#   'YDR076W',
#   'YDR110W',
#   'YBR202W',
#   'YCL034W',
#   'YBL023C',
#   'YOR046C',
#   'YGL251C',
#   'YER047C',
#   'YER143W',
#   'YNR011C',
#   'YOR262W',
#   'YLL067C',
#   'YOL095C',
#   'YPR019W',
#   'YPL217C',
#   'YGL201C',
#   'YJL033W',
#   'YKL113C',
#   'YHR168W',
#   'YOR001W',
#   'YLR032W',
#   'YNL287W',
#   'YGR270W',
#   'YDR194C',
#   'YPR179C',
#   'YOR290C',
#   'YIL143C',
#   'YDL154W',
#   'YDR021W',
#   'YGL120C',
#   'YOR304W',
#   'YHR169W',
#   'YML082W',
#   'YDR164C',
#   'YLR368W',
#   'YLR398C',
#   'YNL290W',
#   'YBR237W',
#   'YKR024C',
#   'YKL197C',
#   'YKR059W',
#   'YBR073W',
#   'YGL078C',
#   'YPR204W',
#   'YER171W',
#   'YDR004W',
#   'YKL078W',
#   'YAL019W',
#   'YER017C',
#   'YJL194W',
#   'YJL034W',
#   'YJL138C',
#   'YHR031C',
#   'YJL092W',
#   'YGL163C',
#   'YOL090W',
#   'YGL048C',
#   'YIL126W',
#   'YHR065C',
#   'YDR332W',
#   'YLR274W',
#   'YJL080C',
#   'YKR086W',
#   'YDL084W',
#   'YNL112W',
#   'YGL064C',
#   'YDL040C',
#   'YPR024W'],
#  '1.14.11': ['YPL007C',
#   'YDR146C',
#   'YDR451C',
#   'YKR091W',
#   'YDR423C',
#   'YDR151C',
#   'YIL036W',
#   'YPL054W',
#   'YER115C',
#   'YHL009C',
#   'YIL031W',
#   'YNL074C',
#   'YER088C',
#   'YKR029C',
#   'YLL057C',
#   'YCL051W',
#   'YOR066W',
#   'YER051W',
#   'YHL027W',
#   'YHR014W',
#   'YNL012W',
#   'YOR320C',
#   'YKL112W',
#   'YGL071W',
#   'YKL109W',
#   'YLL012W',
#   'YIR018W',
#   'YML007W'],
#  '3.1.26': ['YDR447C',
#   'YHR141C',
#   'YML063W',
#   'YFR016C',
#   'YGL207W',
#   'YNL301C',
#   'YMR194W',
#   'YJR097W',
#   'YMR042W',
#   'YKR079C',
#   'YNL072W',
#   'YAL033W',
#   'YCL059C',
#   'YIL069C',
#   'YGR027C',
#   'YLR197W',
#   'YBR031W',
#   'YIL127C',
#   'YDL075W',
#   'YER131W',
#   'YBR048W',
#   'YBR189W',
#   'YGR014W',
#   'YDL082W',
#   'YPL079W',
#   'YER126C',
#   'YLR035C-A',
#   'YLR406C',
#   'YNL031C',
#   'YMR234W',
#   'YIL163C',
#   'YKL003C',
#   'YMR142C',
#   'YDR012W',
#   'YNL056W',
#   'YDR224C',
#   'YDR334W',
#   'YGR230W',
#   'YOR033C',
#   'YGR006W',
#   'YKR063C',
#   'YPL081W',
#   'YMR280C',
#   'YML024W',
#   'YMR239C',
#   'YLL045C',
#   'YKR019C',
#   'YLR441C',
#   'YAL024C',
#   'YOR145C',
#   'YDR025W',
#   'YBL027W',
#   'YNL297C',
#   'YER093C-A',
#   'YNL162W',
#   'YBR167C',
#   'YBL092W',
#   'YBR230C',
#   'YBR084C-A',
#   'YNL178W',
#   'YPL249C-A',
#   'YEL057C',
#   'YBL002W',
#   'YOL051W',
#   'YLR333C',
#   'YGL189C',
#   'YMR317W',
#   'YOL120C',
#   'YHL033C',
#   'YER074W',
#   'YDR420W',
#   'YOL024W',
#   'YBR010W',
#   'YCR046C',
#   'YBR191W',
#   'YNL269W'],
#  '3.4.21': ['YEL060C',
#   'YHR058C',
#   'YGL068W',
#   'YMR056C',
#   'YLR069C',
#   'YCR045C',
#   'YGR014W',
#   'YMR150C',
#   'YLL026W',
#   'YNL238W',
#   'YBR085W',
#   'YBL030C',
#   'YMR035W',
#   'YAL063C',
#   'YHR016C',
#   'YMR317W',
#   'YIR022W',
#   'YDR420W',
#   'YGR101W'],
#  '3.1.22': ['YBR022W', 'YDR225W', 'YBL003C', 'YJR055W', 'YDR391C'],
#  '3.1.4': ['YOL136C',
#   'YDR484W',
#   'YKR014C',
#   'YNL144C',
#   'YKL110C',
#   'YNL127W',
#   'YEL016C',
#   'YKR031C',
#   'YOR336W',
#   'YPL206C',
#   'YIR033W',
#   'YLR345W',
#   'YML001W',
#   'YBR140C',
#   'YPL268W',
#   'YKL057C',
#   'YBR150C',
#   'YFR040W',
#   'YEL022W',
#   'YOL081W',
#   'YJR140C',
#   'YNL093W',
#   'YOL082W'],
#  '4.2.1': ['YGL009C',
#   'YMR323W',
#   'YGR254W',
#   'YGL040C',
#   'YDR234W',
#   'YPR071W',
#   'YJR024C',
#   'YPL262W',
#   'YKR051W',
#   'YHL018W',
#   'YDR533C',
#   'YGR155W',
#   'YJR016C',
#   'YHR140W',
#   'YJL097W',
#   'YJL200C',
#   'YOR202W',
#   'YNL036W',
#   'YPR002W',
#   'YGL026C',
#   'YLR165C',
#   'YPL281C',
#   'YLR304C',
#   'YHR174W',
#   'YNL316C',
#   'YJL014W',
#   'YLR284C',
#   'YOR278W',
#   'YKL151C',
#   'YOR393W'],
#  '6.2.1': ['YPR066W',
#   'YBR041W',
#   'YGR244C',
#   'YER015W',
#   'YOR142W',
#   'YLR153C',
#   'YMR246W',
#   'YKL210W',
#   'YAL054C',
#   'YBR222C',
#   'YDR390C'],
#  '2.1.1': ['YBR236C',
#   'YKL162C',
#   'YBR034C',
#   'YMR310C',
#   'YMR306W',
#   'YLR172C',
#   'YDR435C',
#   'YLR090W',
#   'YJL125C',
#   'YJL168C',
#   'YML110C',
#   'YDL201W',
#   'YGR026W',
#   'YHR209W',
#   'YNL063W',
#   'YMR288W',
#   'YEL076C',
#   'YIL064W',
#   'YJR073C',
#   'YOL141W',
#   'YDR410C',
#   'YGL050W',
#   'YER091C',
#   'YDR086C',
#   'YOR173W',
#   'YPL030W',
#   'YOL041C',
#   'YOL080C',
#   'YOL093W',
#   'YBR061C',
#   'YJL042W',
#   'YDR140W',
#   'YGR157W',
#   'YKL195W',
#   'YDR120C',
#   'YGL197W',
#   'YBL024W',
#   'YPL118W',
#   'YER016W',
#   'YGR047C',
#   'YJR102C',
#   'YOR074C',
#   'YLR137W',
#   'YOL096C',
#   'YMR317W',
#   'YIL062C',
#   'YDR440W',
#   'YNL240C',
#   'YOL124C',
#   'YPL266W',
#   'YLR270W',
#   'YGR001C',
#   'YOL125W',
#   'YBL085W',
#   'YHR070W',
#   'YDL200C',
#   'YML008C',
#   'YNL077W'],
#  '6.1.1': ['YLR382C',
#   'YPR081C',
#   'YOR335C',
#   'YNL247W',
#   'YGL245W',
#   'YGR094W',
#   'YHR091C',
#   'YDR341C',
#   'YGR185C',
#   'YOL097C',
#   'YPR033C',
#   'YPR047W',
#   'YDR023W',
#   'YKL194C',
#   'YHR011W',
#   'YDR268W',
#   'YHR020W',
#   'YFL022C',
#   'YOL033W',
#   'YCR024C',
#   'YLL018C',
#   'YGL224C',
#   'YPL040C',
#   'YOR168W',
#   'YML108W',
#   'YLR060W',
#   'YGR171C',
#   'YBL076C',
#   'YPL104W',
#   'YNL040W',
#   'YNL073W',
#   'YDR037W',
#   'YHR019C',
#   'YBR121C',
#   'YPL097W',
#   'YGR264C',
#   'YER087W',
#   'YIL078W',
#   'YDL040C'],
#  '1.16.1': ['YGL084C',
#   'YLL051C',
#   'YOR381W',
#   'YNR060W',
#   'YPL092W',
#   'YOR384W',
#   'YOL084W',
#   'YLR214W',
#   'YKL220C'],
#  '3.4.22': ['YKR044W', 'YDR331W', 'YNL239W'],
#  '1.14.13': ['YBL098W', 'YHR176W', 'YMR154C', 'YHR007C', 'YKL182W'],
#  '1.2.1': ['YBR006W',
#   'YPL061W',
#   'YJR009C',
#   'YHR037W',
#   'YER073W',
#   'YDR158W',
#   'YMR169C',
#   'YGR192C',
#   'YMR110C',
#   'YMR170C',
#   'YER069W',
#   'YHR171W',
#   'YOR374W',
#   'YOR323C',
#   'YJL052W'],
#  '7.6.2': ['YAL026C',
#   'YBR290W',
#   'YMR162C',
#   'YIL048W',
#   'YDR093W',
#   'YLR443W',
#   'YER166W',
#   'YOR328W'],
#  '1.4.4': ['YMR189W'],
#  '2.7.8': ['YNL130C',
#   'YBR243C',
#   'YHR123W',
#   'YCL001W',
#   'YOL129W',
#   'YCL004W',
#   'YER026C',
#   'YDL142C',
#   'YPL148C',
#   'YPR113W'],
#  '3.6.3': ['Q0130',
#   'YKR035W-A',
#   'YLR448W',
#   'YCR024C-A',
#   'YGL091C',
#   'YER036C',
#   'YPL234C',
#   'YML073C',
#   'YLL015W',
#   'YNL153C',
#   'YDL100C',
#   'YHR039C-A',
#   'YBR187W',
#   'YJL074C',
#   'YHR026W',
#   'YOR332W',
#   'YBR127C',
#   'YFR009W',
#   'YKL142W',
#   'YOR158W',
#   'YOR215C',
#   'YEL027W',
#   'Q0080',
#   'YMR251W-A',
#   'YMR292W'],
#  '2.3.1': ['YNL071W',
#   'YDR264C',
#   'YBR042C',
#   'YIL160C',
#   'YNR053C',
#   'YMR153W',
#   'YLR246W',
#   'YLR372W',
#   'YDR018C',
#   'YOR127W',
#   'YGR002C',
#   'YLL002W',
#   'YPL028W',
#   'YHR123W',
#   'YDR191W',
#   'YDR062W',
#   'YLR033W',
#   'YPR071W',
#   'YFL017C',
#   'YJL218W',
#   'YGR177C',
#   'YLR312C',
#   'YMR127C',
#   'YNL194C',
#   'YLR239C',
#   'YKR038C',
#   'YMR296C',
#   'YPR079W',
#   'YMR210W',
#   'YMR091C',
#   'YOR025W',
#   'YLR195C',
#   'YMR069W',
#   'YNL326C',
#   'YOL141W',
#   'YJL071W',
#   'YDR148C',
#   'YKR029C',
#   'YBL052C',
#   'YMR093W',
#   'YDR072C',
#   'YMR062C',
#   'YMR319C',
#   'YCR034W',
#   'YOL068C',
#   'YGR103W',
#   'YBR177C',
#   'YOR245C',
#   'YDL104C',
#   'YLR092W',
#   'YJL196C',
#   'YNL227C',
#   'YER061C',
#   'YDR232W',
#   'YOL003C',
#   'YPL001W',
#   'YBR058C-A',
#   'YDR391C',
#   'YOR244W',
#   'YAL067C',
#   'YGR252W',
#   'YDR126W',
#   'YDL042C',
#   'YDL216C',
#   'YHR188C',
#   'R0020C',
#   'YOR034C',
#   'YDL052C',
#   'YNL277W',
#   'YPL015C',
#   'YBR207W',
#   'YDR459C',
#   'YIL029C',
#   'YGR197C'],
#  '1.4.1': ['YAL062W', 'YOR375C', 'YDL215C'],
#  '1.6.5': ['YBR052C',
#   'YDL212W',
#   'YER004W',
#   'YDR032C',
#   'YLR043C',
#   'YMR145C',
#   'YCR004C',
#   'YBR046C',
#   'YLR011W'],
#  '5.2.1': ['YKR035W-A',
#   'YBR119W',
#   'YGR159C',
#   'YDR155C',
#   'YLR449W',
#   'YML098W',
#   'YJR017C',
#   'YAL034W-A',
#   'YHL034C',
#   'YLL011W',
#   'YER105C',
#   'YJR032W',
#   'YGR193C',
#   'YNL236W',
#   'YDR304C',
#   'YCR069W',
#   'YLR216C',
#   'YNL135C',
#   'YER165W',
#   'YDR519W',
#   'YOR232W',
#   'YNR028W',
#   'YML074C',
#   'YHR057C',
#   'YJR076C',
#   'YKL089W',
#   'YIL153W',
#   'YFL023W',
#   'YNR036C',
#   'YML078W',
#   'YPL152W',
#   'YJL076W',
#   'YNL077W'],
#  '1.8.3': ['YGR029W', 'YOL088C', 'YPR037C', 'YER128W'],
#  '6.3.2': ['YBR082C',
#   'YOR241W',
#   'YAR015W',
#   'YGL058W',
#   'YDR059C',
#   'YEL012W',
#   'YJL101C',
#   'YDR092W',
#   'YDR054C',
#   'YOL049W',
#   'YIL145C',
#   'YEL019C',
#   'YAL024C',
#   'YMR022W',
#   'YDR198C',
#   'YOL051W',
#   'YMR113W',
#   'YJL076W'],
#  '2.7.10': ['YDR213W', 'YNL023C', 'YBL085W'],
#  '2.4.99': ['YKL219W', 'YGL022W', 'YMR266W', 'YGR038W', 'YJR054W'],
#  '3.5.1': ['YNL021W',
#   'YFL060C',
#   'YNL334C',
#   'YPR068C',
#   'YGL037C',
#   'YLR308W',
#   'YMR281W',
#   'YBR248C',
#   'YLR155C',
#   'YPL096W',
#   'YBR208C',
#   'YOL148C',
#   'YPL116W',
#   'YDR428C',
#   'YJL172W',
#   'YGL194C',
#   'YNL330C',
#   'YLR158C',
#   'YNR066C',
#   'YDR321W',
#   'YMR293C',
#   'YPL098C',
#   'YLR157C',
#   'YDR242W',
#   'YLR160C',
#   'YMR095C',
#   'YFR044C'],
#  '3.5.2': ['YBL050W', 'YIR027C', 'YPR027C', 'YLR420W'],
#  '2.4.2': ['YML022W',
#   'YLR078C',
#   'YBR057C',
#   'YMR271C',
#   'YGR144W',
#   'YGR014W',
#   'YFR047C',
#   'YLR209C',
#   'YDR441C',
#   'YMR084W',
#   'YNL204C',
#   'YML106W',
#   'YLR017W',
#   'YDR354W',
#   'YHR155W',
#   'YMR300C',
#   'YMR317W',
#   'YHR128W',
#   'YDR420W',
#   'YER055C'],
#  '4.1.3': ['YER090W', 'YPR006C', 'YPL207W', 'YER065C', 'YKL211C'],
#  '3.4.14': ['YHR028C', 'YOR219C', 'YOL057W'],
#  '2.5.1': ['YLL060C',
#   'YDL205C',
#   'YEL077C',
#   'YDR538W',
#   'YLR180W',
#   'YKL191W',
#   'YDL149W',
#   'YKR076W',
#   'YHR190W',
#   'YOR274W',
#   'YPR176C',
#   'YGR012W',
#   'YFR030W',
#   'YOL012C',
#   'YKL019W',
#   'YBR249C',
#   'YIR038C',
#   'YLR303W',
#   'YAL012W',
#   'YGR201C',
#   'YNL256W',
#   'YNL127W',
#   'YGL155W',
#   'YKL056C',
#   'YER145C',
#   'YBR256C',
#   'YDL090C',
#   'YOR147W',
#   'YDR035W',
#   'YPR069C',
#   'YJL031C',
#   'YJL167W',
#   'YNL025C',
#   'YDR476C',
#   'YBL088C',
#   'YNR041C',
#   'YPL214C',
#   'YML005W',
#   'YMR101C',
#   'YIL103W',
#   'YLR146C',
#   'YDR502C',
#   'YHR068W',
#   'YOL143C',
#   'YDL193W'],
#  '4.1.1': ['YNL169C',
#   'YGR087C',
#   'YNR043W',
#   'YLR305C',
#   'YDL080C',
#   'YLR044C',
#   'YEL021W',
#   'YOR128C',
#   'YKR097W',
#   'YMR194C-B',
#   'YOL052C',
#   'YKL184W',
#   'YDR539W',
#   'YDR047W',
#   'YMR250W',
#   'YLR134W',
#   'YKL211C',
#   'YDR161W'],
#  '1.5.5': ['YOR356W', 'YLR142W'],
#  '1.1.1': ['YLR174W',
#   'YHR183W',
#   'YJR096W',
#   'YNL241C',
#   'YIL074C',
#   'YKL029C',
#   'YCL030C',
#   'YDL066W',
#   'YAL060W',
#   'YBR159W',
#   'YCL018W',
#   'YJR159W',
#   'YDR368W',
#   'YLR100W',
#   'YKR009C',
#   'YOL126C',
#   'YNL009W',
#   'YIR035C',
#   'YDR104C',
#   'YDL022W',
#   'YKL055C',
#   'YDL114W',
#   'YDR335W',
#   'YBR149W',
#   'YJR139C',
#   'YNL274C',
#   'YER081W',
#   'YGL256W',
#   'YAL061W',
#   'YOR120W',
#   'YDL168W',
#   'YML056C',
#   'YHR063C',
#   'YCR107W',
#   'YCR105W',
#   'YDL144C',
#   'YNR073C',
#   'YLR426W',
#   'YNL331C',
#   'YBR145W',
#   'YLR432W',
#   'YHR154W',
#   'YMR303C',
#   'YGR256W',
#   'YDL078C',
#   'YEL070W',
#   'YIR036C',
#   'YMR083W',
#   'YOR136W',
#   'YBR153W',
#   'YLR450W',
#   'YDL246C',
#   'YLR355C',
#   'YMR226C',
#   'YIL124W',
#   'YOL059W',
#   'YHR216W',
#   'YPR127W',
#   'YKL071W',
#   'YOL086C',
#   'YKL085W',
#   'YHR104W'],
#  '5.1.3': ['YMR099C', 'YDR222W', 'YNR071C', 'YBR019C', 'YJL121C', 'YCR072C'],
#  '2.7.6': ['YHL011C',
#   'YOR143C',
#   'YOL061W',
#   'YER099C',
#   'YNL256W',
#   'YBL068W',
#   'YKL181W'],
#  '1.3.5': ['YJL045W', 'YKL148C', 'YLL041C', 'YMR020W'],
#  '2.6.1': ['YHR208W',
#   'YLR438W',
#   'YJR148W',
#   'YNR033W',
#   'YIL116W',
#   'YMR084W',
#   'YNR058W',
#   'YMR085W',
#   'YKL104C',
#   'YOL140W',
#   'YKL106W',
#   'YFL030W',
#   'YLR027C',
#   'YJL060W',
#   'YOR184W',
#   'YGR019W'],
#  '6.3.1': ['YPR035W', 'YJL046W', 'YLR143W'],
#  '6.4.1': ['YBR218C', 'YGL062W'],
#  '2.3.3': ['YOR108W',
#   'YNL104C',
#   'YDL131W',
#   'YIR031C',
#   'YCR005C',
#   'YML126C',
#   'YNL117W',
#   'YDL182W'],
#  '5.99.1': ['YFR016C',
#   'YMR128W',
#   'YGR014W',
#   'YMR091C',
#   'YKL180W',
#   'YDL135C',
#   'YLR441C',
#   'YHR127W',
#   'YJL177W',
#   'YGR215W'],
#  '3.1.1': ['YJR107W',
#   'YGR263C',
#   'YAL049C',
#   'YHR189W',
#   'YHR163W',
#   'YCR073W-A',
#   'YOR081C',
#   'YCR068W',
#   'YMR008C',
#   'YBL057C',
#   'YMR006C',
#   'YOL114C',
#   'YDR058C',
#   'YNR034W',
#   'YDL109C',
#   'YBR204C',
#   'YKL058W',
#   'YMR194C-B',
#   'YKL094W',
#   'YBR177C',
#   'YGR248W',
#   'YNL012W',
#   'YJL024C',
#   'YDL219W',
#   'YOL011W',
#   'YHR075C',
#   'YLR343W',
#   'YLR281C',
#   'YHR049W',
#   'YLR118C',
#   'YDL195W'],
#  '3.3.1': ['YER043C'],
#  '4.2.3': ['YGL148W', 'YGR014W', 'YCR053W', 'YKL218C'],
#  '4.6.1': ['YKL128C',
#   'YFL053W',
#   'YLR105C',
#   'YNL172W',
#   'YML070W',
#   'YAR008W',
#   'YLR384C',
#   'YOR086C',
#   'YPR003C',
#   'YDR082W',
#   'YPL123C'],
#  '1.8.4': ['YKL069W', 'YER042W', 'YLR043C', 'YGR209C', 'YPR167C', 'YCL033C'],
#  '1.1.2': ['YDL174C', 'YDL178W', 'YEL071W'],
#  '2.2.1': ['YMR108W', 'YGR043C', 'YLR354C', 'YBR117C', 'YPR074C', 'YMR125W'],
#  '1.15.1': ['YJR104C', 'YLR380W', 'YHR008C'],
#  '2.7.2': ['YDR300C', 'YER052C', 'YHR033W', 'YER069W', 'YCR012W'],
#  '1.10.3': ['YMR058W', 'YFL041W'],
#  '3.1.11': ['YER180C-A', 'YIL002W-A', 'YHR079C-A'],
#  '6.5.1': ['YOL010W', 'YJL087C', 'YDL220C', 'YDL164C', 'YOR005C'],
#  '5.4.2': ['YKL127W',
#   'YFL045C',
#   'YDL021W',
#   'YMR105C',
#   'YEL058W',
#   'YOL056W',
#   'YKL152C'],
#  '3.5.4': ['YCL030C',
#   'YPR062W',
#   'YGR267C',
#   'YJL035C',
#   'YML035C',
#   'YLR320W',
#   'YLR028C',
#   'YMR120C',
#   'YNL141W',
#   'YDL238C',
#   'YGR204W',
#   'YBR084W',
#   'YLR245C'],
#  '3.4.25': ['YFR050C',
#   'YER012W',
#   'YJL001W',
#   'YOR157C',
#   'YOR011W',
#   'YOR362C',
#   'YOL038W',
#   'YGR135W',
#   'YMR314W',
#   'YBL041W',
#   'YER094C',
#   'YGR253C',
#   'YPR103W'],
#  '4.2.99': ['YGL162W', 'YML060W', 'YOL043C', 'YAL015C'],
#  '3.4.24': ['YDL149W',
#   'YDR414C',
#   'YGR014W',
#   'YBR287W',
#   'YPR122W',
#   'YKL134C',
#   'YLR163C',
#   'YJR117W',
#   'YMR317W',
#   'YHR024C',
#   'YDR420W'],
#  '4.2.2': ['YBR280C', 'YIL173W', 'YJL222W'],
#  '1.2.98': ['YAL060W'],
#  '2.7.13': ['YIL147C', 'YGL195W', 'YGL002W', 'YBR074W', 'YGR125W'],
#  '3.1.13': ['YML118W',
#   'YBL079W',
#   'YGL170C',
#   'YNR052C',
#   'YDR096W',
#   'YML100W',
#   'YOL021C',
#   'YMR285C',
#   'YAL021C'],
#  '4.4.1': ['YML004C', 'YHR112C', 'YKR099W', 'YAL039C', 'YFR055W', 'YKL087C'],
#  '1.17.4': ['YGR180C',
#   'YBL074C',
#   'YER070W',
#   'YIL066C',
#   'YJL024C',
#   'YJL026W',
#   'YGL136C'],
#  '1.17.1': ['YOR388C'],
#  '5.6.2': ['YDL227C', 'YLR234W', 'YNL088W', 'YOL006C'],
#  '5.5.1': ['YJR109C', 'YJL153C'],
#  '6.3.5': ['YJR109C',
#   'YGR014W',
#   'YGR124W',
#   'YGR061C',
#   'YML096W',
#   'YHR074W',
#   'YMR293C',
#   'YLR126C',
#   'YPR145W',
#   'YJL130C',
#   'YMR317W',
#   'YOR303W',
#   'YDR420W',
#   'YMR217W'],
#  '1.6.99': ['YML120C', 'YJL213W'],
#  '3.5.3': ['YIR029W', 'YPL111W'],
#  '6.3.4': ['YBL039C',
#   'YOL058W',
#   'YHR069C',
#   'YKR063C',
#   'YNL220W',
#   'YJR103W',
#   'YOR209C',
#   'YGR204W',
#   'YGL234W',
#   'YBR084W'],
#  '2.7.12': ['YJL141C', 'YPL153C'],
#  '5.1.1': ['YDR111C'],
#  '1.14.14': ['YBR219C', 'YMR015C', 'YGR175C'],
#  '3.4.23': ['YDR144C', 'YIR039C', 'YLR120C', 'YLR121C'],
#  '5.3.4': ['YOL088C', 'YOR288C', 'YCL043C', 'YDR518W'],
#  '5.3.1': ['YPR118W',
#   'YIL020C',
#   'YER003C',
#   'YDR050C',
#   'YDR007W',
#   'YBR196C',
#   'YOR095C'],
#  '3.3.2': ['YNL045W'],
#  '2.8.1': ['YLR043C',
#   'YOR286W',
#   'YOR196C',
#   'YDL033C',
#   'YHR111W',
#   'YCL017C',
#   'YOR285W',
#   'YGR286C'],
#  '1.1.5': ['YIL155C'],
#  '1.1.3': ['YML086C'],
#  '4.3.3': ['YMR096W', 'YFL059W', 'YNL333W'],
#  '1.2.4': ['YIL125W', 'YBR221C', 'YER178W'],
#  '1.3.3': ['YER014W', 'YGL205W', 'YFL041W', 'YBR275C', 'YDR044W'],
#  '5.3.3': ['YPL117C'],
#  '1.6.2': ['YIL043C', 'YPR048W', 'YML125C', 'YKL150W', 'YHR042W', 'YML087C'],
#  '2.8.2': ['YOR246C'],
#  '7.1.3': ['YHL016C', 'YNR056C', 'YLR413W'],
#  '5.1.99': ['YIR030C', 'YNL200C'],
#  '1.5.1': ['YIR034C',
#   'YER023W',
#   'YGL125W',
#   'YAL063C',
#   'YOR236W',
#   'YGR204W',
#   'YPL023C',
#   'YBR084W',
#   'YBL008W'],
#  '1.9.3': ['YJL170C', 'YCL005W-A', 'YBR162W-A', 'YJR044C', 'YJL151C'],
#  '5.6.1': ['YLR259C', 'YDL143W', 'YJL014W', 'YJL008C', 'YJL111W'],
#  '3.2.2': ['YHL030W',
#   'YCR067C',
#   'YGL195W',
#   'YGR134W',
#   'YPL110C',
#   'YCR059C',
#   'YLR092W',
#   'YJL055W',
#   'YBL112C',
#   'YOR342C',
#   'YJL080C',
#   'YML021C',
#   'YER142C'],
#  '4.1.99': ['YDR487C', 'YGR060W', 'YDR297W', 'YLR056W'],
#  '7.2.2': ['YGL167C', 'YGL006W'],
#  '6.3.3': ['YNR057C', 'YER183C', 'YGL234W'],
#  '7.1.1': ['YEL024W',
#   'Q0250',
#   'Q0070',
#   'YOR097C',
#   'Q0275',
#   'Q0045',
#   'YMR243C',
#   'YCL058C'],
#  '1.4.3': ['YBR035C'],
#  '3.5.99': ['YER057C', 'YCR020C', 'YIL051C'],
#  '1.13.11': ['YMR009W', 'YPR189W', 'YBL008W', 'YJR025C'],
#  '2.1.2': ['YBR176W',
#   'YLR028C',
#   'YMR120C',
#   'YDR019C',
#   'YBR263W',
#   'YDR408C',
#   'YBL013W',
#   'YLR058C'],
#  '1.16.3': ['YOR257W', 'YDL120W'],
#  '5.4.99': ['YGL063W',
#   'YFL001W',
#   'YLR165C',
#   'YGR169C',
#   'YPL212C',
#   'YPR060C',
#   'YNL292W'],
#  '1.14.99': ['YJR070C', 'YOR125C'],
#  '1.18.1': ['YDR376W'],
#  '3.7.1': ['YLR231C', 'YBR177C'],
#  '4.3.1': ['YER086W', 'YCL064C', 'YKL218C'],
#  '1.8.98': ['YKL086W'],
#  '1.14.19': ['YGL055W', 'YLR056W'],
#  '3.4.17': ['YNL323W'],
#  '1.14.12': ['YGR234W'],
#  '4.3.2': ['YHR018C', 'YLR359W'],
#  '2.10.1': ['YJR098C'],
#  '2.1.3': ['YJL088W'],
#  '7.4.2': ['YFR009W'],
#  '1.3.98': ['YKL216W'],
#  '1.7.99': ['YMR317W'],
#  '4.1.2': ['YKL060C'],
#  '1.7.1': ['YLR011W'],
#  '4.99.1': ['YOR176W']}

# %%
def venn_CLEAN_DeepECtransformer_Uniprotgene(sce_uniprotkb_gene_file,gene2ec_dict1,gene2ec_dict2,label1,label2,gene_lst_venn_figure):
    gene2ec_dict1 = list(gene2ec_dict1.keys())
    print(label1,'gene2ec_dict',len(gene2ec_dict1))

    gene2ec_dict2 = list(gene2ec_dict2.keys())
    print(label2,'gene2ec_dict',len(gene2ec_dict2))

    uniprot_data = pd.read_csv(sce_uniprotkb_gene_file,sep='\t')
    uniprot_data = uniprot_data[~uniprot_data['EC number'].isna()]
    uniprot_data = uniprot_data[~uniprot_data['Gene Names'].isna()]
    uniprot_gene_list = []
    for i in uniprot_data['Gene Names'].to_list():
        uniprot_gene_list += i.split(' ')
    uniprot_gene_list = [x for x in uniprot_gene_list if x.startswith('Y') or x.startswith('Q')]
    uniprot_gene_list = [x for x in uniprot_gene_list if len(x)>4]
    uniprot_gene_list = [x for x in uniprot_gene_list if '.' not in x]

    uniprot_gene_list = [x for x in uniprot_gene_list if x in gene2ec_dict2]

    print('uniprot gene num',len(uniprot_gene_list))

    A = set(gene2ec_dict1)
    B = set(gene2ec_dict2)
    C = set(uniprot_gene_list)
    # set common parameters
    plt.figure(figsize=(2, 2), dpi=400)
    plt.rcParams.update({'font.size': 7})
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['pdf.fonttype']= 42

    # plot Venn diagram
    venn_labels = [label1, label2, 'UniProt']
    venn_diagram = venn3_unweighted([A, B, C], set_labels=venn_labels)
    venn_diagram.get_patch_by_id('100').set_facecolor('#ff7f00')
    venn_diagram.get_patch_by_id('100').set_edgecolor('black')
    venn_diagram.get_patch_by_id('100').set_alpha(1)
    venn_diagram.get_patch_by_id('100').set_linewidth(1)

    venn_diagram.get_patch_by_id('010').set_facecolor('#984ea3')
    venn_diagram.get_patch_by_id('010').set_edgecolor('black')
    venn_diagram.get_patch_by_id('010').set_alpha(1)
    venn_diagram.get_patch_by_id('010').set_linewidth(1)

    venn_diagram.get_patch_by_id('001').set_facecolor('#41ab5d')
    venn_diagram.get_patch_by_id('001').set_edgecolor('black')
    venn_diagram.get_patch_by_id('001').set_alpha(1)
    venn_diagram.get_patch_by_id('001').set_linewidth(1)

    venn_diagram.get_patch_by_id('111').set_facecolor('#1d91c0')
    venn_diagram.get_patch_by_id('111').set_edgecolor('black')
    venn_diagram.get_patch_by_id('111').set_alpha(1)
    venn_diagram.get_patch_by_id('111').set_linewidth(1)

    venn_diagram.get_patch_by_id('011').set_edgecolor('black')
    venn_diagram.get_patch_by_id('011').set_alpha(1)
    venn_diagram.get_patch_by_id('011').set_linewidth(1)

    venn_diagram.get_patch_by_id('101').set_edgecolor('black')
    venn_diagram.get_patch_by_id('101').set_alpha(1)
    venn_diagram.get_patch_by_id('101').set_linewidth(1)

    venn_diagram.get_patch_by_id('110').set_edgecolor('black')
    venn_diagram.get_patch_by_id('110').set_alpha(1)
    venn_diagram.get_patch_by_id('110').set_linewidth(1)

    venn_diagram.set_labels[0].set_fontsize(8)
    venn_diagram.set_labels[0].set_color('#ff7f00')
    venn_diagram.set_labels[0].set_alpha(1)
    venn_diagram.set_labels[1].set_fontsize(8)
    venn_diagram.set_labels[1].set_color('#984ea3')
    venn_diagram.set_labels[1].set_alpha(1)
    venn_diagram.set_labels[2].set_fontsize(8)
    venn_diagram.set_labels[2].set_color('#41ab5d')
    venn_diagram.set_labels[2].set_alpha(1)

    # save figure
    plt.savefig(gene_lst_venn_figure, dpi=400, bbox_inches='tight')
    plt.show()

# %%
gene_lst_venn_figure = figs4b_path
venn_CLEAN_DeepECtransformer_Uniprotgene(sce_uniprotkb_gene_file,DeepEC_gene2ec_dict,clean_gene2ec_dict,'DeepECtransformer','CLEAN',gene_lst_venn_figure)
# Out:
# DeepECtransformer gene2ec_dict 2015
# CLEAN gene2ec_dict 5911
# uniprot gene num 1781
