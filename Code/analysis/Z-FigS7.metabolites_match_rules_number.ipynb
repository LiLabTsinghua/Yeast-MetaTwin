# %%
import pandas as pd
import numpy as np
import json
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import rdChemReactions
from rdkit.Chem.Draw import rdMolDraw2D
from rdkit.Chem.Draw import IPythonConsole
from IPython.display import SVG, display
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit import DataStructs
from rdkit.Chem import MACCSkeys
import pandas as pd
import rdchiral
import itertools
import pickle
import sys
from tqdm import tqdm 
from rdchiral.main import rdchiralRun, rdchiralRunText, rdchiralReaction, rdchiralReactants
import cobra
from itertools import chain, combinations
import sys
from ast import literal_eval
import multiprocessing
from functools import partial
sys.path.append('../retrosynthesis/')

from common import *

# %%
mnxreac_smile_atom_mapping_rules_file_path = '../../Data/rules/MNXreaction_smiles_atommap_rules_filter.csv'
rxndb_total_info_to_model_path = '../../Results/not_lipid/top50_0.3_re/rxndb_total_info_to_model_top50_0.3.csv'
yeast_met_file = '../../Results/not_lipid/yeast_met_not_lipid.pickle'
yeast870_path = '../../Data/model/yeast-GEM.yml'
figs7_data_path = '../../Results/source_data/figS7.csv'
figs7_path = '../../Results/Figures/figS7.pdf'

# %%
yeast_total_smiles_extend = load_pickle(yeast_met_file)
print(len(yeast_total_smiles_extend))
# Out:
# 3680

# %%
rules = pd.read_csv(mnxreac_smile_atom_mapping_rules_file_path)
rules = rules[['MNX_ID','product_smiles','ProductSMARTs','RetroRules']]
print(rules.shape)
rules = rules[~rules['ProductSMARTs'].isna()]
print(rules.shape)
rules.head(1)
# Out:
# (20210, 4)
# (20210, 4)
#        MNX_ID                             product_smiles  \
# 0  MNXR100024  [NH4+].[NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]
#
#                                        ProductSMARTs  \
# 0  [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...
#
#                                           RetroRules
# 0  [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...

# %%
mets_total_smiles = yeast_total_smiles_extend

# %%
def smiles_similarity(target_smiles, product_smiles):
    res = 0
    smiles_list = product_smiles.split('.')
    for smiles in smiles_list:
        if 'c' in smiles or 'C' in smiles:  # only match substrates with Carbon
            smile_fps = MACCSkeys.GenMACCSKeys(Chem.MolFromSmiles(smiles))
            target_smiles_fps = MACCSkeys.GenMACCSKeys(Chem.MolFromSmiles(target_smiles))
            tmp_scores = DataStructs.FingerprintSimilarity(smile_fps, target_smiles_fps)
            if tmp_scores>0.3:
                res = 1
        else:pass

    return(res)

# %%
from rdkit import Chem

def match_smarts(target_smiles, ProductSMARTs):
    res = 0  # No match
    smarts_list = ProductSMARTs.split('.')
    
    # Only match substrates with Carbon
    if 'c' in target_smiles or 'C' in target_smiles:
        target_smiles = Chem.MolFromSmiles(target_smiles)
        
        for smarts in smarts_list:
            if target_smiles.HasSubstructMatch(Chem.MolFromSmarts(smarts)):
                res = 1  # Match found
    else:
        pass  # No carbon in target_smiles
    
    return res

# %%
rules
# Out:
#                    MNX_ID                                 product_smiles  \
# 0              MNXR100024      [NH4+].[NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]
# 1      MNXR100024_reverse         NC(=O)CC[C@H]([NH3+])C(=O)[O-].[H]O[H]
# 2              MNXR100030      [NH4+].[NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]
# 3      MNXR100030_reverse         NC(=O)CC[C@H]([NH3+])C(=O)[O-].[H]O[H]
# 4              MNXR100060                                  O=CCO.[H]O[H]
# ...                   ...                                            ...
# 20205   MNXR99896_reverse  [NH3+][C@@H](CCC=O)C(=O)[O-].O=P([O-])([O-])O
# 20206   MNXR99898_reverse  [NH3+][C@@H](CCC=O)C(=O)[O-].O=P([O-])([O-])O
# 20207   MNXR99920_reverse      O=C([O-])/C=C(\C=C(\O)C(=O)[O-])C(=O)[O-]
# 20208           MNXR99957  O=C([O-])[C@H](O)[C@@H](O)[C@@H](O)[C@H](O)CO
# 20209   MNXR99957_reverse     O=C([O-])C(=O)C[C@@H](O)[C@H](O)CO.[H]O[H]
#
#                                            ProductSMARTs  \
# 0      [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...
# 1      [C:1]-[C;H0;D3;+0:2](-[NH2;D1;+0:5])=[O;D1;H0:...
# 2      [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...
# 3      [C:1]-[C;H0;D3;+0:2](-[NH2;D1;+0:5])=[O;D1;H0:...
# 4           [C:1]-[CH;D2;+0:2]=[O;D1;H0:4].[OH2;D0;+0:3]
# ...                                                  ...
# 20205  [#15:1]-[OH;D1;+0:2].[C:4]-[CH;D2;+0:3]=[O;D1;...
# 20206  [#15:1]-[OH;D1;+0:2].[C:4]-[CH;D2;+0:3]=[O;D1;...
# 20207  [O-;H0;D1:13]-[C;H0;D3;+0:6](=[O;H0;D1;+0:7])-...
# 20208  [C:1]-[C@H;D3;+0:2](-[OH;D1;+0:8])-[C@@H;D3;+0...
# 20209  [C:1]-[CH2;D2;+0:2]-[C;H0;D3;+0:4](=[O;H0;D1;+...
#
#                                               RetroRules
# 0      [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...
# 1      [C:1]-[C;H0;D3;+0:2](-[NH2;D1;+0:5])=[O;D1;H0:...
# 2      [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...
# 3      [C:1]-[C;H0;D3;+0:2](-[NH2;D1;+0:5])=[O;D1;H0:...
# 4      [C:1]-[CH;D2;+0:2]=[O;D1;H0:4].[OH2;D0;+0:3]>>...
# ...                                                  ...
# 20205  [#15:1]-[OH;D1;+0:2].[C:4]-[CH;D2;+0:3]=[O;D1;...
# 20206  [#15:1]-[OH;D1;+0:2].[C:4]-[CH;D2;+0:3]=[O;D1;...
# 20207  [O-;H0;D1:13]-[C;H0;D3;+0:6](=[O;H0;D1;+0:7])-...
# 20208  [C:1]-[C@H;D3;+0:2](-[OH;D1;+0:8])-[C@@H;D3;+0...
# 20209  [C:1]-[CH2;D2;+0:2]-[C;H0;D3;+0:4](=[O;H0;D1;+...
#
# [20210 rows x 4 columns]

# %%
def process_smiles(smiles):
    match_num = 0
    match_rule_lst = []
    for index,row in rules.iterrows():
        if match_smarts(smiles, row['ProductSMARTs']) and smiles_similarity(smiles, row['product_smiles']):
            match_num+=1
            match_rule_lst.append(row['MNX_ID'])
    return(smiles, match_num,match_rule_lst)

smiles_pool = multiprocessing.Pool(processes=20)
smiles_match_rules = {'smiles':[],'match_rules':[],'match_rule_lst':[]}

for result in tqdm(smiles_pool.imap_unordered(process_smiles, mets_total_smiles), total=len(mets_total_smiles)):
    smiles_match_rules['smiles'].append(result[0])
    smiles_match_rules['match_rules'].append(result[1])
    smiles_match_rules['match_rule_lst'].append(result[2])
# Out:
# 100%|██████████| 3680/3680 [39:58<00:00,  1.53it/s]

# %%
smiles_match_rules_df = pd.DataFrame(smiles_match_rules)
smiles_match_rules_df
# Out:
#                                                  smiles  match_rules  \
# 0                                            CCOC(C)OCC           22
# 1                                    Cc1occc1SSc1ccoc1C            3
# 2                                 O=c1[nH]cnc2nc[nH]c12          271
# 3                                           CC(N)(CO)CO          652
# 4                                   CC(=O)N1CCCC1C(=O)O          820
# ...                                                 ...          ...
# 3675           CCCCCCCCC=CCCCCCCCC(=O)OCC(O)COP(=O)(O)O         1587
# 3676                           CSCCC(N)C(=O)NC(C)C(=O)O         1228
# 3677  Cc1cc2c(cc1C)N(C[C@H](O)[C@H](O)[C@H](O)COP(=O...         2201
# 3678  CCCCCCCCCCCCCCCCCCCCC[C@@H](O)[C@H](O)C(=O)N[C...         2678
# 3679  CCCCCC/C=C\CCCCCCCCCC(=O)OC[C@H](COP(=O)([O-])...         2216
#
#                                          match_rule_lst
# 0     [MNXR111877_reverse, MNXR119784_reverse, MNXR1...
# 1          [MNXR120026, MNXR151908_reverse, MNXR176424]
# 2     [MNXR100348_reverse, MNXR100737_reverse, MNXR1...
# 3     [MNXR100129, MNXR100328, MNXR100348, MNXR10039...
# 4     [MNXR100328, MNXR100348, MNXR100348_reverse, M...
# ...                                                 ...
# 3675  [MNXR100129, MNXR100326, MNXR100327, MNXR10032...
# 3676  [MNXR100114_reverse, MNXR100390, MNXR100410_re...
# 3677  [MNXR100129, MNXR100277_reverse, MNXR100328, M...
# 3678  [MNXR100114_reverse, MNXR100129, MNXR100277_re...
# 3679  [MNXR100129, MNXR100277_reverse, MNXR100328, M...
#
# [3680 rows x 3 columns]

# %% [markdown]
# # merge smiles_match_rules_df based on idendical smiles

# %%
len(smiles_match_rules_df['match_rule_lst'].to_list()[0])
# Out:
# 22

# %%
smiles_match_rules_dict = {}
for index, row in tqdm(smiles_match_rules_df.iterrows(), total=len(smiles_match_rules_df)):
    if smiles_has_carbon(row['smiles']):
        # Check if any SMILES in the dictionary matches the current row's SMILES
        matched_key = None
        for smiles in smiles_match_rules_dict.keys():
            if compare_smiles_inchikey(smiles, row['smiles']):
                matched_key = smiles
                break
        
        if matched_key:
            # Append to the existing match_rule_lst if a match is found
            smiles_match_rules_dict[matched_key] += row['match_rule_lst']
        else:
            # Create a new entry in the dictionary if no match is found
            smiles_match_rules_dict[row['smiles']] = row['match_rule_lst']
# Out:
# 100%|██████████| 3680/3680 [34:49<00:00,  1.76it/s]

# %%
smiles_match_rules_dict = {k:list(set(v)) for k,v in smiles_match_rules_dict.items()}

# %%
smiles_match_rules_dict = {k:len(v) for k,v in smiles_match_rules_dict.items()}

# %%
smiles_match_rules_dict
# Out:
# {'CCOC(C)OCC': 22,
#  'Cc1occc1SSc1ccoc1C': 3,
#  'O=c1[nH]cnc2nc[nH]c12': 271,
#  'CC(N)(CO)CO': 652,
#  'CC(=O)N1CCCC1C(=O)O': 820,
#  '[NH3+][C@@H](CCCC=O)C(=O)[O-]': 1777,
#  'NCCCC(N)C(=O)O': 1543,
#  'OC[C@@H](O)[C@H](O)[C@H](O)[C@H](O)CO': 1152,
#  'CC(N)C(N)CCCCCC(=O)O': 1225,
#  'Nc1nc2ncc(CNc3ccc(C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-])cc3)nc2c(=O)[nH]1': 1643,
#  'CC(O)[C@H](O)C1=Nc2c([nH]c(N)nc2=O)NC1': 1071,
#  'O=C(CO)[C@@H](O)[C@@H](O)[C@@H](O)CO': 1617,
#  'CCC[C@@H](O)CC(=O)O': 1751,
#  'CC1=C(O)C(=O)[C@@H](C)O1': 680,
#  '[NH3+][C@H](CC(=O)c1ccccc1NC=O)C(=O)[O-]': 2192,
#  'O=P([O-])([O-])OC[C@H]1OC(O)[C@H](O)[C@@H](O)[C@@H]1O': 2806,
#  'CCCCCCC=CCCCCCCCC(=O)OC(CO)COC(=O)CCCCCCCC=CCCCCCCCC': 1223,
#  'O=C(CO)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 2673,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])[O-])[C@@H](OP(=O)([O-])[O-])[C@H]1O': 2195,
#  'CC(=O)[O-]': 556,
#  'O=C(/C=C/c1ccc(O)c(O)c1)O[C@@H](C(=O)O)[C@@H](O)C(=O)O': 1901,
#  'NC(=O)CCCC[C@@H]1CCSS1': 145,
#  'O=CC[C@@H](O)[C@@H](O)[C@H](O)CO': 1505,
#  'CC(=O)N[C@@H]1[C@H](O)O[C@H](CO)[C@@H](O)[C@@H]1O': 2293,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](CO)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2703,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(O)C(O)C(=O)NC(CO)C(O)C(O)CCCCCCCCCCCCCC': 1806,
#  'CO': 117,
#  'CC(=O)c1cccs1': 15,
#  'OC[C@H]1OC(O)[C@H](O)[C@@H](O)[C@@H]1O[C@@H]1O[C@H](CO)[C@H](O)[C@H](O)[C@H]1O': 2187,
#  'O=C(O)C(=O)CC1(C(=O)O)C=CC(O)C=C1': 2449,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2694,
#  'O=P(O)(O)OC[C@H]1OC(O)(CO)[C@@H](O)[C@H](O)[C@@H]1O': 1879,
#  'NCCc1c[nH]cn1': 311,
#  'COc1cc(/C=C/C(=O)OC(C(=O)O)C(O)C(=O)O)ccc1O': 2101,
#  'CCCCCCCCC=CCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3203,
#  'NC(=NCCCC(N)C(=O)O)NC(CC(=O)O)C(=O)O': 1007,
#  'C[C@@H](CO)C(=O)[O-]': 1085,
#  'CCCCCCCC=CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3179,
#  'O=C([O-])C=C1C=CC(=O)O1': 850,
#  'CC(=O)CN': 290,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](COC(=O)CCCCCCC/C=C\\CCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 322,
#  'CC(C(=O)[O-])C(O)(CC(=O)[O-])C(=O)[O-]': 1545,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)([O-])OCC[N+](C)(C)C': 1057,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCC': 323,
#  'CC(=O)NC1C(OP(=O)(O)OP(=O)(O)OCC2OC(n3ccc(=O)[nH]c3=O)C(O)C2O)OC(CO)C(O)C1O': 2858,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)(O)OP(=O)(O)O': 777,
#  'O=C(O)CCCCC1SCC2NC(=O)NC21': 1974,
#  'Cc1ncc(CO)c(=O)[nH]1': 1231,
#  'C[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1O': 908,
#  'Nc1nc2c(c(=O)[nH]1)N=C(C(O)C(O)CO)CN2': 1366,
#  'CCCCCCCCCCCCCC=C[C@H](O)[C@H](N)CO': 1591,
#  'O=C(O)c1ccc[n+](C2OC(CO)C(O)C2O)c1': 1708,
#  'N[C@H]1[C@H](O)O[C@H](CO)[C@@H](O)[C@@H]1O': 2275,
#  'Cc1cn(C2CC(OP(=O)(O)O)C(CO)O2)c(=O)nc1O': 2359,
#  'OC[C@H]1O[C@H](O[C@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)[C@H](O)[C@@H](O)[C@@H]1O': 1721,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)([O-])OCC[N+](C)(C)C': 1057,
#  'O=C(c1ccccc1)[C@@H](O)c1ccccc1': 310,
#  'O=C([O-])c1ccccc1': 247,
#  'CCCCO': 504,
#  'CC(=O)C=CC=C(C)C': 95,
#  'Nc1ncnc2c1ncn2[C@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@@H]1O': 2219,
#  'OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@@H]1O[C@H]1O[C@H](CO)[C@H](O[C@@H]2O[C@H](CO)[C@H](O)[C@H](O)[C@H]2O)[C@H](O)[C@H]1O': 2192,
#  'CCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3351,
#  'C=CC1=C(C)C2=N/C1=C\\c1c(C)c(CCC(=O)[O-])c3n1[Fe]n1/c(c(C)c(C=C)/c1=C/2)=C\\C1=N/C(=C\\3)C(CCC(=O)[O-])=C1C': 1199,
#  'O=C([O-])[C@@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O': 2330,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)(O)OP(=O)(O)O': 777,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])O[C@H]3O[C@@H](CO)[C@@H](O)[C@@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)c(=O)[nH]1': 2798,
#  'CCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3177,
#  'O=C([O-])[C@@H](O)[C@H](O)[C@H](O)C(=O)CO': 2276,
#  'NC(Cc1ccc(OP(=O)(O)O)cc1)C(=O)O': 2810,
#  'O=c1[nH]c(=O)c2ncn([C@@H]3O[C@H](CO)[C@@H](O)[C@H]3O)c2[nH]1': 1340,
#  'O=c1ccn(C2OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)C(O)C2O)c(=O)[nH]1': 2247,
#  'Nc1ccn([C@H]2C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])[O-])O2)c(=O)n1': 2293,
#  'O=CC(O)COP(=O)(O)O': 2253,
#  'O=C(CO)COP(=O)(O)O': 2139,
#  'OC[C@H]1O[C@@H](OC[C@H]2O[C@@H](O)[C@H](O)[C@@H](O)[C@H]2O)[C@H](O)[C@@H](O)[C@H]1O': 2199,
#  'Cc1cccc(CO)c1': 220,
#  'CC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3303,
#  'Nc1nc2c(c(=O)[nH]1)N=C(C(O)C(O)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)CN2': 2254,
#  'O=P(O)(O)O[C@H]1[C@@H](OP(=O)(O)O)[C@H](O)[C@@H](OP(=O)(O)O)[C@H](OP(=O)(O)O)[C@H]1OP(=O)(O)O': 1904,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])[O-]': 1262,
#  'OC[C@H]1O[C@@](O)(CO)[C@H](O)[C@H]1O': 1769,
#  '[NH3+][C@H](C(=O)[O-])[C@H](O)CO': 2583,
#  'Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OC(=O)CCCCC2CCSS2)C(O)C1O': 2072,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCC/C=C\\CCCCCCCC)COC(=O)CCCCCCCCC/C=C/CCCCCC': 322,
#  'Cc1ncc(COP(=O)(O)O)c(CN)c1O': 1850,
#  'NC(=O)N[C@@H](CC(=O)[O-])C(=O)[O-]': 1495,
#  'Cc1csc(C(C)C)n1': 4,
#  '[NH3+]CCCC(=O)[O-]': 1260,
#  'CCCC[C@@H]([NH3+])C(=O)[O-]': 1446,
#  'O=[N+]([O-])c1ccc(OP(=O)([O-])[O-])cc1': 1099,
#  'O=C([O-])Cc1ccccc1': 836,
#  'CCCCCC(=O)OCC': 173,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)(O)OC[C@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 2189,
#  'O=C([O-])C(=O)[C@@H](O)[C@H](O)[C@@H](O)CO': 2561,
#  'Cc1cnc2c(n1)CCC2': 24,
#  '[NH3+][C@@H](COP(=O)([O-])OC[C@H](O)CO)C(=O)[O-]': 3113,
#  '[NH3+]CCOP(=O)([O-])OC[C@H](O)CO': 2453,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](CO)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 1749,
#  'O=C([O-])c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c1': 2345,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)cc(O)c1O': 2766,
#  'COc1cc(C2=C(OC3OC(CO)C(O)C(O)C3O)c3c(C=O)c(=O)oc4cc(O)cc(c34)[OH+]2)cc(OC)c1O': 2797,
#  'O=C([O-])C(O)C(O)C(O)C(O)CO': 2242,
#  'C=COCC': 0,
#  'CCCCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3351,
#  'CCCCCCC=CCCCCCCCCCC(=O)OCC(COC(=O)CCCCCCCC=CCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC': 323,
#  'C[C@H](O)[C@@H](C)O': 271,
#  'O[C@H]1CO[C@H](O)[C@H](O)[C@H]1O': 1949,
#  'CCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3177,
#  'CC(=O)C(C)(O)C(=O)O': 1422,
#  'Nc1c(O)cccc1C(=O)C[C@H]([NH3+])C(=O)[O-]': 2772,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)(O)OC[C@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCC/C=C\\CCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC': 2189,
#  'CCCCCCCCCCCCCCC[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3219,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)([O-])OC[C@H]([NH3+])C(=O)[O-])OC(=O)CCCCCCC/C=C\\CCCCCC': 2011,
#  'N#C[C@@H](O)c1ccccc1': 150,
#  'O=C(O)C=CC(=O)CC(=O)O': 1425,
#  'C[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3194,
#  'O=c1[nH]cc([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)[nH]1': 1344,
#  'O=C(O)C(CO)OP(=O)(O)O': 2397,
#  'NC(CO)C(=O)O': 1736,
#  'O=C(CO)C(O)C(O)C(O)COP(=O)(O)O': 2625,
#  'CCCCCCCCC=CCCCC=CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3179,
#  '[NH3+][C@@H](C[C@H](O)C(=O)[O-])C(=O)[O-]': 2406,
#  'O=C(O)CO': 1438,
#  'OC[C@@H]1O[C@@H](O)[C@@H](O)[C@@H](O)[C@@H]1O': 2165,
#  'O=C([O-])/C=C(/CCC(=O)[O-])C(=O)[O-]': 1221,
#  'CCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3217,
#  'CC(O)C(N)C(=O)O': 1575,
#  'O=C(O)C(=O)C(O)COP(=O)(O)O': 3126,
#  'C=CC(C)=CCCC(C)(C)O': 358,
#  'CC=[N+]([O-])[O-]': 2,
#  'O=C([O-])CCC1=C(CC(=O)[O-])c2cc3[nH]c(cc4nc(cc5[nH]c(cc1n2)c(CC(=O)[O-])c5CCC(=O)[O-])C(CCC(=O)[O-])=C4CC(=O)[O-])c(CC(=O)[O-])c3CCC(=O)[O-]': 1647,
#  'O=C1O[C@H]([C@@H](O)CO)C([O-])=C1O': 1746,
#  'O=P([O-])([O-])O[C@H]1[C@H](O)[C@@H](OP(=O)([O-])[O-])[C@H](OP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2065,
#  'NCCCCN': 278,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COC(=O)CCCCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCCCC': 323,
#  'O=C(O)CCC1NC(C(=O)O)Cc2c1[nH]c1ccccc21': 1121,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@@H](O)CCCCCCCCCCCCCC': 2356,
#  'CCOC(=O)C(N)CCSC': 313,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCC': 323,
#  'CCCCCCCCCCCC=CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3179,
#  'Cc1ncc(COP(=O)([O-])[O-])c(N)n1': 1325,
#  'CC(C)=CCCC(C)C1CCC2C3=C(CCC21C)C1(C)CCC(=O)CC1CC3': 505,
#  'ClC(Cl)=C(Cl)Cl': 1,
#  'O=c1ccn([C@H]2O[C@@H](COP(=O)(O)OP(=O)(O)OC3O[C@@H](CO)[C@H](O)[C@@H](O)[C@@H]3O)[C@H](O)[C@@H]2O)c(=O)[nH]1': 2548,
#  'C=C[C@]1(C)CC[C@@H](C(C)(C)O)O1': 322,
#  'C/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3157,
#  'O=c1c(OC2OC(CO)C(O)C(O)C2O)c(-c2cc(O)c(O)c(O)c2)oc2cc(O)cc(O)c12': 2916,
#  'O=C(CO)CO': 1001,
#  'CCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3351,
#  'CCCCCCCCCCCCCCCCCCCCC[C@@H](O)[C@H](O)C(=O)N[C@@H](CO)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 1806,
#  'CCCCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3177,
#  'CCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2375,
#  'NC(=O)c1ncn(C2OC(COP(=O)(O)O)C(O)C2O)c1N': 2144,
#  'CSCCC(N)C(=O)O': 1954,
#  'CC(C)c1ccc(CO)cc1': 210,
#  'O=C1O[C@H]([C@H](O)CO)[C@H](O)[C@H]1O': 1828,
#  'C[C@@H](C=O)CCC[C@@H](C)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@@]21C)[C@@]1(C)CC[C@@H](O)C[C@H]1C[C@H]3O': 1302,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2OC2OC(CO)C(O)C(O)C2O)ccc1O': 2960,
#  'Oc1cc(O)c2c(c1)O[C@H](c1cc(O)c(O)c(O)c1)[C@H](O)C2': 1827,
#  'C=C(C)CCOP(=O)(O)OP(=O)(O)O': 622,
#  'Cc1ccc(C)c(C)c1C': 27,
#  'CC(=O)c1cccc(C)c1': 107,
#  '[NH3+]/C(C(=O)[O-])=C(\\C=C\\C=O)C(=O)[O-]': 975,
#  'Nc1c2ncn(C3OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)C(O)C3O)c2nc[n+]1C1OC(COP(=O)(O)O)C(O)C1O': 1964,
#  '[NH3+][C@@H](CCC(=O)N[C@@H](CSC=O)C(=O)NCC(=O)[O-])C(=O)[O-]': 2845,
#  'Nc1ncnc2c1ncn2C1OC(CO)C2OP(=O)(O)OC21': 1808,
#  'NC(=O)N[C@@H](O)C(=O)[O-]': 1252,
#  'Nc1nc(NCC([O-])C([O-])C([O-])COP(=O)([O-])[O-])c(N)c(=O)[nH]1': 1281,
#  'COc1cccc(OC)c1O': 820,
#  'CC(C)=CCC[C@@H](C)[C@@H]1CC[C@]2(C)C3=C(CC[C@@]12C)[C@@]1(C)CC[C@H](O)C(C)(C)[C@@H]1CC3': 806,
#  'COC1=C(OC)C(=O)C(C/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CCC=C(C)C)=C(C)C1=O': 611,
#  'CO[C@H]1O[C@H](CO)[C@H](O)[C@H](O)[C@H]1O': 1746,
#  'O=P(O)(O)O[C@H]1[C@H](OP(=O)(O)O)[C@@H](OP(=O)(O)OP(=O)(O)O)[C@@H](OP(=O)(O)O)[C@@H](OP(=O)(O)OP(=O)(O)O)[C@@H]1OP(=O)(O)O': 1334,
#  'O=C(O)C(O)c1ccc2c(c1)OCO2': 1126,
#  'CSCCC(=O)C(=O)O': 1929,
#  'CC(O)(CCO)CC(=O)[O-]': 1716,
#  'CC(C(=O)O)C(O)C(=O)O': 1465,
#  'CCCCCCCCCC(=O)CC(=O)[O-]': 1386,
#  'NC(=O)CCC(=O)C(=O)[O-]': 2208,
#  'CCCCCC/C=C/C=C\\CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3161,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](CO)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 1749,
#  'CCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O[C@@H]2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2473,
#  'COc1cccc(C/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CCC=C(C)C)c1O': 907,
#  'COc1c(Br)cc(Br)cc1Br': 274,
#  'C[N+](C)(C)CC(=O)[O-]': 391,
#  '[O]c1ccc(O)cc1': 541,
#  'CCCCCCCCCCCCCCCC(=O)OCC(O)COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O': 2395,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@]2(C)C3=C(CC[C@H]2C1(C)C)[C@]1(C)CC[C@H]([C@H](C)CCC=C(C)C)[C@@]1(C)CC3': 355,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2362,
#  'CC=Cc1cnccn1': 28,
#  'COc1cccc(OC)c1': 314,
#  'OC[C@H](O)C(O)[C@@H](O)CO': 1160,
#  'C[NH2+]C(CCc1ncc(CC(N)C(=O)O)[nH]1)C(=O)O': 2009,
#  'O=C([O-])C[C@@H](C(=O)[O-])[C@@H](O)C(=O)[O-]': 1877,
#  'CCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3177,
#  'NC(=O)NC(=O)[O-]': 369,
#  'O=C([O-])CCc1c[nH]c(Cc2[nH]c(Cc3[nH]c(Cc4[nH]c(CO)c(CC(=O)[O-])c4CCC(=O)[O-])c(CC(=O)[O-])c3CCC(=O)[O-])c(CC(=O)[O-])c2CCC(=O)[O-])c1CC(=O)[O-]': 1599,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(CO)C(O)CCCCCCCCCCCCCCC': 1552,
#  '[NH3+][C@@H](CCOP(=O)([O-])[O-])C(=O)[O-]': 2875,
#  'OC[C@H](O)[C@H]1OC(O)[C@@H](O)[C@@H](O)[C@@H]1O': 2199,
#  'OC[C@H]1O[C@H](O[C@@H]2[C@@H](O)[C@H](O)[C@@H](O)[C@@H](O)[C@H]2O)[C@H](O)[C@@H](O)[C@H]1O': 1740,
#  'NCCC=O': 418,
#  'O=C(O)C(=O)CS': 1810,
#  'CSCCO': 450,
#  '[NH3+]CCCC=O': 424,
#  'O=C([O-])C(=O)C(O)C(O)C(O)COP(=O)([O-])O': 3284,
#  'CC1=C(CCC(=O)O)c2cc3[nH]c(cc4nc(cc5[nH]c(cc1n2)c(CCC(=O)O)c5C)C(CCC(=O)O)=C4C)c(CCC(=O)O)c3C': 1109,
#  'Cc1cn(C2CC(O)C(COP(=O)(O)O)O2)c(=O)[nH]c1=O': 2190,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\COP(=O)([O-])OP(=O)([O-])[O-]': 777,
#  'CC(C)[C@@H](C)/C=C/[C@@H](C)[C@H]1CC[C@H]2C3=CC=C4C[C@@H](O[C@H]5O[C@H](CO)[C@@H](O)[C@H](O)[C@H]5O)CC[C@]4(C)[C@H]3CC[C@@]21C': 2036,
#  'Cc1ccc(C)c(C)c1': 27,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]2O[C@@H]([n+]3cccc(C(=O)[O-])c3)[C@H](O)[C@@H]2O)[C@@H](O)[C@H]1O': 2190,
#  'NCSCCC(S)CCCCC(N)=O': 889,
#  'CSSSC': 0,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O[C@@H]2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2454,
#  'O=C[C@@H](O)[C@@H](O)[C@H](O)[C@H](O)C(=O)[O-]': 1680,
#  'O=C([O-])c1ccccc1O': 1295,
#  'NC(=O)C[C@@H]([NH3+])C(=O)[O-]': 1840,
#  'O=CN[C@@H](Cc1ccc(O)cc1)C(=O)O': 1607,
#  'CC(=O)OCC(C)C': 84,
#  'NC1C(O)OC(COP(=O)([O-])O)C(O)C1O': 2905,
#  'CC(=O)OCC[C@H]([NH3+])C(=O)[O-]': 2276,
#  'O=C([O-])CC(O)(CC(=O)[O-])C(=O)[O-]': 1234,
#  'CCCCC[C@H](O)CC(=O)O': 1710,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2OC2OC(COC(=O)C=Cc3ccc(O)cc3)C(O)C(O)C2O)cc(O)c1O': 2891,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CO': 662,
#  'CCCCCC/C=C\\CCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3168,
#  'C#N': 14,
#  'C/C=C/C(=O)C1=C(C)CCCC1(C)C': 415,
#  '[NH3+][C@@H](CCc1ncc(C[C@H]([NH3+])C(=O)[O-])[nH]1)C(=O)[O-]': 2018,
#  'Cc1cccc(O)c1': 540,
#  'OC[C@H]1O[C@@H](O[C@@H]2[C@@H](O)[C@H](O[C@@H]3[C@@H](O)[C@@H](O)O[C@H](CO)[C@H]3O)O[C@H](CO)[C@H]2O)[C@H](O)[C@@H](O)[C@@H]1O': 2112,
#  'SCCc1ccco1': 20,
#  'O=C(CO)C(O)C(O)CO': 1570,
#  'O=C(O)CC[C@](O)(CC(=O)O)C(=O)O': 1571,
#  'CC(C)(COP(=O)(O)O)C(O)C(=O)NCCC(=O)O': 2887,
#  'C/C=C\\c1ccc(O)c(OC)c1': 825,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OC[C@H](N)C(=O)O': 2807,
#  'CCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3357,
#  'O=c1[nH]cnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)C(O)C1O': 2218,
#  'CCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3155,
#  'CCCCCCCCCCCCCCCCCCCCC[C@@H](O)[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@@H](O)CCCCCCCCCCCCCC': 2411,
#  'O=P([O-])([O-])OC[C@H]1O[C@H](O[C@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)[C@H](O)[C@@H](O)[C@@H]1O': 2516,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OCC(N)C(=O)O': 2807,
#  'C=C(C)[C@@H]1CC=C(C=O)CC1': 323,
#  'O=C(O)C1OC(Oc2c(-c3cc(O)c(O)c(O)c3)oc3cc(O)cc(O)c3c2=O)C(O)C(O)C1O': 2469,
#  'NC(=O)CC[C@H](NC(=O)C[NH3+])C(=O)[O-]': 2033,
#  '[NH3+][C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]': 1954,
#  'O=C([O-])[C@@H]1CCCC[NH2+]1': 1139,
#  'O=P(O)(O)OC[C@H]1O[C@](O)(CO)[C@@H](O)[C@H]1O': 2759,
#  'CC(=O)c1ccco1': 31,
#  'NC(=O)NC1NC(=O)NC1=O': 266,
#  'O=C1C[C@@](O)(C(=O)[O-])C[C@@H](O)[C@@H]1O': 2437,
#  'O=P(O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(CO)C(O)C(O)C1O': 2590,
#  'CC(=O)C(N)C(=O)O': 1405,
#  '[NH3+]CCS': 377,
#  'NC(CS(=O)(=O)O)C(=O)O': 1520,
#  'C[N+](C)(C)CCOP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2ccc(N)nc2=O)[C@H](O)[C@@H]1O': 2016,
#  'CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3219,
#  'CCCCCCCCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3179,
#  'O=C(O[C@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1ccc(O)c(O)c1)c1cc(O)c(O)c(O)c1': 947,
#  'CCCCCCCCCCCCCCCC(O)C(N)CO': 1559,
#  'O=C=O': 513,
#  'O=P(O)(OCC(O)CO)OC1C(O)C(O)C(O)C(O)C1O': 2207,
#  'CC(C)C(=O)O': 450,
#  'N[C@H](C(=O)O)C(O)C(=O)O': 2066,
#  'C=CC=CCCCC': 24,
#  'O=C(O)C1=CC(OP(=O)(O)O)C(O)C(O)C1': 2797,
#  'CC(=O)N[C@H]1[C@@H](OP(=O)([O-])[O-])O[C@H](CO)[C@@H](O)[C@@H]1O': 2869,
#  'Nc1nc(=O)c2c([nH]1)NCC(CNc1ccc(C(=O)N[C@H](CCC(=O)O)C(=O)O)cc1)N2C=O': 1579,
#  'O=C([O-])[C@H](O)[C@@H](O)C(=O)[O-]': 1380,
#  'C=C(C)C1CC=C(C(=O)O)CC1': 742,
#  'O=C(O)c1cc(=O)c2ccccc2[nH]1': 1693,
#  'CCC(C)C(=O)[O-]': 616,
#  '[NH3+][C@@H](CCCC(=O)[O-])C(=O)[O-]': 1729,
#  'COc1cc(/C=C\\C(=O)O)ccc1O': 1766,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)([O-])OP(=O)([O-])[O-]': 777,
#  'CCCCCCCCCCCCCCCCCCCCCCC[C@@H](O)[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2732,
#  'O=C(/C=C\\c1ccc(O)cc1)OC[C@H]1O[C@@H](Oc2cc3c(O)cc(O)cc3[o+]c2-c2cc(O)c(O)c(O)c2)[C@H](O)[C@@H](O)[C@@H]1O': 2653,
#  'C=Cc1c(C)c2cc3[nH]c(cc4nc(cc5nc(cc1[nH]2)C(C)=C5CCC(=O)O)C(CCC(=O)O)=C4C)c(C)c3C=C': 1082,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)([O-])[O-])OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1389,
#  'CCCCCC/C=C\\CCCCCCCCCC(=O)OC[C@H](COC(=O)CCCCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC': 322,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCC)COC(=O)CCCCCCCCCCCCCCCCC': 323,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3177,
#  'O=C([O-])CCCc1c[nH]c2ccccc12': 1602,
#  'O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O': 767,
#  '[NH3+][C@@H](CCC(=O)N[C@@H](CSCO)C(=O)NCC(=O)[O-])C(=O)[O-]': 2837,
#  'CCOC(=O)[C@@H](C)O': 919,
#  'O=C(COP(=O)(O)O)C(O)C(O)C(O)CO': 2632,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)OC[C@H](COP(=O)(O)OC[C@H](N)C(=O)O)OC(=O)CCCCCCC/C=C/CCCCCCCC': 2807,
#  'CCCCCCCCCCCCCCCCCC(=O)OC[C@@H](O)COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O': 2395,
#  'CCCCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OP(=O)(O)O': 513,
#  'NC(CCC=O)C(=O)O': 1767,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C\\CC/C=C(\\C)CC/C=C(/C)CC[C@@H]1OC1(C)C': 253,
#  'CCCCCCC[C@@H](O)CC(=O)O': 1710,
#  'CCCCC[C@H]1CCC(=O)O1': 207,
#  'OCCOc1ccccc1': 896,
#  'C[S+](CCC(N)C(=O)[O-])CC1OC(n2cnc3c(N)ncnc32)C(O)C1O': 2840,
#  'CSCCC=O': 209,
#  'Nc1nc2c(ncn2C2O[C@H](CO)[C@@H](O)[C@@H]2O)c(=O)[nH]1': 1356,
#  'Nc1nc2c(ncn2C2OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)C(O)C2O)c(=O)[nH]1': 2252,
#  'Cc1ccc(C)c2occc12': 62,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)(O)OCCN)OC(=O)CCCCCCCC=CCCCCCC': 1469,
#  'CCCCCC/C=C\\CCCCCCCC(=O)[O-]': 937,
#  '[NH3+][C@@H](CCSC[C@@H]([NH3+])C(=O)[O-])C(=O)[O-]': 2165,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)([O-])OCC(O)COP(=O)([O-])OCC(COC(=O)CCCCCCCC=CCCCCCC)OC(=O)CCCCCCCC=CCCCCCC)OC(=O)CCCCCCCC=CCCCCCC': 2189,
#  'NC(=O)c1ncn(C2OC(COP(=O)(O)O)C(O)C2O)c1N=CO': 2126,
#  'CC1=CCC(C(C)C)=CC1': 122,
#  'CCCCCCCCCCCCCCCC(=O)OCC(=O)COP(=O)(O)O': 1642,
#  'CC(C)=CCCC(C)C1CCC2C3=C(CCC21C)C1(C)CCC(O)C(CO)C1CC3': 1427,
#  'CCCCC/C=C/C=C/C=O': 252,
#  'Oc1cc(O)c2cc(O)c(-c3ccc(O)c(O)c3)[o+]c2c1': 1007,
#  'N=C(CC(=O)O)C(=O)O': 1006,
#  'O=P([O-])([O-])OC[C@H]1O[C@@](CO)(OP(=O)([O-])[O-])[C@@H](O)[C@@H]1O': 2539,
#  'Nc1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@@H](O)[C@H](O)[C@H](O)CO)[C@@H](O)[C@H]2O)c(=O)n1': 2171,
#  'Nc1ncnc2c1ncn2C1CC(O)C(COP(=O)(O)O)O1': 2199,
#  'Nc1ccn(C2OC3COP(=O)(O)OC3C2O)c(=O)n1': 1963,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3177,
#  '[NH3+][C@@H](CCC(=O)NCCCC(=O)[O-])C(=O)[O-]': 2181,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)(O)O': 1389,
#  'O=C([O-])c1cc(O)c(O)c(O)c1': 1538,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C=C(\\C)CC/C=C(\\C)CCC=C(C)C': 175,
#  '[NH3+][C@@H](CCCC[NH2+][C@@H](CCC(=O)[O-])C(=O)[O-])C(=O)[O-]': 2078,
#  'OC[C@H]1O[C@@](CO)(O[C@H]2O[C@H](CO[C@H]3O[C@H](CO)[C@H](O)[C@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@@H]1O': 1858,
#  'Nc1nc2c(c(=O)[nH]1)[N+]1=CN(c3ccc(C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-])cc3)C[C@H]1CN2': 1417,
#  'CCCCCCCCCCCCC[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3219,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])OC1C(O)C(O)C(O)C(O)C1O': 2367,
#  'CC(C)(COP(=O)([O-])[O-])C(O)C(=O)NCCC(=O)NC(CS)C(=O)[O-]': 3002,
#  'OC1C2COC(O2)C(O)C1O': 1489,
#  'CC(C)=C[C@@H]1C[C@H](C)CCO1': 170,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2375,
#  'O=C(O)/C=C/Cl': 70,
#  'C[N+](C)(C)C[C@@H](O)CC(=O)[O-]': 893,
#  'O=c1nc[nH]c2c1ncn2C1O[C@H](CO)[C@@H](O)[C@@H]1O': 1761,
#  'CCCCc1ccco1': 34,
#  'CCOc1cc(C=O)ccc1O': 841,
#  'C=CC=O': 12,
#  'CCCCCCCCC=CCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3154,
#  'O=CCC(=O)[O-]': 830,
#  'O=C([O-])CCC1=C(CC(=O)[O-])c2cc3[nH]c(cc4nc(cc5[nH]c(cc1n2)c(CC(=O)[O-])c5CCC(=O)[O-])C(CC(=O)[O-])=C4CCC(=O)[O-])c(CC(=O)[O-])c3CCC(=O)[O-]': 1647,
#  'C[C@@H](O)C(=O)[O-]': 1068,
#  'CC(O)(CC(=O)C(=O)[O-])C(=O)[O-]': 1923,
#  'C/C=C(/C=O)c1ccccc1': 94,
#  'Nc1cncn1C1OC(COP(=O)(O)O)C(O)C1O': 2108,
#  'CCCCCCCCCCCCCCCCCCCCCC(=O)[O-]': 634,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@@H](CO)COC(=O)CCCCCCCCCCCCCCCCC': 1224,
#  'O=P([O-])([O-])O[C@@H]1[C@@H](O)[C@@H](O)[C@@H](OP(=O)([O-])[O-])[C@H](O)[C@H]1O': 2067,
#  'CC(=O)[C@H](O)COP(=O)([O-])[O-]': 2369,
#  'CCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3177,
#  'CCOC(=O)CCC(C)=O': 519,
#  'O=P([O-])([O-])O[C@H]1[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@@H]1OP(=O)([O-])[O-]': 2076,
#  'CC[C@H](O)CO': 974,
#  'OCc1cccs1': 131,
#  'NC(=O)c1ncn(C2OC(COP(=O)([O-])[O-])C(O)C2O)c1NC=NCC(=O)C(O)C(O)COP(=O)([O-])[O-]': 2399,
#  '[NH3+][C@H](CC(=O)[O-])C(=O)[O-]': 1689,
#  'CCOC(=O)CCC(=O)OCC': 169,
#  'CC(=O)O[C@@H]1[C@@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]2O[C@@H](n3cnc4c(N)ncnc43)[C@H](O)[C@@H]2O)OC(O)[C@@H]1O': 2545,
#  'OCCc1c[nH]c2ccccc12': 899,
#  'NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c1': 2229,
#  'CC(C)[C@H]([NH3+])C(=O)[O-]': 976,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/COP(=O)([O-])OP(=O)([O-])[O-]': 771,
#  'O=C[O-]': 111,
#  'NC(=O)C1=CN([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](OP(=O)([O-])[O-])[C@@H]3O)[C@@H](O)[C@H]2O)C=CC1': 2273,
#  'CCCCCCCCCCCCCC[C@@H](O)[C@H](O)[C@H](N)COP(=O)(O)O': 2627,
#  'O=P(O)(O)O[C@H]1[C@H](O)[C@@H](O)[C@@H](OP(=O)(O)O)[C@@H](OP(=O)(O)O)[C@@H]1OP(=O)(O)O': 2026,
#  'CC(C=O)C(=O)[O-]': 900,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](COP(=O)(O)O[C@H]2C(O)C(O)C(O)[C@@H](O)C2O)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2017,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2467,
#  'CC(CCC[C@@H](C)C1CCC2C3C(CC[C@@]21C)[C@@]1(C)CC[C@@H](O)C[C@H]1C[C@H]3O)C(=O)O': 1846,
#  'O=C[C@H](O)[C@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 2475,
#  'O=C(O)[C@H](O)[C@@H](O)COP(=O)(O)O': 2884,
#  'O=P([O-])([O-])O[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O': 2868,
#  'CCCCCCCCC=CCCCCCCCC(=O)OC1CCC2(C)C3=C(CCC2C1(C)C)C1(C)CCC(C(C)CCC=C(C)C)C1(C)CC3': 355,
#  'CC1(C)COC(=O)C1O': 1338,
#  'C[C@H]([NH3+])C(=O)N[C@H](CC(=O)[O-])C(=O)[O-]': 1813,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)([O-])OC[C@H]([NH3+])C(=O)[O-]': 2807,
#  'CC(=O)N[C@H]1[C@H](O[C@@H]2[C@@H](CO)O[C@H](OP(=O)([O-])OP(=O)([O-])OCCC(C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(\\C)CC/C=C(\\C)CCC=C(C)C)[C@H](NC(C)=O)[C@H]2O)O[C@H](CO)[C@@H](O[C@@H]2O[C@H](CO[C@H]3O[C@H](CO[C@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]4O[C@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]4O)[C@@H](O)[C@H](O[C@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]4O[C@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]4O)[C@@H]3O)[C@@H](O)[C@H](O[C@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]3O[C@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]3O[C@H]3O[C@H](CO)[C@@H](O)[C@H](O[C@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@H]4O)[C@@H]3O)[C@@H]2O)[C@@H]1O': 3040,
#  'CCCCCCCC/C=C\\CCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3119,
#  'N#C[S-]': 0,
#  'CCC(CCO)C(C)C': 546,
#  'Cc1cc2c3c(c1C)C(C)(C)CCN3c1c([nH]c(=O)[nH]c1=O)N2C[C@H](O)[C@H](O)[C@H](O)COP(=O)(O)O': 1496,
#  'CCCCCCC=CCCCCCCCCCC(=O)OCC(COP(=O)([O-])OP(=O)([O-])OCC1OC(n2ccc(N)nc2=O)C(O)C1O)OC(=O)CCCCCCCCCC=CCCCCCC': 2263,
#  'CC(=O)OC(COP(=O)(O)O[C@@H]1[C@H](O)[C@H](OP(=O)(O)O)[C@@H](OP(=O)(O)O)[C@H](OP(=O)(O)O)[C@H]1O)OC(C)=O': 1815,
#  'C[n+]1cccc(C(N)=O)c1': 255,
#  'OCc1ccco1': 468,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O': 1232,
#  'NC(C(=O)O)C(O)COP(=O)(O)O': 3214,
#  'CCc1nccs1': 10,
#  'C[C@@H](O)CO': 973,
#  'CCSSCC': 7,
#  'C[S+](CCC(=O)C(=O)[O-])C[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1O': 2715,
#  'CCCCCCCCC=CCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC': 323,
#  'N[C@H](CCC(=O)O)C(=O)O': 1812,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2OP(=O)([O-])[O-])c(=O)[nH]1': 2310,
#  'CCSCC': 8,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]2O[C@@H]3OP(=O)([O-])O[C@@H]3[C@@H]2O)[C@@H](O)[C@H]1O': 2312,
#  'CCCCCCCCCCCCCCCCCCC[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3219,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)(O)OC[C@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC': 2189,
#  'OC[C@@]1(O)OC[C@H](O)[C@@H](O)[C@@H]1O': 1772,
#  'CCCCCC/C=C\\CCCCC/C=C/C(=O)SCCN=C(O)CCN=C(O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@@H]1O[C@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3186,
#  'CCCCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](CO)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 1771,
#  '[NH3+]C(CC=O)C(=O)[O-]': 1155,
#  'O=C([O-])[C@H]1O[C@H](OP(=O)([O-])OP(=O)([O-])OC[C@H]2O[C@@H](n3ccc(=O)[nH]c3=O)[C@H](O)[C@@H]2O)[C@H](O)[C@@H](O)[C@@H]1O': 2885,
#  'CCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3177,
#  'COc1cc(CCC(C)=O)ccc1O': 1257,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(CO)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2675,
#  'Nc1ncnc2c1ncn2C1OC(COP(=O)(O)O)C(O)C1O': 2177,
#  'Nc1ncnc2c1ncn2[C@H]1C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])[O-])O1': 2246,
#  '[NH2+]=C(CNC=O)NC1OC(COP(=O)([O-])[O-])C(O)C1O': 2164,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]2O[C@H](OP(=O)([O-])[O-])[C@H](O)[C@@H]2O)[C@@H](O)[C@H]1O': 2617,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OC[C@@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 2189,
#  'O=C([O-])[C@H]1CCC[NH2+]1': 1043,
#  'CCCCC/C=C\\C/C=C/CCCCCCCC(=O)O': 967,
#  'CC(=O)OCCc1ccccc1': 201,
#  'O=c1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c(=O)[nH]1': 2262,
#  'CCCCCCCCC[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3224,
#  '[NH3+]CC(=O)NC1OC(COP(=O)([O-])[O-])C(O)C1O': 2455,
#  'CCO': 255,
#  'CCCCCCCC(=O)CCCCCCC': 328,
#  'CCc1cnc(C)s1': 10,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2234,
#  'O=P(O)(O)O[C@@H]1[C@@H](OP(=O)(O)O)[C@H](OP(=O)(O)OP(=O)(O)O)[C@@H](OP(=O)(O)OP(=O)(O)O)[C@H](OP(=O)(O)O)[C@@H]1OP(=O)(O)O': 1329,
#  'O=[N+]([O-])c1ccc([O-])cc1': 360,
#  'NCCS(=O)(=O)O': 309,
#  'CCCCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)(O)O': 1389,
#  'COc1cc(-c2[o+]c3cc(O)cc([O-])c3cc2[O-])cc(OC)c1O': 1240,
#  'O=c1ccn([C@H]2C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])O2)c(=O)[nH]1': 2285,
#  'C[N+](C)(C)CCOP(=O)([O-])OC[C@H](O)CO': 2069,
#  'OC[C@H]1O[C@H](O[C@]2(CO)O[C@H](CO)[C@@H](O)[C@@H]2O)C(O)C(O)C1O': 1814,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)O': 918,
#  'CCCCCCCCC=O': 292,
#  'CC(C)(COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O)[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)CC(=O)O': 3534,
#  'CCCCCCCCC[C@H](O)CC(=O)O': 1710,
#  'COC1=C(O)C(=O)C(C)=C(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)C1=O': 1111,
#  'O=P([O-])([O-])OC[C@H]1O[C@H](O)C[C@@H]1O': 2819,
#  'CC(C)=CCC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CCC(=O)[C@@H](C)[C@@H]1CC3': 506,
#  'O=CCCl': 63,
#  'Nc1nc2c([nH]c(=O)n2C2CC(O)C(COP(=O)(O)O)O2)c(=O)[nH]1': 2228,
#  'CC(=O)N[C@H](CCC(N)=O)C(=O)[O-]': 1827,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OC[C@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC': 1563,
#  'O=C([O-])[C@@H](COP(=O)([O-])[O-])OP(=O)([O-])[O-]': 2207,
#  'CC(=O)Oc1ccc(O)cc1': 697,
#  'C=C(C)c1ccc(C)cc1': 27,
#  'CCC[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3212,
#  'COc1nccnc1C(C)C': 277,
#  'O=C(O)C=CC(=O)O': 708,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCCCC': 323,
#  'CCCCCC=CCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)(O)OC1C(O)C(O)C(O)C(OP(=O)(O)O)C1O': 2705,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](O)CO': 1738,
#  'O=c1cc(O)cc2oc(-c3ccc(O)c(O)c3)c(OC3OC(C/[O+]=C(O)/C=C/c4ccc(O)cc4)C(O)C(O)C3O)cc1-2': 2704,
#  'O=C[C@H](O)[C@H]1OC(=O)[C@@H](O)[C@H]1O': 1346,
#  'NCC(=O)NC(CC(N)=O)C(=O)O': 1976,
#  'OC1CCCCC1': 570,
#  'CC(C(=O)NCCC(=O)NCCS)C(C)(C)COP(=O)([O-])[O-]': 1550,
#  'O=C1O[C@H](CO)[C@H](O)[C@@H]1O': 1768,
#  'CCOC(=O)c1ccc(OCC)cc1': 218,
#  'CC/C=C/CCOC(C)=O': 213,
#  'Cc1ccc(O)c([N+](=O)[O-])c1': 753,
#  'O=C(O)Cc1cc(O)ccc1O': 1894,
#  'CC1=C(C=O)C(C)(C)CCC1': 373,
#  'CC[C@H]([NH3+])C(=O)[O-]': 1261,
#  'CC1(CC(=O)O)C2=Cc3[nH]c(c(CCC(=O)O)c3CC(=O)O)Cc3[nH]c(c(CC(=O)O)c3CCC(=O)O)C=C3N=C(C=C(N2)C1CCC(=O)O)C(C)(CC(=O)O)C3CCC(=O)O': 986,
#  'C[C@H](CCC(=O)NCCS(=O)(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@H](O)[C@@]21C)[C@@]1(C)CC[C@@H](O)C[C@@H]1C[C@H]3O': 1349,
#  'O=C([O-])Nc1cncn1[C@@H]1O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2148,
#  'Cc1c2[nH]c(c1CCC(=O)[O-])Cc1[nH]c(c(CCC(=O)[O-])c1C)Cc1[nH]c(c(CCC(=O)[O-])c1C)Cc1[nH]c(c(C)c1CCC(=O)[O-])C2': 1588,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 1737,
#  'Oc1cc(O)c2cc(O)c(-c3cc(O)c(O)c(O)c3)[o+]c2c1': 990,
#  'C[C@H](NC(=O)CC[C@H](N)C(=O)O)C(=O)O': 2259,
#  'CC(=O)CCC=C(C)C': 430,
#  'O=C([O-])C(O)C(O)C(O)C(O)COP(=O)([O-])O': 2966,
#  'CC=O': 113,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)(O)OP(=O)(O)OC[C@H]2O[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H]1O': 2454,
#  '[O-]c1cc(O)cc2[o+]c(-c3cc(O)c(O)c(O)c3)c(O[C@@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@H]3O)cc12': 2773,
#  'CCCCCCCCCCCCCCCC(=O)OC[C@@H](O)COP(=O)([O-])OC[C@H]([NH3+])C(=O)[O-]': 2913,
#  'CCCCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3179,
#  'C[S+](C)CC[C@H]([NH3+])C(=O)[O-]': 1867,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])OCC(O)COP(=O)([O-])OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCC': 1991,
#  'CCCC/C=C/C=C\\C=O': 222,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1[C@H](OC2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2246,
#  'CC(=O)N[C@@H](C)C(=O)O': 279,
#  'CC(C)(COP(=O)(O)O)C(O)C(=O)NCCC(=O)NCCS': 2512,
#  'CCCCCCCCCCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3185,
#  'O=c1[nH]cnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2241,
#  'CC(=O)OCc1ccccc1': 117,
#  'NCCS(=O)O': 254,
#  'O=CNc1ccccc1C(=O)O': 696,
#  'CCCCCCCCCCCCCCCCCCCCCC(O)C(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1[C@H](O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)C(O)CCCCCCCCCCCCCC': 2732,
#  'O=C1OC(COP(=O)([O-])O)C(O)C(O)C1O': 2474,
#  'CC=CSC': 3,
#  'Nc1ccc(C(=O)[O-])cc1': 294,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COC(=O)CCCCCCCC=CCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCC': 322,
#  'O=C([O-])Cc1c[nH]c2ccccc12': 700,
#  'Nc1ccn([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c(=O)n1': 2525,
#  'CCCCCCCC/C=C\\C=C\\CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3161,
#  'O=C1CCCO1': 134,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\COP(=O)(O)OP(=O)(O)O': 775,
#  'CCc1cc(C)ccc1C': 54,
#  'COC1CC2CCC(C)C(O)(O2)C(=O)C(=O)N2CCCCC2C(=O)OC(C(C)CC2CCC(O)C(OC)C2)CC(=O)C(C)C=C(C)C(O)C(OC)C(=O)C(C)CC(C)C=CC=CC=C1C': 2387,
#  'O=C[C@@H](O)[C@H](O)[C@@H](O)CO': 1569,
#  '[NH3+][C@H]1[C@@H](OP(=O)([O-])[O-])O[C@H](CO)[C@@H](O)[C@@H]1O': 2954,
#  'COc1c(Cl)cc(Cl)cc1Cl': 282,
#  'CC[C@@H](C)[C@H]([NH3+])C(=O)[O-]': 1208,
#  'CCOC(=O)CC': 94,
#  'CCCC(=O)C(C)=O': 371,
#  'NC(=O)c1ccccc1': 33,
#  'CCC(=O)[O-]': 569,
#  'NC(=O)c1ccc[n+](C2OC(COP(=O)([O-])OP(=O)(O)OCC3OC(n4cnc5c(N)ncnc54)C(O)C3O)C(O)C2O)c1': 2083,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)([O-])O[C@@H]1[C@H](O)[C@H](O)[C@@H](OP(=O)([O-])[O-])[C@H](O)[C@H]1O': 2664,
#  'C[C@H]([NH3+])C(=O)N[C@H](C(=O)[O-])[C@@H](C)O': 1761,
#  'CCOC(=O)c1ccccc1': 71,
#  'NC(=O)Cc1ccccc1': 108,
#  'Cc1nc(C(C)C)cs1': 4,
#  'N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(=O)O)C(=O)O': 2530,
#  'CCCCCC(=O)CC': 332,
#  'CCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3351,
#  'CC(=O)C(O)C(O)COP(=O)(O)O': 2467,
#  'CCCCCCCC1CCC(=O)O1': 207,
#  'CC(=O)Oc1ccccc1': 224,
#  'CCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3351,
#  'CC(CC(=O)O)c1ccccc1': 883,
#  'CC(C)CC(=O)C(=O)[O-]': 1652,
#  'Nc1ccn(C2O[C@H](CO)[C@H]3OP(=O)(O)O[C@@H]23)c(=O)n1': 1871,
#  'O=c1ccn([C@@H]2O[C@H](CO)[C@@H](OP(=O)([O-])[O-])[C@H]2O)c(=O)[nH]1': 2283,
#  'O=C([O-])C(=O)C(C(=O)[O-])C(O)C(=O)[O-]': 1606,
#  'Clc1ccccc1': 27,
#  'Cc1cnc(=O)[nH]c1N': 320,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](O)COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O': 2434,
#  '[NH3+][C@@H](CCC(=O)OP(=O)([O-])[O-])C(=O)[O-]': 2808,
#  'CC1=C(CCC(=O)[O-])c2cc3[nH]c(cc4nc(cc5[nH]c(cc1n2)c(CCC(=O)[O-])c5C)C(C)=C4CCC(=O)[O-])c(CCC(=O)[O-])c3C': 1635,
#  'C[C@@H](CO)C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3221,
#  'OC[C@H]1OC(CO)(O[C@@H]2O[C@H](CO[C@@H]3O[C@H](CO[C@@H]4O[C@H](CO)[C@H](O)[C@H](O)[C@H]4O)[C@H](O)[C@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@@H]1O': 1858,
#  'CCCCCCCCC=CCCCCCCCC(=O)OCC(O)COP(=O)([O-])OCC[N+](C)(C)C': 2139,
#  'O=C(O)CCC(C(=O)O)C(=O)C(=O)O': 1051,
#  'CCCCCCCCCCCCCC[C@@H](O)[C@@H](O)[C@@H]([NH3+])CO': 1740,
#  'CS(=O)CC[C@@H](N)C(=O)O': 1461,
#  'COC(=O)[C@H](O)[C@@H](C(=O)[O-])C(C)C': 898,
#  'O=C(O)[C@@H](O)[C@@H](O)[C@H](O)[C@H](O)C(=O)O': 1419,
#  'CC(C)C(C(=O)O)C(=O)C(=O)O': 1441,
#  '[NH3+]CCOP(=O)([O-])[O-]': 1508,
#  '[NH3+][C@@H](COP(=O)([O-])[O-])C(=O)[O-]': 2779,
#  'Cc1ccccc1O': 587,
#  'Cc1ccccc1C': 29,
#  'Nc1ccn(C2CC(O)C(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O2)c(=O)n1': 2278,
#  'O=c1c(OC2OC(C(O)CO)C(O)C2O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12': 2733,
#  'C[C@H]([NH3+])C(=O)CCCCCC(=O)[O-]': 1070,
#  'NC(CS(=O)[O-])C(=O)[O-]': 1376,
#  'O=c1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2OP(=O)([O-])[O-])c(=O)[nH]1': 2300,
#  'O=C([O-])C(=O)Cc1c[nH]c2ccccc12': 2176,
#  'Nc1nc2c(c(=O)[nH]1)N=C(COP(=O)([O-])OP(=O)([O-])[O-])CN2': 1404,
#  'CCCCCCCCCCCCCCCC(=O)OC[C@@H](O)COP(=O)([O-])[O-]': 2417,
#  'CC(=O)OC[C@H]([NH3+])C(=O)[O-]': 1914,
#  'O=C([O-])C(=O)Cc1ccccc1': 1188,
#  'C[N+](C)(C)CCOP(=O)([O-])[O-]': 1119,
#  'NC(C=O)Cc1c[nH]cn1': 473,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)([O-])OCC[N+](C)(C)C)OC(=O)CCCCCCCC=CCCCCCCCC': 1057,
#  'NC(=NCCCC(N)C(=O)O)NP(=O)(O)O': 2394,
#  'O=C1O[C@H]([C@@H](O)CO)C(=O)[C@@H]1O': 1992,
#  'Nc1nc2c(ncn2[C@H]2C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])O2)c(=O)[nH]1': 2257,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@@]2(C)C(=CC=C3[C@@H]2CC[C@@]2(C)[C@H]3CC[C@@H]2[C@H](C)/C=C/[C@H](C)C(C)C)C1': 300,
#  'O=c1cc[nH]c(=O)[nH]1': 286,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])OC[C@@H](O)CO': 2552,
#  'CCCCCC=CCC=CC=CC=CC1OC1CCCC(=O)O': 1245,
#  'C[C@@H](O)[C@H](NC(=O)OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1O)C(=O)[O-]': 2414,
#  'CCCCCC1CCCC(=O)O1': 216,
#  'CC(C)(CO)C(=O)C(=O)O': 1879,
#  'C[C@@]1(CC(=O)[O-])/C2=C/c3[nH]c(c(CCC(=O)[O-])c3CC(=O)[O-])Cc3[nH]c(c(CC(=O)[O-])c3CCC(=O)[O-])Cc3[nH]c(c(CC(=O)[O-])c3CCC(=O)[O-])CC(=N2)[C@H]1CCC(=O)[O-]': 1527,
#  'O=C([O-])[C@@H]1C[C@@H](O)C=N1': 1276,
#  'CC(=O)OCCC(C)C': 187,
#  'Cc1ccc(C(=O)O)c(C)c1': 306,
#  'CCCCCCCCCCCCCCCC(O)C(CO)NC=O': 1456,
#  'CCCCCCCCCCCCCCCCCCCCCCC[C@@H](O)[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2508,
#  'CCc1ccc(O)c(OC)c1': 827,
#  'CCOC(=O)C[C@@H](C)O': 1042,
#  'O=C([O-])C(=O)COP(=O)([O-])[O-]': 2021,
#  'NCC=O': 292,
#  'C[Se]C[C@H]([NH3+])C(=O)[O-]': 1117,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](CO)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 1771,
#  'C[Se]CC[C@@H](N)C(=O)O': 1350,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2448,
#  'O=C([O-])C[C@H](C(=O)[O-])C(=O)C(=O)[O-]': 1888,
#  'CCCCCc1ccco1': 89,
#  'CCCCCCCCCCCCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3185,
#  'CCC(=O)C(O)CC': 794,
#  'O=P(O)(O)OC1C(O)C(OP(=O)(O)O)C(OP(=O)(O)O)C(OP(=O)(O)O)C1O': 2004,
#  'O=P(O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(COP(=O)(O)OC2C(O)C(O)C(O)C(O)C2O)C(O)C(O)C1O': 2419,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(O)COP(=O)([O-])OCC[N+](C)(C)C': 1897,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](OP(=O)([O-])[O-])[C@H](OP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2662,
#  'CN1c2c(nc(N)[nH]c2=O)NCC1CNc1ccc(C(=O)NC(CCC(=O)NC(CCC(=O)NC(CCC(=O)O)C(=O)O)C(=O)O)C(=O)O)cc1': 1780,
#  'C=C(O[C@@H]1C=C(C(=O)[O-])C=C[C@H]1O)C(=O)[O-]': 1303,
#  'NC[C@@H](O)CC[C@H](N)C(=O)O': 2374,
#  'CCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3179,
#  'O=C([O-])c1ccccc1NCC(=O)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 2745,
#  'Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1': 678,
#  '[NH3+][C@@H](CSSC[C@H]([NH3+])C(=O)[O-])C(=O)[O-]': 1350,
#  'C1CCNCC1': 39,
#  'CC(C)=CCC[C@H](C)[C@@H]1CC[C@H]2C3=C(CC[C@]12C)[C@@]1(C)CC[C@H](O)[C@@](C)(C(=O)O)[C@H]1CC3': 1779,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3163,
#  'CC(C)(COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1O)C(O)C(=O)NCCC(=O)NCCS': 2480,
#  'N[C@H](CCOC(=O)CCC(=O)O)C(=O)O': 2278,
#  'COC(=O)C(=CC(=O)[O-])CC(=O)[O-]': 1212,
#  'O=C1CC(C(=O)O)NC(=O)N1': 1467,
#  'O=C(O)CNC(=O)Cc1ccccc1': 1678,
#  'CCCC(=O)[O-]': 613,
#  'Nc1c(NC[C@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-])[nH]c(=O)[nH]c1=O': 2219,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)(O)OCC(O)COP(=O)(O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCC)OC(=O)CCCCCCCC=CCCCCCCCC': 2189,
#  'Nc1nc2c(c(=O)[nH]1)NC(CNc1ccc(C(=O)NC(CCC(=O)O)C(=O)O)cc1)CN2': 1685,
#  'CCCOC(C)=O': 148,
#  'CC1=C(O)C(=O)CC1': 780,
#  'Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)OP(=O)(O)OCC2OC(n3cnc4c(N)ncnc43)C(O)C2O)C(O)C1O': 1928,
#  'O=C(O)c1cc(=O)c2cccc(O)c2[nH]1': 1740,
#  'CCCCCc1cccs1': 11,
#  'O=c1ccn([C@H]2C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])[O-])O2)c(=O)[nH]1': 2300,
#  'O=P([O-])([O-])O[C@@H]1C[C@H](O)[C@@H](CO)O1': 2902,
#  'Nc1nc2c(c(=O)[nH]1)NC(CNc1ccc(C(=O)NC(CCC(=O)NC(CCC(=O)O)C(=O)O)C(=O)O)cc1)CN2': 1280,
#  'CC=C(C=O)CSC': 160,
#  'CC(O)C(O)C1CNc2ncnc(O)c2N1': 1226,
#  'COC(=O)Cc1ccccc1': 110,
#  '[NH3+][C@@H](CCO)C(=O)[O-]': 2136,
#  'CC(C)=CCCC(C)=CCOP(=O)([O-])OP(=O)([O-])[O-]': 763,
#  'CCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3183,
#  'COc1cc(C(=O)O)cc(OC)c1O': 1635,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCc1cc(C(=O)O)cc(O)c1O': 1706,
#  'CC1=CCC2(CC1)C(=C(C)C)CCC2C': 159,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O[C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]2O)[C@@H]1O)[C@@H](O)C(=O)NCCC(=O)NCCS': 2868,
#  'CCCCCOC(=O)CC': 156,
#  'C=CC1=C(C)C(C=c2[nH]c(=Cc3[nH]c(C=C4NC(=O)C(C)=C4C=C)c(C)c3CCC(=O)O)c(CCC(=O)O)c2C)=NC1=O': 1042,
#  'Nc1ccccc1C(=O)CC(=O)C(=O)O': 2376,
#  'Cc1cccs1': 0,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\COP(=O)(O)OP(=O)(O)O': 777,
#  'CCCC(=O)OCC': 166,
#  'O=Cc1cccc(Cl)c1': 117,
#  'CC(C)CC(NC(=O)C(C)N)C(=O)O': 1186,
#  'O=C1CC[C@@H](C(=O)[O-])N1': 1677,
#  'CC(=O)C(=O)[O-]': 1128,
#  '[NH3+]CCSP(=O)([O-])[O-]': 473,
#  'CCc1csc(CC)n1': 4,
#  'Cn1cnc2nc(N)[nH]c(=O)c21': 315,
#  'O=P([O-])([O-])OCC(O)CO': 2229,
#  'Nc1c(NC[C@H](O)[C@H](O)[C@H](O)CO)[nH]c(=O)[nH]c1=O': 1362,
#  'O=c1[nH]cnc2c1ncn2C1CC(O)C(COP(=O)(O)OP(=O)(O)O)O1': 2269,
#  'CC(=O)N[C@H](CO)C(=O)[O-]': 1860,
#  'CC=CC=C1C(C)=CC(=O)CC1(C)C': 437,
#  'O=P(O)(O)OC1[C@@H](O)[C@@H](O)C(O)[C@H](O)[C@H]1O': 2118,
#  'O=C(O)/C=C\\c1ccccc1': 581,
#  'c1ccc(-c2ccccc2)cc1': 35,
#  'O=C([O-])CC(=O)C(=O)[O-]': 1916,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)(O)OP(=O)(O)O': 411,
#  'CC(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)[O-]': 1679,
#  '[NH3+][C@@H](CCC[C@H]([NH3+])C(=O)[O-])C(=O)[O-]': 1511,
#  'CCC(O)C(=O)O': 1669,
#  'CC(=O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1O': 2035,
#  'C=C(O[C@@H]1CC(C(=O)[O-])=C[C@@H](OP(=O)([O-])[O-])[C@H]1O)C(=O)[O-]': 2631,
#  'CC(C)=CCCC(C)C1CCC2C3=C(CCC21C)C1(C)CCC(O)C(C)C1CC3': 801,
#  'CCCC(S)CCOC(C)=O': 321,
#  'Oc1ccc(/C=C\\c2cc(O)cc(O)c2)cc1': 622,
#  'O=P(O)(O)OCC1OC(OC2(CO)OC(CO)C(O)C2O)C(O)C(O)C1O': 2567,
#  'CCCc1ccccc1': 19,
#  'O=C([O-])CC(Nc1ncnc2c1ncn2C1OC(COP(=O)([O-])[O-])C(O)C1O)C(=O)[O-]': 2639,
#  'CSSc1ccoc1C': 3,
#  'O=CCC(O)C(O)CO': 1489,
#  'NC(=O)CC[C@H]([NH3+])C(=O)[O-]': 1966,
#  'COc1c(Cl)cc(Cl)c(Cl)c1Cl': 282,
#  'CC(C)=CCC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CC[C@H](O)[C@@H](C=O)[C@@H]1CC3': 1149,
#  'C#CC(=O)[O-]': 346,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@@H](CO)COC(=O)CCCCCCCCCCCCCCCCC': 1224,
#  'O=Cc1ccc2c(c1)OCO2': 178,
#  'O=C(O)c1ccccc1NC1OC(COP(=O)(O)O)C(O)C1O': 2442,
#  'O=P([O-])([O-])O[C@H]1O[C@H](CO)[C@@H](O)[C@H]1O': 2795,
#  'O=CC(O)C(O)COP(=O)(O)O': 2359,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\COP(=O)(O)OP(=O)(O)O': 777,
#  'Cc1ncc(COP(=O)(O)O)c(CO)c1O': 2375,
#  'NC(CC(O)C=O)C(=O)[O-]': 2347,
#  'CCOC(=O)C(O)C(O)C(=O)OCC': 1121,
#  'O=C([O-])COP(=O)([O-])[O-]': 1510,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2OC2OC(COC(=O)C=Cc3ccc(O)cc3)C(O)C(O)C2O)cc(OC)c1O': 2884,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](CO)COC(=O)CCCCCCCCCCCCCCC': 1224,
#  'Cc1ccc(C=O)cc1': 182,
#  'C=CC1=C(C)/C(=C/c2[nH]c(Cc3[nH]c(/C=C4\\NC(=O)C(C)=C4C=C)c(C)c3CCC(=O)[O-])c(CCC(=O)[O-])c2C)NC1=O': 1587,
#  'CCCCC(C)O': 562,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](CO)[C@@H](OP(=O)([O-])[O-])[C@H]2O)c(=O)[nH]1': 2300,
#  'CCCCCC/C=C\\CCCCCCCCCC(=O)OC(COC(=O)CCCCCCC/C=C\\CCCCCCCC)COC(=O)CCCCCCC/C=C\\CCCCCCCC': 322,
#  'CCCC(=O)CC(=O)SCCN=C(O)CCN=C(O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)C(O)[C@H]1OP(=O)(O)O': 3345,
#  'Nc1ccn(C2CC(O)C(CO)O2)c(=O)n1': 1470,
#  'COc1cc(C23Oc4cc(O)ccc4C(C2OC2OC(CO)C(O)C(O)C2O)C(C)(C(C)=O)O3)cc(O)c1O': 3092,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c(=O)[nH]1': 2203,
#  'CCOC(C)=O': 75,
#  '[NH3+][C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]([NH3+])C(=O)[O-])C(=O)NCC(=O)[O-])C(=O)NCC(=O)[O-])C(=O)[O-]': 2234,
#  'Nc1c(C(=O)O)ncn1C1OC(COP(=O)(O)O)C(O)C1O': 2239,
#  'OCCc1ccccc1': 456,
#  'O=C([O-])C1=CC(=O)[C@@H](O)[C@H](O)C1': 2305,
#  'Nc1ncnc2c1ncn2C1OC(CO)C(OP(=O)([O-])[O-])C1O': 2267,
#  'O=C(O)[C@H]1C[C@H](O)CN1': 1865,
#  'Cc1ccsc1': 7,
#  'CCCCCC(C)=O': 363,
#  'CC(C)=CCCC(C)=CCCC(C)=CC(=O)O': 839,
#  'CC(C)C(=O)C(=O)[O-]': 1045,
#  'O=CCc1c[nH]c2ccc(O)cc12': 966,
#  'NCCC(O)=NC(Cc1cnc[nH]1)C(=O)O': 1863,
#  'Cc1cc(=O)oc2cc(O)ccc12': 720,
#  'CCCCCCCCC(C)CC': 58,
#  'CC(=O)OCC1OC(Oc2cc3c(O)cc(O)cc3[o+]c2-c2cc(O)c(O)c(O)c2)C(O)C(O)C1O': 2708,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](CO)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2684,
#  'CCCCCCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3177,
#  'NC(=O)c1cnccn1': 234,
#  'C=C(CC[C@@H](C)[C@H]1CC[C@H]2C3=CC[C@H]4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@@]21C)C(C)C': 731,
#  'CCCCC/C=C\\C[C@@H](O)/C=C/C=C\\C=C\\[C@@H](O)CCCC(=O)O': 1793,
#  'CC(C(=O)O)C(=O)O': 936,
#  'CCCCCC/C=C\\CCCCCCCCCC(=O)O[C@H](CO)COC(=O)CCCCCCCCCCCCCCC': 1223,
#  'COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O[C@H]2O[C@@H](CO)[C@@H](O)[C@@H](O)[C@@H]2O)ccc1O': 2884,
#  'Oc1cc(O)c2c(c1)OC(c1ccc(O)c(O)c1)C(O)C2O': 1723,
#  'CC(=O)C1=NCCC1': 47,
#  'CCOC(=O)C(C)=O': 316,
#  'CCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3157,
#  'O=C(O)C(=O)C(O)c1ccccc1': 1658,
#  'O=c1[nH]cc([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c(=O)[nH]1': 2117,
#  'Cc1cscc1C': 3,
#  'CC(=O)N[C@@H](CCCC[NH3+])C(=O)[O-]': 1706,
#  'CSC[C@@H](O)[C@@H](O)C(=O)COP(=O)([O-])[O-]': 2642,
#  'NC(=O)CCCC[C@@H](S)CCS': 251,
#  'C=C(C=CC(C)C1CCC2C3=CC=C4CC(O)CCC4(C)C3CCC21C)C(C)C': 711,
#  'CN(CC(=O)O)C(N)=NP(=O)(O)O': 1837,
#  'CC(=O)NCCCC[NH3+]': 419,
#  'O=C([O-])Cc1ccc(O)cc1': 1753,
#  'CCCCCCCCCCCCCCCC(=O)C(N)CO': 1499,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OCC(CO)OC(=O)CCCCCCC/C=C/CCCCCCCC': 1223,
#  'CCCCCCCCCCCCCCCCCC=CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@@H]1O[C@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3183,
#  'CCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3357,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](CO)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1223,
#  'O=C([O-])O': 166,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2OC(CO)[C@@H](O)C(O)C2O)cc(OC)c1O': 2986,
#  'Oc1ccc(C2Oc3cc(O)cc4c3C2c2cc(O)cc(O)c2C(c2ccc(O)cc2)C4C2c3cc(O)cc4c3C(c3cc(O)cc(O)c3C2c2ccc(O)cc2)C(c2ccc(O)cc2)O4)cc1': 736,
#  'O=C([O-])/C=C(/CC(=O)[O-])C(=O)[O-]': 1143,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@@]2(C)C(=CC=C3[C@@H]2CC[C@@]2(C)[C@H]3CC[C@@H]2[C@H](C)/C=C/[C@H](C)C(C)C)C1': 300,
#  'CC1(C)C2=CC=CC(C)(C)C23C=CC1C3': 112,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(CO)OC(=O)CCCCCCCC=CCCCCCC': 1223,
#  'CCC(C)CCO': 563,
#  'COc1ccccc1O': 812,
# ...
#  'O=P(O)(O)O[C@H]1[C@H](OP(=O)(O)O)[C@@H](OP(=O)(O)O)[C@@H](OP(=O)(O)O)[C@@H](OP(=O)(O)O)[C@@H]1OP(=O)(O)OP(=O)(O)O': 1329,
#  'CC(C)=CCCC(C)C1CC=C2C3=C(CCC21C)C1(C)CCC(O)C(C)(C)C1CC3': 825,
#  'CC(C)=CCC[C@@H](C)C1CC[C@H]2C3=C(CC[C@]12C)[C@@]1(C)CC[C@H](O)C(C)(C)[C@@H]1CC3': 815,
#  'NCC(=O)O': 1309,
#  'COc1cc(CC(=O)O)ccc1O': 2074,
#  'COC1OC(CO)C(OC2OC(CO)C(OC)C(O)C2O)C(O)C1O': 1771,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)([O-])OCC[NH+](C)C)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1159,
#  'O=c1[nH]c(=O)c2ncn([C@@H]3O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]3O)c2[nH]1': 2526,
#  'Nc1nc2c(ncn2C2CC(O)C(CO)O2)c(=O)[nH]1': 1409,
#  'Nc1nc2c(c(=O)[nH]1)N1CN(c3ccc(C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-])cc3)C[C@H]1CN2': 1460,
#  'O=P(O)(O)OCC(O)C(O)c1c[nH]c2ccccc12': 2321,
#  'C=C(CC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CC[C@H](O)C[C@@H]1CC3)C(C)C': 714,
#  'CN(C)C=O': 5,
#  'CSCCC(NC(=O)CN)C(=O)O': 2298,
#  'Oc1ccc(C2c3c(O)cc(O)cc3C3C(c4ccc(O)cc4)c4c(O)cc(O)cc4C23)cc1': 649,
#  'NC(=O)NCCC[C@@H](N)C(=O)O': 1860,
#  'C[C@@H]1O[C@H](Oc2cc(O)c3c(=O)c(O[C@@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@H]4O)c(-c4ccc(O)cc4)oc3c2)[C@H](O)[C@H](O)[C@H]1O': 2716,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1[C@H](O[C@@H]2O[C@H](COP(=O)(O)O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)C(O)CCCCCCCCCCCCCC': 2467,
#  'CC1SSC(C)C1=O': 32,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)[O-]': 937,
#  'Cc1ccc(C=O)o1': 113,
#  'C[C@@](O)(CCOP(=O)([O-])[O-])CC(=O)[O-]': 2490,
#  'O=C(O)C(=O)CC(O)C(O)C(O)COP(=O)(O)O': 3342,
#  'O=C([O-])C(CO)OC1OC(COP(=O)([O-])[O-])C(O)C(O)C1O': 2925,
#  'Cn1cncc1CC(N)C(=O)O': 1689,
#  'Cc1cnc(C(C)C)cn1': 29,
#  'O=C1C=CC(=O)C=C1': 107,
#  'O=COCC(=O)OCCOP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O': 1620,
#  'O=C([O-])/C=C/c1ccc(O)cc1': 1324,
#  'CC1CC=C2C(C)(C)CC=CC2(C)O1': 135,
#  'Cc1cc2nc3c(=O)[nH]c(=O)nc-3n(CC(O)C(O)C(O)COP(=O)(O)OP(=O)(O)OCC3OC(n4cnc5c(N)ncnc54)C(O)C3O)c2cc1C': 1486,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1[C@H](O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)C(O)CCCCCCCCCCCCCC': 2675,
#  'O=C(O)CC(COP(=O)(O)OC1C(O)C(O)C(O)C(OP(=O)(O)O)C1O)C(=O)O': 1566,
#  'CCC1(C)N=C(C)CS1': 22,
#  'CC(C)[C@H](C)O': 77,
#  'Nc1ccccc1C(=O)O': 565,
#  'Cc1cn(C2CC(O)C(CO)O2)c(=O)[nH]c1=O': 1441,
#  'Nc1nc2c(c(=O)[nH]1)N[C@@H](CN(C=O)c1ccc(C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-])cc1)CN2': 1581,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2381,
#  'OCC1CCCC1': 465,
#  'O=c1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)[nH]1': 1422,
#  'CCCCCCCCCCCCCCCCCCCCCC(O)C(O)C(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(COP(=O)(O)OC2C(O)C(O)C(O)C(O)C2O)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2508,
#  'C=C(CCC(C)C1CCC2C3=CCC4CC(OC(=O)CCCCCCCC=CCCCCCC)CCC4(C)C3CCC21C)C(C)C': 305,
#  'CCC1CCC(=O)O1': 225,
#  'CCc1nc(C)oc1C': 9,
#  'Cc1ncsc1CCOP(=O)(O)O': 1242,
#  'CC=Cc1ccc(OC)cc1': 269,
#  'O=C[C@H](O)CO': 1287,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCC=CCCCCCCCC)COP(=O)(O)O': 1389,
#  'NC(CC[SeH])C(=O)O': 1443,
#  'O=C([O-])[C@H]1CCC=N1': 503,
#  'CC(N)C(=O)NC(CCC(=O)O)C(=O)O': 1967,
#  'CSc1ccsc1': 2,
#  'CCCCCCC=CCCCCCCCC(=O)OC(CO)COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O': 2023,
#  'C[C@@H]1O[C@@H](O[C@@H]2C(=O)c3c(O)cc(O)cc3O[C@H]2c2ccc(O)c(O)c2)[C@H](O)[C@H](O)[C@H]1O': 2250,
#  'O=C([O-])/C=C\\C(=O)CC(=O)CC(=O)[O-]': 1530,
#  '[NH3+][C@@H](C[SeH])C(=O)[O-]': 1235,
#  'C=C(CCC(C)C1CCC2C3=CCC4CC(OC(=O)CCCCCCCC=CCCCCCCCC)CCC4(C)C3CCC21C)C(C)C': 305,
#  'O=P([O-])([O-])O[C@]1(CO)O[C@H](CO)[C@@H](O)[C@@H]1O': 2571,
#  'O=c1c([O-])c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12': 1027,
#  'CCc1nc(C(C)C)sc1C': 6,
#  'C[C@H]([NH3+])C(=O)N[C@@H](CCC(N)=O)C(=O)[O-]': 1973,
#  'CC(O)(CC(=O)O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3555,
#  'CCCc1cccc(C)c1': 44,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O': 2412,
#  'CCCCCCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3351,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-])[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)CCC(=O)[O-]': 3549,
#  'O=c1[nH]cnc2c1ncn2[C@H]1C[C@H](O)[C@@H](CO)O1': 1467,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COC(=O)c1ccc(O)cc1': 767,
#  '[NH3+]CCCC[C@H]([NH3+])C(=O)[O-]': 1608,
#  'O=C([O-])CCc1c2[nH]c(c1CC(=O)[O-])Cc1[nH]c(c(CC(=O)[O-])c1CCC(=O)[O-])Cc1[nH]c(c(CC(=O)[O-])c1CCC(=O)[O-])Cc1[nH]c(c(CCC(=O)[O-])c1CC(=O)[O-])C2': 1539,
#  'Cc1ncc(C[n+]2c(C(C)O)sc(CCOP(=O)(O)OP(=O)(O)O)c2C)c(N)n1': 1960,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\COP(=O)([O-])OP(=O)([O-])[O-]': 777,
#  'c1ccc2c(c1)CCCC2': 40,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCc1cc(C(=O)O)ccc1O': 1401,
#  'CCCCCCCCCCCCCCCCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3219,
#  'C=C(CC(=O)O)C(=O)O': 998,
#  'CC(=O)O[C@H](CC(=O)[O-])C[N+](C)(C)C': 675,
#  'Cc1cc2nc3c(=O)[nH]c(=O)nc-3n(C[C@@H](O)[C@@H](O)[C@@H](O)CO)c2cc1C': 1565,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O)ccc1O': 1234,
#  'CC(C)CCOC(=O)c1ccco1': 236,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)([O-])[O-])OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1262,
#  'O=C[C@H](O)[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO': 1620,
#  'CC(=O)NC(Cc1ccccc1)C(=O)O': 1336,
#  'CCCCCCCC/C=C\\CCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@@H](O)[C@H]1OP(=O)(O)O': 3201,
#  'CC1=C[C@@H]2OC[C@@H](C)[C@@H]2CC1': 156,
#  'CC(C)C(C)C=CC(C)C1CCC2C3=CC=C4CC(O)CCC4(C)C3CCC21C': 710,
#  'Nc1nc2c(ncn2C2OC(COP(=O)(O)OP(=O)(O)O)C(O)C2O)c(=O)[nH]1': 2266,
#  'Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)OCC2OC(n3cnc4c(N)ncnc43)C(O)C2O)C(O)C1O': 1928,
#  'OCCc1ccccc1O': 1452,
#  'CCCCCCCCCCCCC(O)C(O)C(N)CO': 1469,
#  'CSCCC(=O)C(O)=CO': 1097,
#  'Cc1ncc(C[n+]2csc(CCOP(=O)([O-])OP(=O)([O-])[O-])c2C)c(N)n1': 1397,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OCC(COP(=O)(O)OCC[N+](C)(C)C)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1120,
#  'NC(C=O)C(=O)O': 1284,
#  'NC(Cc1ccc(O)cc1)C(=O)O': 2485,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)(O)OP(=O)(O)O': 777,
#  '[NH3+][C@@H](CC[Se]C[C@H]([NH3+])C(=O)[O-])C(=O)[O-]': 1520,
#  'CCC(C)COC(C)=O': 98,
#  'CCCCCCCCC=CCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3163,
#  'O=P(O)(O)OC1C(O)C(OP(=O)(O)O)C(OP(=O)(O)O)C(O)C1OP(=O)(O)O': 1953,
#  'CCCCC/C=C\\C/C=C\\C=C\\C=C\\[C@@H](O)[C@@H](O)CCCC(=O)[O-]': 2086,
#  'Nc1nc2c(c(=O)[nH]1)N[C@@H](CNc1ccc(C(=O)N[C@@H](CCC(=O)N[C@@H](CCC(=O)N[C@@H](CCC(=O)O)C(=O)O)C(=O)O)C(=O)O)cc1)CN2': 2194,
#  'CSCCCO': 540,
#  'CC(O)c1ccc(O)cc1': 814,
#  'CC(O)(CCOP(=O)(O)OP(=O)(O)O)CC(=O)O': 2550,
#  'OCC(O)CO': 985,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)(O)OP(=O)(O)O': 777,
#  'CCCCCCCCCCCCCC(=O)[O-]': 918,
#  'C=C(CC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CC[C@H](OC(=O)CCCCCCC/C=C\\CCCCCC)C[C@@H]1CC3)C(C)C': 291,
#  'CC(C)[C@@](O)(CC(=O)[O-])C(=O)[O-]': 1537,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)OCC(O)COP(=O)(O)O': 2471,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3357,
#  'CCCCOC(=O)C(C)C': 160,
#  'CCCCCCCCCCCCCCCC(=O)O': 918,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)(O)OP(=O)(O)O': 411,
#  'C=CC1=C(C)c2cc3[nH]c(cc4nc(cc5[nH]c(cc1n2)c(C)c5CCC(=O)[O-])C(CCC(=O)[O-])=C4C)c(C)c3C=C': 1608,
#  'NC1O[C@H](COP(=O)(O)O)[C@@H](O)[C@H]1O': 2318,
#  'CC(=[NH2+])C(=O)[O-]': 418,
#  'CCCCCCCCCCCCCCCCCCCCCCC[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3219,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)([O-])OCC[N+](C)(C)C)OC(=O)CCCCCCC/C=C\\CCCCCC': 1057,
#  'Cc1ncc(CO)c(C[NH3+])c1O': 1414,
#  'Cc1ccc2c(c1)C=CCC2(C)C': 104,
#  'CCc1nc(C)sc1C': 8,
#  'CC[C@](O)(C(C)=O)C(=O)[O-]': 1582,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2OC(COC(C)=O)[C@@H](O)C(O)C2O)cc(O)c1O': 2932,
#  'O=C(O)c1ccc(O)o1': 934,
#  '[NH3+][C@H](CS)C(=O)[O-]': 1451,
#  'CCC(=O)CCSC': 316,
#  'Oc1cc(O)cc(/C=C/c2ccc(O)c(O)c2)c1': 690,
#  'O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc([O-])cc(O)c12': 1082,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2ccc(N)nc2=O)[C@H](O)[C@@H]1O)OC(=O)CCCCCCC/C=C\\CCCCCC': 2263,
#  'c1ccsc1': 0,
#  'O=C1O[C@@H](CO)C([O-])=C1O': 1337,
#  'C/C=C/C(=O)C1=C(C)C=CCC1(C)C': 322,
#  'C=C(OP(=O)([O-])[O-])C(=O)[O-]': 696,
#  'CC(C)SC(C)C': 5,
#  'CCCC[C@H]1OC(=O)C[C@H]1C': 259,
#  'O=C[C@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 2440,
#  'CCCCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](CO)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2703,
#  'O=c1[nH]c(=O)c2[nH]c(=O)[nH]c2[nH]1': 287,
#  'CC(C)CCO': 505,
#  'CCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3177,
#  'Cn1cnc(N)c2ncnc1-2': 87,
#  'CCc1ccccc1C': 34,
#  'CCCCCC=CCC=CCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 2257,
#  'OCC1OC(OC2OC(CO)C(O)C(OC3OC(CO)C(O)C(O)C3O)C2OC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O': 1721,
#  'Oc1cc(O)c2c(c1)O[C@@H](c1ccc(O)c(O)c1)[C@@H](O)C2': 1840,
#  'NC(=O)C1=CN([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)C=CC1': 2012,
#  'CC(C)=CCS': 31,
#  '[NH3+]CCCCC[NH3+]': 288,
#  'CC(C)C(C)C(C)C': 3,
#  'CCc1cccc(C)c1O': 605,
#  'CC(=O)N[C@@H]1C(O)O[C@H](COP(=O)(O)O)[C@@H](O)[C@@H]1O': 2826,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](CO)[C@H](O)CCCCCCCCCCCCCCC': 1662,
#  'NC(CS)C(=O)NCC(=O)O': 2017,
#  'CC(C)(CO)[C@@H](O)C(=O)NCCC(=O)[O-]': 2159,
#  'O=C(O)c1ccc(O)c(O)c1': 1415,
#  'Nc1nc2nc[nH]c2c(=O)[nH]1': 363,
#  'Nc1nc2c(c(=O)[nH]1)N=C(CNc1ccc(C(=O)NC(CCC(=O)O)C(=O)O)cc1)CN2': 1560,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)(O)OC[C@@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC': 2189,
#  'COC(=O)/C=C/c1ccccc1': 128,
#  'NCCCCNCCCN': 297,
#  'C[C@H]([NH3+])C(=O)N[C@@H](Cc1cnc[nH]1)C(=O)[O-]': 1707,
#  'COc1ccc(C(=O)O)cc1': 797,
#  'CCCCCCCCC=CCCCCCCCC(=O)OCC(=O)COP(=O)(O)O': 1674,
#  'COc1cc(C23Oc4cc(O)ccc4C(C2OC2OC(CO)C(O)C(O)C2O)C(C)(C(C)=O)O3)cc(OC)c1O': 3070,
#  'COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O)ccc1O': 1319,
#  'C[N+](C)(C)CCCC(=O)[O-]': 532,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)([O-])OP(=O)([O-])[O-]': 777,
#  'CCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)C(O)[C@H]1OP(=O)(O)O': 3179,
#  'Oc1ccc(Cl)cc1Cl': 500,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@@H](O)CCCCCCCCCCCCCC': 2356,
#  'Cc1ccc(C=O)s1': 42,
#  'Cc1nc(C(=O)[O-])sc1CCOP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1O': 2035,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC': 323,
#  'CC(=O)NCCCNCCCCNCCCN': 445,
#  'CCCCCCC1CCC(=O)O1': 207,
#  'O=C(O)C(O)CO': 1962,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-])[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)c1ccc(O)cc1': 3540,
#  'COc1cc(C=O)ccc1OC(C)=O': 602,
#  'C=C(C)c1ccccc1': 19,
#  'CC(C)(O)[C@@H](O)C(=O)[O-]': 1243,
#  'NC(CCCNN=CNC(CC(=O)O)C(=O)O)C(=O)O': 978,
#  'O=P(O)(O)OC[C@H]1O[C@@H](OP(=O)(O)OP(=O)(O)O)[C@H](O)[C@@H]1O': 2755,
#  'CC(C)(C)C1CCC(=O)CC1': 336,
#  'C=CCCCCCCCCCC': 42,
#  'C=CC(C)(O)CC=CC(=C)C': 269,
#  'CCCCCCCCCCCCCCCCOCC(COP(=O)(O)OCCN)OC(=O)CCCCCCCCCCCCCCC': 1425,
#  '[NH3+]CCC(=O)[O-]': 1247,
#  '[NH3+]CC(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-]': 1998,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](CO)[C@H]3OP(=O)([O-])O[C@H]32)c(=O)[nH]1': 1828,
#  'O=CNCC(=O)NC1OC(COP(=O)(O)O)C(O)C1O': 2264,
#  'CCCCCCCCCCCCCCCCCC(=O)OCC(O)COP(=O)(O)O': 2417,
#  'Nc1ccn(C2O[C@H](CO)[C@@H](O)[C@H]2OP(=O)(O)O)c(=O)n1': 2323,
#  'Cc1ccc(C)o1': 13,
#  'O=CN[C@H]1CO[C@H](OP(=O)([O-])OP(=O)([O-])OC[C@H]2O[C@@H](n3ccc(=O)[nH]c3=O)[C@H](O)[C@@H]2O)[C@H](O)[C@H]1O': 2612,
#  'O=CCc1ccccc1': 108,
#  'Nc1ccn(C2OC(COP(=O)(O)OP(=O)(O)O)C(O)C2O)c(=O)n1': 2287,
#  'CCCCCC/C=C/C=O': 310,
#  'Cc1cc(C(C)(C)C)c(O)c(C(C)(C)C)c1': 560,
#  'CC=C(N)C(=O)[O-]': 548,
#  'NC(C(=O)O)C(=O)COP(=O)(O)O': 3086,
#  'O=CCC(O)C(O)C(O)COP(=O)(O)O': 1430,
#  'O=C(O)CCCC(=O)C(=O)O': 1931,
#  'O=C([O-])C(=O)C[C@H](O)C(=O)[O-]': 2376,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@]2(C)C3=C(CC[C@H]2C1)[C@@H]1CC[C@H]([C@H](C)CCC=C(C)C)[C@@]1(C)CC3': 350,
#  'Nc1ncnc2c1ncn2C1CC2OP(=O)(O)OCC2O1': 440,
#  'NC(=O)c1ccc[n+](C2OC(CO)C(O)C2O)c1': 1503,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-])[C@@H](O)C(=O)NCCC(=O)NCCS': 2763,
#  'CCCCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)(O)OC1C(O)C(O)C(O)C(OP(=O)(O)O)C1O': 2680,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O': 2412,
#  '[NH3+]Cc1[nH]cc(CCC(=O)[O-])c1CC(=O)[O-]': 1726,
#  'C=C(CCC(C)C1CCC2C3=C(CCC21C)C1(C)CCC(OC(=O)CCCCCCCC=CCCCCCCCC)CC1CC3)C(C)C': 291,
#  'CSc1ccoc1C': 9,
#  'CCCCCCCC/C=C\\C[C@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3228,
#  'CC(=O)N[C@@H](CC(C)C)C(=O)[O-]': 1075,
#  'O=C(O)C(CO)c1ccccc1': 1295,
#  'C[C@H]1NC(=O)N[C@@H]1CCCCCC(=O)O': 1602,
#  'O=C([O-])c1cc(=O)[nH]c(=O)n1[C@@H]1O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2300,
#  'C=CC1=C(C)c2cc3nc(cc4[nH]c(cc5[n-]c(cc1n2)c(C)c5C)c(C)c4CCC(=O)[O-])C(CCC(=O)O)=C3C': 1600,
#  'CCOP(=O)(O)O': 241,
#  'CCCCCCCC/C=C/CC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3335,
#  'O=C/C=C/c1ccccc1': 73,
#  'Nc1nc2c(ncn2C2OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)OP(=O)(O)OCC3OC(n4cnc5c(N)ncnc54)C(O)C3O)C(O)C2O)c(=O)[nH]1': 1346,
#  'O=P(O)(O)OC[C@H]1O[C@H](OP(=O)(O)O)[C@@H](O)[C@@H](O)[C@@H]1O': 2667,
#  'CN(C)C(=[NH2+])NCCC[C@H]([NH3+])C(=O)[O-]': 1370,
#  'CCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3351,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2O[C@H](COC(=O)/C=C\\c3ccc(O)cc3)[C@@H](O)[C@H](O)[C@H]2O)ccc1O': 2865,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCC/C=C\\CCCCCCCC)COP(=O)(O)OC[C@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC': 2189,
#  'C1=Cc2cc3ccc(cc4ccc(cc5nc(cc1n2)C=C5)[nH]4)[nH]3': 28,
#  'O=C(CO)C(O)C(O)C(O)C(O)COP(=O)(O)O': 2638,
#  'C[C@](O)(C(=O)[O-])[C@H](CC(=O)[O-])C(=O)[O-]': 1520,
#  'N=c1c2ncn([C@@H]3O[C@H](COP(=O)(O)O)[C@@H](O)[C@H]3O)c2ncn1[C@H]1O[C@H](COP(=O)(O)O)[C@@H](O)[C@H]1O': 2104,
#  'Oc1ccc(O)cc1': 578,
#  '[NH3+]CCCCC[NH2+]CCC[NH3+]': 296,
#  'CCOC(=O)CC(=O)OCC': 186,
#  'COc1cc(C(=O)O)cc(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)c1O': 1752,
#  'Nc1ccccc1C(=O)C[C@@H](N)C(=O)O': 2262,
#  'CC(C)(CO)[C@@H](O)C(=O)[O-]': 1685,
#  'COc1cc(C(=O)[O-])ccc1O': 1557,
#  'O=C(O)OCC1OC(Oc2cc3c(O)cc(O)cc3[o+]c2-c2ccc(O)c(O)c2)C(O)C(O)C1O': 2693,
#  'C=C(C)C(=O)OCC': 53,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1OP(=O)([O-])[O-]': 2280,
#  'CN1CN=c2c(ncn2C2OC(CO)C(O)C2O)=C1N': 1064,
#  'CC(=O)c1ccc(C)cc1': 107,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(CO)C(O)CCCCCCCCCCCCCCC': 1552,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])OC[C@@H](O)COP(=O)([O-])[O-]': 2233,
#  'O=CCO': 680,
#  'SCc1ccco1': 6,
#  'Nc1ncnc2c1ncn2C1OC2COP(=O)(O)OC2C1O': 1885,
#  'CCCCCCCC/C=C\\C/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3181,
#  'NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](OP(=O)([O-])[O-])[C@@H]3O)[C@@H](O)[C@H]2O)c1': 2302,
#  ...}

# %%
# result = {'smiles':[],
#           'match_rules':[],
#           'reaction_num':[]}

# rxndb_total_info_to_model = pd.read_csv(rxndb_total_info_to_model_path)

# for smiles1,match_rules in tqdm(smiles_match_rules_dict.items(),total=len(smiles_match_rules_dict)):
#     reaction_num = 0 
#     for index,row in rxndb_total_info_to_model.iterrows():
#         smiles_lst = row['rxn_smiles_final'].replace('>>','.').split('.')
#         if any(compare_smiles_inchikey(smiles1,smiles2) for smiles2 in smiles_lst):
#             reaction_num+=1
#     result['smiles'].append(smiles1)       
#     result['match_rules'].append(match_rules)        
#     result['reaction_num'].append(reaction_num)

# %%
# Load data
rxndb_total_info_to_model = pd.read_csv(rxndb_total_info_to_model_path)

# Define the worker function
def match_smiles(smiles1_match_rules, rxndb_total_info_to_model):
    smiles1, match_rules = smiles1_match_rules
    reaction_num = 0 
    for index, row in rxndb_total_info_to_model.iterrows():
        smiles_lst = row['rxn_smiles_final'].replace('>>', '.').split('.')
        if any(compare_smiles_inchikey(smiles1, smiles2) for smiles2 in smiles_lst):
            reaction_num += 1
    return smiles1, match_rules, reaction_num

# Define the result dictionary
result = {'smiles': [], 'match_rules': [], 'reaction_num': []}

# Extract the task list for parallel processing
tasks = [(smiles1, match_rules) for smiles1, match_rules in smiles_match_rules_dict.items()]

# Set the number of processes
num_processes = 20
pool = multiprocessing.Pool(num_processes)

# Use partial to pass rxndb_total_info_to_model to match_smiles
match_smiles_partial = partial(match_smiles, rxndb_total_info_to_model=rxndb_total_info_to_model)

# Parallel processing
for smiles1, match_rules, reaction_num in tqdm(pool.imap(match_smiles_partial, tasks), total=len(tasks)):
    result['smiles'].append(smiles1)
    result['match_rules'].append(match_rules)
    result['reaction_num'].append(reaction_num)

# Close the process pool
pool.close()
pool.join()
# Out:
# 100%|██████████| 1457/1457 [45:01<00:00,  1.85s/it]

# %%
result_df = pd.DataFrame(result)

# %%
# Calculate the correlation
correlation = result_df['match_rules'].corr(result_df['reaction_num'])
print(f"Correlation between match_rules and reaction_num: {correlation}")
# Out:
# Correlation between match_rules and reaction_num: 0.1801472403151988

# %%
# Assuming you want to sort by the 'score' column in descending order

result_df_sorted = result_df.sort_values(by='reaction_num', ascending=False)

result_df_sorted[~result_df_sorted['smiles'].str.contains('\.')]
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='O=C=O']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)c1ccc[n+]([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)c1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](OP(=O)([O-])[O-])[C@@H]3O)[C@@H](O)[C@H]2O)c1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)C1=CN([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](OP(=O)([O-])[O-])[C@@H]3O)[C@@H](O)[C@H]2O)C=CC1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)C1=CN([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)C=CC1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='C=O']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='CO']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='CS']

# Calculate the correlation
correlation = result_df_sorted['match_rules'].corr(result_df_sorted['reaction_num'])
print(f"Correlation between match_rules and reaction_num: {correlation}")

result_df_sorted
# Out:
# Correlation between match_rules and reaction_num: 0.21425207195173834
#                                                  smiles  match_rules  \
# 507   NC(=O)c1ccc[n+](C2OC(COP(=O)([O-])OP(=O)(O)OCC...         2083
# 60    Nc1ncnc2c1ncn2[C@H]1O[C@H](COP(=O)([O-])OP(=O)...         2219
# 407              Nc1ncnc2c1ncn2C1OC(COP(=O)(O)O)C(O)C1O         2177
# 421   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...         2234
# 956   CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H]...         2763
# ...                                                 ...          ...
# 585   O=P(O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(COP(=O)(O)...         2419
# 608                                    CC1=C(O)C(=O)CC1          780
# 611                                        CCCCCc1cccs1           11
# 1119                                            C1CSCN1           32
# 0                                            CCOC(C)OCC           22
#
#       reaction_num
# 507            696
# 60             563
# 407            406
# 421            396
# 956            367
# ...            ...
# 585              0
# 608              0
# 611              0
# 1119             0
# 0                0
#
# [1450 rows x 3 columns]

# %%
# Define a function to calculate the number of carbon atoms

def count_carbon_atoms(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    return sum(atom.GetAtomicNum() == 6 for atom in mol.GetAtoms())

# Apply the apply method to apply a function to a SMILES column in a DataFrame
result_df_sorted['carbon_count'] = result_df_sorted['smiles'].apply(count_carbon_atoms)
result_df_sorted
# Out:
#                                                  smiles  match_rules  \
# 507   NC(=O)c1ccc[n+](C2OC(COP(=O)([O-])OP(=O)(O)OCC...         2083
# 60    Nc1ncnc2c1ncn2[C@H]1O[C@H](COP(=O)([O-])OP(=O)...         2219
# 407              Nc1ncnc2c1ncn2C1OC(COP(=O)(O)O)C(O)C1O         2177
# 421   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...         2234
# 956   CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H]...         2763
# ...                                                 ...          ...
# 585   O=P(O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(COP(=O)(O)...         2419
# 608                                    CC1=C(O)C(=O)CC1          780
# 611                                        CCCCCc1cccs1           11
# 1119                                            C1CSCN1           32
# 0                                            CCOC(C)OCC           22
#
#       reaction_num  carbon_count
# 507            696            21
# 60             563            10
# 407            406            10
# 421            396            10
# 956            367            21
# ...            ...           ...
# 585              0            18
# 608              0             6
# 611              0             9
# 1119             0             3
# 0                0             6
#
# [1450 rows x 4 columns]

# %%
result_df_sorted.to_csv(figs7_data_path,index=None)

# %%
# tmp1 = result_df_sorted[(result_df_sorted['Molecular_Weight']<200)&(result_df_sorted['Molecular_Weight']>50)]
# tmp2 = result_df_sorted[(result_df_sorted['Molecular_Weight']>200)|(result_df_sorted['Molecular_Weight']<50)]

tmp1 = result_df_sorted[(result_df_sorted['carbon_count']>2)&(result_df_sorted['carbon_count']<10)]
tmp2 = result_df_sorted[(result_df_sorted['carbon_count']>9)|(result_df_sorted['carbon_count']<3)]

correlation = tmp1['match_rules'].corr(tmp1['reaction_num'])
print(f"Correlation between match_rules and reaction_num: {correlation}")

correlation = tmp2['match_rules'].corr(tmp2['reaction_num'])
print(f"Correlation between match_rules and reaction_num: {correlation}")

print(len(tmp1),len(tmp2))
# Out:
# Correlation between match_rules and reaction_num: 0.40084605248963995
# Correlation between match_rules and reaction_num: 0.11706257539719389
# 746 704

# %%
import matplotlib.pyplot as plt
import numpy as np

# Setting General Parameters
plt.figure(figsize=(2, 2), dpi=400)
plt.rcParams.update({'font.size': 6})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Setting Axis Styles
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Adjusting the size of scatter points (s parameter) and using normalized 'score'
plt.scatter(tmp2['match_rules'], tmp2['reaction_num'], 
            s=4,  # Size of the points
            c='#f46d43',  # Color of the points
            edgecolor='#f46d43',  # Border color of the points
            linewidth=0.25,  # Border width of the points
            alpha=0.4,  # Transparency of the points
            label='Carbon(<3,>9), r = 0.129, N = 742'  # Label
           )

plt.scatter(tmp1['match_rules'], tmp1['reaction_num'], 
            s=4,  # Size of the points
            c='#40004b',  # Color of the points
            edgecolor='#40004b',  # Border color of the points
            linewidth=0.25,  # Border width of the points
            alpha=0.4,  # Transparency of the points
            label='Carbon(3~9), r = 0.399, N = 603'  # Label
           )

# Setting X-axis Labels
plt.xlabel('Metabolites match rules number', fontsize=6)
plt.ylabel('Metabolites participate reaction number', fontsize=6)

plt.xlim(9, 4000)
plt.ylim(0.9, 1000)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.minorticks_off()  # Hide minor ticks

plt.tick_params(axis='both', direction='in', width=0.5, which='both', length=2)

# Adding Legend
plt.legend(frameon=False, fontsize=6, loc='center left', bbox_to_anchor=(-0.05, 0.9), ncol=1, labelspacing=0.5, handletextpad=0.3, handlelength=1)

# Save the figure to a file
plt.savefig(figs7_path, dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Frequency of reaction of metabolites--matched rules/included substructures number
