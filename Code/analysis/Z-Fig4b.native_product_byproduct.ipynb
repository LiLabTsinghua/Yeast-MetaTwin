# %%
import pandas as pd
import numpy as np
import json
import cobra
from cobra import Model, Reaction, Metabolite
from cobra.flux_analysis import flux_variability_analysis,moma,add_moma
import pickle
from tqdm import tqdm 
from ast import literal_eval
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import sys
sys.path.append('../retrosynthesis/')

from common import *

# from IgnoreMet import *

# %% [markdown]
# ### input and output

# %%
### input
yeast870_path =  '../../Data/model/yeast-GEM.yml'
yeast8U_path = '../../Data/model/yeast8U_del2_re.yml'
# new_met_info_to_GEM_path = '../Data/metabolites_info_to_GEM_yeast8_top50.csv'
target_product_file_path = '../../Data/100met.xlsx'
metabolites_info_to_GEM_path = '../../Results/not_lipid/top50_0.3_re/metabolites_info_to_GEM_top50_0.3.csv'
miss_id_path = '../../Data/model/miss_met_id.json'
### output
source_fig4b_path = '../../Results/source_data/fig4-b.csv'
yeast8U_native_product_reaction_figure_path = '../../Results/Figures/fig4-b.pdf'

# %% [markdown]
# ### ① Product degradation

# %%
def get_yeast8_metid_for_keggid(model,keggid):
    metid = 'no this met'
    for met in model.metabolites:
        if met.compartment == 'c':
            if 'kegg.compound' in model.metabolites.get_by_id(met.id).annotation:
                if model.metabolites.get_by_id(met.id).annotation['kegg.compound'] == keggid:
                    metid = met.id
    return(metid)

# %%
def calculate_FBA(Target_met,model):
    exchange_reaction = get_exchange_reaction(Target_met,model)
    model.objective = model.reactions.get_by_id(exchange_reaction)
    model.optimize()
    ### Remove the added reaction
    if abs(model.reactions.get_by_id(exchange_reaction).flux)>0.001:
        flux_tmp = model.reactions.get_by_id(exchange_reaction).flux
    else:
        flux_tmp = 0
    if 'DM_' in exchange_reaction:
        model.remove_reactions(exchange_reaction)    
    return flux_tmp

# %%
def top_three_elements(lst):
    counter = Counter(lst)
    top_three = counter.most_common(3)
    top_three_elements = [item[0] for item in top_three]
    return top_three_elements

def get_subsystem(Target_met,model):
    exchange_reaction = get_exchange_reaction(Target_met,model)
    model.objective = model.reactions.get_by_id(exchange_reaction)
    model.optimize()
    subsystem_list = []
    for i in model.reactions:
        if abs(i.flux)>0.001:
            try:
                subsystem_list.append(i.subsystem[0])
            except: pass

    if 'DM_' in exchange_reaction:
        model.remove_reactions(exchange_reaction)   
    # return subsystem_list
    subsystem_list = [x for x in subsystem_list if 'Transport' not in x and 'Exchange' not in x]
    return top_three_elements(subsystem_list)

# %%
def prepare_target_product(target_product_file_path,yeast870_path):
    yeast8 = cobra.io.load_yaml_model(yeast870_path)
    target_product_pd = pd.read_excel(target_product_file_path)
    target_product_pd.dropna(inplace=True)
    target_product_pd = target_product_pd[target_product_pd['Group'] == 'native']
    target_product_pd['yeast8_id'] = target_product_pd['KEGG ID'].apply(lambda x: get_yeast8_metid_for_keggid(yeast8,x))
    target_product_pd['FBA'] = target_product_pd['yeast8_id'].apply(lambda x : calculate_FBA(x,yeast8))
    target_product_pd = target_product_pd[target_product_pd['FBA']>0.0001]
    target_product_pd['subsystem'] = target_product_pd['yeast8_id'].apply(lambda x : get_subsystem(x,yeast8))
    print(target_product_pd.shape)
    return target_product_pd

# %%
target_product_pd = prepare_target_product(target_product_file_path,yeast870_path)
# Out:
# /home/haohao/anaconda3/envs/gurob/lib/python3.8/site-packages/cobra/core/model.py:777: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# /home/haohao/anaconda3/envs/gurob/lib/python3.8/site-packages/cobra/core/model.py:777: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# (52, 10)

# %%
target_product_pd
# Out:
#                     Name      Formula KEGG ID CHEBI ID   Group  \
# 0   (R,R)-2,3-butanediol      C4H10O2  C03044    16982  native
# 1        2-phenylethanol       C8H10O  C05853    49000  native
# 2               glycerol       C3H8O3  C00116    17754  native
# 3              isoamylol       C5H12O  C07328    15837  native
# 4             isobutanol       C4H10O  C14710    46645  native
# 5                choline      C5H14NO  C00114    15354  native
# 6           hypoxanthine      C5H4N4O  C00262    17368  native
# 7               xanthine     C5H4N4O2  C00385    17712  native
# 8            glutathione  C10H17N3O6S  C00051    16856  native
# 9              L-alanine      C3H7NO2  C00041    16977  native
# 10            L-arginine    C6H14N4O2  C00062    16467  native
# 11          L-asparagine     C4H8N2O3  C00152    17196  native
# 12           L-aspartate      C4H7NO4  C00049    17053  native
# 13          L-citrulline    C6H13N3O3  C00327    16349  native
# 14            L-cysteine     C3H7NO2S  C00097    17561  native
# 15           L-glutamate      C5H8NO4  C00025    29985  native
# 16           L-glutamine    C5H10N2O3  C00064    18050  native
# 17             L-glycine      C2H5NO2  C00037    15428  native
# 18           L-histidine     C6H9N3O2  C00135    15971  native
# 19          L-homoserine      C4H9NO3  C00263    15699  native
# 20          L-isoleucine     C6H13NO2  C00407    17191  native
# 21             L-leucine     C6H13NO2  C00123    15603  native
# 22              L-lysine    C6H15N2O2  C00047    32551  native
# 23          L-methionine    C5H11NO2S  C00073    16643  native
# 24       L-phenylalanine     C9H11NO2  C00079    17295  native
# 25             L-proline      C5H9NO2  C00148    17203  native
# 26              L-serine      C3H7NO3  C00065    17115  native
# 27           L-threonine      C4H9NO3  C00188    16857  native
# 28          L-tryptophan   C11H12N2O2  C00078    16828  native
# 29            L-tyrosine     C9H11NO3  C00082    17895  native
# 30              L-valine     C5H11NO2  C00183    16414  native
# 31             ornithine    C5H13N2O2  C01602    46912  native
# 32            putrescine      C4H14N2  C00134   326268  native
# 33              spermine     C10H30N4  C00750    45725  native
# 35               laurate     C12H23O2  C02679    18262  native
# 36                oleate     C18H34O2  C00712    16196  native
# 37          palmitoleate     C16H29O2  C08362    32372  native
# 38             succinate       C4H4O4  C00042    30031  native
# 40               guanine      C5H5N5O  C00242    16235  native
# 41             thymidine   C10H14N2O5  C00214    17748  native
# 42           (S)-lactate       C3H6O3  C00186    16651  native
# 43            (S)-malate       C4H6O5  C00149    15589  native
# 44        2-oxoglutarate       C5H6O5  C00026    16810  native
# 45               acetate       C2H4O2  C00033    15366  native
# 46               citrate       C6H8O7  C00158    16947  native
# 47              fumarate       C4H4O4  C00122    18012  native
# 48             glycolate       C2H4O3  C00160    17497  native
# 49             hexanoate      C6H12O2  C01585    17120  native
# 50              pyruvate       C3H3O3  C00022    15361  native
# 51          acetaldehyde        C2H4O  C00084    15343  native
# 52                  urea       CH4N2O  C00086    16199  native
# 53            ergosterol      C28H44O  C01694    16933  native
#
#                      class Gene target yeast8_id       FBA  \
# 0                  alcohol        Link    s_0035  1.077151
# 1                  alcohol        Link    s_0185  0.544096
# 2                  alcohol        Link    s_0765  1.558928
# 3                  alcohol        Link    s_0929  0.728744
# 4                  alcohol        Link    s_0932  1.000000
# 5                 alkaloid        Link    s_0512  0.548334
# 6                 alkaloid        Link    s_0843  0.909592
# 7                 alkaloid        Link    s_0357  0.877896
# 8               amino acid        Link    s_0750  0.451167
# 9               amino acid        Link    s_0955  1.815018
# 10              amino acid        Link    s_0965  0.704207
# 11              amino acid        Link    s_0969  1.327558
# 12              amino acid        Link    s_0973  1.500000
# 13              amino acid        Link    s_0979  0.741876
# 14              amino acid        Link    s_0981  1.175787
# 15              amino acid        Link    s_0991  1.052844
# 16              amino acid        Link    s_0999  1.022233
# 17              amino acid        Link    s_1003  2.488083
# 18              amino acid        Link    s_1006  0.730140
# 19              amino acid        Link    s_1014  1.249910
# 20              amino acid        Link    s_1016  0.725940
# 21              amino acid        Link    s_1021  0.707219
# 22              amino acid        Link    s_1025  0.674620
# 23              amino acid        Link    s_1029  0.637875
# 24              amino acid        Link    s_1032  0.523556
# 25              amino acid        Link    s_1035  0.926531
# 26              amino acid        Link    s_1039  1.848709
# 27              amino acid        Link    s_1045  1.170775
# 28              amino acid        Link    s_1048  0.412467
# 29              amino acid        Link    s_1051  0.548388
# 30              amino acid        Link    s_1056  0.950943
# 31              amino acid        Link    s_1266  0.926531
# 32                bioamine        Link    s_1389  0.960110
# 33                bioamine        Link    s_1442  0.281979
# 35  fatty acids and lipids        Link    s_1065  0.254319
# 36  fatty acids and lipids        Link    s_1260  0.184739
# 37  fatty acids and lipids        Link    s_1293  0.208944
# 38  fatty acids and lipids        Link    s_1458  1.437724
# 40            nucleic acid        Link    s_0787  0.838107
# 41            nucleic acid        Link    s_1493  0.469491
# 42            organic acid        Link    s_0063  1.550129
# 43            organic acid        Link    s_0066  1.500000
# 44            organic acid        Link    s_0180  1.115490
# 45            organic acid        Link    s_0362  2.395161
# 46            organic acid        Link    s_0522  1.000000
# 47            organic acid        Link    s_0725  1.500000
# 48            organic acid        Link    s_3997  2.430659
# 49            organic acid        Link    s_2829  0.348784
# 50            organic acid        Link    s_1399  2.000000
# 51                   other        Link    s_0359  2.239550
# 52                   other        Link    s_1552  2.919789
# 53                   other        Link    s_0666  0.040418
#
#                                             subsystem
# 0   [Glycolysis / gluconeogenesis, Glycine, serine...
# 1   [Glycolysis / gluconeogenesis, Citrate cycle (...
# 2   [Glycolysis / gluconeogenesis, Citrate cycle (...
# 3   [Valine, leucine and isoleucine metabolism, Gl...
# 4   [Glycolysis / gluconeogenesis, Thiamine metabo...
# 5   [Glycolysis / gluconeogenesis, Pentose phospha...
# 6   [Purine metabolism, Citrate cycle (TCA cycle),...
# 7   [Purine metabolism, Glycolysis / gluconeogenes...
# 8   [Glycolysis / gluconeogenesis, Pentose phospha...
# 9   [Glycolysis / gluconeogenesis, Pentose phospha...
# 10  [Citrate cycle (TCA cycle), Glycolysis / gluco...
# 11  [Glycolysis / gluconeogenesis, Pentose phospha...
# 12  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 13  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 14  [Glycolysis / gluconeogenesis, Pentose phospha...
# 15  [Glycolysis / gluconeogenesis, Glycine, serine...
# 16  [Glycolysis / gluconeogenesis, Glycine, serine...
# 17  [Glycolysis / gluconeogenesis, Pentose phospha...
# 18  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 19  [Citrate cycle (TCA cycle), Glycolysis / gluco...
# 20  [Glycolysis / gluconeogenesis, Pentose phospha...
# 21  [Glycolysis / gluconeogenesis, Valine, leucine...
# 22  [Glycolysis / gluconeogenesis, Glycine, serine...
# 23  [Glycine, serine and threonine metabolism, Gly...
# 24  [Glycolysis / gluconeogenesis, Phenylalanine, ...
# 25  [Glycolysis / gluconeogenesis, Pentose phospha...
# 26  [Glycolysis / gluconeogenesis, Pentose phospha...
# 27  [Glycolysis / gluconeogenesis, Pentose phospha...
# 28  [Phenylalanine, tyrosine and tryptophan biosyn...
# 29  [Glycolysis / gluconeogenesis, Phenylalanine, ...
# 30  [Glycolysis / gluconeogenesis, Pentose phospha...
# 31  [Glycolysis / gluconeogenesis, Pentose phospha...
# 32  [Glycolysis / gluconeogenesis, Pentose phospha...
# 33  [Citrate cycle (TCA cycle), Glycolysis / gluco...
# 35  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 36  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 37  [Glycolysis / gluconeogenesis, Pentose phospha...
# 38  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 40  [Purine metabolism, Citrate cycle (TCA cycle),...
# 41  [Pyrimidine metabolism, Glycolysis / gluconeog...
# 42  [Glycolysis / gluconeogenesis, Pentose phospha...
# 43  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 44  [Glycolysis / gluconeogenesis, Glycine, serine...
# 45  [Glycolysis / gluconeogenesis, Glycine, serine...
# 46  [Glycolysis / gluconeogenesis, Glycine, serine...
# 47  [Fatty acid degradation, Citrate cycle (TCA cy...
# 48  [Glycolysis / gluconeogenesis, Glycine, serine...
# 49  [Fatty acid degradation, Glycolysis / gluconeo...
# 50  [Glycolysis / gluconeogenesis, Thiamine metabo...
# 51  [Glycine, serine and threonine metabolism, Gly...
# 52  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 53  [Purine metabolism, Steroid biosynthesis, Phen...

# %%
yeast8U = cobra.io.load_yaml_model(yeast8U_path)

# %%
with open(miss_id_path) as f:
    miss_met_id = json.load(f)

# %%
yeast8 = cobra.io.load_yaml_model(yeast870_path)
met_info = pd.read_csv(metabolites_info_to_GEM_path)

def get_smiles(metid,model,met_info):
    # print(metid)
    smiles = None
    if metid.startswith('s_'):
        if hasattr(model.metabolites.get_by_id(metid), 'smiles'):
            smiles = model.metabolites.get_by_id(metid).smiles
    elif metid.startswith('sn_'):
        if metid in met_info['ID'].tolist():
            smiles =  met_info[met_info['ID'] == metid]['new_met_smiles'].to_list()[0]
    return smiles

# %%
def get_new_smiles_lst_has_carbon(self_smiles,smiles_lst):
    smiles_lst = list(set(smiles_lst))
    smiles_lst = [x for x in smiles_lst if not compare_smiles_inchikey(self_smiles,x)]
    smiles_lst = [x for x in smiles_lst if calculate_carbon_count(x)<=calculate_carbon_count(self_smiles)]
    result = []
    for i in smiles_lst:
        if any(compare_smiles_inchikey(i,j) for j in result):
            pass
        else:
            result.append(i)
    return result

# %%
target_met = 's_0680'#s_1025#s_0991
def target_met_in_reaction_lst(target_met,yeast8U):
    reaction_lst = []
    for rea in yeast8U.reactions:
        if target_met in rea.reaction and rea.bounds==(0,1000) and  rea.metabolites[yeast8U.metabolites.get_by_id(target_met)]<0:
            reaction_lst.append(rea.id)
        elif target_met in rea.reaction and rea.bounds==(-1000,0) and  rea.metabolites[yeast8U.metabolites.get_by_id(target_met)]>0:
            reaction_lst.append(rea.id)
        elif target_met in rea.reaction and rea.bounds==(-1000,1000):
            reaction_lst.append(rea.id)
    return reaction_lst
target_met_in_reaction_lst(target_met,yeast8U)
# Out:
# ['r_0159',
#  'r_0163',
#  'r_1762',
#  'r_1763',
#  'r_4711',
#  'r_4712',
#  'r_4713',
#  'r_4714',
#  'r_4715',
#  'r_4716',
#  'r_4720',
#  'r_4721',
#  'rxn14765',
#  'rxn44336',
#  'rxn25879',
#  'rxn54403',
#  'rxn64957',
#  'rxn64958',
#  'rxn71687',
#  'rxn75929',
#  'rxn11677',
#  'rxn11678',
#  'rxn11688',
#  'rxn11689',
#  'rxn12309',
#  'rxn5824']

# %%
target_product_pd['yeast8_reaction_lst'] = target_product_pd['yeast8_id'].apply(lambda x: target_met_in_reaction_lst(x,yeast8))
target_product_pd['yeast8U_reaction_lst'] = target_product_pd['yeast8_id'].apply(lambda x: target_met_in_reaction_lst(x,yeast8U))

target_product_pd['yeast8_reaction_num'] = target_product_pd['yeast8_reaction_lst'].apply(lambda x:len(x))
target_product_pd['yeast8U_reaction_num'] = target_product_pd['yeast8U_reaction_lst'].apply(lambda x: len(x))

# %%
target_100met_df = target_product_pd[['Name','Group','class','yeast8_reaction_lst','yeast8_reaction_num','yeast8U_reaction_lst','yeast8U_reaction_num']]
target_100met_df.head(3)
# Out:
#                    Name   Group    class               yeast8_reaction_lst  \
# 0  (R,R)-2,3-butanediol  native  alcohol                  [r_0003, r_1097]
# 1       2-phenylethanol  native  alcohol          [r_0162, r_1590, r_1591]
# 2              glycerol  native  alcohol  [r_0487, r_0488, r_1172, r_3597]
#
#    yeast8_reaction_num                               yeast8U_reaction_lst  \
# 0                    2                                   [r_0003, r_1097]
# 1                    3  [r_0162, r_1590, r_1591, rxn20557, rxn25236, r...
# 2                    4  [r_0487, r_0488, r_1172, r_3597, rxn37611, rxn...
#
#    yeast8U_reaction_num
# 0                     2
# 1                     8
# 2                    35

# %%
target_100met_df['class'].value_counts()
# Out:
# class
# amino acid                24
# organic acid               9
# alcohol                    5
# fatty acids and lipids     4
# alkaloid                   3
# other                      3
# bioamine                   2
# nucleic acid               2
# Name: count, dtype: int64

# %%
classes_order = ['nucleic acid', 'bioamine','other','alkaloid','fatty acids and lipids','alcohol','organic acid','amino acid']
target_100met_df = target_100met_df.sort_values(by='class', key=lambda x: pd.Categorical(x, categories=classes_order, ordered=True), na_position='last')
target_100met_df = target_100met_df.groupby('class', sort=False).apply(lambda x: x.sort_values(by='yeast8U_reaction_num', ascending=True)).reset_index(drop=True)
target_100met_df.head(3)
# Out:
#         Name   Group         class  \
# 0  thymidine  native  nucleic acid
# 1    guanine  native  nucleic acid
# 2   spermine  native      bioamine
#
#                                 yeast8_reaction_lst  yeast8_reaction_num  \
# 0                                  [r_2074, r_2075]                    2
# 1  [r_0526, r_0527, r_0949, r_1176, r_1819, r_4758]                    6
# 2                  [r_0937, r_1262, r_1263, r_1739]                    4
#
#                                 yeast8U_reaction_lst  yeast8U_reaction_num
# 0  [r_2074, r_2075, rxn27399, rxn27400, rxn6871, ...                     6
# 1  [r_0526, r_0527, r_0949, r_1176, r_1819, r_475...                    26
# 2                   [r_0937, r_1262, r_1263, r_1739]                     4

# %%
target_100met_df.head(1)
# Out:
#         Name   Group         class yeast8_reaction_lst  yeast8_reaction_num  \
# 0  thymidine  native  nucleic acid    [r_2074, r_2075]                    2
#
#                                 yeast8U_reaction_lst  yeast8U_reaction_num
# 0  [r_2074, r_2075, rxn27399, rxn27400, rxn6871, ...                     6

# %%
target_100met_df = target_100met_df[target_100met_df['class']!='fatty acids and lipids'].reset_index(drop=True)
target_100met_df
# Out:
#                     Name   Group         class  \
# 0              thymidine  native  nucleic acid
# 1                guanine  native  nucleic acid
# 2               spermine  native      bioamine
# 3             putrescine  native      bioamine
# 4                   urea  native         other
# 5             ergosterol  native         other
# 6           acetaldehyde  native         other
# 7               xanthine  native      alkaloid
# 8                choline  native      alkaloid
# 9           hypoxanthine  native      alkaloid
# 10  (R,R)-2,3-butanediol  native       alcohol
# 11            isobutanol  native       alcohol
# 12             isoamylol  native       alcohol
# 13       2-phenylethanol  native       alcohol
# 14              glycerol  native       alcohol
# 15           (S)-lactate  native  organic acid
# 16             glycolate  native  organic acid
# 17               acetate  native  organic acid
# 18              fumarate  native  organic acid
# 19             hexanoate  native  organic acid
# 20               citrate  native  organic acid
# 21            (S)-malate  native  organic acid
# 22              pyruvate  native  organic acid
# 23        2-oxoglutarate  native  organic acid
# 24          L-citrulline  native    amino acid
# 25             L-proline  native    amino acid
# 26              L-valine  native    amino acid
# 27           L-threonine  native    amino acid
# 28            L-arginine  native    amino acid
# 29          L-homoserine  native    amino acid
# 30           L-histidine  native    amino acid
# 31           glutathione  native    amino acid
# 32          L-tryptophan  native    amino acid
# 33          L-asparagine  native    amino acid
# 34             ornithine  native    amino acid
# 35              L-lysine  native    amino acid
# 36          L-isoleucine  native    amino acid
# 37             L-leucine  native    amino acid
# 38              L-serine  native    amino acid
# 39             L-glycine  native    amino acid
# 40       L-phenylalanine  native    amino acid
# 41            L-tyrosine  native    amino acid
# 42           L-aspartate  native    amino acid
# 43             L-alanine  native    amino acid
# 44          L-methionine  native    amino acid
# 45            L-cysteine  native    amino acid
# 46           L-glutamine  native    amino acid
# 47           L-glutamate  native    amino acid
#
#                                   yeast8_reaction_lst  yeast8_reaction_num  \
# 0                                    [r_2074, r_2075]                    2
# 1    [r_0526, r_0527, r_0949, r_1176, r_1819, r_4758]                    6
# 2                    [r_0937, r_1262, r_1263, r_1739]                    4
# 3                            [r_1001, r_1251, r_1252]                    3
# 4                    [r_0189, r_1075, r_1273, r_4210]                    4
# 5   [r_1068, r_1147, r_1148, r_1758, r_1759, r_355...                    7
# 6   [r_0095, r_0173, r_0960, r_1632, r_1633, r_211...                    8
# 7                                    [r_1091, r_2101]                    2
# 8                            [r_0273, r_1684, r_4332]                    3
# 9                            [r_0562, r_0951, r_1842]                    3
# 10                                   [r_0003, r_1097]                    2
# 11                           [r_0161, r_1868, r_1869]                    3
# 12                           [r_0160, r_1863, r_1864]                    3
# 13                           [r_0162, r_1590, r_1591]                    3
# 14                   [r_0487, r_0488, r_1172, r_3597]                    4
# 15                           [r_0004, r_1206, r_4711]                    3
# 16                                           [r_4315]                    1
# 17  [r_0112, r_1106, r_1635, r_4397, r_4569, r_460...                    7
# 18  [r_0152, r_0207, r_0452, r_0453, r_0455, r_100...                    7
# 19                                   [r_2191, r_2230]                    2
# 20  [r_0303, r_1112, r_1126, r_1127, r_1128, r_168...                    8
# 21  [r_0452, r_0714, r_1126, r_1226, r_1652, r_168...                    9
# 22  [r_0958, r_0959, r_0960, r_1138, r_1254, r_203...                   13
# 23  [r_0018, r_0068, r_0216, r_0471, r_0472, r_065...                   31
# 24                                   [r_0208, r_4469]                    2
# 25                           [r_0941, r_1216, r_1905]                    3
# 26                   [r_1087, r_1089, r_1224, r_2093]                    4
# 27  [r_0692, r_1040, r_1042, r_1218, r_2072, r_424...                    7
# 28  [r_0206, r_0207, r_0209, r_1184, r_1185, r_165...                    8
# 29                           [r_0548, r_0549, r_1895]                    3
# 30   [r_0539, r_0541, r_1200, r_1201, r_1837, r_4162]                    6
# 31  [r_0443, r_0457, r_0483, r_0697, r_0964, r_116...                   11
# 32   [r_0694, r_1056, r_1057, r_1219, r_2082, r_2118]                    6
# 33           [r_0212, r_0679, r_1186, r_1187, r_1658]                    5
# 34                   [r_0816, r_0817, r_0819, r_1238]                    4
# 35           [r_0711, r_1212, r_1213, r_1919, r_4163]                    5
# 36           [r_0663, r_0665, r_1202, r_1203, r_1205]                    5
# 37           [r_0699, r_0701, r_1208, r_1209, r_1211]                    5
# 38  [r_0309, r_0502, r_0689, r_0690, r_0992, r_099...                   11
# 39  [r_0485, r_0502, r_0512, r_0914, r_1173, r_181...                   13
# 40           [r_0851, r_0852, r_1215, r_2004, r_2117]                    5
# 41  [r_0695, r_1063, r_1066, r_1220, r_1221, r_122...                    9
# 42  [r_0153, r_0208, r_0211, r_0214, r_0215, r_021...                   10
# 43  [r_0094, r_0156, r_0157, r_0457, r_1183, r_211...                   10
# 44  [r_0726, r_0729, r_1214, r_4186, r_4202, r_439...                    7
# 45  [r_0311, r_0313, r_0460, r_0815, r_0905, r_119...                   11
# 46  [r_0066, r_0079, r_0203, r_0211, r_0250, r_030...                   20
# 47  [r_0018, r_0026, r_0216, r_0346, r_0460, r_046...                   30
#
#                                  yeast8U_reaction_lst  yeast8U_reaction_num
# 0   [r_2074, r_2075, rxn27399, rxn27400, rxn6871, ...                     6
# 1   [r_0526, r_0527, r_0949, r_1176, r_1819, r_475...                    26
# 2                    [r_0937, r_1262, r_1263, r_1739]                     4
# 3   [r_1001, r_1251, r_1252, rxn26973, rxn41825, r...                    18
# 4           [r_0189, r_1075, r_1273, r_4210, rxn3657]                     5
# 5   [r_1068, r_1147, r_1148, r_1758, r_1759, r_355...                     8
# 6   [r_0095, r_0173, r_0960, r_1632, r_1633, r_211...                    25
# 7   [r_1091, r_2101, rxn37957, rxn34169, rxn3246, ...                    10
# 8   [r_0273, r_1684, r_4332, rxn20125, rxn20126, r...                    19
# 9   [r_0562, r_0951, r_1842, rxn37849, rxn37884, r...                    19
# 10                                   [r_0003, r_1097]                     2
# 11                           [r_0161, r_1868, r_1869]                     3
# 12  [r_0160, r_1863, r_1864, rxn10827, rxn11682, r...                     7
# 13  [r_0162, r_1590, r_1591, rxn20557, rxn25236, r...                     8
# 14  [r_0487, r_0488, r_1172, r_3597, rxn37611, rxn...                    35
# 15                           [r_0004, r_1206, r_4711]                     3
# 16              [r_4315, rxn37584, rxn45912, rxn3741]                     4
# 17  [r_0112, r_1106, r_1635, r_4397, r_4569, r_460...                     7
# 18  [r_0152, r_0207, r_0452, r_0453, r_0455, r_100...                     9
# 19  [r_2191, r_2230, rxn30200, rxn30201, rxn30202,...                    10
# 20  [r_0303, r_1112, r_1126, r_1127, r_1128, r_168...                    10
# 21  [r_0452, r_0714, r_1126, r_1226, r_1652, r_168...                    10
# 22  [r_0958, r_0959, r_0960, r_1138, r_1254, r_203...                    43
# 23  [r_0018, r_0068, r_0216, r_0471, r_0472, r_065...                    78
# 24                                   [r_0208, r_4469]                     2
# 25       [r_0941, r_1216, r_1905, rxn55519, rxn66465]                     5
# 26  [r_1087, r_1089, r_1224, r_2093, rxn11814, rxn...                     7
# 27  [r_0692, r_1040, r_1042, r_1218, r_2072, r_424...                     7
# 28  [r_0206, r_0207, r_0209, r_1184, r_1185, r_165...                     9
# 29  [r_0548, r_0549, r_1895, rxn46992, rxn49105, r...                    11
# 30  [r_0539, r_0541, r_1200, r_1201, r_1837, r_416...                    12
# 31  [r_0443, r_0457, r_0483, r_0697, r_0964, r_116...                    16
# 32  [r_0694, r_1056, r_1057, r_1219, r_2082, r_211...                    17
# 33  [r_0212, r_0679, r_1186, r_1187, r_1658, rxn38...                    18
# 34  [r_0816, r_0817, r_0819, r_1238, rxn39471, rxn...                    23
# 35  [r_0711, r_1212, r_1213, r_1919, r_4163, rxn32...                    26
# 36  [r_0663, r_0665, r_1202, r_1203, r_1205, rxn54...                    37
# 37  [r_0699, r_0701, r_1208, r_1209, r_1211, rxn14...                    38
# 38  [r_0309, r_0502, r_0689, r_0690, r_0992, r_099...                    42
# 39  [r_0485, r_0502, r_0512, r_0914, r_1173, r_181...                    45
# 40  [r_0851, r_0852, r_1215, r_2004, r_2117, rxn20...                    53
# 41  [r_0695, r_1063, r_1066, r_1220, r_1221, r_122...                    54
# 42  [r_0153, r_0208, r_0211, r_0214, r_0215, r_021...                    60
# 43  [r_0094, r_0156, r_0157, r_0457, r_1183, r_211...                    61
# 44  [r_0726, r_0729, r_1214, r_4186, r_4202, r_439...                    63
# 45  [r_0311, r_0313, r_0460, r_0815, r_0905, r_119...                    63
# 46  [r_0066, r_0079, r_0203, r_0211, r_0250, r_030...                    70
# 47  [r_0018, r_0026, r_0216, r_0346, r_0460, r_046...                    76

# %%
target_100met_df.to_csv(source_fig4b_path,index=None)

# %% [markdown]
# # figure

# %%
# Set common parameters
plt.figure(figsize=(1.5, 4.8), dpi=400)
plt.rcParams.update({'font.size': 6})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Set axis style
ax = plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0.5)
ax.spines['left'].set_linewidth(0.5)
ax.spines['right'].set_linewidth(0)

# Draw stacked bar chart, swapping x and y axes
bar_width = 0.6
index = np.arange(len(target_100met_df['Name']))

# Define colors and sections
colors = ['#a6cee3', '#1f78b4', '#b2df8a', '#fb9a99', '#e31a1c', '#fdbf6f', '#cab2d6']
sections = [(24, 48), (15, 24), (10, 15), (7, 10), (4, 7), (2, 4), (0, 2)]
labels = ['Amino acid', 'Organic acid', 'Alcohol', 'Alkaloid', 'Other', 'Bioamine', 'Nucleic acid']

for i, (start, end) in enumerate(sections):
    plt.barh(index[start:end], target_100met_df['yeast8U_reaction_num'][start:end], height=bar_width, color='white', edgecolor=colors[i], linewidth=0.5)
    plt.barh(index[start:end], target_100met_df['yeast8_reaction_num'][start:end], height=bar_width, label=labels[i], color=colors[i])

# Set axis parameters
plt.tick_params(axis='x', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='y', which='both', width=0.5, length=1, pad=1)
plt.ylim(-1, 48)
plt.xlim(0, 120)
plt.yticks(index, target_100met_df['Name'], fontsize=5.7)
plt.xticks(np.arange(0, 121, 30), fontsize=6)
plt.xlabel('Number of reaction', fontsize=6)

# Set legend
custom_patch1 = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=0.5, label='Yeast-MetaTwin')
custom_patch2 = mpatches.Patch(facecolor='black', edgecolor='black', linewidth=0.5, label='Yeast8')

# Get current legend handles and labels
handles, labels = ax.get_legend_handles_labels()

# Insert custom legend entries
handles.insert(0, custom_patch1)
handles.insert(1, custom_patch2)

# Create legend
plt.legend(handles=handles, frameon=False, fontsize=7, loc='center left', bbox_to_anchor=(-1.3, 0.5), labelspacing=0.5, handletextpad=0.3, handlelength=1)

plt.tight_layout()
plt.savefig(yeast8U_native_product_reaction_figure_path, dpi=400, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_2516076/2942232006.py:50: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## ec

# %%
target_100met_df.head(1)
# Out:
#         Name   Group         class yeast8_reaction_lst  yeast8_reaction_num  \
# 0  thymidine  native  nucleic acid    [r_2074, r_2075]                    2
#
#                                 yeast8U_reaction_lst  yeast8U_reaction_num
# 0  [r_2074, r_2075, rxn27399, rxn27400, rxn6871, ...                     6

# %%
def get_gene_lst_for_reaction_lst(reaction_lst,yeast8U):
    gene_lst = []
    for i in reaction_lst:
        # print(yeast8U.reactions.get_by_id(i).gpr)
        gene_tmp_lst = str(yeast8U.reactions.get_by_id(i).gpr).replace('(','').replace(')','').replace(' and ',' ').replace(' or ',' ').split(' ')
        # print(gene_tmp_lst)
        gene_lst += gene_tmp_lst
    gene_lst = list(set(gene_lst))
    gene_lst = [x for x in gene_lst if x!='']
    return gene_lst

reaction_lst = ['r_0526']
get_gene_lst_for_reaction_lst(reaction_lst,yeast8U)
# Out:
# ['YDL238C']

# %%
target_100met_df['yeast8_gene'] = target_100met_df['yeast8_reaction_lst'].apply(lambda x:get_gene_lst_for_reaction_lst(x,yeast8))
target_100met_df['yeast8U_gene'] = target_100met_df['yeast8U_reaction_lst'].apply(lambda x:get_gene_lst_for_reaction_lst(x,yeast8U))

target_100met_df['yeast8_gene_num'] = target_100met_df['yeast8_gene'].apply(lambda x:len(x))
target_100met_df['yeast8U_gene_num'] = target_100met_df['yeast8U_gene'].apply(lambda x:len(x))

# %%
target_100met_df['class'].value_counts()
# Out:
# class
# amino acid      24
# organic acid     9
# alcohol          5
# other            3
# alkaloid         3
# nucleic acid     2
# bioamine         2
# Name: count, dtype: int64

# %%
target_100met_df_1 = target_100met_df[target_100met_df['class']=='amino acid']
target_100met_df_2 = target_100met_df[target_100met_df['class']=='organic acid']
target_100met_df_3 = target_100met_df[target_100met_df['class']=='alcohol']
# target_100met_df_4 = target_100met_df[target_100met_df['class']=='fatty acids and lipids']
target_100met_df_5 = target_100met_df[target_100met_df['class']=='other']
target_100met_df_6 = target_100met_df[target_100met_df['class']=='alkaloid']
target_100met_df_7 = target_100met_df[target_100met_df['class']=='nucleic acid']
target_100met_df_8 = target_100met_df[target_100met_df['class']=='bioamine']

# %%
# Setting General Parameters
plt.figure(figsize=(2, 2), dpi=400)
plt.rcParams.update({'font.size': 6})
plt.rcParams['font.family'] = 'Arial'

# Setting Axis Styles
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Plot scatter points with normalized 'score'
plt.scatter(target_100met_df_1['yeast8U_reaction_num'], target_100met_df_1['yeast8U_gene_num'], s=3, c='#e41a1c', label='Amino acid')
plt.scatter(target_100met_df_2['yeast8U_reaction_num'], target_100met_df_2['yeast8U_gene_num'], s=3, c='#377eb8', label='Organic acid')
plt.scatter(target_100met_df_3['yeast8U_reaction_num'], target_100met_df_3['yeast8U_gene_num'], s=3, c='#4daf4a', label='Alcohol')
plt.scatter(target_100met_df_5['yeast8U_reaction_num'], target_100met_df_5['yeast8U_gene_num'], s=3, c='#ff7f00', label='Other')
plt.scatter(target_100met_df_6['yeast8U_reaction_num'], target_100met_df_6['yeast8U_gene_num'], s=3, c='#ffff33', label='Alkaloid')
plt.scatter(target_100met_df_7['yeast8U_reaction_num'], target_100met_df_7['yeast8U_gene_num'], s=3, c='#a65628', label='Nucleic acid')
plt.scatter(target_100met_df_8['yeast8U_reaction_num'], target_100met_df_8['yeast8U_gene_num'], s=3, c='#ff7f00', label='Bioamine')

# Setting X-axis and Y-axis Labels
plt.xlabel('Reactions Involved as Reactants', fontsize=6)
plt.ylabel('Putative genes of reactions', fontsize=6)

# Configure x and y axis limits and scales
plt.xlim(-5, 180)
plt.ylim(0.8, 1200)
plt.yscale('log')
plt.minorticks_off()  # Hide minor ticks

plt.tick_params(axis='both', direction='in', width=0.5, which='both', length=2)

# Add legend
plt.legend(fontsize=5, markerscale=1, bbox_to_anchor=(1, 0), loc='lower right', frameon=False, handletextpad=0.05)

# Display the plot
plt.show()
