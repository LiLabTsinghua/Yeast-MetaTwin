# %%
import pandas as pd
import numpy as np
import json
import cobra
from cobra import Model, Reaction, Metabolite
from cobra.flux_analysis import flux_variability_analysis,moma,add_moma
import pickle
from tqdm import tqdm 
from ast import literal_eval
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import sys
sys.path.append('../retrosynthesis/')

from common import *
# from IgnoreMet import *

# %% [markdown]
# ### input and output

# %%
### input
yeast870_path =  '../../Data/model/yeast-GEM.yml'
yeast8U_path = '../../Data/model/Yeast-MetaTwin.yml'
target_product_file_path = '../../Data/100met_with_smiles.xlsx'
metabolites_info_to_GEM_path = '../../Results/not_lipid/top50_0.3_re/metabolites_info_to_GEM_top50_0.3.csv'
miss_id_path = '../../Data/miss_met_id.json'
YMDB_total_smiles_path = '../../Data/database/ymdb/ymdb_final_result.xlsx'

### output

# %% [markdown]
# ### native product

# %%
def get_yeast8_metid_for_keggid(model,keggid):
    metid = 'no this met'
    for met in model.metabolites:
        if met.compartment == 'c':
            if 'kegg.compound' in model.metabolites.get_by_id(met.id).annotation:
                if model.metabolites.get_by_id(met.id).annotation['kegg.compound'] == keggid:
                    metid = met.id
    return(metid)

def calculate_FBA(Target_met,model):
    exchange_reaction = get_exchange_reaction(Target_met,model)
    model.objective = model.reactions.get_by_id(exchange_reaction)
    model.optimize()
    ### Remove the added reaction
    if abs(model.reactions.get_by_id(exchange_reaction).flux)>0.001:
        flux_tmp = model.reactions.get_by_id(exchange_reaction).flux
    else:
        flux_tmp = 0
    if 'DM_' in exchange_reaction:
        model.remove_reactions(exchange_reaction)    
    return flux_tmp

def top_three_elements(lst):
    counter = Counter(lst)
    top_three = counter.most_common(3)
    top_three_elements = [item[0] for item in top_three]
    return top_three_elements

def get_subsystem(Target_met,model):
    exchange_reaction = get_exchange_reaction(Target_met,model)
    model.objective = model.reactions.get_by_id(exchange_reaction)
    model.optimize()
    subsystem_list = []
    for i in model.reactions:
        if abs(i.flux)>0.001:
            try:
                subsystem_list.append(i.subsystem[0])
            except: pass

    if 'DM_' in exchange_reaction:
        model.remove_reactions(exchange_reaction)   
    # return subsystem_list
    subsystem_list = [x for x in subsystem_list if 'Transport' not in x and 'Exchange' not in x]
    return top_three_elements(subsystem_list)

def prepare_target_product(target_product_file_path,yeast870_path):
    yeast8 = cobra.io.load_yaml_model(yeast870_path)
    target_product_pd = pd.read_excel(target_product_file_path)
    # target_product_pd.dropna(inplace=True)
    target_product_pd = target_product_pd[target_product_pd['Group'] == 'native']
    target_product_pd['yeast8_id'] = target_product_pd['KEGG ID'].apply(lambda x: get_yeast8_metid_for_keggid(yeast8,x))
    target_product_pd['FBA'] = target_product_pd['yeast8_id'].apply(lambda x : calculate_FBA(x,yeast8))
    target_product_pd = target_product_pd[target_product_pd['FBA']>0.0001]
    target_product_pd['subsystem'] = target_product_pd['yeast8_id'].apply(lambda x : get_subsystem(x,yeast8))
    print(target_product_pd.shape)
    return target_product_pd

# %%
target_product_pd = prepare_target_product(target_product_file_path,yeast870_path)
target_product_pd.head()
# Out:
# /home/wuke/anaconda3/envs/kcat/lib/python3.7/site-packages/cobra/core/model.py:777: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# (52, 11)
#               Name  Formula KEGG ID  CHEBI ID   Group    class Gene target  \
# 0   2,3-Butanediol  C4H10O2  C03044   16982.0  native  alcohol        Link
# 1  2-Phenylethanol   C8H10O  C05853   49000.0  native  alcohol        Link
# 2         Glycerol   C3H8O3  C00116   17754.0  native  alcohol        Link
# 3        Isoamylol   C5H12O  C07328   15837.0  native  alcohol        Link
# 4       Isobutanol   C4H10O  C14710   46645.0  native  alcohol        Link
#
#   Smiles yeast8_id       FBA  \
# 0    NaN    s_0035  1.077151
# 1    NaN    s_0185  0.544096
# 2    NaN    s_0765  1.558928
# 3    NaN    s_0929  0.728744
# 4    NaN    s_0932  1.000000
#
#                                            subsystem
# 0  [Glycolysis / gluconeogenesis, Glycine, serine...
# 1  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 2  [Glycolysis / gluconeogenesis, Citrate cycle (...
# 3  [Valine, leucine and isoleucine metabolism, Gl...
# 4  [Glycolysis / gluconeogenesis, Thiamine metabo...

# %% [markdown]
# ### byproduct reaction

# %%
def get_smiles(metid,model,met_info):
    # print(metid)
    smiles = None
    if metid.startswith('s_'):
        if hasattr(model.metabolites.get_by_id(metid), 'smiles'):
            smiles = model.metabolites.get_by_id(metid).smiles
    elif metid.startswith('sn_'):
        if metid in met_info['ID'].tolist():
            smiles =  met_info[met_info['ID'] == metid]['new_met_smiles'].to_list()[0]
    return smiles

def get_new_smiles_lst_has_carbon(self_smiles,smiles_lst):
    smiles_lst = list(set(smiles_lst))
    smiles_lst = [x for x in smiles_lst if not compare_smiles_inchikey(self_smiles,x)]
    smiles_lst = [x for x in smiles_lst if calculate_carbon_count(x)<=calculate_carbon_count(self_smiles)]
    result = []
    for i in smiles_lst:
        if any(compare_smiles_inchikey(i,j) for j in result):
            pass
        else:
            result.append(i)
    return result

def target_met_in_reaction_lst(target_met,yeast8U):
    reaction_lst = []
    for rea in yeast8U.reactions:
        if target_met in rea.reaction and rea.bounds==(0,1000) and  rea.metabolites[yeast8U.metabolites.get_by_id(target_met)]<0:
            reaction_lst.append(rea.id)
        elif target_met in rea.reaction and rea.bounds==(-1000,0) and  rea.metabolites[yeast8U.metabolites.get_by_id(target_met)]>0:
            reaction_lst.append(rea.id)
        elif target_met in rea.reaction and rea.bounds==(-1000,1000):
            reaction_lst.append(rea.id)
    return reaction_lst

# %%
yeast8U = cobra.io.load_yaml_model(yeast8U_path)
yeast8 = cobra.io.load_yaml_model(yeast870_path)
met_info = pd.read_csv(metabolites_info_to_GEM_path)
with open(miss_id_path) as f:
    miss_met_id = json.load(f)

# %%
target_product_pd['yeast8_reaction_lst'] = target_product_pd['yeast8_id'].apply(lambda x: target_met_in_reaction_lst(x,yeast8))
target_product_pd['yeast8U_reaction_lst'] = target_product_pd['yeast8_id'].apply(lambda x: target_met_in_reaction_lst(x,yeast8U))
target_product_pd['yeast8_reaction_num'] = target_product_pd['yeast8_reaction_lst'].apply(lambda x:len(x))
target_product_pd['yeast8U_reaction_num'] = target_product_pd['yeast8U_reaction_lst'].apply(lambda x: len(x))

# %%
target_100met_df = target_product_pd[['Name','Group','class','yeast8_reaction_lst','yeast8_reaction_num','yeast8U_reaction_lst','yeast8U_reaction_num']]
target_100met_df.head(3)
# Out:
#               Name   Group    class               yeast8_reaction_lst  \
# 0   2,3-Butanediol  native  alcohol                  [r_0003, r_1097]
# 1  2-Phenylethanol  native  alcohol          [r_0162, r_1590, r_1591]
# 2         Glycerol  native  alcohol  [r_0487, r_0488, r_1172, r_3597]
#
#    yeast8_reaction_num                               yeast8U_reaction_lst  \
# 0                    2                          [r_0003, r_1097, rxn1560]
# 1                    3  [r_0162, r_1590, r_1591, rxn46, rxn1092, rxn12...
# 2                    4  [r_0487, r_0488, r_1172, r_3597, rxn289, rxn53...
#
#    yeast8U_reaction_num
# 0                     3
# 1                    10
# 2                    34

# %%
target_100met_df['class'].value_counts()
# Out:
# amino acid                24
# organic acid               9
# alcohol                    5
# fatty acids and lipids     4
# alkaloid                   3
# other                      3
# bioamine                   2
# nucleic acid               2
# Name: class, dtype: int64

# %%
classes_order = ['nucleic acid', 'bioamine','other','alkaloid','fatty acids and lipids','alcohol','organic acid','amino acid']
target_100met_df = target_100met_df.sort_values(by='class', key=lambda x: pd.Categorical(x, categories=classes_order, ordered=True), na_position='last')
target_100met_df = target_100met_df.groupby('class', sort=False).apply(lambda x: x.sort_values(by='yeast8U_reaction_num', ascending=True)).reset_index(drop=True)
target_100met_df = target_100met_df[target_100met_df['class']!='fatty acids and lipids'].reset_index(drop=True)
target_100met_df.head(3)
# Out:
#         Name   Group         class  \
# 0  Thymidine  native  nucleic acid
# 1    Guanine  native  nucleic acid
# 2   Spermine  native      bioamine
#
#                                 yeast8_reaction_lst  yeast8_reaction_num  \
# 0                                  [r_2074, r_2075]                    2
# 1  [r_0526, r_0527, r_0949, r_1176, r_1819, r_4758]                    6
# 2                  [r_0937, r_1262, r_1263, r_1739]                    4
#
#                                 yeast8U_reaction_lst  yeast8U_reaction_num
# 0  [r_2074, r_2075, rxn327, rxn2430, rxn2431, rxn...                     7
# 1  [r_0526, r_0527, r_0949, r_1176, r_1819, r_475...                    24
# 2          [r_0937, r_1262, r_1263, r_1739, rxn2611]                     5

# %% [markdown]
# ### fig4b

# %%
target_100met_df = target_100met_df[::-1].reset_index(drop=True)

# %%
rxndb_total_info_to_model_path = '../../Results/not_lipid/top50_0.3_re/rxndb_total_info_to_model_del2_reaction_top50_0.3.csv'

rxndb_total_info_to_model = pd.read_csv(rxndb_total_info_to_model_path)
rxndb_total_info_to_model.head()

def get_rxn_smiles_final_by_ID(reaID,rxndb_total_info_to_model):
    return rxndb_total_info_to_model[rxndb_total_info_to_model['NO']==reaID]['rxn_smiles_final'].to_list()[0]

rxn_smiles = get_rxn_smiles_final_by_ID('rxn2431',rxndb_total_info_to_model)
reaction = AllChem.ReactionFromSmarts(rxn_smiles)
display(reaction)

# %%
def generate_reaction_equation(reaction_dict):
    reactants = []
    products = []
    for metabolite, coefficient in reaction_dict.items():
        if coefficient < 0:
            if abs(coefficient) == 1:
                reactants.append(metabolite)
            else:
                reactants.append(f"{abs(coefficient)} {metabolite}")
        elif coefficient > 0:
            if coefficient == 1:
                products.append(metabolite)
            else:
                products.append(f"{coefficient} {metabolite}")
    
    return " + ".join(reactants) + " => " + " + ".join(products)

reaction_dict = {'(R)-5-diphosphomevalonic acid': -2, '(R)-5-phosphomevalonic acid': 1, 'H+': 10, 'thymidine': -1, "thymidine 3'-monophosphate": 1}
equation = generate_reaction_equation(reaction_dict)
print(equation)
# Out:
# 2 (R)-5-diphosphomevalonic acid + thymidine => (R)-5-phosphomevalonic acid + 10 H+ + thymidine 3'-monophosphate

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
import matplotlib.pyplot as plt


def draw_reaction(smiles,figure_path):
    reactant_smiles = smiles.split('>>')[0]
    product_smiles = smiles.split('>>')[1]
    reactant_mol = Chem.MolFromSmiles(reactant_smiles)
    product_mol = Chem.MolFromSmiles(product_smiles)

    img1 = Draw.MolToImage(reactant_mol)
    img2 = Draw.MolToImage(product_mol)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4, 8))

    ax1.imshow(img1)
    ax1.set_title('Reactant')
    ax1.axis('off')

    ax2.imshow(img2)
    ax2.set_title('Product')
    ax2.axis('off')

    plt.tight_layout()

    plt.savefig(figure_path, dpi=200, bbox_inches='tight')
    plt.show()

# %%
met_info = pd.read_csv(metabolites_info_to_GEM_path)
met_info = met_info[~met_info['ID'].str.contains('s_')]
YMDB_Data = pd.read_excel(YMDB_total_smiles_path)
# YMDB_Data = YMDB_Data[YMDB_Data['in_model']==0]

def process_metinfoID(metinfoID, met_info, YMDB_Data):
    metinfoID_smiles = met_info[met_info['ID'] == metinfoID]['new_met_smiles'].to_list()[0]
    YMDB_ID = []
    for index, row in YMDB_Data.iterrows():
        if compare_smiles_inchikey(metinfoID_smiles, row['SMILES']):
            YMDB_ID.append(row['NAME'])
    if len(YMDB_ID)>0:
        return metinfoID, YMDB_ID[0]
    else:
        return metinfoID, YMDB_ID


ID2name = {}
metinfoID_list = list(set(met_info['ID'].to_list()))
process_partial = partial(process_metinfoID, met_info=met_info, YMDB_Data=YMDB_Data)
with mp.Pool(60) as pool:
    results = list(tqdm(pool.imap_unordered(process_partial, metinfoID_list), total=len(metinfoID_list)))
for metinfoID, YMDB_ID in results:
    ID2name[metinfoID] = YMDB_ID
# Out:
# 100%|██████████| 418/418 [04:46<00:00,  1.46it/s]

# %%
for i in yeast8U.metabolites:
    if 'sn_' in i.id:
        i.name = str(ID2name[i.id])

# %%
for index,row in target_100met_df.iterrows():
    result_df = {'Product name':[],
                'Predicted reaction number':[],
                'Predicted reaction Yeast-MetaTwin ID':[],
                'Predicted reaction':[],
                'Predicted genes of reaction':[]}
    num = 0
    print(row['Name'])
    print(row['yeast8U_reaction_lst'])
    reaction_lst = [x for x in row['yeast8U_reaction_lst'] if 'r_' not in x]
    print(reaction_lst)
    for reaction_ID in reaction_lst:
        reaction = yeast8U.reactions.get_by_id(reaction_ID)
        # if any(ID in reaction.reaction for ID in miss_data):
            # pass
        # else:
        num+=1
        print(reaction_ID,reaction.gene_reaction_rule)
        print({k.name:v for k,v in reaction.metabolites.items() if k.name != '[]'})
        reaction_equation = generate_reaction_equation({k.name:v for k,v in reaction.metabolites.items()})
        print(reaction_equation)

        # rxn_smiles = get_rxn_smiles_final_by_ID(reaction_ID,rxndb_total_info_to_model)
        # img_path = f"../Data/Predicted reaction/{row['Name']}_{num}.png"
        # draw_reaction(rxn_smiles,img_path)

        # reaction_mol = AllChem.ReactionFromSmarts(rxn_smiles)
        # img = Draw.ReactionToImage(reaction_mol)
        # img_path = f"../Data/Predicted reaction/{row['Name']}_{num}.png"
        # img.save(img_path)

        result_df['Product name'].append(row['Name'])
        result_df['Predicted reaction number'].append(num)
        result_df['Predicted reaction Yeast-MetaTwin ID'].append(reaction_ID)
        result_df['Predicted reaction'].append(reaction_equation)
        result_df['Predicted genes of reaction'].append(reaction.gene_reaction_rule)
        pd.DataFrame(result_df).to_csv(f"../../Results/byproduct/native/{row['Name']}.csv",index=None)
    print('==========')
# Out:
# L-glutamate
# ['r_0018', 'r_0026', 'r_0216', 'r_0346', 'r_0460', 'r_0468', 'r_0469', 'r_0470', 'r_0476', 'r_0479', 'r_0538', 'r_0663', 'r_0699', 'r_0851', 'r_0918', 'r_0989', 'r_1031', 'r_1063', 'r_1087', 'r_1118', 'r_1194', 'r_1196', 'r_1659', 'r_1890', 'r_4211', 'r_4212', 'r_4226', 'r_4355', 'r_4572', 'r_4702', 'rxn436', 'rxn448', 'rxn464', 'rxn465', 'rxn468', 'rxn470', 'rxn542', 'rxn696', 'rxn743', 'rxn769', 'rxn806', 'rxn827', 'rxn867', 'rxn936', 'rxn1259', 'rxn1260', 'rxn1261', 'rxn1496', 'rxn1831', 'rxn1854', 'rxn1885', 'rxn1897', 'rxn1910', 'rxn2041', 'rxn2042', 'rxn2155', 'rxn2195', 'rxn2196', 'rxn2260', 'rxn2357', 'rxn2359', 'rxn2366', 'rxn2458', 'rxn2531', 'rxn2545', 'rxn2690', 'rxn2885', 'rxn2951', 'rxn2967', 'rxn2977', 'rxn3029']
# ['rxn436', 'rxn448', 'rxn464', 'rxn465', 'rxn468', 'rxn470', 'rxn542', 'rxn696', 'rxn743', 'rxn769', 'rxn806', 'rxn827', 'rxn867', 'rxn936', 'rxn1259', 'rxn1260', 'rxn1261', 'rxn1496', 'rxn1831', 'rxn1854', 'rxn1885', 'rxn1897', 'rxn1910', 'rxn2041', 'rxn2042', 'rxn2155', 'rxn2195', 'rxn2196', 'rxn2260', 'rxn2357', 'rxn2359', 'rxn2366', 'rxn2458', 'rxn2531', 'rxn2545', 'rxn2690', 'rxn2885', 'rxn2951', 'rxn2967', 'rxn2977', 'rxn3029']
# rxn436 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'L-glutamate': -1, 'phenylacetaldehyde': -1, 'phenylethylamine': 1}
# L-glutamate + phenylacetaldehyde => 2-oxoglutarate + phenylethylamine
# rxn448 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'L-glutamate': -1, 'Imidazole-4-acetaldehyde': -1, 'histamine': 1}
# L-glutamate + Imidazole-4-acetaldehyde => 2-oxoglutarate + histamine
# rxn464 YLL060C or YDL205C or YDR538W or YMR251W or YMR310C or YLR180W or YKL191W or YKR076W or YBR003W or YJR130C or YHR190W or YOR274W or YPR176C or YGR012W or YKL019W or YBR249C or YOR051C or YIR038C or YLR303W or YPL069C or YGR201C or YGR154C or YNL256W or YHR116W or YGL155W or YPL059W or YBR256C or YLL058W or YDL090C or YMR280C or YDR035W or YHR096C or YPR069C or YDR513W or YJL031C or YJL167W or YNL297C or YCL035C or YNR041C or YBR002C or YML082W or YML005W or YMR101C or YIL103W or YLR146C or YDR502C or YHR068W or YOL143C or YDL193W or YPL172C or YGR001C or YML007W or YNL229C
# {'ammonium': 1, 'L-glutamate': -1, 'L-lysine': -1, 'L-saccharopine': 1}
# L-glutamate + L-lysine => ammonium + L-saccharopine
# rxn465 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'AMP': 1, 'ATP': -1, 'diphosphate': 1, 'L-alanine': -1, 'L-gamma-glutamyl-L-alanine': 1, 'L-glutamate': -1}
# ATP + L-alanine + L-glutamate => AMP + diphosphate + L-gamma-glutamyl-L-alanine
# rxn468 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'H+': 1, 'L-glutamate': -1, 'L-glutamine': 1, '2-Oxoglutaramate': -1}
# L-glutamate + 2-Oxoglutaramate => 2-oxoglutarate + H+ + L-glutamine
# rxn470 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'H2O': -1, 'L-glutamate': -1, 'L-kynurenine': 1, 'kynurenic acid': -1}
# H2O + L-glutamate + kynurenic acid => 2-oxoglutarate + L-kynurenine
# rxn542 YJL172W or YPL096C-A
# {'5,6,7,8-tetrahydrofolyl-L-glutamic acid': -1, 'H+': -3, 'H2O': 1, 'L-glutamate': -1, 'tetrahydropteroyltri-L-glutamic acid': 1}
# 5,6,7,8-tetrahydrofolyl-L-glutamic acid + 3 H+ + L-glutamate => H2O + tetrahydropteroyltri-L-glutamic acid
# rxn696 YBR006W or YPL061W or YJR009C or YHR037W or YER073W or YDR158W or YMR169C or YGR192C or YPL098C or YMR110C or YMR170C or YOR374W or YOR323C or YJL052W
# {'H+': -1, 'H2O': 1, 'L-glutamate': -1, 'L-glutamic 5-semialdehyde': 1, 'NADP(+)': 1, 'NADPH': -1}
# H+ + L-glutamate + NADPH => H2O + L-glutamic 5-semialdehyde + NADP(+)
# rxn743 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'ethanolamine': 1, 'glycolaldehyde': -1, 'L-glutamate': -1}
# glycolaldehyde + L-glutamate => 2-oxoglutarate + ethanolamine
# rxn769 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'5,6,7,8-tetrahydrofolyl-L-glutamic acid': -1, 'ADP': 1, 'ATP': -1, 'H+': 4, 'L-glutamate': -1, 'phosphate': 1, 'tetrahydropteroyltri-L-glutamic acid': 1}
# 5,6,7,8-tetrahydrofolyl-L-glutamic acid + ATP + L-glutamate => ADP + 4 H+ + phosphate + tetrahydropteroyltri-L-glutamic acid
# rxn806 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'5,6,7,8-tetrahydrofolyl-L-glutamic acid': -1, 'ADP': 1, 'ATP': -1, 'H+': 1, 'L-glutamate': -1, 'phosphate': 1, 'tetrahydropteroyltri-L-glutamic acid': 1}
# 5,6,7,8-tetrahydrofolyl-L-glutamic acid + ATP + L-glutamate => ADP + H+ + phosphate + tetrahydropteroyltri-L-glutamic acid
# rxn827 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'L-glutamate': -1, 'L-glutamine': 1, 'D-Glucosamine': -1, 'beta-D-Fructose': 1}
# L-glutamate + D-Glucosamine => L-glutamine + beta-D-Fructose
# rxn867 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'5,6,7,8-tetrahydrofolyl-L-glutamic acid': -1, 'AMP': 1, 'ATP': -1, 'diphosphate': 1, 'H+': 1, 'L-glutamate': -1, 'tetrahydropteroyltri-L-glutamic acid': 1}
# 5,6,7,8-tetrahydrofolyl-L-glutamic acid + ATP + L-glutamate => AMP + diphosphate + H+ + tetrahydropteroyltri-L-glutamic acid
# rxn936 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'gamma-aminobutyrate': -1, 'H+': -1, 'H2O': 1, 'L-glutamate': -1, '4-(glutamylamino) butanoate': 1}
# gamma-aminobutyrate + H+ + L-glutamate => H2O + 4-(glutamylamino) butanoate
# rxn1259 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-glutamate': -1, 'L-glycine': 1, 'Ala-Glu': 1, 'Ala-Gly': -1}
# L-glutamate + Ala-Gly => L-glycine + Ala-Glu
# rxn1260 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-aspartate': 1, 'L-glutamate': -1, 'Ala-Glu': 1, 'Ala-Asp': -1}
# L-glutamate + Ala-Asp => L-aspartate + Ala-Glu
# rxn1261 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-glutamate': -1, 'L-leucine': 1, 'Ala-Glu': 1, 'Ala-Leu': -1}
# L-glutamate + Ala-Leu => L-leucine + Ala-Glu
# rxn1496 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'ammonium': 1, 'L-glutamate': -1, 'N-acetyl-L-glutamate': 1, 'acetamide': -1}
# L-glutamate + acetamide => ammonium + N-acetyl-L-glutamate
# rxn1831 YBR006W or YPL061W or YJR009C or YHR037W or YER073W or YDR158W or YMR169C or YGR192C or YPL098C or YMR110C or YMR170C or YOR374W or YOR323C or YJL052W
# {'H+': -1, 'H2O': 1, 'L-glutamate': -1, 'L-glutamic 5-semialdehyde': 1, 'NAD': 1, 'NADH': -1}
# H+ + L-glutamate + NADH => H2O + L-glutamic 5-semialdehyde + NAD
# rxn1854 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'H+': 1, 'L-allysine': -1, 'L-glutamate': -1, 'L-lysine': 1}
# L-allysine + L-glutamate => 2-oxoglutarate + H+ + L-lysine
# rxn1885 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'H+': 1, 'L-glutamate': -1, 'phenylacetaldehyde': -1, 'phenylethylamine': 1}
# L-glutamate + phenylacetaldehyde => 2-oxoglutarate + H+ + phenylethylamine
# rxn1897 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'ethanolamine': 1, 'glycolaldehyde': -1, 'H+': 1, 'L-glutamate': -1}
# glycolaldehyde + L-glutamate => 2-oxoglutarate + ethanolamine + H+
# rxn1910 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'H+': 1, 'L-glutamate': -1, 'Imidazole-4-acetaldehyde': -1, 'histamine': 1}
# L-glutamate + Imidazole-4-acetaldehyde => 2-oxoglutarate + H+ + histamine
# rxn2041 YDR138W or YGL084C or YNL071W or YDR264C or YBR042C or YOL089C or YOR175C or YIL160C or YOR162C or YDL044C or YLR246W or YPL248C or YNR019W or YOR269W or YLR372W or YGL162W or YOR221C or YDR018C or YMR266W or YJL117W or YMR042W or YMR306W or YDR451C or YMR191W or YBL074C or YAR035W or YGR032W or YHR159W or YBR289W or YLL002W or YPL028W or YEL066W or YDR191W or YDR062W or YLR033W or YGR015C or YFL017C or YJL218W or YGR177C or YPR139C or YMR127C or YLR418C or YLR239C or YDR071C or YKR038C or YDR501W or YKR067W or YNR008W or YMR296C or YNR063W or YDR235W or YKR099W or YGR110W or YPL231W or YGR193C or YOR253W or YOR025W or YLR195C or YMR069W or YPR140W or YBR081C or YLR360W or YLR439W or YMR019W or YNL326C or YLR099C or YOL141W or YHR051W or YJL071W or YDR148C or YER024W or YBL052C or YLL031C or YJL206C or YDL073W or YMR062C or YCR034W or YOL068C or YML042W or YLR342W or YNL025C or YJR098C or YBR177C or YOR245C or YBR297W or YCR106W or YPL189W or YIL101C or YDL104C or YJL024C or YML002W or YCR048W or YHL003C or YJL196C or YDR303C or YER061C or YDR232W or YOL003C or YER184C or YPL001W or YPR018W or YCL016C or YDR391C or YOR244W or YGR252W or YPL095C or YDR126W or YOL084W or YMR125W or YDL042C or YKL182W or YJL176C or YPL134C or YKL008C or YHR013C or YNL084C or YAL044C or YOR034C or YDL052C or YNL277W or YGR084C or YPL015C or YPR193C or YCR072C or YOR172W or YDR459C or YGR246C or YBL011W or YOR377W or YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-glutamate': -1, 'L-lysine': 1, 'N-acetyl-L-glutamate': 1, 'acetyllysine': -1}
# L-glutamate + acetyllysine => L-lysine + N-acetyl-L-glutamate
# rxn2042 YDR138W or YGL084C or YNL071W or YDR264C or YBR042C or YOL089C or YOR175C or YIL160C or YOR162C or YDL044C or YLR246W or YPL248C or YNR019W or YOR269W or YLR372W or YGL162W or YOR221C or YDR018C or YMR266W or YJL117W or YMR042W or YMR306W or YDR451C or YMR191W or YBL074C or YAR035W or YGR032W or YHR159W or YBR289W or YLL002W or YPL028W or YEL066W or YDR191W or YDR062W or YLR033W or YGR015C or YFL017C or YJL218W or YGR177C or YPR139C or YMR127C or YLR418C or YLR239C or YDR071C or YKR038C or YDR501W or YKR067W or YNR008W or YMR296C or YNR063W or YDR235W or YKR099W or YGR110W or YPL231W or YGR193C or YOR253W or YOR025W or YLR195C or YMR069W or YPR140W or YBR081C or YLR360W or YLR439W or YMR019W or YNL326C or YLR099C or YOL141W or YHR051W or YJL071W or YDR148C or YER024W or YBL052C or YLL031C or YJL206C or YDL073W or YMR062C or YCR034W or YOL068C or YML042W or YLR342W or YNL025C or YJR098C or YBR177C or YOR245C or YBR297W or YCR106W or YPL189W or YIL101C or YDL104C or YJL024C or YML002W or YCR048W or YHL003C or YJL196C or YDR303C or YER061C or YDR232W or YOL003C or YER184C or YPL001W or YPR018W or YCL016C or YDR391C or YOR244W or YGR252W or YPL095C or YDR126W or YOL084W or YMR125W or YDL042C or YKL182W or YJL176C or YPL134C or YKL008C or YHR013C or YNL084C or YAL044C or YOR034C or YDL052C or YNL277W or YGR084C or YPL015C or YPR193C or YCR072C or YOR172W or YDR459C or YGR246C or YBL011W or YOR377W
# {'2-acetamido-5-oxopentanoate': -1, 'L-glutamate': -1, 'L-glutamic 5-semialdehyde': 1, 'N-acetyl-L-glutamate': 1}
# 2-acetamido-5-oxopentanoate + L-glutamate => L-glutamic 5-semialdehyde + N-acetyl-L-glutamate
# rxn2155 YDR138W or YGL084C or YNL071W or YDR264C or YBR042C or YOL089C or YOR175C or YIL160C or YOR162C or YDL044C or YLR246W or YPL248C or YNR019W or YOR269W or YLR372W or YGL162W or YOR221C or YDR018C or YMR266W or YJL117W or YMR042W or YMR306W or YDR451C or YMR191W or YBL074C or YAR035W or YGR032W or YHR159W or YBR289W or YLL002W or YPL028W or YEL066W or YDR191W or YDR062W or YLR033W or YGR015C or YFL017C or YJL218W or YGR177C or YPR139C or YMR127C or YLR418C or YLR239C or YDR071C or YKR038C or YDR501W or YKR067W or YNR008W or YMR296C or YNR063W or YDR235W or YKR099W or YGR110W or YPL231W or YGR193C or YOR253W or YOR025W or YLR195C or YMR069W or YPR140W or YBR081C or YLR360W or YLR439W or YMR019W or YNL326C or YLR099C or YOL141W or YHR051W or YJL071W or YDR148C or YER024W or YBL052C or YLL031C or YJL206C or YDL073W or YMR062C or YCR034W or YOL068C or YML042W or YLR342W or YNL025C or YJR098C or YBR177C or YOR245C or YBR297W or YCR106W or YPL189W or YIL101C or YDL104C or YJL024C or YML002W or YCR048W or YHL003C or YJL196C or YDR303C or YER061C or YDR232W or YOL003C or YER184C or YPL001W or YPR018W or YCL016C or YDR391C or YOR244W or YGR252W or YPL095C or YDR126W or YOL084W or YMR125W or YDL042C or YKL182W or YJL176C or YPL134C or YKL008C or YHR013C or YNL084C or YAL044C or YOR034C or YDL052C or YNL277W or YGR084C or YPL015C or YPR193C or YCR072C or YOR172W or YDR459C or YGR246C or YBL011W or YOR377W
# {'L-gamma-glutamyl phosphate': 1, 'L-glutamate': -1, 'N-acetyl-L-gamma-glutamyl phosphate': -1, 'N-acetyl-L-glutamate': 1}
# L-glutamate + N-acetyl-L-gamma-glutamyl phosphate => L-gamma-glutamyl phosphate + N-acetyl-L-glutamate
# rxn2195 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'L-allysine': -1, 'L-glutamate': -1, 'L-lysine': 1}
# L-allysine + L-glutamate => 2-oxoglutarate + L-lysine
# rxn2196 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'L-glutamate': -1, 'N-acetylputrescine': 1, 'N4-Acetylaminobutanal': -1}
# L-glutamate + N4-Acetylaminobutanal => 2-oxoglutarate + N-acetylputrescine
# rxn2260 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'5,6,7,8-tetrahydrofolyl-L-glutamic acid': -1, 'ADP': 1, 'ATP': -1, 'H+': -2, 'L-glutamate': -1, 'phosphate': 1, 'tetrahydropteroyltri-L-glutamic acid': 1}
# 5,6,7,8-tetrahydrofolyl-L-glutamic acid + ATP + 2 H+ + L-glutamate => ADP + phosphate + tetrahydropteroyltri-L-glutamic acid
# rxn2357 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'L-glutamate': -1, 'L-glutamine': 1, '2-Oxoglutaramate': -1}
# L-glutamate + 2-Oxoglutaramate => 2-oxoglutarate + L-glutamine
# rxn2359 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'glutathione': 1, 'L-glutamate': -1, 'N-(4-oxoglutarate)-L-cysteinylglycine': -1}
# L-glutamate + N-(4-oxoglutarate)-L-cysteinylglycine => 2-oxoglutarate + glutathione
# rxn2366 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'AMP': 1, 'ATP': -1, 'diphosphate': 1, 'gamma-aminobutyrate': -1, 'H+': 1, 'L-glutamate': -1, '4-(glutamylamino) butanoate': 1}
# ATP + gamma-aminobutyrate + L-glutamate => AMP + diphosphate + H+ + 4-(glutamylamino) butanoate
# rxn2458 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'AMP': 3, 'ATP': -3, 'diphosphate': 3, 'glutathione': 1, 'H+': 3, 'H2O': -1, 'L-cysteine': -1, 'L-glutamate': -1, 'L-glycine': -1}
# 3 ATP + H2O + L-cysteine + L-glutamate + L-glycine => 3 AMP + 3 diphosphate + glutathione + 3 H+
# rxn2531 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W
# {'AMP': 1, 'ATP': -1, 'diphosphate': 1, 'H+': 1, 'L-alanine': -1, 'L-gamma-glutamyl-L-alanine': 1, 'L-glutamate': -1}
# ATP + L-alanine + L-glutamate => AMP + diphosphate + H+ + L-gamma-glutamyl-L-alanine
# rxn2545 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': 1, 'L-glutamate': -1, '(S)-Methylmalonate semialdehyde': -1, '3-aminoisobutyrate': 1}
# L-glutamate + (S)-Methylmalonate semialdehyde => 2-oxoglutarate + 3-aminoisobutyrate
# rxn2690 YHR113W or YBR286W or YKL103C or YKL165C or YLL029W or YBL091C or YLR244C or YKL157W or YER078C or YHR047C or YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C or YNL021W or YFL060C or YIL060W or YNL334C or YLR351C or YPR068C or YGL037C or YLR308W or YMR281W or YBR248C or YLR155C or YBR183W or YJL213W or YPL096W or YPL087W or YMR154C or YPL116W or YIL163C or YDR428C or YPR138C or YGL194C or YNL330C or YLR158C or YLR307W or YJL126W or YDR321W or YLR157C or YDR242W or YLR160C or YMR095C
# {'H+': -1, 'H2O': 1, 'L-alanine': -1, 'L-gamma-glutamyl-L-alanine': 1, 'L-glutamate': -1}
# H+ + L-alanine + L-glutamate => H2O + L-gamma-glutamyl-L-alanine
# rxn2885 YNL119W or YBR218C or YBL039C or YOL058W or YGL062W or YDL141W or YNL220W or YJR103W or YOR209C or YGR204W or YGL234W or YBR084W or YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W or YPR035W or YJL046W or YIR019C or YLR143W
# {'ADP': 1, 'ATP': -1, 'gamma-aminobutyrate': -1, 'H+': 1, 'L-glutamate': -1, 'phosphate': 1, '4-(glutamylamino) butanoate': 1}
# ATP + gamma-aminobutyrate + L-glutamate => ADP + H+ + phosphate + 4-(glutamylamino) butanoate
# rxn2951 YJL172W or YPL096C-A or YHL013C or YER151C or YBR058C or YHR058C or YDR069C or YOR124C or YOR138C or YMR223W or YJR099W or YDR326C or YJL095W or YMR160W or YGR229C or YKR098C or YER098W or YJL197W or YER111C or YFR010W or YFR019W or YER059W or YIL156W or YER144C or YMR304W or YIL153W or YLR126C or YNL186W or YFL044C or YPL191C or YBL067C or YJL005W or YDL216C or YFR005C or YDR420W or YKL010C or YCL014W or YLR299W or YDL122W or YPL072W or YBR281C or YFR044C or YHR113W or YBR286W or YKL103C or YKL165C or YLL029W or YBL091C or YLR244C or YKL157W or YER078C or YHR047C or YNL021W or YFL060C or YIL060W or YNL334C or YLR351C or YPR068C or YGL037C or YLR308W or YMR281W or YBR248C or YLR155C or YBR183W or YJL213W or YPL096W or YPL087W or YMR154C or YPL116W or YIL163C or YDR428C or YPR138C or YGL194C or YNL330C or YLR158C or YLR307W or YJL126W or YDR321W or YLR157C or YDR242W or YLR160C or YMR095C
# {'5,6,7,8-tetrahydrofolyl-L-glutamic acid': -1, 'H2O': 1, 'L-glutamate': -1, 'tetrahydropteroyltri-L-glutamic acid': 1}
# 5,6,7,8-tetrahydrofolyl-L-glutamic acid + L-glutamate => H2O + tetrahydropteroyltri-L-glutamic acid
# rxn2967 YNL021W or YFL060C or YIL060W or YNL334C or YLR351C or YPR068C or YGL037C or YLR308W or YMR281W or YBR248C or YLR155C or YBR183W or YJL213W or YPL096W or YPL087W or YMR154C or YPL116W or YIL163C or YDR428C or YPR138C or YGL194C or YNL330C or YLR158C or YLR307W or YJL126W or YDR321W or YLR157C or YDR242W or YLR160C or YMR095C or YHR113W or YBR286W or YKL103C or YKL165C or YLL029W or YBL091C or YLR244C or YKL157W or YER078C or YHR047C
# {'gamma-aminobutyrate': -1, 'H2O': 1, 'L-glutamate': -1, '4-(glutamylamino) butanoate': 1}
# gamma-aminobutyrate + L-glutamate => H2O + 4-(glutamylamino) butanoate
# rxn2977 YOR241W or YAR015W or YJL101C or YOL049W or YIL145C or YIL083C or YKL132C or YMR113W or YNL119W or YBR218C or YBL039C or YOL058W or YGL062W or YDL141W or YNL220W or YJR103W or YOR209C or YGR204W or YGL234W or YBR084W or YPR035W or YJL046W or YIR019C or YLR143W
# {'ADP': 1, 'ATP': -1, 'H+': 1, 'L-alanine': -1, 'L-gamma-glutamyl-L-alanine': 1, 'L-glutamate': -1, 'phosphate': 1}
# ATP + L-alanine + L-glutamate => ADP + H+ + L-gamma-glutamyl-L-alanine + phosphate
# rxn3029 YBR281C or YFR044C or YBR180W or YJR152W or YGR260W or YHR113W or YBR286W or YKL103C or YKL165C or YLL029W or YBL091C or YLR244C or YKL157W or YER078C or YHR047C or YNL021W or YFL060C or YIL060W or YNL334C or YLR351C or YPR068C or YGL037C or YLR308W or YMR281W or YBR248C or YLR155C or YBR183W or YJL213W or YPL096W or YPL087W or YMR154C or YPL116W or YIL163C or YDR428C or YPR138C or YGL194C or YNL330C or YLR158C or YLR307W or YJL126W or YDR321W or YLR157C or YDR242W or YLR160C or YMR095C or YJL172W or YPL096C-A
# {'H2O': 1, 'L-alanine': -1, 'L-gamma-glutamyl-L-alanine': 1, 'L-glutamate': -1}
# L-alanine + L-glutamate => H2O + L-gamma-glutamyl-L-alanine
# ==========
# L-glutamine
# ['r_0066', 'r_0079', 'r_0203', 'r_0211', 'r_0250', 'r_0306', 'r_0472', 'r_0475', 'r_0477', 'r_0478', 'r_0514', 'r_0563', 'r_0768', 'r_0915', 'r_1197', 'r_1199', 'r_1892', 'r_4211', 'r_4212', 'r_4615', 'rxn117', 'rxn120', 'rxn124', 'rxn136', 'rxn180', 'rxn260', 'rxn365', 'rxn446', 'rxn459', 'rxn732', 'rxn763', 'rxn764', 'rxn803', 'rxn804', 'rxn805', 'rxn937', 'rxn938', 'rxn943', 'rxn1098', 'rxn1255', 'rxn1262', 'rxn1263', 'rxn1264', 'rxn1265', 'rxn1476', 'rxn1481', 'rxn1493', 'rxn1494', 'rxn1498', 'rxn1864', 'rxn1875', 'rxn1895', 'rxn1908', 'rxn1921', 'rxn1933', 'rxn2029', 'rxn2138', 'rxn2143', 'rxn2152', 'rxn2237', 'rxn2238', 'rxn2239', 'rxn2240', 'rxn2284', 'rxn2453', 'rxn2454', 'rxn2543', 'rxn2556']
# ['rxn117', 'rxn120', 'rxn124', 'rxn136', 'rxn180', 'rxn260', 'rxn365', 'rxn446', 'rxn459', 'rxn732', 'rxn763', 'rxn764', 'rxn803', 'rxn804', 'rxn805', 'rxn937', 'rxn938', 'rxn943', 'rxn1098', 'rxn1255', 'rxn1262', 'rxn1263', 'rxn1264', 'rxn1265', 'rxn1476', 'rxn1481', 'rxn1493', 'rxn1494', 'rxn1498', 'rxn1864', 'rxn1875', 'rxn1895', 'rxn1908', 'rxn1921', 'rxn1933', 'rxn2029', 'rxn2138', 'rxn2143', 'rxn2152', 'rxn2237', 'rxn2238', 'rxn2239', 'rxn2240', 'rxn2284', 'rxn2453', 'rxn2454', 'rxn2543', 'rxn2556']
# rxn117 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'L-alanine': 1, 'L-glutamine': -1, 'pyruvate': -1, '2-Oxoglutaramate': 1}
# L-glutamine + pyruvate => L-alanine + 2-Oxoglutaramate
# rxn120 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'keto-phenylpyruvate': -1, 'L-glutamine': -1, 'L-phenylalanine': 1, '2-Oxoglutaramate': 1}
# keto-phenylpyruvate + L-glutamine => L-phenylalanine + 2-Oxoglutaramate
# rxn124 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'3-methyl-2-oxobutanoate': -1, 'L-glutamine': -1, 'L-valine': 1, '2-Oxoglutaramate': 1}
# 3-methyl-2-oxobutanoate + L-glutamine => L-valine + 2-Oxoglutaramate
# rxn136 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'(S)-3-methyl-2-oxopentanoate': -1, 'L-glutamine': -1, 'L-isoleucine': 1, '2-Oxoglutaramate': 1}
# (S)-3-methyl-2-oxopentanoate + L-glutamine => L-isoleucine + 2-Oxoglutaramate
# rxn180 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'L-glutamate': 1, 'L-glutamine': -1, 'D-Glucosamine': 1, 'd-fructose': -1}
# L-glutamine + d-fructose => L-glutamate + D-Glucosamine
# rxn260 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'H+': 2, 'L-aspartate': 1, 'L-glutamine': -1, 'oxaloacetate': -1, '2-Oxoglutaramate': 1}
# L-glutamine + oxaloacetate => 2 H+ + L-aspartate + 2-Oxoglutaramate
# rxn365 YDR138W or YGL084C or YNL071W or YDR264C or YBR042C or YOL089C or YOR175C or YIL160C or YOR162C or YDL044C or YLR246W or YPL248C or YNR019W or YOR269W or YLR372W or YGL162W or YOR221C or YDR018C or YMR266W or YJL117W or YMR042W or YMR306W or YDR451C or YMR191W or YBL074C or YAR035W or YGR032W or YHR159W or YBR289W or YLL002W or YPL028W or YEL066W or YDR191W or YDR062W or YLR033W or YGR015C or YFL017C or YJL218W or YGR177C or YPR139C or YMR127C or YLR418C or YLR239C or YDR071C or YKR038C or YDR501W or YKR067W or YNR008W or YMR296C or YNR063W or YDR235W or YKR099W or YGR110W or YPL231W or YGR193C or YOR253W or YOR025W or YLR195C or YMR069W or YPR140W or YBR081C or YLR360W or YLR439W or YMR019W or YNL326C or YLR099C or YOL141W or YHR051W or YJL071W or YDR148C or YER024W or YBL052C or YLL031C or YJL206C or YDL073W or YMR062C or YCR034W or YOL068C or YML042W or YLR342W or YNL025C or YJR098C or YBR177C or YOR245C or YBR297W or YCR106W or YPL189W or YIL101C or YDL104C or YJL024C or YML002W or YCR048W or YHL003C or YJL196C or YDR303C or YER061C or YDR232W or YOL003C or YER184C or YPL001W or YPR018W or YCL016C or YDR391C or YOR244W or YGR252W or YPL095C or YDR126W or YOL084W or YMR125W or YDL042C or YKL182W or YJL176C or YPL134C or YKL008C or YHR013C or YNL084C or YAL044C or YOR034C or YDL052C or YNL277W or YGR084C or YPL015C or YPR193C or YCR072C or YOR172W or YDR459C or YGR246C or YBL011W or YOR377W
# {'acetyl-CoA': -1, 'coenzyme A': 1, 'H+': 1, 'L-glutamine': -1, 'n-acetyl-glutamine': 1}
# acetyl-CoA + L-glutamine => coenzyme A + H+ + n-acetyl-glutamine
# rxn446 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'L-glutamine': -1, 'phenylacetaldehyde': -1, '2-Oxoglutaramate': 1, 'phenylethylamine': 1}
# L-glutamine + phenylacetaldehyde => 2-Oxoglutaramate + phenylethylamine
# rxn459 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'L-glutamine': -1, 'Imidazole-4-acetaldehyde': -1, '2-Oxoglutaramate': 1, 'histamine': 1}
# L-glutamine + Imidazole-4-acetaldehyde => 2-Oxoglutaramate + histamine
# rxn732 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'3-(4-hydroxyphenyl)pyruvate': -1, 'L-glutamine': -1, 'L-tyrosine': 1, '2-Oxoglutaramate': 1}
# 3-(4-hydroxyphenyl)pyruvate + L-glutamine => L-tyrosine + 2-Oxoglutaramate
# rxn763 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'gamma-aminobutyrate': 1, 'L-glutamine': -1, 'succinic semialdehyde': -1, '2-Oxoglutaramate': 1}
# L-glutamine + succinic semialdehyde => gamma-aminobutyrate + 2-Oxoglutaramate
# rxn764 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'ethanolamine': 1, 'glycolaldehyde': -1, 'L-glutamine': -1, '2-Oxoglutaramate': 1}
# glycolaldehyde + L-glutamine => ethanolamine + 2-Oxoglutaramate
# rxn803 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'4-methyl-2-oxopentanoate': -1, 'L-glutamine': -1, 'L-leucine': 1, '2-Oxoglutaramate': 1}
# 4-methyl-2-oxopentanoate + L-glutamine => L-leucine + 2-Oxoglutaramate
# rxn804 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxobutanoate': -1, 'L-glutamine': -1, '2-Oxoglutaramate': 1, '2-aminobutanoate': 1}
# 2-oxobutanoate + L-glutamine => 2-Oxoglutaramate + 2-aminobutanoate
# rxn805 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoadipic acid': -1, 'L-2-aminoadipate': 1, 'L-glutamine': -1, '2-Oxoglutaramate': 1}
# 2-oxoadipic acid + L-glutamine => L-2-aminoadipate + 2-Oxoglutaramate
# rxn937 YAL062W or YOR375C
# {'2-oxoadipic acid': -1, 'H+': -1, 'L-2-aminoadipate': 1, 'L-glutamate': 1, 'L-glutamine': -1, 'NAD': 1, 'NADH': -1}
# 2-oxoadipic acid + H+ + L-glutamine + NADH => L-2-aminoadipate + L-glutamate + NAD
# rxn938 YAL062W or YOR375C
# {'H+': -1, 'L-aspartate': 1, 'L-glutamate': 1, 'L-glutamine': -1, 'NAD': 1, 'NADH': -1, 'oxaloacetate': -1}
# H+ + L-glutamine + NADH + oxaloacetate => L-aspartate + L-glutamate + NAD
# rxn943 YAL062W or YOR375C
# {'4-hydroxy-2-oxoglutarate': -1, 'erythro-4-hydroxy-L-glutamic acid': 1, 'H+': -1, 'L-glutamate': 1, 'L-glutamine': -1, 'NAD': 1, 'NADH': -1}
# 4-hydroxy-2-oxoglutarate + H+ + L-glutamine + NADH => erythro-4-hydroxy-L-glutamic acid + L-glutamate + NAD
# rxn1098 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'indole-3-pyruvate': -1, 'L-glutamine': -1, 'L-tryptophan': 1, '2-Oxoglutaramate': 1}
# indole-3-pyruvate + L-glutamine => L-tryptophan + 2-Oxoglutaramate
# rxn1255 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-glutamate': 1, 'L-glutamine': -1, 'Gly-Gln': 1, 'Gly-Glu': -1}
# L-glutamine + Gly-Glu => L-glutamate + Gly-Gln
# rxn1262 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-glutamine': -1, 'L-glycine': 1, 'Ala-Gln': 1, 'Ala-Gly': -1}
# L-glutamine + Ala-Gly => L-glycine + Ala-Gln
# rxn1263 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-aspartate': 1, 'L-glutamine': -1, 'Ala-Gln': 1, 'Ala-Asp': -1}
# L-glutamine + Ala-Asp => L-aspartate + Ala-Gln
# rxn1264 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-glutamate': 1, 'L-glutamine': -1, 'Ala-Gln': 1, 'Ala-Glu': -1}
# L-glutamine + Ala-Glu => L-glutamate + Ala-Gln
# rxn1265 YNL167C or YDR177W or YOR161C or YPL007C or YDR073W or YBR082C or YFL009W or YMR269W or YJR090C or YGL058W or YMR153W or YPR125W or YLR078C or YOR269W or YOL054W or YGR159C or YOL013C or YBR280C or YJR097W or YDR059C or YKL084W or YHL010C or YDR485C or YEL012W or YOR358W or YJL095W or YLL036C or YDR313C or YLR394W or YML114C or YER068W or YFR018C or YOL027C or YBR290W or YER021W or YNL023C or YGL017W or YHL034C or YDR092W or YHR039C-A or YKR017C or YDR228C or YBR260C or YNL236W or YER125W or YBR062C or YML097C or YIL079C or YLR427W or YJR054W or YJR052W or YHR069C or YOR181W or YBR273C or YNL243W or YPR056W or YDR054C or YDR211W or YDR425W or YDL240W or YDR143C or YOR216C or YAL002W or YJR134C or YPL120W or YOL133W or YER143W or YEL019C or YDR388W or YDR460W or YMR026C or YOL044W or YDR323C or YLR007W or YDL013W or YPR030W or YML002W or YMR022W or YDR266C or YNL227C or YNL097C or YER016W or YGR009C or YKL057C or YMR276W or YJR055W or YMR147W or YKR007W or YGL164C or YEL022W or YCR033W or YKR078W or YDL074C or YOL051W or YGR184C or YIR018W or YNL260C or YIL062C or YER116C or YBR128C or YKL059C or YML068W or YBR275C or YOR156C or YCR066W or YOR339C or YDL195W or YLR299W or YNL159C or YPR093C or YCR084C
# {'L-glutamine': -1, 'L-leucine': 1, 'Ala-Gln': 1, 'Ala-Leu': -1}
# L-glutamine + Ala-Leu => L-leucine + Ala-Gln
# ...
# {'4-aminobutanal': 1, '4-hydroxy-2-oxoglutarate': -1, 'erythro-4-hydroxy-L-glutamic acid': 1, 'H+': -1, 'putrescine': -1}
# 4-hydroxy-2-oxoglutarate + H+ + putrescine => 4-aminobutanal + erythro-4-hydroxy-L-glutamic acid
# rxn1585 YER004W or YKR080W or YIR034C or YER023W or YGL125W or YOR236W or YNR050C or YPL023C or YLR011W
# {'3-aminopropanal': -1, 'H+': -1, 'H2O': 1, 'NAD': 1, 'NADH': -1, 'putrescine': -1, 'spermidine': 1}
# 3-aminopropanal + H+ + NADH + putrescine => H2O + NAD + spermidine
# rxn1588 YER004W or YKR080W or YIR034C or YER023W or YGL125W or YOR236W or YNR050C or YPL023C or YLR011W
# {'H+': -1, 'H2O': 1, 'N(1)-acetylspermidine': 1, 'NAD': 1, 'NADH': -1, 'putrescine': -1, 'acetamidopropanal': -1}
# H+ + NADH + putrescine + acetamidopropanal => H2O + N(1)-acetylspermidine + NAD
# rxn1941 YHR208W or YLR438W or YIL087C or YER152C or YDR111C or YJR148W or YNR033W or YIL116W or YGR243W or YHR137W or YMR084W or YNR058W or YMR085W or YKL104C or YER137C or YHR162W or YOL140W or YGL202W or YKL106W or YFL030W or YLR089C or YLR201C or YLR027C or YJL060W or YOR184W or YGR019W or YLR333C or YDR204W
# {'2-oxoglutarate': -1, 'gamma-aminobutyrate': 1, 'L-glutamic 5-semialdehyde': 1, 'putrescine': -1}
# 2-oxoglutarate + putrescine => gamma-aminobutyrate + L-glutamic 5-semialdehyde
# rxn2122 YBR035C or YFR033C or YMR020W
# {'4-aminobutanal': 1, 'ammonium': 1, 'H2O': -1, 'hydrogen peroxide': 1, 'oxygen': -1, 'putrescine': -1}
# H2O + oxygen + putrescine => 4-aminobutanal + ammonium + hydrogen peroxide
# ==========
# Spermine
# ['r_0937', 'r_1262', 'r_1263', 'r_1739', 'rxn2611']
# ['rxn2611']
# rxn2611 YLL060C or YDL205C or YDR538W or YMR251W or YMR310C or YLR180W or YKL191W or YKR076W or YBR003W or YJR130C or YHR190W or YOR274W or YPR176C or YGR012W or YKL019W or YBR249C or YOR051C or YIR038C or YLR303W or YPL069C or YGR201C or YGR154C or YNL256W or YHR116W or YGL155W or YPL059W or YBR256C or YLL058W or YDL090C or YMR280C or YDR035W or YHR096C or YPR069C or YDR513W or YJL031C or YJL167W or YNL297C or YCL035C or YNR041C or YBR002C or YML082W or YML005W or YMR101C or YIL103W or YLR146C or YDR502C or YHR068W or YOL143C or YDL193W or YPL172C or YGR001C or YML007W or YNL229C
# {'ammonium': -1, 'spermidine': 1, 'spermine': -1, 'trimethylenediamine': 1}
# ammonium + spermine => spermidine + trimethylenediamine
# ==========
# Guanine
# ['r_0526', 'r_0527', 'r_0949', 'r_1176', 'r_1819', 'r_4758', 'rxn313', 'rxn2014', 'rxn2288', 'rxn2289', 'rxn2290', 'rxn2291', 'rxn2292', 'rxn2307', 'rxn2308', 'rxn2309', 'rxn2310', 'rxn2311', 'rxn2312', 'rxn2313', 'rxn2316', 'rxn2317', 'rxn2318', 'rxn2565']
# ['rxn313', 'rxn2014', 'rxn2288', 'rxn2289', 'rxn2290', 'rxn2291', 'rxn2292', 'rxn2307', 'rxn2308', 'rxn2309', 'rxn2310', 'rxn2311', 'rxn2312', 'rxn2313', 'rxn2316', 'rxn2317', 'rxn2318', 'rxn2565']
# rxn313 YDR497C or YBR236C or YCR024C-A or YKL162C or YBR034C or YDL212W or YBR213W or YBR119W or YPL216W or YEL017C-A or YHL036W or YGR002C or YLR285W or YLR172C or YDR435C or YLL062C or YGR027C or YKR069W or YMR160W or YJL125C or YOL103W or YNL092W or YER060W-A or YJL168C or YML110C or YHR034C or YDL201W or YHR209W or YNL063W or YPL092W or YIL064W or YPR186C or YDR105C or YKL088W or YJR073C or YHR109W or YOL141W or YDR410C or YGL050W or YGR006W or YER091C or YKR029C or YPL030W or YER175C or YPR187W or YOL093W or YBR061C or YDR140W or YJR044C or YGR157W or YMR257C or YJR137C or YDR120C or YBL024W or YOL020W or YDR198C or YBR115C or YPL273W or YHR119W or YOR074C or YLR137W or YOL096C or YER056C or YLR333C or YER060W or YDR440W or YGL136C or YOL124C or YBR241C or YPL266W or YOL125W or YGL186C or YHR070W or YDL200C or YJL056C or YML008C
# {'guanine': -1, 'H+': 1, 'S-adenosyl-L-homocysteine': 1, 'S-adenosyl-L-methionine': -1, '7-methylguanine': 1}
# guanine + S-adenosyl-L-methionine => H+ + S-adenosyl-L-homocysteine + 7-methylguanine
# rxn2014 YKR044W or YKL219W or YHL017W or YJL039C or YMR065W or YPR071W or YHL030W or YBR302C or YPL271W or YLR305C or YPR079W or YJL159W or YJR118C or YML060W or YMR247C or YIL017C or YOL043C or YMR029C or YKL058W or YPR036W or YJL207C or YBL004W or YDR400W or YBR140C or YML132W or YKL142W or YJL055W or YGL002W or YOR249C or YNL212W or YDL215C or YOL081W or YML103C or YKL014C or YER187W or YML021C or YER142C
# {"2'-deoxyguanosine": 1, '2-deoxy-D-ribose': -1, 'guanine': -1, 'H2O': 1}
# 2-deoxy-D-ribose + guanine => 2'-deoxyguanosine + H2O
# rxn2288 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {"2'-deoxyguanosine": 1, 'cytosine': 1, 'deoxycytidine': -1, 'guanine': -1}
# deoxycytidine + guanine => 2'-deoxyguanosine + cytosine
# rxn2289 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {"2'-deoxyguanosine": 1, "2'-deoxyuridine": -1, 'guanine': -1, 'uracil': 1}
# 2'-deoxyuridine + guanine => 2'-deoxyguanosine + uracil
# rxn2290 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'cytidine': -1, 'cytosine': 1, 'guanine': -1, 'guanosine': 1}
# cytidine + guanine => cytosine + guanosine
# rxn2291 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'guanine': -1, 'guanosine': 1, 'uracil': 1, 'uridine': -1}
# guanine + uridine => guanosine + uracil
# rxn2292 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'adenine': 1, 'adenosine': -1, 'guanine': -1, 'guanosine': 1}
# adenosine + guanine => adenine + guanosine
# rxn2307 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'cytosine': 1, 'guanine': -1, "guanosine 2'-monophosphate": 1, "cytidine 2'-phosphate": -1}
# guanine + cytidine 2'-phosphate => cytosine + guanosine 2'-monophosphate
# rxn2308 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'guanine': -1, 'uracil': 1, "guanosine 2'-monophosphate": 1, "uridine 2'-phosphate": -1}
# guanine + uridine 2'-phosphate => uracil + guanosine 2'-monophosphate
# rxn2309 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'adenine': 1, "adenosine 2'-phosphate": -1, 'guanine': -1, "guanosine 2'-monophosphate": 1}
# adenosine 2'-phosphate + guanine => adenine + guanosine 2'-monophosphate
# rxn2310 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'guanine': -1, 'uracil': 1, "3'-GMP": 1, "3'-UMP": -1}
# guanine + 3'-UMP => uracil + 3'-GMP
# rxn2311 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'adenine': 1, 'guanine': -1, "3'-GMP": 1, "3'-AMP": -1}
# guanine + 3'-AMP => adenine + 3'-GMP
# rxn2312 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {"3',5'-cyclic CMP": -1, "3',5'-cyclic GMP": 1, 'cytosine': 1, 'guanine': -1}
# 3',5'-cyclic CMP + guanine => 3',5'-cyclic GMP + cytosine
# rxn2313 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {"3',5'-cyclic AMP": -1, "3',5'-cyclic GMP": 1, 'adenine': 1, 'guanine': -1}
# 3',5'-cyclic AMP + guanine => 3',5'-cyclic GMP + adenine
# rxn2316 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'cytosine': 1, 'guanine': -1, "2',3'-cyclic GMP": 1, "2',3'-cyclic CMP": -1}
# guanine + 2',3'-cyclic CMP => cytosine + 2',3'-cyclic GMP
# rxn2317 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {'guanine': -1, 'uracil': 1, "2',3'-cyclic GMP": 1, "2',3'-cyclic UMP": -1}
# guanine + 2',3'-cyclic UMP => uracil + 2',3'-cyclic GMP
# rxn2318 YBL037W or YML022W or YPR144C or YJL039C or YDL171C or YMR271C or YGR144W or YGL195W or YFR047C or YNL191W or YLR209C or YDR441C or YMR247C or YML106W or YDR399W or YLR017W or YJR133W or YDR354W or YBL004W or YMR300C or YHR128W or YER055C or YKL014C
# {"2',3'-cyclic AMP": -1, 'adenine': 1, 'guanine': -1, "2',3'-cyclic GMP": 1}
# 2',3'-cyclic AMP + guanine => adenine + 2',3'-cyclic GMP
# rxn2565 YKR044W or YKL219W or YHL017W or YJL039C or YMR065W or YPR071W or YHL030W or YBR302C or YPL271W or YLR305C or YPR079W or YJL159W or YJR118C or YML060W or YMR247C or YIL017C or YOL043C or YMR029C or YKL058W or YPR036W or YJL207C or YBL004W or YDR400W or YBR140C or YML132W or YKL142W or YJL055W or YGL002W or YOR249C or YNL212W or YDL215C or YOL081W or YML103C or YKL014C or YER187W or YML021C or YER142C or YFL060C or YNL334C or YMR096W or YFL059W or YNL333W or YMR095C
# {'guanine': -1, 'guanosine': 1, 'H2O': 1, 'd-ribose': -1}
# guanine + d-ribose => guanosine + H2O
# ==========
# Thymidine
# ['r_2074', 'r_2075', 'rxn327', 'rxn2430', 'rxn2431', 'rxn2598', 'rxn2599']
# ['rxn327', 'rxn2430', 'rxn2431', 'rxn2598', 'rxn2599']
# rxn327 YDR497C or YBR236C or YCR024C-A or YKL162C or YBR034C or YDL212W or YBR213W or YBR119W or YPL216W or YEL017C-A or YHL036W or YGR002C or YLR285W or YLR172C or YDR435C or YLL062C or YGR027C or YKR069W or YMR160W or YJL125C or YOL103W or YNL092W or YER060W-A or YJL168C or YML110C or YHR034C or YDL201W or YHR209W or YNL063W or YPL092W or YIL064W or YPR186C or YDR105C or YKL088W or YJR073C or YHR109W or YOL141W or YDR410C or YGL050W or YGR006W or YER091C or YKR029C or YPL030W or YER175C or YPR187W or YOL093W or YBR061C or YDR140W or YJR044C or YGR157W or YMR257C or YJR137C or YDR120C or YBL024W or YOL020W or YDR198C or YBR115C or YPL273W or YHR119W or YOR074C or YLR137W or YOL096C or YER056C or YLR333C or YER060W or YDR440W or YGL136C or YOL124C or YBR241C or YPL266W or YOL125W or YGL186C or YHR070W or YDL200C or YJL056C or YML008C
# {"2'-deoxyuridine": 1, '5,10-methylenetetrahydrofolate': 1, 'dihydrofolic acid': -1, 'thymidine': -1}
# dihydrofolic acid + thymidine => 2'-deoxyuridine + 5,10-methylenetetrahydrofolate
# rxn2430 YDR051C or YFR053C or YOL136C or YGR205W or YJR049C or YGR194C or YFL053W or YGL253W or YJL155C or YLR240W or YDR248C or YNL267W or YDR236C or YOR119C or YMR208W or YHL032C or YDR017C or YOR311C or YIL107C or YPL258C or YOR347C or YKL001C or YKL110C or YLR260W or YDR529C or YNL275W or YOL055C or YCL040W or YDR147W or YCR036W or YHR025W or YDR020C or YNR012W or YNL249C or YGR240C or YMR013C or YBR020W or YJL100W or YDR009W or YJR105W or YMR278W or YJL091C or YPL188W or YLR345W or YLL043W or YML070W or YDR072C or YEL029C or YLR133W or YDR531W or YDR315C or YPR121W or YDR109C or YGR262C or YMR205C or YLR446W or YAL038W or YPR184W or YPL214C or YOR171C or YHR155W or YNL129W or YEL041W or YKL004W or YDR516C or YDR196C or YNR027W or YGR121C or YOL102C or YDR173C or YDR208W
# {'(R)-5-diphosphomevalonic acid': -1, '(R)-5-phosphomevalonic acid': 1, 'H+': 1, 'thymidine': -1, "thymidine 3'-monophosphate": 1}
# (R)-5-diphosphomevalonic acid + thymidine => (R)-5-phosphomevalonic acid + H+ + thymidine 3'-monophosphate
# rxn2431 YDR051C or YFR053C or YOL136C or YGR205W or YJR049C or YGR194C or YFL053W or YGL253W or YJL155C or YLR240W or YDR248C or YNL267W or YDR236C or YOR119C or YMR208W or YHL032C or YDR017C or YOR311C or YIL107C or YPL258C or YOR347C or YKL001C or YKL110C or YLR260W or YDR529C or YNL275W or YOL055C or YCL040W or YDR147W or YCR036W or YHR025W or YDR020C or YNR012W or YNL249C or YGR240C or YMR013C or YBR020W or YJL100W or YDR009W or YJR105W or YMR278W or YJL091C or YPL188W or YLR345W or YLL043W or YML070W or YDR072C or YEL029C or YLR133W or YDR531W or YDR315C or YPR121W or YDR109C or YGR262C or YMR205C or YLR446W or YAL038W or YPR184W or YPL214C or YOR171C or YHR155W or YNL129W or YEL041W or YKL004W or YDR516C or YDR196C or YNR027W or YGR121C or YOL102C or YDR173C or YDR208W
# {'H+': 1, 'thymidine': -1, 'phosphatidate (1-16:1, 2-18:1)': 1, '1,2-diacylglycerol 3-diphosphate (1-16:0, 2-18:1)': -1, "thymidine 3'-monophosphate": 1}
# thymidine + 1,2-diacylglycerol 3-diphosphate (1-16:0, 2-18:1) => H+ + phosphatidate (1-16:1, 2-18:1) + thymidine 3'-monophosphate
# rxn2598 YDR051C or YFR053C or YOL136C or YGR205W or YJR049C or YGR194C or YFL053W or YGL253W or YJL155C or YLR240W or YDR248C or YNL267W or YDR236C or YOR119C or YMR208W or YHL032C or YDR017C or YOR311C or YIL107C or YPL258C or YOR347C or YKL001C or YKL110C or YLR260W or YDR529C or YNL275W or YOL055C or YCL040W or YDR147W or YCR036W or YHR025W or YDR020C or YNR012W or YNL249C or YGR240C or YMR013C or YBR020W or YJL100W or YDR009W or YJR105W or YMR278W or YJL091C or YPL188W or YLR345W or YLL043W or YML070W or YDR072C or YEL029C or YLR133W or YDR531W or YDR315C or YPR121W or YDR109C or YGR262C or YMR205C or YLR446W or YAL038W or YPR184W or YPL214C or YOR171C or YHR155W or YNL129W or YEL041W or YKL004W or YDR516C or YDR196C or YNR027W or YGR121C or YOL102C or YDR173C or YDR208W
# {'dADP': 1, 'dATP': -1, 'H+': 1, 'thymidine': -1, "thymidine 3'-monophosphate": 1}
# dATP + thymidine => dADP + H+ + thymidine 3'-monophosphate
# rxn2599 YDR051C or YFR053C or YOL136C or YGR205W or YJR049C or YGR194C or YFL053W or YGL253W or YJL155C or YLR240W or YDR248C or YNL267W or YDR236C or YOR119C or YMR208W or YHL032C or YDR017C or YOR311C or YIL107C or YPL258C or YOR347C or YKL001C or YKL110C or YLR260W or YDR529C or YNL275W or YOL055C or YCL040W or YDR147W or YCR036W or YHR025W or YDR020C or YNR012W or YNL249C or YGR240C or YMR013C or YBR020W or YJL100W or YDR009W or YJR105W or YMR278W or YJL091C or YPL188W or YLR345W or YLL043W or YML070W or YDR072C or YEL029C or YLR133W or YDR531W or YDR315C or YPR121W or YDR109C or YGR262C or YMR205C or YLR446W or YAL038W or YPR184W or YPL214C or YOR171C or YHR155W or YNL129W or YEL041W or YKL004W or YDR516C or YDR196C or YNR027W or YGR121C or YOL102C or YDR173C or YDR208W
# {'dADP': -1, 'dAMP': 1, 'H+': 1, 'thymidine': -1, "thymidine 3'-monophosphate": 1}
# dADP + thymidine => dAMP + H+ + thymidine 3'-monophosphate
# ==========

# %%
# Set common parameters
plt.figure(figsize=(8, 1.5), dpi=400)
plt.rcParams.update({'font.size': 8})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Set axis style
ax = plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0.5)
ax.spines['left'].set_linewidth(0.5)
ax.spines['right'].set_linewidth(0)

# Draw stacked bar chart, keeping x and y axes as they are now swapped
bar_width = 0.6
index = np.arange(len(target_100met_df['Name']))

# Define colors and sections
colors = ['#cab2d6', '#fdbf6f', '#e31a1c', '#fb9a99', '#b2df8a', '#1f78b4', '#a6cee3']
sections = [(0, 24), (24, 33), (33, 38), (38, 41), (41, 44), (44, 46), (46, 48)]
labels = ['Amino acid', 'Organic acid', 'Alcohol', 'Alkaloid', 'Other', 'Bioamine', 'Nucleic acid']

for i, (start, end) in enumerate(sections):
    plt.bar(index[start:end], target_100met_df['yeast8U_reaction_num'][start:end], width=bar_width, color='white', edgecolor=colors[i], linewidth=0.5)
    plt.bar(index[start:end], target_100met_df['yeast8_reaction_num'][start:end], width=bar_width, label=labels[i], color=colors[i])

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', which='both', width=0.5, length=1, pad=1)
plt.xlim(-0.5, 47.5)
plt.ylim(0, 100)
plt.xticks(index, target_100met_df['Name'], fontsize=8, rotation=90)
plt.yticks(np.arange(0, 101, 20), fontsize=8)
plt.ylabel('Counts of reaction', fontsize=8)

# Set legend
custom_patch1 = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=0.5, label='Yeast-MetaTwin')
custom_patch2 = mpatches.Patch(facecolor='black', edgecolor='black', linewidth=0.5, label='Yeast8')

# Get current legend handles and labels
handles, labels = ax.get_legend_handles_labels()

# Insert custom legend entries
handles.insert(1, custom_patch2)
handles.insert(3, custom_patch1)

# Create legend
plt.legend(handles=handles, frameon=False, fontsize=8, loc='upper right', bbox_to_anchor=(1, 1.1), labelspacing=0.5, handletextpad=0.3, handlelength=1, ncol=7, columnspacing=0.7)

plt.show()

# %%
break
# Out:
#   File "/tmp/ipykernel_2371841/668683560.py", line 4
# SyntaxError: 'break' outside loop

# %%
# Set common parameters
plt.figure(figsize=(8, 1.5), dpi=400)
plt.rcParams.update({'font.size': 8})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Set axis style
ax = plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0.5)
ax.spines['left'].set_linewidth(0.5)
ax.spines['right'].set_linewidth(0)

# Draw stacked bar chart, keeping x and y axes as they are now swapped
bar_width = 0.6
index = np.arange(len(target_100met_df['Name']))

# Define colors and sections
colors = ['#cab2d6', '#fdbf6f', '#e31a1c', '#fb9a99', '#b2df8a', '#1f78b4', '#a6cee3']
sections = [(0, 24), (24, 33), (33, 38), (38, 41), (41, 44), (44, 46), (46, 48)]
labels = ['Amino acid', 'Organic acid', 'Alcohol', 'Alkaloid', 'Other', 'Bioamine', 'Nucleic acid']

for i, (start, end) in enumerate(sections):
    plt.bar(index[start:end], target_100met_df['yeast8U_reaction_num'][start:end], width=bar_width, color='white', edgecolor=colors[i], linewidth=0.5)
    plt.bar(index[start:end], target_100met_df['yeast8_reaction_num'][start:end], width=bar_width, label=labels[i], color=colors[i])

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', which='both', width=0.5, length=1, pad=1)
plt.xlim(-0.5, 47.5)
plt.ylim(0, 100)
plt.xticks(index, target_100met_df['Name'], fontsize=8, rotation=90)
plt.yticks(np.arange(0, 101, 20), fontsize=8)
plt.ylabel('Counts of reaction', fontsize=8)

# Set legend
custom_patch1 = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=0.5, label='Yeast-MetaTwin')
custom_patch2 = mpatches.Patch(facecolor='black', edgecolor='black', linewidth=0.5, label='Yeast8')

# Get current legend handles and labels
handles, labels = ax.get_legend_handles_labels()

# Insert custom legend entries
handles.insert(1, custom_patch2)
handles.insert(3, custom_patch1)

# Create legend
plt.legend(handles=handles, frameon=False, fontsize=8, loc='upper right', bbox_to_anchor=(1, 1.1), labelspacing=0.5, handletextpad=0.3, handlelength=1, ncol=7, columnspacing=0.7)

plt.show()
