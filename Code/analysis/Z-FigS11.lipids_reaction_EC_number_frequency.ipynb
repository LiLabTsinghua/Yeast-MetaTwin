# %%
import pandas as pd
import numpy as np
import json
import pandas as pd
import re
from rdkit import Chem
from rdkit.Chem import AllChem
from collections import Counter,defaultdict
from ast import literal_eval
import cobra
from cobra import Metabolite,Reaction,Gene
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import sys
sys.path.append('../retrosynthesis/')

import sys
from common import *
# from check_newinfo_getyeast8U import *

# %%
### input
yeast870_path =  '../../Data/model/yeast-GEM.yml'
yeast8U_path = '../../Data/model/yeast8U_lipid.yml'
sce_gene_clean_ec = '../../Data/Saccharomyces_cerevisiae_teacher_maxsep.csv'
DeepEC_path = '../../Data/Sce_DeepECv2.txt'

### output
figs11_path = '../../Results/Figures/figS11.pdf'

# %%
yeast8 = cobra.io.load_yaml_model(yeast870_path)
yeast8.summary()

yeast8U = cobra.io.load_yaml_model(yeast8U_path)
# yeast8U.summary()

# %% [markdown]
# ## gene frequency

# %% [markdown]
# # lipids only look at the reaction of lipids

# %%
yeast8U_gene_frequece_dict = {}
gene_lst = []
for rea in yeast8U.reactions:
    if 'rxnl' in rea.id:    #####################################################################################################################
        tmp = str(rea.gpr).replace(')','').replace('(','').replace(' and ',' ').replace(' or ',' ').split(' ')
        gene_lst += tmp
gene_lst = [x for x in gene_lst if x!='']
print(len(set(gene_lst)))
yeast8U_gene_frequece_dict = list_to_frequency_dict(gene_lst)
yeast8U_gene_frequece_dict

yeast8_gene_frequece_dict = {}
gene_lst = []
for rea in yeast8.reactions:
    tmp = str(rea.gpr).replace(')','').replace('(','').replace(' and ',' ').replace(' or ',' ').split(' ')
    gene_lst += tmp
gene_lst = [x for x in gene_lst if x!='']
print(len(set(gene_lst)))
yeast8_gene_frequece_dict = list_to_frequency_dict(gene_lst)
yeast8_gene_frequece_dict
# Out:
# 2382
# 1163
# {'YDL174C': 2,
#  'YEL039C': 8,
#  'YJR048W': 8,
#  'YEL071W': 3,
#  'YDL178W': 3,
#  'YAL060W': 2,
#  'YML054C': 2,
#  'YPR165W': 3,
#  'YLR342W': 1,
#  'YGR032W': 1,
#  'YMR306W': 1,
#  'YGR143W': 1,
#  'YPR159W': 1,
#  'YIL020C': 1,
#  'YHR037W': 3,
#  'YEL038W': 1,
#  'YMR009W': 1,
#  'YOL066C': 1,
#  'YBR153W': 1,
#  'YCL009C': 2,
#  'YMR108W': 4,
#  'YNL256W': 4,
#  'YER152C': 1,
#  'YGL202W': 5,
#  'YJL060W': 4,
#  'YHR063C': 1,
#  'YDR035W': 2,
#  'YBR249C': 2,
#  'YDR204W': 5,
#  'YGR255C': 5,
#  'YLR201C': 5,
#  'YML110C': 5,
#  'YOL096C': 5,
#  'YOR125C': 5,
#  'YGL009C': 2,
#  'YNL104C': 2,
#  'YOR108W': 1,
#  'YHR208W': 4,
#  'YJR148W': 4,
#  'YHR137W': 5,
#  'YDR234W': 2,
#  'YPR001W': 2,
#  'YOL064C': 1,
#  'YGL248W': 1,
#  'YOR360C': 5,
#  'YDR487C': 1,
#  'YDR127W': 5,
#  'YBR265W': 1,
#  'YPL252C': 2,
#  'YDR376W': 2,
#  'YDR538W': 2,
#  'YDR539W': 1,
#  'YLR231C': 2,
#  'YKR009C': 36,
#  'YJR025C': 1,
#  'YER175C': 2,
#  'YCL018W': 1,
#  'YGR087C': 8,
#  'YLR044C': 8,
#  'YLR134W': 8,
#  'YBR176W': 1,
#  'YDL080C': 2,
#  'YNR033W': 1,
#  'YMR289W': 1,
#  'YGR019W': 1,
#  'YCR053W': 2,
#  'YLR410W': 4,
#  'YOR163W': 4,
#  'YDR017C': 4,
#  'YLR017W': 1,
#  'YER037W': 7,
#  'YGL224C': 2,
#  'YOR155C': 1,
#  'YGR061C': 1,
#  'YGL125W': 1,
#  'YPL023C': 1,
#  'YDR232W': 1,
#  'YER183C': 3,
#  'YER091C': 2,
#  'YJR024C': 1,
#  'YPR118W': 1,
#  'YIL107C': 1,
#  'YOL136C': 1,
#  'YGR248W': 1,
#  'YHR163W': 1,
#  'YLR355C': 2,
#  'YKL192C': 5,
#  'YIL160C': 18,
#  'YPL028W': 2,
#  'YMR207C': 1,
#  'YDL141W': 2,
#  'YNR016C': 1,
#  'YBL015W': 2,
#  'YAL054C': 2,
#  'YLR153C': 2,
#  'YER069W': 2,
#  'YBR093C': 1,
#  'YAR071W': 1,
#  'YBR092C': 3,
#  'YHR215W': 1,
#  'YPR002W': 1,
#  'YOL140W': 1,
#  'YPL148C': 1,
#  'YGL205W': 18,
#  'YCR048W': 42,
#  'YNR019W': 34,
#  'YJL091C': 1,
#  'YNL141W': 3,
#  'YDR441C': 1,
#  'YML022W': 1,
#  'YJR105W': 1,
#  'YML035C': 1,
#  'YER043C': 1,
#  'YOL052C': 1,
#  'YNR058W': 1,
#  'YJL005W': 2,
#  'YDL166C': 2,
#  'YDR226W': 1,
#  'YER170W': 2,
#  'YLR359W': 2,
#  'YNL220W': 1,
#  'YKL001C': 1,
#  'YGR247W': 4,
#  'YFL030W': 1,
#  'YOR335C': 1,
#  'YGR177C': 9,
#  'YOR377W': 9,
#  'YMR303C': 1,
#  'YDR368W': 5,
#  'YHR104W': 4,
#  'YGL256W': 9,
#  'YMR083W': 9,
#  'YBR145W': 9,
#  'YDL168W': 9,
#  'YOL086C': 9,
#  'YCR105W': 7,
#  'YMR318C': 7,
#  'YMR110C': 19,
#  'YMR169C': 3,
#  'YMR170C': 4,
#  'YPL061W': 4,
#  'YOR374W': 9,
#  'YER073W': 3,
#  'YDR481C': 2,
#  'YIR029W': 1,
#  'YIR027C': 1,
#  'YBR208C': 2,
#  'YBR199W': 1,
#  'YBR205W': 1,
#  'YDR483W': 1,
#  'YJL139C': 1,
#  'YKR061W': 1,
#  'YNL029C': 1,
#  'YOR099W': 1,
#  'YPL053C': 1,
#  'YPR026W': 1,
#  'YBR001C': 1,
#  'YDR001C': 1,
#  'YBR126C': 4,
#  'YDR074W': 4,
#  'YML100W': 2,
#  'YMR261C': 2,
#  'YBR299W': 3,
#  'YGR287C': 1,
#  'YGR292W': 3,
#  'YIL172C': 1,
#  'YJL216C': 1,
#  'YJL221C': 1,
#  'YDR242W': 5,
#  'YMR293C': 1,
#  'YDR354W': 1,
#  'YER090W': 1,
#  'YKL211C': 2,
#  'YDR305C': 2,
#  'YPL111W': 1,
#  'YHR018C': 1,
#  'YOL058W': 1,
#  'YDR341C': 1,
#  'YHR091C': 1,
#  'YGR124W': 1,
#  'YPR145W': 1,
#  'YHR019C': 1,
#  'YCR024C': 1,
#  'YJL130C': 2,
#  'YER052C': 1,
#  'YLR027C': 5,
#  'YKL106W': 2,
#  'YDR158W': 1,
#  'YLL018C': 1,
#  'YPL104W': 1,
#  'YDR530C': 1,
#  'YCL050C': 3,
#  'YER055C': 1,
#  'Q0080': 1,
#  'Q0085': 1,
#  'Q0130': 1,
#  'YBL099W': 1,
#  'YBR039W': 1,
#  'YDL004W': 1,
#  'YDR298C': 1,
#  'YDR377W': 1,
#  'YJR121W': 1,
#  'YKL016C': 1,
#  'YLR295C': 1,
#  'YML081C-A': 1,
#  'YPL078C': 1,
#  'YPL271W': 1,
#  'YDR322C-A': 1,
#  'YPR020W': 1,
#  'YOL077W-A': 1,
#  'YCR024C-A': 2,
#  'YEL017C-A': 2,
#  'YGL008C': 1,
#  'YPL036W': 1,
#  'YER005W': 10,
#  'YBR110W': 1,
#  'YGR286C': 1,
#  'YNL280C': 1,
#  'YMR015C': 1,
#  'YGL001C': 2,
#  'YLR100W': 2,
#  'YGR060W': 4,
#  'YLR056W': 1,
#  'YMR202W': 1,
#  'YGL012W': 1,
#  'YDL090C': 1,
#  'YKL019W': 1,
#  'YJR109C': 1,
#  'YOR303W': 1,
#  'YAR035W': 1,
#  'YER024W': 1,
#  'YML042W': 2,
#  'YGR088W': 1,
#  'YDR256C': 1,
#  'YDR297W': 3,
#  'YMR272C': 6,
#  'YKL008C': 4,
#  'YHL003C': 4,
#  'YMR298W': 4,
#  'YLR307W': 1,
#  'YLR308W': 1,
#  'YBR023C': 1,
#  'YBR038W': 1,
#  'YNL192W': 1,
#  'YLR133W': 2,
#  'YGR202C': 1,
#  'YPR060C': 1,
#  'YGL148W': 1,
#  'YLR304C': 4,
#  'YBR002C': 19,
#  'YMR101C': 19,
#  'YNR001C': 1,
#  'YCR005C': 1,
#  'YDR044W': 1,
#  'YBL039C': 2,
#  'YJR103W': 2,
#  'YFR055W': 2,
#  'YGL184C': 1,
#  'YGR155W': 1,
#  'YAL012W': 2,
#  'YJR130C': 2,
#  'YLR303W': 3,
#  'YNL247W': 1,
#  'YLR245C': 2,
#  'YNR012W': 4,
#  'YHR007C': 1,
#  'YHR042W': 1,
#  'YPR062W': 2,
#  'YML086C': 1,
#  'YMR041C': 1,
#  'YBR149W': 1,
#  'YKL060C': 3,
#  'YDL246C': 2,
#  'YJR159W': 2,
#  'YHR144C': 2,
#  'YDR454C': 3,
#  'YHR068W': 1,
#  'YCR036W': 2,
#  'YDR196C': 2,
#  'YNR057C': 1,
#  'YPL087W': 4,
#  'YOR236W': 2,
#  'YMR113W': 1,
#  'YDL100C': 1,
#  'YLR420W': 1,
#  'YJR016C': 2,
#  'YFL053W': 2,
#  'YML070W': 2,
#  'YJL167W': 2,
#  'YKL152C': 2,
#  'YLR172C': 1,
#  'YMR013C': 1,
#  'YPR183W': 1,
#  'YAL023C': 1,
#  'YDL095W': 1,
#  'YDL093W': 1,
#  'YJR143C': 1,
#  'YOR321W': 1,
#  'YJR057W': 1,
#  'YJR069C': 6,
#  'YBR252W': 1,
#  'YJR153W': 1,
#  'YPL281C': 1,
#  'YGR254W': 1,
#  'YHR174W': 1,
#  'YMR323W': 1,
#  'YOR393W': 1,
#  'YDR147W': 1,
#  'YOR126C': 12,
#  'YDR261C': 1,
#  'YGR282C': 1,
#  'YLR300W': 1,
#  'YNR067C': 1,
#  'YOR190W': 1,
#  'YPL069C': 1,
#  'YER015W': 10,
#  'YOR176W': 1,
#  'YKR066C': 2,
#  'Q0045': 5,
#  'Q0250': 5,
#  'Q0275': 5,
#  'YDL067C': 5,
#  'YGL187C': 4,
#  'YGL191W': 4,
#  'YHR051W': 4,
#  'YIL111W': 2,
#  'YLR038C': 4,
#  'YLR395C': 4,
#  'YMR256C': 4,
#  'YNL052W': 2,
#  'YHR116W': 1,
#  'YDR231C': 1,
#  'YGR062C': 1,
#  'YJL003W': 1,
#  'YPL132W': 1,
#  'YLL018C-A': 1,
#  'Q0105': 2,
#  'YBL045C': 2,
#  'YDR529C': 2,
#  'YEL024W': 2,
#  'YFR033C': 2,
#  'YGR183C': 2,
#  'YHR001W-A': 2,
#  'YJL166W': 2,
#  'YOR065W': 2,
#  'YPR191W': 2,
#  'YDL045C': 2,
#  'YLR011W': 2,
#  'YOR388C': 1,
#  'YGR204W': 3,
#  'YBR084W': 3,
#  'YLR345W': 2,
#  'YJL155C': 1,
#  'YLR377C': 1,
#  'YPL262W': 2,
#  'YKL216W': 1,
#  'YEL047C': 3,
#  'YLR299W': 1,
#  'YBR020W': 1,
#  'YBR018C': 2,
#  'YJL101C': 1,
#  'YPR184W': 1,
#  'YIL099W': 1,
#  'YNL241C': 1,
#  'YBR196C': 1,
#  'YDR300C': 1,
#  'YMR250W': 1,
#  'YDL215C': 1,
#  'YAL062W': 1,
#  'YOR375C': 1,
#  'YDL171C': 1,
#  'YOR323C': 1,
#  'YFL060C': 2,
#  'YNL334C': 2,
#  'YPR035W': 1,
#  'YMR084W': 1,
#  'YKL104C': 1,
#  'YOR168W': 1,
#  'YGL245W': 1,
#  'YOL033W': 1,
#  'YCL035C': 2,
#  'YPL091W': 6,
#  'YDR098C': 1,
#  'YDR513W': 2,
#  'YER174C': 1,
#  'YPL059W': 2,
#  'YNL229C': 1,
#  'YBR244W': 1,
#  'YIR037W': 1,
#  'YKL026C': 1,
#  'YOL049W': 1,
#  'YGR192C': 1,
#  'YJL052W': 1,
#  'YJR009C': 1,
#  'YOR120W': 1,
#  'YHL032C': 1,
#  'YER062C': 2,
#  'YIL053W': 2,
#  'YIL155C': 1,
#  'YDL022W': 1,
#  'YOL059W': 2,
#  'YPL110C': 1,
#  'YDR408C': 1,
#  'YAL044C': 8,
#  'YDR019C': 8,
#  'YFL018C': 14,
#  'YMR189W': 8,
#  'YLR058C': 1,
#  'YBR263W': 1,
#  'YDR148C': 5,
#  'YIL125W': 5,
#  'YFR015C': 2,
#  'YJL137C': 2,
#  'YKR058W': 2,
#  'YLR258W': 2,
#  'YPR160W': 1,
#  'YBR121C': 1,
#  'YPR081C': 1,
#  'YMR217W': 1,
#  'YMR281W': 1,
#  'YCL052C': 1,
#  'YJR013W': 1,
#  'YKL165C': 1,
#  'YBR004C': 1,
#  'YGL142C': 1,
#  'YDR302W': 1,
#  'YLL031C': 1,
#  'YGR267C': 1,
#  'YBL033C': 1,
#  'YDL238C': 1,
#  'YDR399W': 2,
#  'YER141W': 1,
#  'YPL172C': 1,
#  'YLR446W': 8,
#  'YFR053C': 3,
#  'YGL253W': 3,
#  'YCL040W': 1,
#  'YDR516C': 1,
#  'YCL030C': 3,
#  'YFR025C': 1,
#  'YIL116W': 1,
#  'YPR033C': 2,
#  'YBR034C': 1,
#  'YJL200C': 2,
#  'YDL131W': 2,
#  'YDL182W': 2,
#  'YLL062C': 1,
#  'YPL273W': 1,
#  'YIL094C': 1,
#  'YJR139C': 2,
#  'YHR025W': 1,
#  'YNL277W': 1,
#  'YDR453C': 2,
#  'YGR209C': 9,
#  'YLR043C': 5,
#  'YBL064C': 1,
#  'YCR083W': 3,
#  'YLR109W': 2,
#  'YDR272W': 1,
#  'YOR040W': 1,
#  'YNR041C': 1,
#  'YPL214C': 3,
#  'YDL205C': 1,
#  'YLR450W': 1,
#  'YML075C': 1,
#  'YML126C': 2,
#  'YOL055C': 2,
#  'YPL258C': 2,
#  'YPR121W': 2,
#  'YBR248C': 1,
#  'YOR202W': 1,
#  'YHR216W': 1,
#  'YLR432W': 1,
#  'YML056C': 1,
#  'YBR011C': 1,
#  'YMR267W': 1,
#  'YLR028C': 2,
#  'YMR120C': 2,
#  'YDR315C': 1,
#  'YDR173C': 4,
#  'YER019W': 60,
#  'YNL037C': 1,
#  'YOR136W': 1,
#  'YLR174W': 1,
#  'YNL009W': 1,
#  'YER065C': 1,
#  'YBL076C': 1,
#  'YPL040C': 1,
#  'YPL117C': 1,
#  'YGR244C': 2,
#  'YOR142W': 2,
#  'YBL098W': 1,
#  'YLR089C': 1,
#  'YEL046C': 2,
#  'YMR226C': 2,
#  'YBR115C': 1,
#  'YGL154C': 1,
#  'YDR321W': 1,
#  'YLR155C': 1,
#  'YLR157C': 1,
#  'YLR158C': 1,
#  'YLR160C': 1,
#  'YER023W': 3,
#  'YOL151W': 2,
#  'YCL064C': 2,
#  'YER086W': 1,
#  'YJR078W': 1,
#  'YDR403W': 2,
#  'YML004C': 1,
#  'YHR072W': 1,
#  'YPL160W': 1,
#  'YLR382C': 1,
#  'YNL045W': 6,
#  'YDR037W': 1,
#  'YNL073W': 1,
#  'YKL085W': 1,
#  'YOL126C': 1,
#  'YDL078C': 1,
#  'YIR031C': 1,
#  'YNL117W': 2,
#  'YKL029C': 2,
#  'YOR221C': 1,
#  'YDL055C': 1,
#  'YER003C': 1,
#  'YDR502C': 1,
#  'YLR180W': 1,
#  'YBL013W': 1,
#  'YGR264C': 1,
#  'YGR171C': 1,
#  'YKR080W': 1,
#  'YPR006C': 1,
#  'YMR208W': 4,
#  'YNR043W': 1,
#  'YBR036C': 20,
#  'YBR161W': 10,
#  'YPL057C': 10,
#  'YDR287W': 1,
#  'YHR046C': 1,
#  'YJL153C': 1,
#  'YFL017C': 1,
#  'YJL071W': 1,
#  'YMR062C': 2,
#  'YDR428C': 1,
#  'YDR402C': 2,
#  'YGL067W': 2,
#  'YEL041W': 4,
#  'YJR049C': 4,
#  'YPL188W': 2,
#  'YDL042C': 1,
#  'YDR191W': 1,
#  'YOL068C': 1,
#  'YOR025W': 1,
#  'YPL015C': 1,
#  'YHR074W': 2,
#  'YDL085W': 1,
#  'YMR145C': 1,
#  'YML120C': 1,
#  'YOR209C': 2,
#  'YGL037C': 1,
#  'YLR285W': 1,
#  'YCL047C': 1,
#  'YLR328W': 3,
#  'YGR010W': 2,
#  'YFR047C': 2,
#  'YEL042W': 2,
#  'YKL067W': 19,
#  'YAL035W': 1,
#  'YLL001W': 1,
#  'YLL058W': 3,
#  'YML082W': 3,
#  'YJL088W': 1,
#  'YKL184W': 1,
#  'YLR438W': 1,
#  'YML106W': 1,
#  'YMR271C': 1,
#  'YEL021W': 1,
#  'YFR049W': 2,
#  'YGR277C': 1,
#  'YDR531W': 1,
#  'YIL145C': 1,
#  'YJR019C': 10,
#  'YFL022C': 1,
#  'YLR060W': 1,
#  'YPR047W': 1,
#  'YDR380W': 1,
#  'YGL234W': 2,
#  'YEL058W': 2,
#  'YPR167C': 2,
#  'YKR097W': 1,
#  'YGR007W': 1,
#  'YGR240C': 2,
#  'YMR205C': 2,
#  'YMR105C': 2,
#  'YKL127W': 2,
#  'YGR256W': 1,
#  'YHR183W': 1,
#  'YER081W': 2,
#  'YIL074C': 2,
#  'YCR012W': 1,
#  'YOR283W': 1,
#  'YFL045C': 1,
#  'YMR220W': 1,
#  'YIL083C': 1,
#  'YKL088W': 1,
#  'YKR072C': 1,
#  'YOR054C': 1,
#  'YMR278W': 1,
#  'YAR015W': 1,
#  'YOR128C': 1,
#  'YDR007W': 1,
#  'YMR300C': 1,
#  'YKL181W': 3,
#  'YER099C': 2,
#  'YHL011C': 1,
#  'YBL068W': 2,
#  'YOL061W': 2,
#  'YGR208W': 1,
#  'YOR184W': 1,
#  'YBR183W': 1,
#  'YDR294C': 2,
#  'YMR020W': 3,
#  'YGL040C': 1,
#  'YNL316C': 1,
#  'YBR166C': 1,
#  'YLR142W': 1,
#  'YHR020W': 1,
#  'YER014W': 1,
#  'YLR209C': 6,
#  'YBR035C': 4,
#  'YBR218C': 1,
#  'YGL062W': 1,
#  'YBR221C': 1,
#  'YER178W': 1,
#  'YGR193C': 1,
#  'YNL071W': 1,
#  'YAL038W': 1,
#  'YOR347C': 1,
#  'YDR135C': 2,
#  'YDR236C': 2,
#  'YOL143C': 1,
#  'YBR256C': 1,
#  'YER070W': 6,
#  'YGR180C': 6,
#  'YIL066C': 6,
#  'YJL026W': 6,
#  'YOR095C': 1,
#  'YNL129W': 1,
#  'YJL121C': 1,
#  'YML008C': 1,
#  'YJL068C': 1,
#  'YIR034C': 1,
#  'YNR050C': 1,
#  'YHR013C': 1,
#  'YDL040C': 1,
#  'YOR253W': 1,
#  'YMR296C': 1,
#  'YKL212W': 33,
#  'YDR062W': 1,
#  'YGR038W': 1,
#  'YLR350W': 1,
#  'YBR058C-A': 1,
#  'YDR023W': 1,
#  'YHR011W': 1,
#  'YBR213W': 2,
#  'YPR069C': 2,
#  'YLR146C': 2,
#  'YJL134W': 2,
#  'YKR053C': 2,
#  'YLR260W': 2,
#  'YOR171C': 2,
#  'YGR175C': 2,
#  'YHR190W': 1,
#  'YDR178W': 2,
#  'YJL045W': 2,
#  'YKL141W': 3,
#  'YLL041C': 3,
#  'YKL148C': 1,
#  'YLR164W': 1,
#  'YBR006W': 1,
#  'YIL162W': 1,
#  'YJR010W': 1,
#  'YFR030W': 1,
#  'YJR137C': 1,
#  'YLL048C': 1,
#  'YLL057C': 2,
#  'YKL132C': 1,
#  'YOR241W': 1,
#  'YOR143C': 2,
#  'YIL010W': 2,
#  'YDR353W': 3,
#  'YHR106W': 1,
#  'YIL078W': 1,
#  'YKL194C': 1,
#  'YOR074C': 1,
#  'YBR003W': 1,
#  'YGR043C': 1,
#  'YLR354C': 1,
#  'YBR117C': 2,
#  'YPR074C': 2,
#  'YDR050C': 1,
#  'YGL026C': 1,
#  'YOL097C': 1,
#  'YDR268W': 1,
#  'YGR185C': 1,
#  'YPL097W': 1,
#  'YLR189C': 1,
#  'YDL103C': 1,
#  'YBR019C': 2,
#  'YKL024C': 6,
#  'YHR128W': 1,
#  'YIR032C': 2,
#  'YDR020C': 3,
#  'YDR047W': 1,
#  'YKR069W': 1,
#  'YOR278W': 1,
#  'YHL012W': 1,
#  'YKL035W': 1,
#  'YPR170W-B': 2,
#  'YBR127C': 4,
#  'YDL185W': 4,
#  'YOR332W': 4,
#  'YHR026W': 4,
#  'YEL027W': 4,
#  'YKL080W': 4,
#  'YLR447C': 4,
#  'YEL051W': 4,
#  'YPL234C': 4,
#  'YMR054W': 2,
#  'YGR020C': 4,
#  'YPR036W': 4,
#  'YHR039C-A': 4,
#  'YGR106C': 4,
#  'YCL005W-A': 4,
#  'YOR270C': 2,
#  'YGR094W': 2,
#  'YJR133W': 1,
#  'YLR070C': 1,
#  'YGR194C': 1,
#  'YFL001W': 1,
#  'YGL063W': 1,
#  'YNL292W': 1,
#  'YPL212C': 1,
#  'YNL065W': 8,
#  'YKL217W': 7,
#  'YOR222W': 2,
#  'YPL134C': 2,
#  'YDL210W': 2,
#  'YOR348C': 4,
#  'YNR056C': 1,
#  'YCR010C': 1,
#  'YER056C': 3,
#  'YER060W': 3,
#  'YER060W-A': 3,
#  'YAL022C': 2,
#  'YBL030C': 1,
#  'YBR085W': 1,
#  'YMR056C': 1,
#  'YPR128C': 2,
#  'YMR241W': 1,
#  'YJR152W': 13,
#  'YIR028W': 1,
#  'YDR384C': 1,
#  'YGR121C': 1,
#  'YNL142W': 1,
#  'YPR138C': 1,
#  'YPR021C': 2,
#  'YGR065C': 1,
#  'YOR100C': 3,
#  'YGL077C': 3,
#  'YBR291C': 3,
#  'YHR002W': 2,
#  'YBR192W': 6,
#  'YGL186C': 2,
#  'YDL245C': 8,
#  'YDR342C': 9,
#  'YDR343C': 5,
#  'YDR345C': 5,
#  'YEL069C': 7,
#  'YFL011W': 6,
#  'YHR092C': 9,
#  'YHR094C': 4,
#  'YHR096C': 5,
#  'YJL214W': 5,
#  'YJL219W': 6,
#  'YJR158W': 7,
#  'YMR011W': 3,
#  'YNR072W': 7,
#  'YOL156W': 6,
#  'YLR081W': 2,
#  'YNL318C': 1,
#  'YIL013C': 8,
#  'YOR011W': 8,
#  'YIL134W': 1,
#  'YGL225W': 2,
#  'YDL247W': 2,
#  'YDR536W': 2,
#  'YJR160C': 2,
#  'YDR387C': 1,
#  'YJL212C': 2,
#  'YLL015W': 1,
#  'YCR098C': 4,
#  'YGL084C': 1,
#  'YPL189W': 1,
#  'YFL054C': 1,
#  'YLL043W': 2,
#  'YCL025C': 14,
#  'YKR039W': 25,
#  'YOL020W': 5,
#  'YPL265W': 7,
#  'YDL198C': 1,
#  'YDR497C': 1,
#  'YOL103W': 1,
#  'YMR319C': 1,
#  'YMR058W': 1,
#  'YJL133W': 1,
#  'YKR052C': 1,
#  'YEL063C': 1,
#  'YNL270C': 1,
#  'YOL092W': 3,
#  'YBR293W': 4,
#  'YDR508C': 11,
#  'YJR001W': 5,
#  'YKL146W': 5,
#  'YNL101W': 5,
#  'YER119C': 2,
#  'YFL055W': 3,
#  'YBR132C': 2,
#  'YBR068C': 8,
#  'YBR069C': 7,
#  'YDR046C': 8,
#  'YCR075C': 1,
#  'YCL069W': 2,
#  'YMR088C': 2,
#  'YGR191W': 2,
#  'YCL038C': 3,
#  'YNL268W': 1,
#  'YGR055W': 1,
#  'YHL036W': 1,
#  'YDR105C': 1,
#  'YLR348C': 2,
#  'YBR298C': 1,
#  'YGR289C': 2,
#  'YBR180W': 1,
#  'YEL006W': 1,
#  'YIL006W': 4,
#  'YGR260W': 1,
#  'YKL188C': 15,
#  'YPL147W': 15,
#  'YOR130C': 1,
#  'YKL120W': 2,
#  'YCR028C': 1,
#  'YBR296C': 1,
#  'YCR037C': 2,
#  'YJL198W': 2,
#  'YML123C': 2,
#  'YNR013C': 3,
#  'YER053C': 2,
#  'YJR077C': 2,
#  'YDR456W': 2,
#  'YJL129C': 1,
#  'YKL174C': 2,
#  'YLL028W': 6,
#  'YOR273C': 6,
#  'YPL274W': 2,
#  'YNL003C': 1,
#  'YLL061W': 1,
#  'YLR138W': 1,
#  'YHL016C': 2,
#  'YGR138C': 2,
#  'YPR156C': 2,
#  'YJR095W': 1,
#  'YBR294W': 1,
#  'YLR092W': 1,
#  'YPL092W': 1,
#  'YGR096W': 1,
#  'YLR237W': 1,
#  'YOR071C': 1,
#  'YOR192C': 1,
#  'YPL244C': 1,
#  'YBR021W': 1,
#  'YBL042C': 2,
#  'YLL052C': 4,
#  'YPR192W': 4,
#  'YFL058W': 1,
#  'YGL101W': 4,
#  'YBR242W': 4,
#  'YPR011C': 1,
#  'YBR147W': 6,
#  'YNL036W': 1,
#  'YOR161C': 2,
#  'YDR071C': 1,
#  'YBR041W': 13,
#  'YBR241C': 3,
#  'YPR058W': 1,
#  'YNR027W': 2,
#  'YEL029C': 1,
#  'YGL080W': 2,
#  'YGR243W': 1,
#  'YHR162W': 1,
#  'YOR306C': 1,
#  'YDL024C': 2,
#  'YKR043C': 1,
#  'YDL066W': 1,
#  'YKL182W': 2,
#  'YPL231W': 2,
#  'YER061C': 3,
#  'YKL055C': 3,
#  'YHR067W': 3,
#  'YBR026C': 3,
#  'YJL196C': 2,
#  'YCR034W': 4,
#  'YLR372W': 4,
#  'YBR159W': 7,
#  'YJL097W': 7,
#  'YDL015C': 7,
#  'YGL055W': 2,
#  'YOR317W': 14,
#  'YMR246W': 12,
#  'YIL009W': 6,
#  'YLR284C': 6,
#  'YOR180C': 2,
#  'YNL202W': 2,
#  'YBL011W': 4,
#  'YKR067W': 16,
#  'YIL124W': 8,
#  'YOR175C': 8,
#  'YDL052C': 8,
#  'YKR089C': 52,
#  'YOR081C': 36,
#  'YMR165C': 8,
#  'YDR284C': 20,
#  'YDR503C': 20,
#  'YOR245C': 64,
#  'YBR029C': 14,
#  'YER026C': 8,
#  'YPR113W': 8,
#  'YBR042C': 2,
#  'YNL169C': 8,
#  'YGR170W': 16,
#  'YGR157W': 8,
#  'YJR073C': 24,
#  'YOR311C': 8,
#  'YHR123W': 16,
#  'YNL130C': 8,
#  'YCL004W': 6,
#  'YHR100C': 6,
#  'YDL142C': 36,
#  'YGR110W': 36,
#  'YPR140W': 192,
#  'YJL100W': 16,
#  'YLR305C': 8,
#  'YDR373W': 8,
#  'YNL267W': 16,
#  'YBR097W': 24,
#  'YLR240W': 24,
#  'YPL120W': 16,
#  'YLR360W': 8,
#  'YBR128C': 8,
#  'YLR211C': 8,
#  'YDR208W': 16,
#  'YFR019W': 16,
#  'YNR008W': 128,
#  'YML059C': 12,
#  'YMR008C': 24,
#  'YMR006C': 24,
#  'YOL011W': 24,
#  'YPL268W': 16,
#  'YPL206C': 6,
#  'YKR031C': 8,
#  'YNL106C': 64,
#  'YOR109W': 64,
#  'YJR110W': 8,
#  'YIL002C': 16,
#  'YOL065C': 8,
#  'YNL325C': 8,
#  'YFR021W': 8,
#  'YNL054W': 8,
#  'YLR386W': 8,
#  'YKL140W': 2,
#  'YLL012W': 10,
#  'YLR020C': 2,
#  'YBR204C': 32,
#  'YMR313C': 44,
#  'YCR068W': 2,
#  'YDR058C': 4,
#  'YKL094W': 4,
#  'YDR072C': 80,
#  'YDR367W': 80,
#  'YKL004W': 80,
#  'YLL053C': 1,
#  'YIL048W': 16,
#  'YMR162C': 9,
#  'YAL026C': 16,
#  'YDR400W': 2,
#  'YAL039C': 1,
#  'YKL087C': 1,
#  'YAL061W': 3,
#  'YBL080C': 1,
#  'YBL091C': 1,
#  'YLR244C': 1,
#  ...}

# %%
len(yeast8U_gene_frequece_dict)
# Out:
# 2382

# %% [markdown]
# ## gene2ec

# %%
clean_gene2ec_dict = get_gene2ec_dict_clean(sce_gene_clean_ec)
clean_ec2gene_dict = get_ec2gene_dict_clean(clean_gene2ec_dict)
print(clean_ec2gene_dict.keys())
print(len(clean_ec2gene_dict))
# Out:
# dict_keys(['5.3.99', '2.3.2', '3.1.2', '2.3.1', '1.12.99', '5.6.2', '3.2.2', '4.2.3', '1.14.15', '2.7.6', '3.5.1', '3.6.4', '3.4.21', '2.1.1', '7.1.2', '2.7.4', '3.4.13', '3.4.22', '3.1.3', '2.4.1', '3.4.16', '3.1.1', '3.2.1', '1.11.1', '3.4.24', '2.7.1', '1.6.5', '3.1.13', '3.1.12', '2.7.7', '7.1.1', '3.1.4', '3.6.1', '4.4.1', '5.2.1', '2.7.11', '2.7.10', '4.6.1', '5.3.4', '4.2.2', '3.4.11', '1.16.3', '3.6.5', '2.7.13', '3.4.19', '3.1.26', '5.4.99', '1.10.3', '7.6.2', '4.1.3', '3.1.21', '2.4.2', '2.7.8', '4.2.1', '6.2.1', '2.5.1', '1.14.99', '5.6.1', '1.13.12', '1.3.7', '6.1.1', '1.8.3', '1.3.99', '1.1.1', '1.14.13', '1.2.1', '1.14.14', '1.2.4', '1.4.4', '7.2.1', '1.4.1', '3.1.11', '2.1.3', '1.11.2', '3.4.23', '3.4.14', '1.7.5', '4.5.1', '4.1.1', '1.17.5', '1.3.1', '1.5.5', '5.1.3', '6.3.4', '1.16.1', '6.3.2', '3.4.25', '3.3.2', '1.8.1', '1.97.1', '4.1.2', '5.5.1', '2.7.12', '1.4.3', '1.14.16', '4.99.1', '1.8.4', '1.3.5', '1.15.1', '2.6.1', '1.1.99', '6.3.1', '1.23.5', '6.4.1', '2.3.3', '1.3.8', '2.4.99', '3.3.1', '5.3.2', '1.5.1', '4.2.99', '1.1.2', '2.2.1', '7.4.2', '1.6.2', '2.8.3', '1.2.99', '2.7.2', '6.5.1', '5.4.2', '3.5.4', '7.5.2', '1.12.1', '1.8.5', '1.14.19', '4.7.1', '4.3.3', '1.14.11', '5.4.4', '1.12.98', '5.3.1', '2.8.4', '1.17.4', '3.5.2', '3.5.3', '3.4.17', '1.17.1', '6.6.1', '3.8.1', '7.2.2', '6.3.5', '1.20.4', '1.2.5', '1.2.7', '7.3.2', '4.3.1', '5.3.3', '2.8.1', '1.8.98', '1.1.5', '1.21.99', '1.1.3', '3.1.7', '1.14.17', '1.3.3', '7.2.4', '4.3.2', '4.1.99', '5.1.99', '1.17.99', '3.1.30', '2.8.2', '1.18.6', '1.13.11', '1.8.99', '6.3.3', '1.8.7', '1.7.7', '2.7.3', '3.5.5', '3.5.99', '5.1.1', '2.1.2', '1.7.6', '1.18.1', '3.7.1', '1.12.2', '1.5.3', '1.14.12', '1.14.18', '3.1.6', '1.2.3', '7.1.3', '1.3.98', '3.1.31', '3.6.2', '1.6.99'])
# 187

# %%
DeepEC_gene2ec_dict = get_gene2ec_dict_DeepEC(DeepEC_path)
DeepEC_ec2gene_dict = get_ec2gene_dict_DeepEC(DeepEC_gene2ec_dict)
print(DeepEC_ec2gene_dict.keys())
print(len(DeepEC_ec2gene_dict))
# Out:
# dict_keys(['2.7.11', '3.1.2', '2.7.1', '3.4.19', '3.6.5', '2.4.1', '3.1.21', '2.7.9', '7.1.2', '2.7.4', '1.8.1', '2.7.7', '3.2.1', '1.11.1', '2.3.2', '1.3.1', '1.10.2', '3.6.1', '3.1.3', '3.4.11', '3.6.4', '1.14.11', '3.1.26', '3.4.21', '3.1.22', '3.1.4', '4.2.1', '6.2.1', '2.1.1', '6.1.1', '1.16.1', '3.4.22', '1.14.13', '1.2.1', '7.6.2', '1.4.4', '2.7.8', '3.6.3', '2.3.1', '1.4.1', '1.6.5', '5.2.1', '1.8.3', '6.3.2', '2.7.10', '2.4.99', '3.5.1', '3.5.2', '2.4.2', '4.1.3', '3.4.14', '2.5.1', '4.1.1', '1.5.5', '1.1.1', '5.1.3', '2.7.6', '1.3.5', '2.6.1', '6.3.1', '6.4.1', '2.3.3', '5.99.1', '3.1.1', '3.3.1', '4.2.3', '4.6.1', '1.8.4', '1.1.2', '2.2.1', '1.15.1', '2.7.2', '1.10.3', '3.1.11', '6.5.1', '5.4.2', '3.5.4', '3.4.25', '4.2.99', '3.4.24', '4.2.2', '1.2.98', '2.7.13', '3.1.13', '4.4.1', '1.17.4', '1.17.1', '5.6.2', '5.5.1', '6.3.5', '1.6.99', '3.5.3', '6.3.4', '2.7.12', '5.1.1', '1.14.14', '3.4.23', '5.3.4', '5.3.1', '3.3.2', '2.8.1', '1.1.5', '1.1.3', '4.3.3', '1.2.4', '1.3.3', '5.3.3', '1.6.2', '2.8.2', '7.1.3', '5.1.99', '1.5.1', '1.9.3', '5.6.1', '3.2.2', '4.1.99', '7.2.2', '6.3.3', '7.1.1', '1.4.3', '3.5.99', '1.13.11', '2.1.2', '1.16.3', '5.4.99', '1.14.99', '1.18.1', '3.7.1', '4.3.1', '1.8.98', '1.14.19', '3.4.17', '1.14.12', '4.3.2', '2.10.1', '2.1.3', '7.4.2', '1.3.98', '1.7.99', '4.1.2', '1.7.1', '4.99.1'])
# 142

# %%
yeast8U_ec_frequency_dict = process_reactions_to_ec_frequency(yeast8U.reactions, clean_gene2ec_dict)

# Process reactions for yeast8
yeast8_ec_frequency_dict = process_reactions_to_ec_frequency(yeast8.reactions, clean_gene2ec_dict)

yeast8U_yeast8_ec_frequency = {'EC':[],
                               'yeast8':[],
                               'yeast8U':[]}
for k,v in yeast8U_ec_frequency_dict.items():
    yeast8U_yeast8_ec_frequency['EC'].append(k)
    yeast8U_yeast8_ec_frequency['yeast8U'].append(v)
    if k in yeast8_ec_frequency_dict.keys():
        yeast8U_yeast8_ec_frequency['yeast8'].append(yeast8_ec_frequency_dict[k])
    else:
        yeast8U_yeast8_ec_frequency['yeast8'].append(0)

yeast8U_yeast8_ec_frequency_df = pd.DataFrame(yeast8U_yeast8_ec_frequency)
yeast8U_yeast8_ec_frequency_df['ratio'] = yeast8U_yeast8_ec_frequency_df.apply(
    lambda row: row['yeast8U'] / row['yeast8'] if row['yeast8'] != 0 else 0,
    axis=1
)
yeast8U_yeast8_ec_frequency_df.head(10)
# Out:
#         EC  yeast8  yeast8U        ratio
# 0    1.3.1      27    19216   711.703704
# 1    1.4.3       5    18716  3743.200000
# 2    1.1.1     158    18523   117.234177
# 3   1.6.99       0    16591     0.000000
# 4   1.10.3       2     9507  4753.500000
# 5  1.14.19       7     8288  1184.000000
# 6    1.3.7       0     2747     0.000000
# 7   1.8.98       0     2314     0.000000
# 8  1.13.12       1     2215  2215.000000
# 9   1.8.99       0     2214     0.000000

# %%
def get_ec_rank(ec,yeast8U_yeast8_ec_frequency_df):
    tmp_df = yeast8U_yeast8_ec_frequency_df[yeast8U_yeast8_ec_frequency_df['EC'].apply(lambda x:x.split('.')[0]== ec.split('.')[0])]
    tmp = tmp_df.reset_index()
    tmp = tmp[tmp['EC']==ec]
    return (tmp.index[0]+1)/len(tmp_df)

ec = '7.5.2'
get_ec_rank(ec,yeast8U_yeast8_ec_frequency_df)
# Out:
# 0.7777777777777778

# %%
yeast8U_yeast8_ec_frequency_df.shape
# Out:
# (164, 4)

# %%
# Set general parameters
plt.figure(figsize=(5.8, 1.8), dpi=400)
plt.rcParams.update({'font.size': 6})
plt.rcParams['font.family'] = 'Arial'

# Set axis style
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Draw stacked bar chart
bar_width = 0.6
index = np.arange(len(yeast8U_yeast8_ec_frequency_df['EC']))
plt.bar(index, yeast8U_yeast8_ec_frequency_df['yeast8'], width=bar_width, label='Yeast8U', color='#4575b4')
plt.bar(index, yeast8U_yeast8_ec_frequency_df['yeast8U'] - yeast8U_yeast8_ec_frequency_df['yeast8'], width=bar_width, label='Yeast8U+lipids', color='#762a83', 
        bottom=yeast8U_yeast8_ec_frequency_df['yeast8'])

# Set x-axis labels
plt.xticks(index, yeast8U_yeast8_ec_frequency_df['EC'], fontsize=2.5, rotation=90)  # Set x-axis labels and rotation
plt.yticks(fontsize=6)  # Set y-axis labels

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', which='both', width=0.5, length=1, pad=1)  # Do not show x-axis tick lines, but keep labels

plt.xlim(-1, 152)
plt.ylim(0.9, 60000)  # Adjust y-axis range
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.minorticks_off()  # Hide minor ticks

plt.ylabel('Reaction number of EC code', fontsize=6)  # Adjust label

# Set legend
plt.legend(frameon=False, fontsize=6, loc='upper right', ncol=2)

# Show plot
plt.tight_layout()
# plt.savefig('../Figure_plus/fig2-e.pdf', dpi=400, bbox_inches='tight')                         
plt.show()

# %%
# Set general parameters
plt.figure(figsize=(5.8, 1.8), dpi=400)
plt.rcParams.update({'font.size': 6})
plt.rcParams['font.family'] = 'Arial'

# Set axis style
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(0.5)

# Draw stacked bar chart
bar_width = 0.6
index = np.arange(len(yeast8U_yeast8_ec_frequency_df['EC']))

# colors = ['#d53e4f', '#fdae61', '#fee08b', '#e6f598', '#abdda4', '#66c2a5', '#3288bd']
colors = ['#762a83', '#762a83', '#762a83', '#762a83', '#762a83', '#762a83', '#762a83']
sections = [(0, 52), (52, 77), (77, 109), (109, 124), (124, 137), (137, 145), (145, 152)]

for i, (start, end) in enumerate(sections):
    plt.bar(index[start:end], yeast8U_yeast8_ec_frequency_df['yeast8U'][start:end], width=bar_width, color='white', edgecolor=colors[i], linewidth=0.5)
    plt.bar(index[start:end], yeast8U_yeast8_ec_frequency_df['yeast8'][start:end], width=bar_width, color=colors[i])

# Set y-axis labels
plt.yticks(fontsize=6)

# Set x-axis tick positions and labels
specific_ticks = [0, 51, 52, 76, 77, 108, 109, 123, 124, 136, 137, 143, 145, 151]
plt.xticks(specific_ticks, [''] * len(specific_ticks))

specific_ticks2 = [25, 64, 92.5, 116, 130, 140, 148]
specific_labels2 = ['Yeast8/Yeast-MetaTwin = 7.1%', '11.4%', '7.6%', '6.0%', '4.1%', '41%', '6.0%']
for tick, label in zip(specific_ticks2, specific_labels2):
    plt.text(tick, 0.7, label, ha='center', va='top', fontsize=6, rotation=0)

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', which='both', width=0.5, length=4, pad=1)

plt.xlim(-1, 152)
plt.ylim(0.9, 50000)
plt.yscale('log')
plt.minorticks_off()

plt.ylabel('Reaction number of EC code', fontsize=6)

# Set legend
custom_patch1 = mpatches.Patch(facecolor='white', edgecolor='#762a83', linewidth=0.5, label='Yeast-MetaTwin(Lipids)')
custom_patch2 = mpatches.Patch(facecolor='#762a83', edgecolor='#762a83', linewidth=0.5, label='Yeast8')

# Get current legend handles and labels
handles, labels = ax.get_legend_handles_labels()

# Insert custom legend entries into handles and labels
handles.insert(0, custom_patch1)
handles.insert(1, custom_patch2)

# Create legend
plt.legend(handles=handles, frameon=False, fontsize=7, loc='center left', bbox_to_anchor=(0.62, 0.95), ncol=2, labelspacing=0.5, handletextpad=0.3, handlelength=1)

plt.tight_layout()
plt.savefig(figs11_path, dpi=400, bbox_inches='tight')                         
plt.show()

# %%
#extract the first digit of EC number
yeast8U_yeast8_ec_frequency_df['EC_first_digit'] = yeast8U_yeast8_ec_frequency_df['EC'].str.split('.').str[0]
# group by the first digit of EC number and sum
yeast8U_yeast8_ec_frequency_df_first = yeast8U_yeast8_ec_frequency_df.groupby('EC_first_digit')[['yeast8', 'yeast8U']].sum().reset_index()
yeast8U_yeast8_ec_frequency_df_first['ratio'] = yeast8U_yeast8_ec_frequency_df_first.apply(
    lambda row: row['yeast8U'] / row['yeast8'] if row['yeast8'] != 0 else 0,
    axis=1
)
yeast8U_yeast8_ec_frequency_df_first
# Out:
#   EC_first_digit  yeast8  yeast8U       ratio
# 0              1     424   117555  277.252358
# 1              2    1477   216995  146.916046
# 2              3     909   173834  191.236524
# 3              4     181    83674  462.287293
# 4              5      60    45735  762.250000
# 5              6     130     4927   37.900000
# 6              7     110    56564  514.218182

# %%
yeast8U_yeast8_ec_frequency_df_first['ratio/1'] = yeast8U_yeast8_ec_frequency_df_first['yeast8']/yeast8U_yeast8_ec_frequency_df_first['yeast8U']
yeast8U_yeast8_ec_frequency_df_first
# Out:
#   EC_first_digit  yeast8  yeast8U       ratio   ratio/1
# 0              1     424   117555  277.252358  0.003607
# 1              2    1477   216995  146.916046  0.006807
# 2              3     909   173834  191.236524  0.005229
# 3              4     181    83674  462.287293  0.002163
# 4              5      60    45735  762.250000  0.001312
# 5              6     130     4927   37.900000  0.026385
# 6              7     110    56564  514.218182  0.001945
