# %%
import pandas as pd
import numpy as np
import json
import pandas as pd
import re
import sys
from rdkit import Chem
from rdkit.Chem import AllChem
from collections import Counter,defaultdict
from ast import literal_eval
import cobra
import multiprocessing
from functools import partial
sys.path.append('../retrosynthesis/')
import matplotlib.pyplot as plt

from common import *

import sys
# sys.path.append('../Script/')
# from check_newinfo_getyeast8U import *

import warnings
warnings.filterwarnings('ignore', 'A value is trying to be set on a copy of a slice from a DataFrame')

# %%
### input
# yeast870_path =  '../../Data/model/yeast-GEM.mat'
yeast8U_path = '../../Data/model/Yeast-MetaTwin.yml'
uniprot_sce_path = '../../Data/database/uniprot/uniprotkb_organism_id_559292_2023_11_08.tsv'

metabolites_info_to_GEM_path = '../../Results/not_lipid/top50_0.3_re/metabolites_info_to_GEM_top50_0.3.csv'
rxndb_total_info_to_model_path = '../../Results/not_lipid/top50_0.3_re/rxndb_total_info_to_model_top50_0.3.csv'

### output
uniprot_reaction_path = '../../Data/database/uniprot/uniprot_reaction_smiles.csv'
figs5_path = '../../Results/Figures/figs5.pdf'

# %% [markdown]
# # uniprot

# %%
uniprot_sce_entry = pd.read_csv(uniprot_sce_path,sep='\t')
uniprot_sce_entry = uniprot_sce_entry['Entry'].to_list()
len(uniprot_sce_entry)
# Out:
# 6735

# %%
uniprot_reaction = pd.read_csv(uniprot_reaction_path)
uniprot_sce_reaction = uniprot_reaction[uniprot_reaction['Entry'].isin(uniprot_sce_entry)]
uniprot_sce_reaction['reaction_smiles'] = uniprot_sce_reaction['reaction_smiles'].apply(lambda x:literal_eval(x))
print(uniprot_sce_reaction.shape)
uniprot_sce_reaction
# Out:
# (1380, 6)
# /home/wuke/anaconda3/envs/kcat/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              Entry  Reviewed   Entry Name  \
# 38      A0A0B7P3V8  reviewed  YP41B_YEAST
# 1927        O13297  reviewed   CET1_YEAST
# 1936        O13527  reviewed  YA11B_YEAST
# 1937        O13535  reviewed  YH11B_YEAST
# 3279        P00163  reviewed    CYB_YEAST
# ...            ...       ...          ...
# 199891      P38635  reviewed   HIS9_YEAST
# 199892      P38709  reviewed  UGPA2_YEAST
# 199893      P38744  reviewed    PHS_YEAST
# 200218      P47145  reviewed   LIH1_YEAST
# 203379      Q07505  reviewed   DLHH_YEAST
#
#                                        Catalytic activity  \
# 38      CATALYTIC ACTIVITY: Reaction=a 2'-deoxyribonuc...
# 1927    CATALYTIC ACTIVITY: Reaction=a 5'-end triphosp...
# 1936    CATALYTIC ACTIVITY: Reaction=a 2'-deoxyribonuc...
# 1937    CATALYTIC ACTIVITY: Reaction=a 2'-deoxyribonuc...
# 3279    CATALYTIC ACTIVITY: Reaction=a quinol + 2 Fe(I...
# ...                                                   ...
# 199891  CATALYTIC ACTIVITY: Reaction=H2O + L-histidino...
# 199892  CATALYTIC ACTIVITY: Reaction=alpha-D-glucose 1...
# 199893  CATALYTIC ACTIVITY: Reaction=(4aS,6R)-4a-hydro...
# 200218  CATALYTIC ACTIVITY: Reaction=a triacylglycerol...
# 203379  CATALYTIC ACTIVITY: Reaction=2-(5-oxo-2,5-dihy...
#
#                reaction_rhea_id  \
# 38      ['22508', 22509, 22510]
# 1927    ['67005', 67005, 67006]
# 1936    ['22508', 22509, 22510]
# 1937    ['22508', 22509, 22510]
# 3279             [11485, 11486]
# ...                         ...
# 199891           [14466, 14467]
# 199892           [19890, 19891]
# 199893           [11921, 11922]
# 200218  ['12045', 12045, 12046]
# 203379           [12373, 12374]
#
#                                           reaction_smiles
# 38      {'22509': '*[C@H]1C[C@H](O)[C@@H](COP(=O)([O-]...
# 1927    {'67005': '*O[C@H]1[C@@H](O)[C@H](*)O[C@@H]1CO...
# 1936    {'22509': '*[C@H]1C[C@H](O)[C@@H](COP(=O)([O-]...
# 1937    {'22509': '*[C@H]1C[C@H](O)[C@@H](COP(=O)([O-]...
# 3279    {'11485': '[1*]C1=C(O)C([4*])=C([3*])C(O)=C1[2...
# ...                                                   ...
# 199891  {'14466': '[H]O[H].[NH3+][C@H](COP(=O)([O-])[O...
# 199892  {'19890': 'O=C1C=CN([C@@H]2O[C@H](COP(=O)([O-]...
# 199893  {'11921': 'C[C@H](O)[C@H](O)[C@H]1CNC2=NC(N)=N...
# 200218  {'12045': '[1*]C(=O)OCC(COC([3*])=O)OC([2*])=O...
# 203379  {'12373': '[H]C(C(=O)[O-])=C1C=CC(=O)O1.[H]O[H...
#
# [1380 rows x 6 columns]

# %%
uniprot_sce_reaction['reaction_smiles'] = uniprot_sce_reaction['reaction_smiles'].apply(lambda x:{k:v for k,v in x.items() if 'R' not in v})
print(uniprot_sce_reaction.shape)
uniprot_sce_reaction = uniprot_sce_reaction[uniprot_sce_reaction['reaction_smiles'].apply(lambda x:x!={})]
print(uniprot_sce_reaction.shape)
# Out:
# (1380, 6)
# (1376, 6)
# /home/wuke/anaconda3/envs/kcat/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
uniprot_sce_reaction['reaction_smiles'] = uniprot_sce_reaction['reaction_smiles'].apply(lambda x:{k:v for k,v in x.items() if '*' not in v})
print(uniprot_sce_reaction.shape)
uniprot_sce_reaction = uniprot_sce_reaction[uniprot_sce_reaction['reaction_smiles'].apply(lambda x:x!={})]
print(uniprot_sce_reaction.shape)
# Out:
# (1376, 6)
# (755, 6)
# /home/wuke/anaconda3/envs/kcat/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
uniprot_sce_reaction.head(3)
# Out:
#        Entry  Reviewed  Entry Name  \
# 3280  P00175  reviewed  CYB2_YEAST
# 3310  P00358  reviewed  G3P2_YEAST
# 3311  P00359  reviewed  G3P3_YEAST
#
#                                      Catalytic activity  \
# 3280  CATALYTIC ACTIVITY: Reaction=(S)-lactate + 2 F...
# 3310  CATALYTIC ACTIVITY: Reaction=D-glyceraldehyde ...
# 3311  CATALYTIC ACTIVITY: Reaction=D-glyceraldehyde ...
#
#              reaction_rhea_id  \
# 3280  ['19910', 19910, 19911]
# 3310           [10301, 10302]
# 3311           [10301, 10302]
#
#                                         reaction_smiles
# 3280  {'19910': 'C[C@H](O)C(=O)[O-].[Fe+3].[Fe+3]>>C...
# 3310  {'10301': 'NC(=O)C1=CC=C[N+]([C@@H]2O[C@H](COP...
# 3311  {'10301': 'NC(=O)C1=CC=C[N+]([C@@H]2O[C@H](COP...

# %% [markdown]
# ## Generate similar rxndb_df

# %%
uniprot_sce_reaction_df = pd.DataFrame(columns=['NO','RheaID','rxn_smiles_final'])
for index, row in tqdm(uniprot_sce_reaction.iterrows(),total = len(uniprot_sce_reaction)):
    num = 1
    for k, v in row['reaction_smiles'].items():
        new_row = {}
        new_row['NO'] = row['Entry'] + '_' + str(num)
        new_row['RheaID'] = k
        new_row['rxn_smiles_final'] = v
        uniprot_sce_reaction_df = uniprot_sce_reaction_df.append(new_row, ignore_index=True)
        num += 1
        
uniprot_sce_reaction_df.head(3)
# Out:
# 100%|██████████| 755/755 [00:03<00:00, 211.63it/s]
#          NO RheaID                                   rxn_smiles_final
# 0  P00175_1  19910  C[C@H](O)C(=O)[O-].[Fe+3].[Fe+3]>>CC(=O)C(=O)[...
# 1  P00175_2  19911  CC(=O)C(=O)[O-].[Fe+2].[Fe+2].[H+].[H+]>>C[C@H...
# 2  P00358_1  10301  NC(=O)C1=CC=C[N+]([C@@H]2O[C@H](COP(=O)([O-])O...

# %% [markdown]
# # uniprot smiles list and rxndb smiles list

# %%
def compare_reaction_smiles_pair(smiles1,smiles2):
    smiles1_lst = smiles1.replace('>>','.').split('.')
    smiles1_lst = list(set([x for x in smiles1_lst if  smiles_has_carbon(x)]))

    smiles2_lst = smiles2.replace('>>','.').split('.')
    smiles2_lst = list(set([x for x in smiles2_lst if  smiles_has_carbon(x)]))

    if len(smiles1_lst)==len(smiles2_lst):
        score = 0
        for s1 in smiles1_lst:
            if any(compare_smiles_inchikey(s1,s2) for s2 in smiles2_lst):
                score += 1
            else:
                score += 0
        if score == len(smiles1_lst):
            return True
        else:
            return False
    else:
        return False

# %%
# nocarbon_list = []
# for i in uniprot_sce_reaction_df['rxn_smiles_final']:
#     smiles_lst = i.replace('>>','.').split('.')
#     for smiles in smiles_lst:
#         if not smiles_has_carbon(smiles):
#             nocarbon_list.append(smiles)

# %%
rxndb_total_info_to_model = pd.read_csv(rxndb_total_info_to_model_path)
rxndb_total_info_to_model = rxndb_total_info_to_model[['NO','EC_number','templateID','rxn_smiles_final','GPR']]
rxndb_total_info_to_model.head(3)
# Out:
#          NO EC_number          templateID  \
# 0  rxn19747   1.14.13  MNXR180996_reverse
# 1  rxn19748   1.14.13          MNXR149799
# 2  rxn19749   1.14.13          MNXR149799
#
#                                     rxn_smiles_final  \
# 0  COc1cc(CC(=O)[O-])ccc1O.O.NC(=O)c1ccc[n+]([C@@...
# 1  CCCCCCCCCCCC(=O)[O-].O=O.[H+].NC(=O)C1=CN([C@@...
# 2  CCCCCCCCCC(=O)[O-].O=O.[H+].NC(=O)C1=CN([C@@H]...
#
#                                                  GPR
# 0  (YBL098W) or (YNR053C) or (YCL059C) or (YHR176...
# 1  (YBL098W) or (YNR053C) or (YCL059C) or (YHR176...
# 2  (YBL098W) or (YNR053C) or (YCL059C) or (YHR176...

# %%
rxndb_smiles_lst = []
for index,row in rxndb_total_info_to_model.iterrows():
    smiles_lst = row['rxn_smiles_final'].replace('>>','.').split('.')
    rxndb_smiles_lst +=smiles_lst
rxndb_smiles_lst = [normalize_smiles(x) for x in rxndb_smiles_lst]
rxndb_smiles_lst = list(set(rxndb_smiles_lst))

uniprot_smiles_lst = []
for index,row in uniprot_sce_reaction_df.iterrows():
    smiles_lst = row['rxn_smiles_final'].replace('>>','.').split('.')
    uniprot_smiles_lst +=smiles_lst
# uniprot_smiles_lst = [normalize_smiles(x) for x in rxndb_smiles_lst]
uniprot_smiles_lst = list(set(uniprot_smiles_lst))

error_smiles = []
for met in tqdm(uniprot_smiles_lst,total=len(uniprot_smiles_lst)):
    if any(compare_smiles_inchikey(met,smiles) for smiles in rxndb_smiles_lst):
        pass
    else:
        error_smiles.append(met)

print(len(error_smiles))
error_smiles = [x for x in error_smiles if smiles_has_carbon(x)]
print(len(error_smiles))
# Out:
# 100%|██████████| 698/698 [14:14<00:00,  1.22s/it]
# 146
# 134

# %%
for smiles in error_smiles:
    uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].apply(lambda x: smiles in x.replace('>>', '.').split('.'))]
print(uniprot_sce_reaction_df.shape)
# Out:
# (1658, 3)

# %%
uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].str.contains(r'\[Fe\+2\]')]
uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].str.contains(r'\[Zn\+2\]')]
uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].str.contains(r'\[Ca\+2\]')]
uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].str.contains(r'\[Cu\+\]')]
uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].str.contains(r'\[K\+\]')]
uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].str.contains(r'\[Cd\+2\]')]
uniprot_sce_reaction_df = uniprot_sce_reaction_df[~uniprot_sce_reaction_df['rxn_smiles_final'].str.contains(r'\[Cu\+2\]')]
print(uniprot_sce_reaction_df.shape)
# Out:
# (1574, 3)

# %%
# Function executed by each process
def match_reactions(row1, rxndb_total_info_to_model):
    reaction_match = []
    for _, row2 in rxndb_total_info_to_model.iterrows():
        if compare_reaction_smiles_pair(row1['rxn_smiles_final'], row2['rxn_smiles_final']):
            reaction_match.append(row2['NO'])
    return row1['NO'], reaction_match

# Only process the first 50 rows
# uniprot_sce_reaction_df = uniprot_sce_reaction_df.head(50)

num_processes = 30
pool = multiprocessing.Pool(num_processes)

# Use partial to pass rxndb_total_info_to_model to match_reactions
match_reactions_partial = partial(match_reactions, rxndb_total_info_to_model=rxndb_total_info_to_model)

# Parallel processing
result = list(tqdm(pool.imap(match_reactions_partial, [row for _, row in uniprot_sce_reaction_df.iterrows()]), total=len(uniprot_sce_reaction_df)))
# Out:
#   0%|          | 0/1574 [00:00<?, ?it/s]
# 100%|██████████| 1574/1574 [41:39<00:00,  1.59s/it]

# %%
reaction_match_dict = {no: match for no, match in result}

# %%
print(len(reaction_match_dict))

num = 0
for k,v in reaction_match_dict.items():
    if len(v)>0:
        num +=1
num
# Out:
# 1574
# 1252

# %%
num / len(reaction_match_dict)
# Out:
# 0.795425667090216

# %%
reaction_match_dict = {k:v for k,v in reaction_match_dict.items() if len(v)>0}

# %%
uniprot_data = pd.read_csv(uniprot_sce_path,sep='\t')
uniprot_data = uniprot_data[~uniprot_data['Gene Names'].isna()]
uniprot_data.head(3)

entry2geneID = {}
for index,row in uniprot_data.iterrows():
    uniprot_gene_lst = row['Gene Names'].split(' ')
    entry2geneID [row['Entry']] = uniprot_gene_lst


entry2geneID = {k:v for k,v in entry2geneID.items() if len(v)>0}
entry2geneID
# Out:
# {'A0A0B7P3V8': ['TY4B-P', 'YPLCTy4-1', 'POL', 'YPL060C-A'],
#  'D6VTK4': ['STE2', 'YFL026W'],
#  'O13297': ['CET1', 'YPL228W', 'P1433'],
#  'O13329': ['FOB1', 'HRM1', 'YDR110W', 'YD9727.06'],
#  'O13516': ['RPS9A', 'RPS13A', 'YS11A', 'YPL081W'],
#  'O13527': ['TY1B-A', 'YARCTy1-1', 'POL', 'YAR009C'],
#  'O13535': ['TY1B-H', 'YHRCTy1-1', 'POL', 'YHR214C-B'],
#  'O13547': ['CCW14', 'ICWP', 'SSR1', 'YLR390W-A', 'YLR391W-A'],
#  'O13563': ['RPN13', 'DAQ1', 'YLR421C'],
#  'O14467': ['MBF1', 'SUF13', 'YOR298C-A'],
#  'O60200': ['MDM35', 'YKL053C-A'],
#  'O74700': ['TIM9', 'YEL020W-A', 'YEL020BW'],
#  'O94742': ['SEM1', 'DSH1', 'YDR363W-A'],
#  'P00044': ['CYC1', 'YJR048W', 'J1653'],
#  'P00045': ['CYC7', 'CYP3', 'YEL039C'],
#  'P00127': ['QCR6', 'UCR6', 'YFR033C'],
#  'P00128': ['QCR7', 'CRO1', 'UCR7', 'YDR529C', 'D9719.32'],
#  'P00163': ['COB', 'CYTB', 'Q0105'],
#  'P00175': ['CYB2', 'YML054C', 'YM9958.08C'],
#  'P00330': ['ADH1', 'ADC1', 'YOL086C', 'O0947'],
#  'P00331': ['ADH2', 'ADR2', 'YMR303C', 'YM9952.05C'],
#  'P00358': ['TDH2', 'GPD2', 'YJR009C', 'J1433'],
#  'P00359': ['TDH3', 'GPD3', 'YGR192C', 'G7576'],
#  'P00360': ['TDH1', 'GPD1', 'SSS2', 'YJL052W', 'J1154'],
#  'P00401': ['COX1', 'OXI3', 'Q0045'],
#  'P00410': ['COX2', 'OXI1', 'Q0250'],
#  'P00420': ['COX3', 'OXI2', 'Q0275'],
#  'P00424': ['COX5A', 'YNL052W', 'N2474', 'YNL2474W'],
#  'P00431': ['CCP1', 'CCP', 'CPO', 'YKR066C'],
#  'P00445': ['SOD1', 'YJR104C', 'J1968'],
#  'P00546': ['CDC28', 'CDK1', 'HSL5', 'SRM5', 'YBR160W', 'YBR1211'],
#  'P00549': ['CDC19', 'PYK1', 'YAL038W'],
#  'P00560': ['PGK1', 'YCR012W', 'YCR12W'],
#  'P00572': ['CDC8', 'YJR057W', 'J1715'],
#  'P00635': ['PHO5', 'YBR093C', 'YBR0814'],
#  'P00724': ['SUC2', 'YIL162W'],
#  'P00729': ['PRC1', 'YMR297W'],
#  'P00812': ['CAR1', 'YPL111W', 'LPH15W'],
#  'P00815': ['HIS4', 'YCL030C', 'YCL183', 'YCL30C'],
#  'P00817': ['IPP1', 'PPA', 'PPA1', 'YBR011C', 'YBR0202'],
#  'P00830': ['ATP2', 'YJR121W', 'J2041'],
#  'P00854': ['ATP6', 'OLI2', 'OLI4', 'PHO1', 'Q0085'],
#  'P00890': ['CIT1', 'GLU3', 'LYS6', 'YNR001C', 'N2019'],
#  'P00924': ['ENO1', 'ENOA', 'HSP48', 'YGR254W', 'G9160'],
#  'P00925': ['ENO2', 'ENOB', 'YHR174W'],
#  'P00927': ['ILV1', 'YER086W'],
#  'P00937': ['TRP3', 'YKL211C'],
#  'P00942': ['TPI1', 'YDR050C', 'YD9609.05C'],
#  'P00950': ['GPM1', 'GPM', 'YKL152C', 'YKL607'],
#  'P00958': ['MES1', 'YGR264C'],
#  'P01094': ['PAI3', 'YMR174C', 'YM8010.04C'],
#  'P01097': ['INH1', 'YDL181W', 'D1305'],
#  'P01119': ['RAS1', 'YOR101W', 'YOR3205W'],
#  'P01120': ['RAS2', 'ASC1', 'CTN5', 'GLC5', 'YNL098C', 'N2198'],
#  'P01123': ['YPT1', 'YP2', 'YFL038C'],
#  'P02293': ['HTB1', 'H2B1', 'SPT12', 'YDR224C', 'YD9934.09C'],
#  'P02294': ['HTB2', 'H2B2', 'YBL002W', 'YBL0104'],
#  'P02309': ['HHF1', 'YBR009C', 'YBR0122;', 'HHF2', 'YNL030W', 'N2752'],
#  'P02400': ['RPP2B', 'L12EIA', 'RPL45', 'RPLA4', 'YDR382W'],
#  'P02406': ['RPL28', 'CYH2', 'YGL103W'],
#  'P02557': ['TUB2', 'YFL037W'],
#  'P02829': ['HSP82', 'HSP90', 'YPL240C'],
#  'P02992': ['TUF1', 'TUFM', 'YOR187W'],
#  'P02994': ['TEF1', 'YPR080W', 'P9513.7;', 'TEF2', 'YBR118W', 'YBR0913'],
#  'P03069': ['GCN4', 'AAS101', 'AAS3', 'ARG9', 'YEL009C'],
#  'P03870': ['FLP1', 'R0010W'],
#  'P03871': ['REP1', 'R0020C'],
#  'P03873': ['BI2', 'Q0110'],
#  'P03877': ['AI3', 'ENS3', 'I-SCEIII', 'Q0060'],
#  'P03878': ['AI4', 'ENS2', 'I-SCEII', 'Q0065'],
#  'P03879': ['BI4', 'SCBI4', 'Q0120'],
#  'P03962': ['URA3', 'YEL021W'],
#  'P03965': ['CPA2', 'YJR109C', 'J2002'],
#  'P04037': ['COX4', 'YGL187C', 'G1362'],
#  'P04039': ['COX8', 'YLR395C', 'L8084.14'],
#  'P04050': ['RPO21', 'RPB1', 'RPB220', 'SUA8', 'YDL140C', 'D2150'],
#  'P04051': ['RPO31', 'RPC1', 'RPC160', 'YOR116C', 'O3254', 'YOR3254C'],
#  'P04147': ['PAB1', 'YER165W'],
#  'P04385': ['GAL1', 'YBR020W', 'YBR0302'],
#  'P04386': ['GAL4', 'YPL248C'],
#  'P04387': ['GAL80', 'YML051W', 'YM9827.01', 'YM9958.12'],
#  'P04397': ['GAL10', 'YBR019C', 'YBR0301'],
#  'P04456': ['RPL25', 'YOL127W'],
#  'P04710': ['AAC1', 'YMR056C', 'YM9796.09C'],
#  'P04786': ['TOP1', 'MAK1', 'YOL006C'],
#  'P04802': ['DPS1', 'APS', 'APS1', 'YLL018C', 'L1295'],
#  'P04806': ['HXK1', 'HKA', 'YFR053C'],
#  'P04807': ['HXK2', 'HEX1', 'HKB', 'YGL253W', 'NRB486'],
#  'P04817': ['CAN1', 'YEL063C'],
#  'P04819': ['CDC9', 'YDL164C'],
#  'P04821': ['CDC25', 'CTN1', 'YLR310C', 'L2142.6'],
#  'P04840': ['POR1', 'OMP2', 'VDAC1', 'YNL055C', 'N2441', 'YNL2441C'],
#  'P04911': ['HTA1', 'H2A1', 'SPT11', 'YDR225W', 'YD9934.10'],
#  'P04912': ['HTA2', 'H2A2', 'YBL003C', 'YBL0103'],
#  'P05030': ['PMA1', 'YGL008C'],
#  'P05066': ['PHR1', 'YOR386W'],
#  'P05150': ['ARG3', 'YJL088W', 'J0924'],
#  'P05317': ['RPP0', 'L10E', 'RPA0', 'RPL10E', 'RPLA0', 'YLR340W', 'L8300.8'],
#  'P05318': ['RPP1A', 'L12EIIA', 'RPA1', 'RPLA1', 'YDL081C'],
#  'P05319': ['RPP2A', 'L12EIB', 'RPA2', 'RPL44', 'RPLA2', 'YOL039W'],
#  'P05373': ['HEM2', 'YGL040C'],
#  'P05374': ['CHO2', 'PEM1', 'YGR157W', 'G6673'],
#  'P05375': ['OPI3', 'PEM2', 'YJR073C', 'J1824'],
#  'P05453': ['SUP35',
#   'GST1',
#   'PNM2',
#   'SAL3',
#   'SUF12',
#   'SUP2',
#   'YDR172W',
#   'YD9395.05'],
#  'P05626': ['ATP4', 'YPL078C', 'LPF7C'],
#  'P05737': ['RPL7A', 'RPL6A', 'RPL8A', 'YL8A', 'YGL076C'],
#  'P05739': ['RPL6B', 'RPL16B', 'RPL17B', 'YL16B', 'YLR448W', 'L9324.4'],
#  'P05740': ['RPL17A', 'RPL17', 'RPL20A', 'YKL180W'],
#  'P05744': ['RPL33A', 'RPL37A', 'YPL143W', 'LPI4W', 'P2625'],
#  'P05745': ['RPL36A', 'RPL39A', 'YMR194W', 'YM9646.06'],
#  'P05748': ['RPL15A', 'RPL10A', 'RPL13A', 'YL10A', 'YLR029C'],
#  'P05750': ['RPS3', 'SUF14', 'YNL178W', 'N1653'],
#  'P05755': ['RPS9B', 'RPS13B', 'SUP46', 'YBR189W', 'YBR1317'],
#  'P05756': ['RPS13', 'RPS13C', 'YDR064W', 'D4252', 'YD9609.18'],
#  'P05759': ['RPS31', 'RPS37', 'UBI3', 'YLR167W', 'L9470.14'],
#  'P05986': ['TPK3', 'PKA3', 'YKL166C', 'YKL630'],
#  'P06100': ['CDC36', 'DNA19', 'NOT2', 'YDL165W'],
#  'P06101': ['CDC37', 'SMO1', 'YDR168W', 'YD9489.03'],
#  'P06102': ['NOT3', 'YIL038C'],
#  'P06103': ['PRT1', 'CDC63', 'YOR361C'],
#  'P06104': ['RAD6', 'UBC2', 'YGL058W'],
#  'P06105': ['SCP160', 'HX', 'YJL080C', 'J1017'],
#  'P06106': ['MET17', 'MET15', 'MET25', 'YLR303W', 'L8003.1'],
#  'P06115': ['CTT1', 'YGR088W'],
#  'P06168': ['ILV5', 'YLR355C', 'L9638.7'],
#  'P06169': ['PDC1', 'YLR044C', 'L2104'],
#  'P06197': ['PIS1', 'PIS', 'YPR113W', 'P8283.5'],
#  'P06208': ['LEU4', 'YNL104C', 'N2173'],
#  'P06242': ['KIN28', 'YDL108W', 'D2330'],
#  'P06243': ['CDC7', 'OAF2', 'YDL017W', 'D2855'],
#  'P06244': ['TPK1', 'PKA1', 'SRA3', 'YJL164C', 'J0541'],
#  'P06245': ['TPK2', 'PKA2', 'YKR1', 'YPL203W'],
#  'P06367': ['RPS14A', 'CRY1', 'RPL59', 'YCR031C', 'YCR31C'],
#  'P06634': ['DED1', 'SPP81', 'YOR204W'],
#  'P06700': ['SIR2', 'MAR1', 'YDL042C', 'D2714'],
#  'P06701': ['SIR3', 'CMT1', 'MAR2', 'STE8', 'YLR442C', 'L9753.10'],
#  'P06704': ['CDC31', 'DSK1', 'YOR257W'],
#  'P06738': ['GPH1', 'YPR160W', 'P9584.1'],
#  'P06774': ['HAP2', 'YGL237C'],
#  'P06777': ['RAD1', 'YPL022W'],
#  'P06778': ['RAD52', 'YML032C'],
#  'P06779': ['RAD7', 'YJR052W', 'J1665'],
#  'P06780': ['RHO1', 'YPR165W', 'P9325.3'],
#  'P06781': ['RHO2', 'YNL090W', 'N2237'],
#  'P06782': ['SNF1', 'CAT1', 'CCR1', 'GLC2', 'PAS14', 'YDR477W', 'D8035.20'],
#  'P06784': ['STE7', 'YDL159W', 'D1525'],
#  'P06785': ['CDC21', 'CRT9', 'TMP1', 'YOR074C', 'YOR29-25'],
#  'P06786': ['TOP2', 'TOR3', 'YNL088W', 'N2244'],
#  'P06787': ['CMD1', 'YBR109C', 'YBR0904'],
#  'P06838': ['RAD10', 'YML095C'],
#  'P06839': ['RAD3', 'REM1', 'YER171W'],
#  'P06843': ['SPT2', 'SIN1', 'SPM2', 'YER161C'],
#  'P06844': ['SPT3', 'YDR392W', 'D9509.12'],
#  'P07143': ['CYT1', 'CTC1', 'YOR065W', 'YOR29-16'],
#  'P07149': ['FAS1', 'YKL182W'],
#  'P07170': ['ADK1', 'AKY', 'AKY1', 'AKY2', 'YDR226W', 'YD9934.11'],
#  'P07213': ['TOM70', 'MAS70', 'OMP1', 'YNL121C', 'N1905'],
#  'P07244': ['ADE57', 'ADE5,7', 'YGL234W'],
#  'P07245': ['ADE3', 'YGR204W', 'G7733'],
#  'P07246': ['ADH3', 'YMR083W', 'YM9582.08'],
#  'P07248': ['ADR1', 'YDR216W', 'YD8142.16', 'YD8142B.08'],
#  'P07249': ['ARG80', 'ARGR1', 'YMR042W', 'YM9532.07'],
#  'P07250': ['ARG82', 'ARGR3', 'GSL3', 'IPK2', 'YDR173C', 'YD9395.06C'],
#  'P07251': ['ATP1', 'YBL099W', 'YBL0827'],
#  'P07255': ['COX9', 'YDL067C', 'D2520'],
#  'P07256': ['COR1', 'QCR1', 'YBL045C', 'YBL0403'],
#  'P07257': ['QCR2', 'COR2', 'UCR2', 'YPR191W', 'P9677.6'],
#  'P07259': ['URA2', 'YJL130C', 'J0686'],
#  'P07260': ['CDC33', 'TIF45', 'YOL139C'],
#  'P07261': ['GCR1', 'SIT3', 'YPL075W', 'LPF10W'],
#  'P07263': ['HTS1', 'YPR033C', 'YP9367.13C'],
#  'P07264': ['LEU1', 'YGL009C'],
#  'P07267': ['PEP4', 'PHO9', 'PRA1', 'YPL154C', 'P2585'],
#  'P07269': ['PHO2', 'BAS2', 'GRF10', 'YDL106C', 'D2350'],
#  'P07270': ['PHO4', 'YFR034C'],
#  'P07271': ['PIF1', 'TST1', 'YML061C', 'YM9958.01C'],
#  'P07273': ['DST1', 'PPR2', 'YGL043W'],
#  'P07274': ['PFY1', 'PFY', 'PRF1', 'YOR122C', 'O3275', 'YOR3275C'],
#  'P07276': ['RAD2', 'YGR258C'],
#  'P07277': ['ERG12', 'RAR1', 'YMR208W', 'YM8261.02'],
#  'P07278': ['BCY1', 'REG1', 'SRA1', 'YIL033C'],
#  'P07280': ['RPS19A', 'RP55A', 'RPS16AA', 'YOL121C'],
#  'P07281': ['RPS19B', 'RP55B', 'RPS16AB', 'YNL302C', 'N0422'],
#  'P07283': ['SEC53', 'ALG4', 'YFL045C'],
#  'P07286': ['ALG7', 'TUR1', 'YBR243C', 'YBR1628'],
#  'P07342': ['ILV2', 'SMR1', 'YMR108W', 'YM9718.07'],
#  'P07347': ['ARD1', 'YHR013C'],
#  'P07560': ['SEC4', 'SRO6', 'YFL005W'],
#  'P07702': ['LYS2', 'YBR115C', 'YBR0910'],
#  'P07703': ['RPC40', 'RPC5', 'YPR110C', 'P8283.18'],
#  'P07834': ['CDC4', 'YFL009W'],
#  'P07866': ['LTE1', 'EIS4', 'MSI2', 'YAL024C'],
#  'P07884': ['MOD5', 'YOR274W'],
#  'P07991': ['CAR2', 'CARGB', 'YLR438W', 'L9753.2'],
#  'P08004': ['CHS1', 'YNL192W', 'N1404'],
#  'P08018': ['PBS2', 'HOG4', 'SFS4', 'SSK4', 'YJL128C', 'J0699'],
#  'P08067': ['RIP1', 'YEL024W'],
#  'P08153': ['SWI5', 'YDR146C', 'YD8358.03C'],
#  'P08417': ['FUM1', 'YPL262W'],
#  'P08425': ['MSF1', 'YPR047W', 'YP9499.05'],
#  'P08432': ['SPE1', 'ORD1', 'YKL184W'],
#  'P08458': ['SPS1', 'YDR523C', 'D9719.27'],
#  'P08466': ['NUC1', 'YJL208C', 'HRE329', 'J0310'],
#  'P08518': ['RPB2', 'RPB150', 'RPO22', 'YOR151C'],
#  'P08524': ['ERG20', 'BOT3', 'FDS1', 'FPP1', 'YJL167W', 'J0525'],
#  'P08525': ['QCR8', 'YJL166W', 'J0526'],
#  'P08536': ['MET3', 'YJR010W', 'J1436'],
#  'P08539': ['GPA1', 'CDC70', 'DAC1', 'SCG1', 'YHR005C'],
#  'P08566': ['ARO1', 'AROM', 'YDR127W', 'YD9302.02'],
#  'P08638': ['LEU3', 'YLR451W', 'L9324.1'],
#  'P08640': ['FLO11', 'MAL5', 'MUC1', 'S1', 'S2', 'YIR019C'],
#  'P08678': ['CYR1', 'CDC35', 'HSR1', 'SRA4', 'YJL005W', 'J1401'],
#  'P08679': ['CIT2', 'YCR005C', 'YCR043', 'YCR5C'],
#  'P08964': ['MYO1', 'YHR023W'],
#  'P09032': ['GCD1', 'TIF223', 'TRA3', 'YOR260W'],
#  'P09064': ['SUI3', 'TIF212', 'YPL237W'],
#  'P09119': ['CDC6', 'YJL194W', 'J0347'],
#  'P09201': ['FBP1', 'YLR377C', 'L8039.18'],
#  'P09232': ['PRB1', 'YEL060C'],
#  'P09440': ['MIS1', 'YBR084W', 'YBR0751'],
#  'P09547': ['SWI1', 'ADR6', 'GAM3', 'YPL016W', 'LPA1'],
#  'P09620': ['KEX1', 'YGL203C'],
#  'P09624': ['LPD1', 'DHLP1', 'YFL018C'],
#  'P09733': ['TUB1', 'YML085C'],
#  'P09734': ['TUB3', 'YML124C', 'YM7056.02C'],
#  'P09798': ['CDC16', 'YKL022C'],
#  'P09880': ['TRL1', 'RLG1', 'YJL087C', 'J0927'],
#  'P09938': ['RNR2', 'CRT6', 'YJL026W', 'J1271'],
#  'P09950': ['HEM1', 'CYD1', 'YDR232W', 'YD9934.16'],
#  'P09959': ['SWI6', 'YLR182W', 'L9470.8'],
#  'P0C0T4': ['RPS25B', 'RPS31', 'RPS31B', 'YLR333C', 'L8300.10'],
#  'P0C0V8': ['RPS21A', 'RPS25', 'RPS25A', 'RPS26A', 'YKR057W'],
#  'P0C0W9': ['RPL11A', 'RP39A', 'RPL16A', 'YPR102C', 'P8283.14'],
#  'P0C0X0': ['RPS28B', 'RPS33B', 'YLR264W', 'L8479.5'],
#  'P0C2I2': ['TY1B-DR5', 'YDRWTy1-4', 'POL', 'YDR316W-B', 'D9740.1'],
#  'P0C2I3': ['TY1B-DR6', 'YDRWTy1-5', 'POL', 'YDR365W-B', 'D9481.12'],
#  'P0C2I5': ['TY1B-LR2', 'YLRCTy1-2', 'POL', 'YLR157C-B', 'L9632.7'],
#  'P0C2I6': ['TY1B-LR3', 'YLRWTy1-3', 'POL', 'YLR227W-B', 'L8083.11'],
#  'P0C2I7': ['TY1B-LR4', 'YLRWTy1-4', 'POL', 'YLR256W-B/YLR256W-C'],
#  'P0C2I9': ['TY1B-PR1', 'YPRCTy1-2', 'POL', 'YPR137C-B', 'P9659.6c'],
#  'P0C2J0': ['TY1B-PR2', 'YPRWTy1-3', 'POL', 'YPR158W-B', 'P9584.3c'],
#  'P0C2J1': ['TY1B-PR3', 'YPRCTy1-4', 'POL', 'YPR158C-D', 'P9584.3'],
#  'P0C2J3': ['TY2B-LR1', 'YLRWTy2-1', 'POL', 'YLR410W-B', 'L9931.7b'],
#  'P0C2J5': ['TY2B-LR2', 'YLRCTy2-2', 'POL', 'YLR424C-A', 'L9576.6c'],
#  'P0C2J7': ['TY4B-H', 'YHLWTy4-1', 'POL', 'YHL009W-B', 'YHL008W-A'],
#  'P0C5R9': ['YPR170W-B'],
#  'P0CD91': ['AQY1', 'AQY1-2', 'YPR192W', 'P9677.5'],
#  'P0CE41': ['HAP1', 'CYP1', 'YLR256W', 'L9672.1'],
#  'P0CG63': ['UBI4', 'SCD2', 'YLL039C'],
#  'P0CH08': ['RPL40A', 'UBI1', 'YIL148W'],
#  'P0CH09': ['RPL40B', 'UBI2', 'YKR094C'],
#  'P0CS90': ['SSC1', 'ENS1', 'YJR045C', 'J1639'],
#  'P0CT04': ['PBI2', 'YNL015W', 'N2844'],
#  'P0CX27': ['RPL42A', 'RPL41A', 'SCL41A', 'YNL162W', 'N1722'],
#  'P0CX28': ['RPL42B', 'MAK18', 'RPL41B', 'SCL41B', 'YHR141C'],
#  'P0CX29': ['RPS23A', 'RPS28A', 'YGR118W', 'G6178'],
#  'P0CX30': ['RPS23B', 'RPS28B', 'YPR132W', 'P9659.9'],
#  'P0CX31': ['RPS24A', 'RPS24EA', 'YER074W'],
#  'P0CX32': ['RPS24B', 'RPS24EB', 'YIL069C'],
#  'P0CX35': ['RPS4A', 'RPS7B', 'YJR145C', 'J2186'],
#  'P0CX36': ['RPS4B', 'RPS7A', 'YHR203C'],
#  'P0CX37': ['RPS6A', 'RPS101', 'RPS10B', 'YPL090C', 'LPG18C'],
#  'P0CX38': ['RPS6B', 'RPS102', 'RPS10A', 'YBR181C', 'YBR1244'],
#  'P0CX39': ['RPS8A', 'RPS14A', 'YBL072C', 'YBL06.05', 'YBL0613'],
#  'P0CX40': ['RPS8B', 'RPS14B', 'YER102W'],
#  'P0CX41': ['RPL23A', 'RPL17A', 'RPL17AA', 'YBL087C', 'YBL0713'],
#  'P0CX42': ['RPL23B', 'RPL17AB', 'RPL17B', 'YER117W'],
#  'P0CX43': ['RPL1A', 'SSM1', 'SSM1A', 'YPL220W'],
#  'P0CX44': ['RPL1B', 'SSM1B', 'SSM2', 'YGL135W', 'G2834'],
#  'P0CX45': ['RPL2A', 'RPL5B', 'YFR031C-A', 'YFR031BC'],
#  'P0CX46': ['RPL2B', 'RPL5A', 'YIL018W'],
#  'P0CX47': ['RPS11A', 'RPS18A', 'YDR025W', 'YD9813.03'],
#  'P0CX48': ['RPS11B', 'RPS18B', 'YBR048W', 'YBR0501'],
#  'P0CX49': ['RPL18A', 'RP28A', 'YOL120C'],
#  'P0CX50': ['RPL18B', 'RP28B', 'YNL301C', 'N0425'],
#  'P0CX51': ['RPS16A', 'RP61R', 'YMR143W', 'YM9375.12'],
#  'P0CX53': ['RPL12A', 'RPL15B', 'YEL054C'],
#  'P0CX54': ['RPL12B', 'RPL15A', 'YDR418W', 'D9461.7'],
#  'P0CX55': ['RPS18A', 'YDR450W', 'D9461.35'],
#  'P0CX56': ['RPS18B', 'YML026C'],
#  'P0CX63': ['TY2B-F', 'YFLWTy2-1', 'POL', 'YFL002W-A', 'FN01'],
#  'P0CX64': ['TY2B-GR2', 'YGRWTy2-2', 'POL', 'YGR161W-B', 'G7017'],
#  'P0CX77': ['ASP3-2', 'YLR157C', 'L9632.7'],
#  'P0CX78': ['ASP3-3', 'YLR158C', 'L9632.8'],
#  'P0CX79': ['ASP3-4', 'YLR160C', 'L9632.9'],
#  'P0CX80': ['CUP1-1', 'MTH1', 'YHR053C'],
#  'P0CX81': ['CUP1-2', 'MTH1', 'YHR055C'],
#  'P0CX82': ['RPL19A', 'RPL23A', 'YL14A', 'YBR084C-A', 'YBR084BC'],
#  'P0CX83': ['RPL19B', 'RPL23B', 'YL14B', 'YBL027W', 'YBL0424'],
#  'P0CX84': ['RPL35A', 'SOS1', 'YDL191W', 'D1249'],
#  'P0CX85': ['RPL35B', 'SOS2', 'YDL136W', 'D2170'],
#  'P0CY06': ['MATALPHA1', 'ALPHA-1', 'MAT1A', 'MATAL1', 'YCR040W', 'YCR40W'],
#  'P0CY08': ['MATALPHA2', 'ALPHA-2', 'MAT2A', 'MATAL2', 'YCR039C', 'YCR39C'],
#  'P0CZ17': ['ASP3-1', 'YLR155C', 'L9632.6'],
#  'P10080': ['SBP1', 'SSB1', 'SSBR1', 'YHL034C'],
#  'P10081': ['TIF1',
#   'TIF41A',
#   'YKR059W;',
#   'TIF2',
#   'TIF41B',
#   'YJL138C',
#   'J0660'],
#  'P10127': ['ADH4', 'ZRG5', 'YGL256W', 'NRC465'],
#  'P10174': ['COX7', 'YMR256C', 'YM9920.10C'],
#  'P10363': ['PRI1', 'YIR008C', 'YIB8C'],
#  'P10507': ['MAS1', 'MIF1', 'YLR163C', 'L9632.10'],
#  'P10591': ['SSA1', 'YAL005C'],
#  'P10592': ['SSA2', 'YLL024C', 'L0931'],
#  'P10614': ['ERG11', 'CYP51', 'YHR007C'],
#  'P10622': ['RPP1B', 'L12EIIB', 'RPL44P', 'RPLA3', 'YDL130W'],
#  'P10659': ['SAM1', 'ETH10', 'YLR180W', 'L9470.9'],
#  'P10664': ['RPL4A', 'RPL2', 'RPL2A', 'YBR031W', 'YBR0315'],
#  'P10823': ['GPA2', 'SSP101', 'YER020W'],
#  'P10862': ['RAD18', 'YCR066W', 'YCR66W'],
#  'P10863': ['TIR1', 'SRP1', 'YER011W'],
#  'P10870': ['SNF3', 'YDL194W', 'D1234'],
#  'P10961': ['HSF1', 'YGL073W'],
#  'P10962': ['MAK16', 'YAL025C'],
#  'P10964': ['RPA190', 'RPA1', 'RRN1', 'YOR341W', 'O6276'],
#  'P11075': ['SEC7', 'YDR170C', 'YD9395.01C', 'YD9489.05C'],
#  'P11076': ['ARF1', 'YDL192W', 'D1244'],
#  'P11154': ['PYC1', 'PYV', 'YGL062W'],
#  'P11325': ['NAM2', 'MSL1', 'YLR382C', 'L3502.6'],
#  'P11353': ['HEM13', 'YDR044W', 'YD5112.02'],
#  'P11412': ['ZWF1', 'MET19', 'YNL241C', 'N1110'],
#  'P11433': ['CDC24', 'CLS4', 'YAL041W'],
#  'P11484': ['SSB1', 'YG101', 'YDL229W'],
#  'P11491': ['PHO8', 'YDR481C', 'D8035.24'],
#  'P11632': ['NHP6A', 'NHPA', 'YPR052C', 'YP9499.09C'],
#  'P11633': ['NHP6B', 'NHPB', 'YBR089C-A', 'YBR090BC'],
#  'P11655': ['SEC12', 'SED2', 'YNR026C', 'N3244'],
#  'P11709': ['BIK1', 'YCL029C', 'YCL29C'],
#  'P11710': ['FUS1', 'YCL027W', 'YCL27W'],
#  'P11745': ['RNA1', 'YMR235C', 'YM9959.17C'],
#  'P11746': ['MCM1', 'FUN80', 'YMR043W', 'YM9532.08'],
#  'P11747': ['TAF13', 'FUN81', 'TAF19', 'YML098W'],
#  'P11792': ['SCH9', 'KOM1', 'YHR205W'],
#  'P11914': ['MAS2', 'MIF2', 'YHR024C'],
#  'P11938': ['RAP1', 'GRF1', 'TUF1', 'YNL216W', 'N1310'],
#  'P11972': ['SST2', 'YLR452C', 'L9324.9'],
#  'P11978': ['SIR4', 'ASD1', 'STE9', 'UTH2', 'YDR227W', 'YD9934.12'],
#  'P11986': ['INO1', 'YJL153C', 'J0610'],
#  'P12383': ['PDR1',
#   'AMY1',
#   'ANT1',
#   'BOR2',
#   'CYH3',
#   'NRA2',
#   'SMR2',
#   'TIL1',
#   'TPE1',
#   'TPE3',
#   'YGL013C'],
#  'P12385': ['SUP45', 'SAL4', 'SUP1', 'YBR143C', 'YBR1120'],
#  'P12611': ['WHI2', 'YOR043W'],
#  'P12630': ['BAR1', 'SST1', 'YIL015W'],
#  'P12683': ['HMG1', 'YML075C'],
#  'P12684': ['HMG2', 'YLR450W', 'L9324.2'],
#  'P12688': ['YPK1', 'SLI2', 'YKL126W'],
#  'P12689': ['REV1', 'YOR346W', 'O6339'],
#  'P12695': ['LAT1', 'ODP2', 'PDA2', 'YNL071W', 'N2374'],
#  'P12709': ['PGI1', 'YBR196C', 'YBR1406'],
#  'P12753': ['RAD50', 'YNL250W', 'N0872'],
#  'P12754': ['GCD2', 'TIF224', 'YGR083C'],
#  'P12866': ['STE6', 'YKL209C'],
#  'P12868': ['PEP5',
#   'END1',
#   'VAM1',
#   'VPL9',
#   'VPS11',
#   'VPT11',
#   'YMR231W',
#   'YM9959.13'],
#  'P12904': ['SNF4', 'CAT3', 'SCI1', 'YGL115W'],
#  'P12945': ['NAT1', 'AAA1', 'YDL040C', 'D2720'],
#  'P12954': ['SRS2', 'HPR5', 'RADH', 'YJL092W', 'J0913'],
#  'P12962': ['CAF20', 'CAF2', 'CAP20', 'YOR276W', 'O5453W'],
#  'P13099': ['TOP3', 'EDR1', 'YLR234W', 'L8083.3'],
#  'P13134': ['KEX2', 'QDS1', 'YNL238W', 'N1122'],
#  'P13185': ['KIN1', 'YDR122W', 'YD9727.17'],
#  'P13186': ['KIN2', 'YLR096W', 'L8004.3'],
#  'P13259': ['PCT1', 'CCT', 'CCT1', 'YGR202C', 'G7729'],
#  'P13365': ['CLN3', 'DAF1', 'WHI1', 'YAL040C', 'FUN10'],
#  'P13382': ['POL1', 'CDC17', 'YNL102W', 'N2181'],
#  'P13393': ['SPT15', 'BTF1', 'TBP1', 'YER148W'],
#  'P13433': ['RPO41', 'YFL036W'],
#  'P13517': ['CAP2', 'YIL034C'],
#  'P13574': ['STE12', 'YHR084W'],
#  'P13586': ['PMR1', 'BSD1', 'SCC1', 'YGL167C', 'G1666'],
#  'P13587': ['ENA1', 'HOR6', 'PMR2', 'PMR2A', 'YDR040C', 'YD6888.02C'],
#  'P13663': ['HOM2', 'YDR158W', 'YD8358.12'],
#  'P13712': ['MSI1', 'CAC3', 'YBR195C', 'YBR1405'],
#  'P13856': ['RSR1', 'BUD1', 'YGR152C', 'G6658'],
#  'P14020': ['DPM1', 'SED3', 'YPR183W', 'P9705.3'],
#  'P14064': ['HAP4', 'YKL109W', 'YKL465'],
#  'P14065': ['GCY1', 'GCY', 'YOR120W', 'O31567', 'YOR3269W'],
#  'P14120': ['RPL30', 'RPL32', 'YGL030W'],
#  'P14126': ['RPL3', 'MAK8', 'TCM1', 'YOR063W', 'YOR29-14'],
#  'P14164': ['ABF1', 'BAF1', 'OBF1', 'REB2', 'SBF1', 'YKL112W', 'YKL505'],
#  'P14180': ['CHS2', 'YBR038W', 'YBR0407'],
#  'P14242': ['PMS1', 'YNL082W', 'N2317'],
#  'P14284': ['REV3', 'PSO1', 'YPL167C', 'P2535'],
#  'P14291': ['RED1', 'YLR263W', 'L8479.6'],
#  'P14306': ['TFS1', 'DKA1', 'NSP1', 'YLR178C', 'L9470.19'],
#  'P14540': ['FBA1', 'YKL060C', 'YKL320'],
#  'P14680': ['YAK1', 'YJL141C', 'J0652'],
#  'P14681': ['KSS1', 'YGR040W'],
#  'P14682': ['CDC34', 'DNA6', 'UBC3', 'YDR054C', 'D4211', 'YD9609.08C'],
#  'P14693': ['SAM35', 'OMP85', 'TOB38', 'TOM38', 'YHR083W'],
#  'P14724': ['CDC26', 'HIT3', 'SCD26', 'YFR036W'],
#  'P14736': ['RAD4', 'YER162C'],
#  'P14737': ['RAD9', 'YDR217C', 'YD9934.02C'],
#  'P14741': ['GCN3', 'AAS2', 'TIF221', 'YKR026C'],
#  'P14742': ['GFA1', 'YKL104C', 'YKL457'],
#  'P14743': ['NMT1', 'CDC72', 'YLR195C', 'L8167.14'],
#  'P14747': ['CMP2', 'CNA2', 'YML057W', 'YM9958.05'],
#  'P14772': ['BPT1', 'YLL015W', 'L1313'],
#  'P14832': ['CPR1', 'CPH1', 'CYP1', 'SCC1', 'YDR155C', 'YD8358.10C'],
#  'P14904': ['APE1', 'API', 'LAP4', 'YSC1', 'YKL103C', 'YKL455'],
#  'P14906': ['SEC63', 'NPL1', 'PTL1', 'YOR254C'],
#  'P14907': ['NSP1', 'YJL041W', 'J1207'],
#  'P14908': ['MTF1', 'YMR228W', 'YM9959.10'],
#  'P14922': ['CYC8', 'CRT8', 'SSN6', 'YBR112C', 'YBR0908'],
#  'P15019': ['TAL1', 'YLR354C', 'L9638.6'],
#  'P15108': ['HSC82', 'YMR186W', 'YM8010.16'],
#  'P15180': ['KRS1', 'GCD5', 'YDR037W', 'YD9673.09'],
#  'P15202': ['CTA1', 'YDR256C', 'YD9320A.06C'],
#  'P15274': ['AMD1', 'AMD', 'YML035C'],
#  'P15303': ['SEC23', 'YPR181C', 'P9705.14'],
#  'P15315': ['CUP2', 'ACE1', 'YGL166W', 'G1810'],
#  'P15367': ['SEC11', 'YIR022W'],
#  'P15424': ['MSS116', 'YDR194C', 'YD9346.05C'],
#  'P15436': ['POL3', 'CDC2', 'TEX1', 'YDL102W', 'D2366'],
#  'P15442': ['GCN2', 'AAS1', 'YDR283C'],
#  'P15454': ['GUK1', 'YDR454C', 'D9461.39'],
#  'P15496': ['IDI1', 'BOT2', 'YPL117C', 'LPH10C'],
#  'P15565': ['TRM1', 'YDR120C', 'YD9727.15C'],
#  'P15624': ['FRS1', 'YLR060W', 'L2165'],
#  'P15625': ['FRS2', 'YFL022C'],
#  'P15646': ['NOP1', 'LOT3', 'YDL014W', 'D2870'],
#  'P15700': ['URA6', 'SOC8', 'YKL024C'],
#  'P15703': ['BGL2', 'SCW9', 'YGR282C'],
#  'P15705': ['STI1', 'YOR027W', 'OR26.17'],
#  'P15731': ['UBC4', 'YBR082C', 'YBR0745'],
#  'P15732': ['UBC5', 'YDR059C', 'D4234', 'YD9609.13C'],
#  'P15790': ['CKA1', 'YIL035C'],
#  'P15801': ['MIP1', 'YOR330C'],
#  'P15807': ['MET8', 'YBR213W', 'YBR1461'],
#  'P15873': ['POL30', 'YBR088C', 'YBR0811'],
#  'P15891': ['ABP1', 'YCR088W', 'YCR88W'],
#  'P15938': ['PRP16', 'YKR086W', 'YKR406'],
#  'P15992': ['HSP26', 'YBR072W', 'YBR0714'],
#  'P16140': ['VMA2', 'VAT2', 'YBR127C', 'YBR1002'],
#  'P16370': ['RPB3', 'YIL021W'],
#  'P16387': ['PDA1', 'YER178W'],
#  'P16451': ['PDX1', 'YGR193C', 'G7579'],
#  'P16467': ['PDC5', 'YLR134W', 'L3133', 'L9606.7'],
#  'P16474': ['KAR2', 'GRP78', 'SSD1', 'YJL034W', 'J1248'],
#  'P16521': ['YEF3', 'EFC1', 'TEF3', 'YEF3A', 'YLR249W', 'L9672.5'],
#  'P16522': ['CDC23', 'YHR166C'],
#  'P16550': ['APA1', 'DTP', 'YCL050C', 'YCL50C'],
#  'P16603': ['NCP1', 'CPR1', 'NCPR1', 'PRD1', 'YHR042W'],
#  'P16622': ['HEM15', 'YOR176W'],
#  'P16649': ['TUP1',
#   'AAR1',
#   'AER2',
#   'AMM1',
#   'CYC9',
#   'FLK1',
#   'SFL2',
#   'UMR7',
#   'YCR084C',
#   'YCR84C'],
#  'P16658': ['SEN2', 'YLR105C', 'L8004.12'],
#  'P16661': ['ALG1', 'YBR110W', 'YBR0906'],
#  'P16664': ['RGP1', 'YDR137W', 'YD9302.13'],
#  'P16861': ['PFK1', 'YGR240C', 'G8599'],
#  'P16862': ['PFK2', 'YMR205C', 'YM8325.06C'],
#  'P16892': ['FUS3', 'DAC2', 'YBL016W', 'YBL03.21', 'YBL0303'],
#  'P17064': ['FCY2', 'YER056C'],
#  'P17065': ['SEC2', 'YNL272C', 'N0641'],
#  'P17076': ['RPL8A', 'MAK7', 'RPL4A', 'YHL033C'],
#  'P17106': ['CBF1', 'CEP1', 'CP1', 'CPF1', 'YJR060W', 'J1730'],
#  'P17119': ['KAR3', 'YPR141C', 'P9659.16'],
#  'P17157': ['PHO85', 'SSG3', 'YPL031C', 'P7102.18A'],
#  'P17214': ['EST1', 'YLR233C', 'L8083.15'],
#  'P17255': ['VMA1', 'CLS8', 'TFP1', 'YDL185W', 'D1286'],
#  'P17260': ['KRE1', 'YNL322C', 'N0336'],
#  'P17442': ['PHO81', 'YGR233C', 'G8567'],
#  'P17505': ['MDH1', 'YKL085W'],
#  'P17555': ['SRV2', 'CAP1', 'YNL138W', 'N1210', 'N1838'],
#  'P17629': ['HPR1', 'YDR138W', 'YD9302.14'],
#  'P17649': ['UGA1', 'YGR019W'],
#  'P17695': ['GRX2', 'TTR', 'TTR1', 'YDR513W', 'D9719.17'],
#  'P17709': ['GLK1', 'HOR3', 'YCL040W', 'YCL312', 'YCL40W'],
#  'P17883': ['SKI3', 'YPR189W', 'P9677.7'],
#  'P17890': ['RPC31', 'ACP2', 'RPC8', 'YNL151C', 'N1769'],
#  'P17891': ['CLC1', 'YGR167W'],
#  'P17898': ['CPT1', 'YNL130C', 'N1218', 'N1867'],
#  'P17967': ['PDI1', 'MFP1', 'TRG1', 'YCL043C', 'YCL313', 'YCL43C'],
#  'P18238': ['AAC3', 'YBR085W', 'YBR0753'],
#  'P18239': ['PET9', 'AAC2', 'YBL030C', 'YBL0421'],
#  'P18409': ['MDM10', 'YAL010C', 'FUN37'],
#  'P18410': ['SPO7', 'YAL009W'],
#  'P18412': ['TEC1', 'ROC1', 'YBR083W', 'YBR0750'],
#  'P18480': ['SNF5', 'SWI10', 'TYE4', 'YBR289W', 'YBR2036'],
#  'P18494': ['GLN3', 'YER040W'],
#  'P18562': ['FUR1', 'YHR128W'],
#  'P18759': ['SEC18', 'YBR080C', 'YBR0736'],
#  'P18851': ['STE4', 'YOR212W', 'YOR50-2'],
#  'P18852': ['STE18', 'YJR086W', 'J1866'],
#  'P18888': ['SNF6', 'YHL025W'],
#  'P18898': ['CDC43', 'CAL1', 'YGL155W', 'G1864'],
#  'P18899': ['DDR48', 'FSP', 'YMR173W', 'YM8010.03'],
#  'P18961': ['YPK2', 'YKR2', 'YMR104C', 'YM9718.03C'],
#  'P19073': ['CDC42', 'SRO2', 'YLR229C', 'L8083.13'],
#  'P19097': ['FAS2', 'YPL231W', 'P1409'],
#  'P19145': ['GAP1', 'YKR039W'],
#  'P19146': ['ARF2', 'YDL137W', 'D2165'],
#  'P19211': ['ANB1', 'HYP1', 'TIF51B', 'YJR047C', 'J1651'],
#  'P19262': ['KGD2', 'YDR148C', 'YD8358.05C'],
#  'P19263': ['RGR1', 'MED14', 'YLR071C'],
#  'P19358': ['SAM2', 'ETH2', 'YDR502C', 'D9719.8'],
#  'P19414': ['ACO1', 'GLU1', 'YLR304C', 'L8003.22'],
#  'P19454': ['CKA2', 'YOR061W', 'YOR29-12'],
#  'P19524': ['MYO2', 'CDC66', 'YOR326W', 'O6167'],
#  'P19541': ['RDS2', 'YPL133C', 'LPI12C'],
#  'P19657': ['PMA2', 'YPL036W'],
#  'P19658': ['EXO70', 'YJL085W', 'J0932'],
#  'P19659': ['GAL11', 'ABE1', 'MED15', 'RAR3', 'SDS4', 'SPT13', 'YOL051W'],
#  'P19807': ['HNM1', 'CTR', 'CTR1', 'YGL077C'],
#  'P19812': ['UBR1', 'PTR1', 'YGR184C', 'G7168'],
#  'P19880': ['YAP1', 'PAR1', 'PDR4', 'SNQ3', 'YML007W', 'YM9571.12'],
#  'P19882': ['HSP60', 'MIF4', 'YLR259C', 'L8479.10'],
#  'P19955': ['YMR31', 'KGD4', 'YFR049W'],
#  'P20050': ['HOP1', 'YIL072W'],
#  'P20052': ['PHO80', 'AGS3', 'TUP7', 'VAC5', 'YOL001W', 'O2505', 'UNB293'],
#  'P20081': ['FPR1', 'FKB1', 'RBP1', 'YNL135C', 'N1213', 'N1845'],
#  'P20095': ['PRP2', 'RNA2', 'YNR011C', 'N2048'],
#  'P20107': ['ZRC1', 'YMR243C', 'YM9408.05C'],
#  'P20133': ['BET2', 'YPR176C', 'P9705.12'],
#  'P20424': ['SRP54', 'SRH1', 'YPR088C', 'P9513.14'],
#  'P20433': ['RPB4', 'YJL140W', 'J0654'],
#  'P20434': ['RPB5', 'RPA7', 'RPC9', 'YBR154C', 'YBR1204'],
#  'P20435': ['RPO26', 'RPB6', 'YPR187W', 'P9677.8'],
#  'P20436': ['RPB8', 'YOR224C', 'YOR50-14'],
#  'P20437': ['CLN1', 'YMR199W', 'YM9646.13'],
#  'P20438': ['CLN2', 'YPL256C'],
#  'P20447': ['DBP3', 'YGL078C'],
#  'P20448': ['HCA4', 'DBP4', 'ECM24', 'YJL033W', 'J1250'],
#  'P20449': ['DBP5', 'RAT8', 'YOR046C'],
#  'P20457': ['PRI2', 'YKL045W', 'YKL258'],
#  'P20459': ['SUI2', 'TIF211', 'YJR007W', 'J1429'],
#  'P20485': ['CKI1', 'CKI', 'YLR133W', 'L3130', 'L9606.8'],
#  'P20486': ['CKS1', 'YBR135W', 'YBR1011'],
#  'P20604': ['SIT4', 'PPH1', 'YDL047W', 'D2693'],
#  'P20606': ['SAR1', 'YPL218W'],
#  'P20676': ['NUP1', 'YOR098C', 'YOR3182C'],
#  'P20795': ['VPS33', 'SLP1', 'VAM5', 'YLR396C', 'L8084.15'],
#  'P20840': ['SAG1', 'AGAL1', 'YJR004C', 'J1418'],
#  'P20967': ['KGD1', 'OGD1', 'YIL125W'],
#  'P21147': ['OLE1', 'YGL055W'],
#  'P21182': ['SPE2', 'YOL052C', 'O1275'],
#  'P21190': ['IME1', 'YJR094C', 'J1916'],
#  'P21192': ['ACE2', 'YLR131C', 'L3123', 'L9606.10'],
#  'P21242': ['PRE10', 'PRC1', 'PRS1', 'YOR362C', 'O6650'],
#  'P21243': ['SCL1', 'PRC2', 'PRS2', 'YGL011C'],
#  'P21268': ['FAR1', 'YJL157C', 'J0565'],
#  'P21269': ['CCA1', 'TNT1', 'YER168C'],
#  'P21306': ['ATP15', 'YPL271W', 'P0345'],
#  'P21372': ['PRP5', 'RNA5', 'YBR237W', 'YBR1603'],
#  'P21373': ['UTR1', 'YJR049C', 'J1655'],
#  'P21374': ['ISY1', 'NTC30', 'UTR3', 'YJR050W', 'J1657'],
#  'P21375': ['OSM1', 'YJR051W', 'J1659'],
#  'P21524': ['RNR1', 'CRT7', 'RIR1', 'SDS12', 'YER070W'],
#  'P21538': ['REB1', 'GRF2', 'YBR049C', 'YBR0502'],
#  'P21560': ['CBP3', 'YPL215W', 'P1775'],
#  'P21576': ['VPS1', 'LAM1', 'SPO15', 'YKR001C'],
#  'P21651': ['REC107', 'MER2', 'YJR021C', 'J1462'],
#  'P21672': ['RNR3', 'DIN1', 'YIL066C'],
#  'P21691': ['SIR1', 'YKR101W'],
#  'P21734': ['UBC1', 'YDR177W', 'YD9395.10'],
#  'P21801': ['SDH2', 'SDH', 'SDHB', 'YLL041C'],
#  'P21825': ['SEC62', 'YPL094C', 'LPG14C'],
#  'P21826': ['DAL7', 'MLS2', 'YIR031C'],
#  'P21827': ['SRM1', 'MTR1', 'PRP20', 'YGL097W'],
#  'P21951': ['POL2', 'DUN2', 'YNL262W', 'N0825'],
#  'P21954': ['IDP1', 'YDL066W'],
#  'P21957': ['OPI1', 'YHL020C'],
#  'P21965': ['MCK1', 'YPK1', 'YNL307C', 'N0392'],
#  'P22007': ['RAM1', 'DPR1', 'SCG2', 'STE16', 'YDL090C', 'D2412'],
#  'P22082': ['SNF2', 'GAM1', 'RIC1', 'SWI2', 'TYE3', 'YOR290C'],
#  'P22108': ['APA2', 'YDR530C', 'D9719.33'],
#  'P22133': ['MDH2', 'YOL126C'],
#  'P22134': ['MAG1', 'MAG', 'YER142C'],
#  'P22137': ['CHC1', 'YGL206C'],
#  'P22138': ['RPA135', 'RPA2', 'RRN2', 'SRP3', 'YPR010C', 'YP9531.03C'],
#  'P22139': ['RPB10', 'YOR210W'],
#  'P22140': ['EPT1', 'YHR123W'],
#  'P22141': ['PRE1', 'YER012W'],
#  'P22146': ['GAS1', 'GGP1', 'YMR307W', 'YM9952.09'],
#  'P22147': ['XRN1',
#   'DST2',
#   'KEM1',
#   'RAR5',
#   'SEP1',
#   'SKI1',
#   'YGL173C',
#   'G1645'],
#  'P22149': ['AFT1', 'RCS1', 'YGL071W'],
#  'P22203': ['VMA4', 'VAT5', 'YOR332W', 'O6241'],
#  'P22204': ['DBF2', 'YGR092W'],
#  'P22211': ['NPR1', 'YNL183C', 'N1631'],
#  'P22213': ['SLY1', 'YDR189W', 'YD9346.01', 'YD9395.22'],
#  'P22214': ['SEC22', 'SLY2', 'TSL26', 'YLR268W', 'L8479.3'],
#  'P22216': ['RAD53', 'MEC2', 'SAD1', 'SPK1', 'YPL153C', 'P2588'],
#  'P22217': ['TRX1', 'TRX2', 'YLR043C'],
#  'P22219': ['VPS15', 'GRD8', 'VAC4', 'VPL19', 'YBR097W', 'YBR0825'],
#  'P22224': ['SEC15', 'YGL233W'],
#  'P22276': ['RET1', 'RPC128', 'RPC2', 'YOR207C'],
#  'P22289': ['QCR9', 'UCR9', 'YGR183C'],
#  'P22336': ['RFA1', 'BUF2', 'RPA1', 'YAR007C', 'FUN3'],
#  'P22515': ['UBA1', 'YKL210W'],
#  'P22516': ['CHL1', 'CTF1', 'YPL008W', 'YP8132.05'],
#  'P22517': ['CMK2', 'YOL016C'],
#  'P22543': ['VPS34', 'END12', 'PEP15', 'VPL7', 'VPT29', 'YLR240W', 'L9672.10'],
#  'P22579': ['SIN3',
#   'CPE1',
#   'GAM2',
#   'RPD1',
#   'SDI1',
#   'SDS16',
#   'UME4',
#   'YOL004W'],
#  'P22696': ['ESS1', 'PIN1', 'PTF1', 'YJR017C', 'J1452'],
#  'P22768': ['ARG1', 'YOL058W', 'O1228'],
#  'P22803': ['TRX2', 'TRX1', 'YGR209C', 'G7746'],
#  'P22804': ['BET1', 'SLY12', 'YIL004C', 'YIA4C'],
#  'P22855': ['AMS1', 'YGL156W', 'G1861'],
#  'P22936': ['APN1', 'YKL114C', 'YKL513'],
#  'P22943': ['HSP12', 'GLP1', 'HOR5', 'YFL014W'],
#  'P23179': ['SPO11', 'YHL022C'],
#  'P23201': ['SPA2', 'PEA1', 'YLL021W', 'L1209'],
#  'P23202': ['URE2', 'YNL229C', 'N1165'],
#  'P23254': ['TKL1', 'YPR074C', 'YP9499.29C'],
#  'P23255': ['TAF2', 'TAF150', 'TSM1', 'YCR042C', 'YCR42C', 'YCR724'],
#  'P23287': ['CNA1', 'CMP1', 'YLR433C', 'L9753.6'],
#  'P23291': ['YCK1', 'CKI2', 'YHR135C'],
#  'P23292': ['YCK2', 'CKI1', 'YNL154C', 'N1755'],
#  'P23293': ['SGV1', 'BUR1', 'YPR161C', 'P9584.8'],
#  'P23301': ['HYP2', 'TIF51A', 'YEL034W', 'SYGP-ORF21'],
#  'P23337': ['GSY1', 'YFR015C'],
#  'P23394': ['PRP28', 'YDR243C', 'YD8419.10C'],
#  'P23503': ['NAR1', 'YNL240C', 'N1114'],
#  'P23542': ['AAT2', 'ASP5', 'YLR027C', 'L1746'],
#  'P23561': ['STE11', 'YLR362W', 'L8039.10'],
#  'P23585': ['HXT2', 'YMR011W', 'YM8270.15'],
#  'P23594': ['PPH21', 'YDL134C', 'D2180'],
#  'P23595': ['PPH22', 'SIS4', 'YDL188C', 'D1271'],
#  'P23615': ['SPT6', 'CRE2', 'SSN20', 'YGR116W', 'G6169'],
#  'P23638': ['PRE9', 'PRS5', 'YGR135W'],
#  'P23639': ['PRE8', 'PRS4', 'YML092C'],
#  'P23642': ['VAN1', 'VRG7', 'YML115C', 'YM8339.04C'],
#  'P23643': ['VPS3', 'VPT17', 'YDR495C', 'D9719.1'],
#  'P23644': ['TOM40', 'ISP42', 'MOM38', 'YMR203W', 'YM8325.04'],
#  'P23724': ['PRE7', 'PRS3', 'PTS1', 'YBL041W', 'YBL0407'],
#  'P23776': ['EXG1', 'BGL1', 'SCW6', 'YLR300W', 'L8003.3'],
#  'P23900': ['FPS1', 'YLL043W'],
#  'P23968': ['VMA16', 'PPA1', 'YHR026W'],
#  'P24004': ['PEX1', 'PAS1', 'YKL197C'],
#  'P24276': ['SSD1', 'CLA1', 'RLD1', 'SRK1', 'YDR293C', 'D9819.4'],
#  'P24279': ['MCM3', 'YEL032W', 'SYGP-ORF23'],
#  'P24280': ['SEC14', 'PIT1', 'YMR079W', 'YM9582.04'],
#  'P24309': ['DBR1', 'PRP26', 'YKL149C', 'YKL604'],
#  'P24384': ['PRP22', 'YER013W'],
#  'P24482': ['DPB2', 'YPR175W', 'P9705.7'],
#  'P24583': ['PKC1', 'HPO2', 'STT1', 'YBL105C', 'YBL0807'],
#  'P24783': ['DBP2', 'YNL112W', 'N1945'],
#  'P24784': ['DBP1', 'YPL119C', 'LPH8C'],
#  'P24813': ['CAD1', 'YAP2', 'YDR423C', 'D9461.12'],
#  'P24814': ['GRR1', 'CAT80', 'COT2', 'YJR090C', 'J1885'],
#  'P24867': ['PCL1', 'HCS26', 'YNL289W', 'N0536'],
#  'P24868': ['CLB1', 'SCB1', 'YGR108W', 'G5967'],
#  'P24869': ['CLB2', 'YPR119W', 'P9642.6'],
#  'P24870': ['CLB3', 'YDL155W', 'D1539'],
#  'P25042': ['ROX1', 'YPR065W', 'YP9499.20'],
#  'P25043': ['PUP1', 'YOR157C'],
#  'P25044': ['PTP1', 'YDL230W'],
#  'P25045': ['LCB1', 'END8', 'TSC2', 'YMR296C'],
#  'P25046': ['ROX3', 'MED19', 'NUT3', 'SSN7', 'YBL093C', 'YBL0837'],
#  'P25087': ['ERG6', 'ISE1', 'LIS1', 'SED6', 'YML008C', 'YM9571.10C'],
#  'P25293': ['NAP1', 'YKR048C'],
#  'P25294': ['SIS1', 'YNL007C', 'N2879'],
#  'P25296': ['CNB1', 'YCN2', 'YCNB', 'YKL190W'],
#  'P25297': ['PHO84', 'YML123C', 'YM7056.03C'],
#  'P25298': ['RNA14', 'YMR061W', 'YM9796.14'],
#  'P25299': ['RNA15', 'YGL044C'],
#  'P25300': ['BUD5', 'YCR038C', 'YCR38C', 'YCR526'],
#  'P25301': ['RAD57', 'YDR004W', 'YD8119.10'],
#  'P25302': ['SWI4', 'ART1', 'YER111C'],
#  'P25303': ['SCJ1', 'YMR214W', 'YM8261.08'],
#  'P25333': ['SAT4', 'HAL4', 'YCR008W', 'YCR046', 'YCR101', 'YCR8W'],
#  'P25336': ['MSH3', 'YCR092C', 'YCR1152', 'YCR92C'],
#  'P25340': ['ERG4', 'YGL012W', 'YGL022'],
#  'P25341': ['KIN82', 'FPK2', 'YCR091W', 'YCR1153', 'YCR91W'],
#  'P25342': ['CDC10', 'YCR002C', 'YCR022', 'YCR2C'],
#  'P25343': ['RVS161', 'END6', 'SPE161', 'YCR009C', 'YCR9C'],
#  'P25344': ['STE50', 'YCL032W', 'YCL32W'],
#  'P25346': ['GIT1', 'YCR098C', 'YCR137', 'YCR98C'],
#  'P25353': ['NPP1', 'YCR026C', 'YCR246', 'YCR26C'],
#  'P25357': ['SNT1', 'YCR033W', 'YCR33W', 'YCR592'],
#  'P25358': ['ELO2', 'FEN1', 'GNS1', 'VBM2', 'YCR034W', 'YCR34W', 'YCR521'],
#  'P25359': ['RRP43', 'YCR035C', 'YCR35C', 'YCR522'],
#  'P25364': ['HCM1', 'YCR065W', 'YCR65W', 'YCR902'],
#  'P25368': ['RRP7', 'YCL031C', 'YCL184', 'YCL31C'],
#  'P25369': ['LSB5', 'YCL034W', 'YCL186', 'YCL34W'],
#  'P25373': ['GRX1', 'YCL035C', 'YCL35C'],
#  'P25374': ['NFS1', 'SPL1', 'YCL017C'],
#  'P25375': ['PRD1', 'YCL057W', 'YCL57W'],
#  'P25376': ['AGP1', 'YCL025C', 'YCL25C'],
#  'P25377': ['ADH7', 'YCR105W'],
#  'P25378': ['RHB1', 'RSG1', 'YCR027C', 'YCR27C'],
#  'P25382': ['RSA4', 'YCR072C', 'YCR72C'],
#  'P25384': ['TY2B-C', 'YCLWTy2-1', 'POL', 'YCL019W', 'YCL19W'],
#  'P25385': ['BOS1', 'YLR078C', 'L9449.9'],
#  'P25386': ['USO1', 'INT1', 'YDL058W'],
#  'P25389': ['KCC4', 'YCL024W', 'YCL24W'],
#  'P25390': ['SSK22', 'YCR073C', 'YCR73C'],
#  'P25441': ['RPC53', 'RPC4', 'YDL150W', 'D1557'],
#  'P25443': ['RPS2', 'RPS4', 'SUP38', 'SUP44', 'YGL123W', 'G2893'],
#  'P25451': ['PUP3', 'YER094C'],
#  'P25453': ['DMC1', 'ISC2', 'YER179W'],
#  'P25454': ['RAD51', 'YER095W'],
#  'P25491': ['YDJ1', 'MAS5', 'YNL064C', 'N2418', 'YNL2418C'],
#  'P25502': ['PUT3', 'YKL015W'],
#  'P25515': ['VMA3', 'CLS7', 'CUP5', 'GEF2', 'YEL027W'],
#  'P25554': ['SGF29', 'YCL010C', 'YCL10C'],
#  'P25555': ['GBP2', 'RLF6', 'YCL011C', 'YCL11C'],
#  'P25567': ['SRO9', 'YCL037C', 'YCL37C'],
#  'P25573': ['MGR1', 'YCL044C', 'YCL314', 'YCL44C'],
#  'P25574': ['EMC1', 'YCL045C', 'YCL315', 'YCL45C'],
#  'P25576': ['POF1', 'YCL047C', 'YCL47C'],
#  'P25580': ['PBN1', 'YCL052C', 'YCL52C'],
#  'P25582': ['SPB1', 'YCL054W', 'YCL431', 'YCL54W'],
#  'P25583': ['KAR4', 'YCL055W', 'YCL432', 'YCL55W'],
#  'P25586': ['KRR1', 'YCL059C', 'YCL59C'],
#  'P25588': ['MRC1', 'YCL061C', 'YCL61C/YCL60C'],
#  'P25591': ['VAC17', 'YCL063W', 'YCL63W/YCL62W'],
#  'P25604': ['STP22', 'VPS23', 'YCL008C', 'YCL8C'],
#  'P25605': ['ILV6', 'YCL009C', 'YCL9C'],
#  'P25613': ['ADY2', 'ATO1', 'YCR010C', 'YCR10C'],
#  'P25615': ['POL4', 'POLX', 'YCR014C', 'YCR14C'],
#  'P25618': ['CWH43', 'YCR017C', 'YCR17C'],
#  'P25623': ['SYP1', 'YCR030C', 'YCR30C/YCR29C'],
#  'P25627': ['BUD23', 'YCR047C', 'YCR47C'],
#  'P25635': ['PWP2', 'UTP1', 'YCR057C', 'YCR55C/YCR57C/YCR58C'],
#  'P25637': ['YIH1', 'YCR059C', 'YCR59C'],
#  'P25641': ['ATG15', 'AUT5', 'CVT17', 'YCR068W', 'YCR68W'],
#  'P25644': ['PAT1', 'MRT1', 'YCR077C', 'YCR77C'],
#  'P25646': ['PTC6', 'AUP1', 'PPP2', 'YCR079W', 'YCR79C', 'YCR79W'],
#  'P25648': ['SRB8',
#   'GIG1',
#   'MED12',
#   'NUT6',
#   'SSN5',
#   'YCR081W',
#   'YCR81W/YCR80W'],
#  'P25651': ['CSM1', 'SPO86', 'YCR086W', 'YCR86W'],
#  'P25653': ['FIG2', 'YCR089W', 'YCR1102', 'YCR89W'],
#  'P25655': ['CDC39', 'NOT1', 'ROS1', 'YCR093W', 'YCR1151', 'YCR93W'],
#  'P25656': ['CDC50', 'SWA4', 'YCR094W', 'YCR94W'],
#  'P25693': ['PCL2', 'CLN4', 'YDL127W', 'D2223'],
#  'P25694': ['CDC48', 'YDL126C'],
#  'P25719': ['CPR3', 'CYP3', 'YML078W'],
#  'P25808': ['SPB4', 'YFL002C'],
#  'P25846': ['MSH1', 'YHR120W'],
#  'P25847': ['MSH2', 'YOL090W', 'O0935'],
#  'P26188': ['MGT1', 'YDL200C', 'D1204'],
#  'P26263': ['PDC6', 'YGR087C'],
#  'P26309': ['CDC20', 'YGL116W'],
#  'P26321': ['RPL5', 'RPL1', 'RPL1A', 'YPL131W', 'LPI14W'],
#  'P26364': ['ADK2', 'AKY3', 'PAK3', 'YER170W'],
#  'P26370': ['UGA3', 'YDL170W'],
#  'P26448': ['BUB2', 'YMR055C', 'YM9796.08C'],
#  'P26449': ['BUB3', 'YOR026W', 'OR26.16'],
#  'P26570': ['PPZ1', 'YML016C', 'YM9571.02C'],
#  'P26754': ['RFA2', 'BUF1', 'YNL312W', 'N0368'],
#  'P26755': ['RFA3', 'YJL173C', 'J0506'],
#  'P26783': ['RPS5', 'RPS2', 'YJR123W', 'J2045'],
#  'P26784': ['RPL16A', 'RPL13', 'RPL21A', 'YIL133C'],
#  'P26785': ['RPL16B', 'RP23', 'RPL21B', 'YNL069C', 'N2377'],
#  'P26786': ['RPS7A', 'RPS30', 'YOR096W', 'YOR3177W'],
#  'P26793': ['RAD27', 'FEN1', 'RTH1', 'YKL113C', 'YKL510'],
#  'P27351': ['APL1', 'YAP80', 'YJR005W', 'J1422'],
#  'P27466': ['CMK1', 'YFR014C'],
#  'P27472': ['GSY2', 'YLR258W', 'L8479.8'],
#  'P27476': ['NSR1', 'YGR159C', 'G7001'],
#  'P27514': ['PHO91', 'YNR013C', 'N2052'],
#  'P27515': ['URK1', 'YNR012W', 'N2050'],
#  'P27614': ['CPS1', 'CPS', 'YJL172W', 'J0510'],
#  'P27616': ['ADE1', 'YAR015W'],
#  'P27636': ['CDC15', 'LYT1', 'YAR019C'],
#  'P27637': ['BUD14', 'YAR014C', 'FUN2'],
#  'P27654': ['TIP1', 'YBR067C', 'YBR0622'],
#  'P27680': ['COQ3', 'YOL096C', 'HRF316'],
#  'P27692': ['SPT5', 'YML010W', 'YM9571.08'],
#  'P27697': ['COQ8', 'ABC1', 'YGL119W'],
#  'P27705': ['MIG1', 'CAT4', 'SSN1', 'YGL035C'],
#  'P27796': ['POT1', 'FOX3', 'POX3', 'YIL160C'],
#  'P27801': ['PEP3', 'VAM8', 'VPS18', 'VPT18', 'YLR148W', 'L9634.2'],
#  'P27809': ['KRE2', 'MNT1', 'YDR483W', 'D8035.26'],
#  'P27810': ['KTR1', 'YOR099W', 'YOR3189W'],
#  'P27825': ['CNE1', 'YAL058W', 'FUN48'],
#  'P27882': ['ERV1', 'YGR029W'],
#  'P27895': ['CIN8', 'KSL2', 'YEL061C'],
#  'P27999': ['RPB9', 'YGL070C'],
#  'P28000': ['RPC19', 'YNL113W', 'N1937'],
#  'P28004': ['PRP45', 'FUN20', 'YAL032C'],
#  'P28005': ['POP5', 'YAL033W', 'FUN53'],
#  'P28007': ['GAR1', 'YHR089C'],
#  'P28240': ['ICL1', 'YER065C'],
#  'P28241': ['IDH2', 'YOR136W', 'O3326', 'YOR3326W'],
#  'P28263': ['UBC8', 'GID3', 'YEL012W'],
#  'P28272': ['URA1', 'YKL216W'],
#  'P28274': ['URA7', 'YBL039C', 'YBL0410'],
#  'P28319': ['CWP1', 'YKL096W', 'YJU1', 'YKL443'],
#  'P28320': ['YJU2', 'CWC16', 'YKL095W', 'YKL442'],
#  'P28321': ['YJU3', 'YKL094W', 'YKL441'],
#  'P28495': ['CAP1', 'YKL007W', 'YKL155'],
#  'P28496': ['LAC1', 'DGT1', 'YKL008C', 'YKL156'],
#  'P28519': ['RAD14', 'YMR201C', 'YM8325.02C'],
#  'P28627': ['IMP1', 'PET2858', 'YMR150C', 'YM9375.20C'],
#  'P28707': ['SBA1', 'YKL117W', 'YKL518'],
#  'P28708': ['PRR1', 'YKL116C', 'YKL516'],
#  'P28737': ['MSP1', 'YTA4', 'YGR028W'],
#  'P28742': ['KIP1', 'CIN9', 'YBL063W', 'YBL0504', 'YBL0521'],
#  'P28743': ['KIP2', 'YPL155C', 'P2581'],
#  'P28777': ['ARO2', 'YGL148W'],
#  'P28791': ['SEC20', 'YDR498C', 'D9719.4'],
#  'P28795': ['PEX3', 'PAS3', 'YDR329C', 'D9798.15'],
#  'P28817': ['EHD3', 'MRP5', 'YDR036C', 'YD9673.08C'],
#  'P28834': ['IDH1', 'YNL037C', 'N2690'],
#  'P29029': ['CTS1', 'SCW2', 'YLR286C', 'L8003.13'],
#  'P29055': ['SUA7', 'YPR086W', 'P9513.4'],
#  'P29056': ['BRF1', 'PCF4', 'TDS4', 'YGR246C'],
#  'P29295': ['HRR25', 'YPL204W'],
#  'P29311': ['BMH1', 'YER177W'],
#  'P29340': ['PEX4', 'PAS2', 'UBC10', 'YGR133W'],
#  'P29366': ['BEM1', 'SRO1', 'YBR200W', 'YBR1412'],
#  'P29453': ['RPL8B', 'KRB1', 'RPL4B', 'YLL045C'],
#  'P29461': ['PTP2', 'YOR208W'],
#  'P29465': ['CHS3', 'CAL1', 'CSD2', 'DIT101', 'KIT2', 'YBR023C', 'YBR0305'],
#  'P29468': ['PAP1', 'YKR002W'],
#  'P29469': ['MCM2', 'YBL023C', 'YBL0438'],
#  'P29496': ['MCM5', 'CDC46', 'YLR274W', 'L9328.1'],
#  'P29509': ['TRR1', 'YDR353W', 'D9476.5'],
#  'P29539': ['RIF1', 'YBR275C', 'YBR1743'],
#  'P29547': ['CAM1', 'TEF3', 'YPL048W'],
#  'P29703': ['RAM2', 'YKL019W'],
#  'P29704': ['ERG9', 'YHR190W'],
#  'P29952': ['PMI40', 'YER003C'],
#  'P30283': ['CLB5', 'YPR120C', 'P9642.8'],
#  'P30605': ['ITR1', 'YDR497C', 'D9719.3'],
#  'P30619': ['SEC1', 'YDR164C', 'YD8358.18C'],
#  'P30620': ['PSO2', 'SNM1', 'YMR137C', 'YM9375.06C'],
#  'P30624': ['FAA1', 'YOR317W', 'O6136'],
#  'P30656': ['PRE2', 'DOA3', 'PRG1', 'YPR103W', 'P8283.10'],
#  'P30657': ['PRE4', 'YFR050C'],
#  'P30665': ['MCM4', 'CDC54', 'HCD21', 'YPR019W', 'YP9531.13'],
#  'P30771': ['NAM7', 'IFS2', 'MOF4', 'UPF1', 'YMR080C', 'YM9582.05C'],
#  'P30775': ['MRF1', 'YGL143C'],
#  'P30822': ['CRM1', 'KAP124', 'XPO1', 'YGR218W', 'G8514'],
#  'P30902': ['ATP7', 'YKL016C'],
#  'P30952': ['MLS1', 'YNL117W', 'N1921'],
#  'P31109': ['SNC1', 'YAL030W'],
#  'P31111': ['ZIP1', 'YDR285W', 'D9819.9'],
#  'P31115': ['DEG1', 'HRM3', 'PUS3', 'YFL001W'],
#  'P31116': ['HOM6', 'YJR139C', 'J2132'],
#  'P31244': ['RAD16', 'YBR114W', 'YBR0909'],
#  'P31373': ['CYS3', 'CYI1', 'STR1', 'YAL012W', 'FUN35'],
#  'P31374': ['PSK1', 'YAL017W', 'FUN31', 'YAL002'],
#  'P31376': ['SWC3', 'FUN36', 'SWC1', 'YAL011W'],
#  'P31377': ['SYN8', 'UIP2', 'YAL014C', 'FUN34'],
#  'P31378': ['NTG1', 'OGG2', 'SCR1', 'YAL015C', 'FUN33'],
#  'P31380': ['FUN30', 'YAL019W', 'YAL001'],
#  'P31382': ['PMT2', 'FUN25', 'YAL023C'],
#  'P31383': ['TPD3', 'YAL016W', 'FUN32'],
#  'P31384': ['CCR4', 'YAL021C', 'FUN27'],
#  'P31385': ['DEP1', 'FUN54', 'YAL013W'],
#  'P31412': ['VMA5', 'VAT3', 'VATC', 'YKL080W', 'YKL410'],
#  'P31539': ['HSP104', 'YLL026W', 'L0948'],
#  'P31688': ['TPS2', 'PFK3', 'YDR074W', 'YD8554.07'],
#  'P31755': ['OCH1', 'NGD29', 'YGL038C'],
#  'P32074': ['SEC21', 'YNL287W', 'N0543'],
#  'P32178': ['ARO7', 'OSM2', 'YPR060C', 'YP9499.15C'],
#  'P32179': ['MET22', 'HAL2', 'YOL064C'],
#  'P32259': ['SIN4',
#   'BEL2',
#   'GAL22',
#   'MED16',
#   'RYE1',
#   'SDI3',
#   'SSF5',
#   'SSN4',
#   'TSF3',
#   'YNL236W',
#   'N1135'],
#  'P32266': ['MGM1', 'MDM17', 'YOR211C', 'YOR50-1'],
#  'P32288': ['GLN1', 'YPR035W', 'YP3085.01', 'YP9367.15'],
#  'P32316': ['ACH1', 'YBL015W', 'YBL03.18', 'YBL0304'],
#  'P32318': ['THI4', 'ESP35', 'MOL1', 'YGR144W', 'G6620'],
#  'P32319': ['PEP1', 'VPS10', 'VPT1', 'YBL017C', 'YBL03.22', 'YBL0302'],
#  'P32323': ['AGA1', 'YNR044W', 'N3431'],
#  'P32324': ['EFT1', 'YOR133W', 'O3317', 'YOR3317W;', 'EFT2', 'YDR385W'],
#  'P32325': ['DBF4', 'DNA52', 'YDR052C', 'D4205', 'YD9609.07C'],
#  'P32327': ['PYC2', 'YBR218C', 'YBR1507'],
#  'P32328': ['DBF20', 'YPR111W'],
#  'P32329': ['YPS1', 'YAP3', 'YLR120C', 'L2961', 'L9233.9'],
#  'P32332': ['OAC1', 'PMT', 'PMT1', 'YKL120W', 'YKL522'],
#  'P32333': ['MOT1', 'YPL082C', 'LPF4C'],
#  'P32334': ['MSB2', 'YGR014W'],
#  'P32335': ['MSS51', 'YLR203C', 'L8167.17'],
#  'P32336': ['NUD1', 'YOR373W'],
#  'P32337': ['PSE1', 'KAP121', 'YMR308C', 'YM9952.10C'],
#  'P32338': ['RME1', 'YGR044C'],
#  'P32340': ['NDI1', 'YML120C', 'YM7056.06C'],
#  'P32342': ['SRP21', 'YKL122C', 'YKL527'],
#  'P32345': ['PPH3', 'YDR075W', 'D4421'],
#  'P32347': ['HEM12', 'HEM6', 'POP3', 'YDR047W', 'YD9609.03'],
#  'P32349': ['RPC82', 'RPC3', 'YPR190C', 'P9677.11'],
#  'P32350': ['KNS1', 'YLL019C'],
#  'P32353': ['ERG3', 'PSO6', 'SYR1', 'YLR056W', 'L2150'],
#  'P32354': ['MCM10', 'DNA43', 'YIL150C'],
#  'P32356': ['NTH1', 'NTH', 'YDR001C', 'YD8119.07C'],
#  'P32357': ['AAR2', 'YBL074C', 'YBL06.06', 'YBL0611'],
#  'P32361': ['IRE1', 'ERN1', 'YHR079C'],
#  'P32363': ['SPT14', 'CWH6', 'GPI3', 'YPL175W', 'P2269'],
#  'P32364': ['SMY1', 'YKL079W', 'YKL409'],
#  'P32366': ['VMA6', 'YLR447C', 'L9324.8'],
#  'P32367': ['TFC1', 'YBR123C', 'YBR0919'],
#  'P32368': ['SAC1', 'RSD1', 'YKL212W'],
#  'P32377': ['MVD1', 'ERG19', 'MPD', 'YNR043W', 'N3427'],
#  'P32378': ['COQ2', 'YNR041C', 'N3419'],
#  'P32379': ['PUP2', 'DOA5', 'YGR253C', 'G9155'],
#  'P32380': ['SPC110', 'NUF1', 'XCM1', 'YDR356W', 'D9476.3'],
#  'P32381': ['ARP2', 'ACT2', 'YDL029W', 'D2778'],
#  'P32383': ['PLC1', 'YPL268W'],
#  'P32386': ['YBT1', 'BAT1', 'YLL048C'],
#  'P32389': ['MET4', 'YNL103W', 'N2177'],
#  'P32419': ['MDH3', 'YDL078C', 'D2468'],
#  'P32432': ['SFP1', 'YLR403W', 'L8084.4'],
#  'P32447': ['ASF1', 'CIA1', 'YJL115W', 'J0755'],
#  'P32454': ['APE2', 'LAP1', 'YKL157W', 'YKL158W', 'YKL611', 'YKL612'],
#  'P32457': ['CDC3', 'YLR314C', 'L8543.7'],
#  'P32458': ['CDC11', 'PSL9', 'YJR076C', 'J1833'],
#  'P32461': ['DPH2', 'YKL191W'],
#  'P32462': ['ERG24', 'YNL280C', 'N0593'],
#  'P32465': ['HXT1', 'HOR4', 'YHR094C'],
#  'P32466': ['HXT3', 'YDR345C', 'D9651.14'],
#  'P32467': ['HXT4', 'LGT1', 'RAG1', 'YHR092C'],
#  'P32468': ['CDC12', 'CLA10', 'PSL7', 'YHR107C'],
#  'P32471': ['EFB1', 'TEF5', 'YAL003W'],
#  'P32472': ['FPR2', 'FKB2', 'YDR519W', 'D9719.24'],
#  'P32473': ['PDB1', 'YBR221C', 'YBR1511'],
#  'P32474': ['EUG1', 'YDR518W', 'D9719.23'],
#  'P32476': ['ERG1', 'YGR175C'],
#  'P32478': ['HSP150', 'CCW7', 'ORE1', 'PIR2', 'YJL159W', 'J0558'],
#  'P32479': ['HIR1', 'YBL008W', 'YBL0318'],
#  'P32480': ['HIR2', 'YOR038C', 'OR26.31'],
#  'P32481': ['GCD11', 'SUI4', 'TIF213', 'YER025W'],
#  'P32485': ['HOG1', 'SSK3', 'YLR113W', 'L2931', 'L9354.2'],
#  'P32486': ['KRE6', 'CWH48', 'YPR159W'],
#  'P32490': ['MKK1', 'SSP32', 'YOR231W', 'O5095'],
#  'P32491': ['MKK2', 'SSP33', 'YPL140C', 'LPI6C'],
#  'P32492': ['MYO4', 'SHE1', 'YAL029C', 'FUN22'],
#  'P32494': ['NGG1', 'ADA3', 'SWI7', 'YDR176W', 'YD9395.09'],
#  'P32495': ['NHP2', 'YDL208W', 'D1045'],
#  'P32497': ['NIP1', 'YMR309C', 'YM9924.01C', 'YM9952.11C'],
#  'P32499': ['NUP2', 'YLR335W', 'L8300.9'],
#  'P32500': ['NDC1', 'YML031W'],
#  'P32501': ['GCD6', 'TIF225', 'YDR211W', 'YD8142.12', 'YD8142B.03'],
#  'P32502': ['GCD7', 'TIF222', 'YLR291C', 'L8003.17'],
#  'P32504': ['CBF2', 'CBF3A', 'CEP2', 'CTF14', 'NDC10', 'YGR140W'],
#  'P32505': ['NAB2', 'YGL122C'],
#  'P32521': ['PAN1', 'DIM2', 'MDP3', 'MIP3', 'YIR006C', 'YIB6C'],
#  'P32523': ['PRP19', 'PSO4', 'YLL036C'],
#  'P32526': ['KAR9', 'YPL269W'],
#  'P32527': ['ZUO1', 'YGR285C'],
#  'P32528': ['DUR1,2', 'YBR208C', 'YBR1448'],
#  'P32529': ['RPA12', 'RRN4', 'YJR063W', 'J1747'],
#  'P32558': ['SPT16', 'CDC68', 'SSF1', 'YGL207W'],
#  'P32561': ['RPD3', 'MOF6', 'REC3', 'SDI2', 'SDS6', 'YNL330C', 'N0305'],
#  'P32562': ['CDC5', 'MSD2', 'PKX2', 'YMR001C', 'YM8270.03C'],
#  'P32563': ['VPH1', 'YOR270C'],
#  'P32565': ['RPN2', 'SEN3', 'YIL075C'],
#  'P32566': ['SMI1', 'KNR4', 'KTR4', 'YGR229C', 'G8553'],
#  'P32567': ['PAH1', 'PAP1', 'SMP2', 'YMR165C', 'YM8520.14C'],
#  'P32569': ['SRB4', 'MED17', 'YER022W'],
#  'P32570': ['SRB6', 'MED22', 'YBR253W', 'YBR1721'],
#  'P32571': ['DOA4',
#   'DOS1',
#   'MUT4',
#   'NPI2',
#   'SSV7',
#   'UBP4',
#   'YDR069C',
#   'D4270',
#   'YD8554.02C',
#   'YD9609.23C'],
#  'P32573': ['SPS19', 'SPX19', 'YNL202W', 'N1362'],
#  'P32578': ['SIP1', 'YDR422C', 'D9461.11'],
#  'P32579': ['SUA5', 'YGL169W', 'G1660'],
#  'P32580': ['SUV3', 'YPL029W', 'LPB2W'],
#  'P32581': ['IME2', 'SME1', 'YJL106W', 'J0817'],
#  'P32582': ['CYS4', 'STR4', 'YGR155W', 'G6667'],
#  'P32584': ['STE14', 'YDR410C', 'D9461.1'],
#  'P32585': ['SRB5', 'MED18', 'YGR104C'],
#  'P32588': ['PUB1', 'RNP1', 'YNL016W', 'N2842'],
#  'P32589': ['SSE1', 'MSI3', 'YPL106C', 'LPG3C'],
#  'P32591': ['SWI3', 'TYE2', 'YJL176C', 'J0495'],
#  'P32597': ['STH1', 'NPS1', 'YIL126W'],
#  'P32598': ['GLC7', 'CID1', 'DIS2', 'YER133W'],
#  'P32599': ['SAC6', 'YDR129C', 'YD9302.04C'],
#  'P32600': ['TOR2', 'DRR2', 'TSC14', 'YKL203C'],
#  'P32602': ['SEC17', 'YBL050W', 'YBL0505', 'YBL0517'],
#  'P32603': ['SPR1', 'SSG1', 'YOR190W'],
#  'P32604': ['FBP26', 'YJL155C', 'J0575'],
#  'P32605': ['MUD1', 'YBR119W', 'YBR0915'],
#  'P32607': ['RTG1', 'YOL067C'],
#  'P32609': ['PEP7', 'VAC1', 'VPL21', 'VPS19', 'VPT19', 'YDR323C'],
#  'P32610': ['VMA8', 'YEL051W', 'SYGP-ORF11'],
#  'P32614': ['FRD1', 'FRDS', 'FRDS1', 'YEL047C', 'SYGP-ORF35'],
#  'P32621': ['GDA1', 'YEL042W', 'SYGP-ORF16'],
#  'P32622': ['YEF1', 'YEL041W', 'SYGP-ORF17'],
#  'P32623': ['UTR2', 'CRH2', 'YEL040W', 'SYGP-ORF18'],
#  'P32626': ['UTR4', 'YEL038W', 'SYGP-ORF20'],
#  'P32628': ['RAD23', 'YEL037C', 'SYGP-ORF29'],
#  'P32629': ['ANP1', 'GEM3', 'YEL036C', 'SYGP-ORF28'],
#  'P32639': ['BRR2', 'RSS1', 'SNU246', 'YER172C', 'SYGP-ORF66'],
#  'P32641': ['RAD24', 'YER173W', 'SYGP-ORF60'],
#  'P32642': ['GRX4', 'YER174C', 'SYGP-ORF64'],
#  'P32643': ['TMT1', 'TAM1', 'YER175C', 'SYGP-ORF63'],
#  'P32644': ['ECM32', 'HEL1', 'MTT1', 'YER176W', 'SYGP-ORF61'],
#  'P32657': ['CHD1', 'YER164W', 'SYGP-ORF4'],
#  'P32660': ['DNF1', 'YER166W', 'SYGP-ORF7'],
#  'P32768': ['FLO1', 'FLO2', 'FLO4', 'FLO8', 'YAR050W'],
#  'P32769': ['HBS1', 'YKR084C', 'YKR404'],
#  'P32771': ['SFA1', 'SFA', 'YDL168W'],
#  'P32773': ['TOA1', 'YOR194C'],
#  'P32774': ['TOA2', 'YKL058W'],
#  'P32776': ['TFB1', 'YDR311W', 'D9740.3'],
#  'P32783': ['ABD1', 'YBR236C', 'YBR1602'],
#  'P32784': ['SCT1', 'GAT2', 'YBL011W', 'YBL0309', 'YBL0315'],
#  'P32789': ['ALK2', 'YBL009W', 'YBL0317'],
#  'P32790': ['SLA1', 'YBL007C', 'YBL0321'],
#  'P32791': ['FRE1', 'YLR214W', 'L8167.2'],
#  'P32793': ['YSC84', 'LSB4', 'YHR016C'],
#  'P32794': ['AFG2', 'DRG1', 'YLR397C', 'L8084.16'],
#  'P32795': ['YME1', 'OSD1', 'YTA11', 'YPR024W', 'YP9367.04'],
#  'P32796': ['CAT2', 'CAT', 'YCAT', 'YML042W', 'YM8054.01'],
#  'P32797': ['CDC13', 'YDL220C'],
#  'P32798': ['COT1', 'YOR316C', 'O6131'],
#  'P32799': ['COX13', 'YGL191W', 'G1341'],
#  'P32800': ['PEX2', 'CRT1', 'PAS5', 'YJL210W', 'HRA271', 'J0240'],
#  'P32801': ['ELM1', 'YKL048C', 'YKL261'],
#  'P32802': ['EMP70', 'TMN1', 'YLR083C', 'L2385', 'L9449.11'],
#  'P32803': ['EMP24', 'YGL200C', 'G1271'],
#  'P32807': ['YKU70', 'HDF1', 'NES24', 'YMR284W', 'YM8021.10'],
#  'P32828': ['SLX5', 'HEX3', 'YDL013W', 'D2875'],
#  'P32829': ['MRE11', 'YMR224C', 'YM9959.06C'],
#  'P32830': ['TIM12', 'MRS5', 'YBR091C', 'YBR0812'],
#  ...}

# %%
def rxn2geneID(rxnlst,rxndb_total_info_to_model):
    genelst = []
    for i in rxnlst:
        tmp = rxndb_total_info_to_model[rxndb_total_info_to_model['NO']==i]['GPR'].to_list()[0]
        tmp = tmp.replace(')','').replace('(','').split(' or ')
        genelst += tmp
    return list(set(genelst))

# %%
success_gpr_num = 0
for k,v in tqdm(reaction_match_dict.items(),total=len(reaction_match_dict)):
    if len(v)>0:
        uniprot_gene_list = entry2geneID[k.split('_')[0]]
        rxndb_gene_list = rxn2geneID(v,rxndb_total_info_to_model)
        if len(set(rxndb_gene_list).intersection(uniprot_gene_list)) > 0:
            success_gpr_num += 1

success_gpr_num
# Out:
# 100%|██████████| 1252/1252 [00:01<00:00, 1017.31it/s]
# 1061

# %%
1061/1252
# Out:
# 0.847444089456869

# %%
uniprot_reaction_ratio = 0.795
uniprot_gpr_ratio = 0.847

# %%
# Set general parameters
plt.figure(figsize=(1.5, 2), dpi=400)
plt.rcParams.update({'font.size': 8})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Set axis styles
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Data
labels = ['Reaction ', ' Enzyme']
data2 = [uniprot_reaction_ratio, uniprot_gpr_ratio]

# Create bar chart
width = 0.4

plt.bar([1, 2], data2, color='#f781bf', width=width, edgecolor='black', linewidth=0.5)

# Set axis parameters
plt.tick_params(axis='y', direction='in', width=0.5, which='both', length=1)
plt.tick_params(axis='x', direction='in', width=0.5, which='both', length=1)
plt.xlim(0, 3)
plt.ylim(0, 1)

# Set x-axis labels
plt.xticks([1, 2], labels)

# Set labels and title
plt.ylabel('UniProt recovery rate by our workflow', fontsize=6)

plt.tight_layout()

# Save the figure
plt.savefig(figs5_path, dpi=400)

# Show the figure
plt.show()
